# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from variants import Detect

# %% [markdown]
# # Load TF corpus

# %%
A = use("suriano/letters:clone", checkout="clone", backend="gitlab.huc.knaw.nl")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/ner</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.5.4</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/app" title="suriano/letters app">suriano/letters/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/about.md" title="provenance of suriano - letters/tf">suriano - letters 0.7.1</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="suriano - letters feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>11</td>
#     <td>157692.09</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>725</td>
#     <td>2392.57</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>725</td>
#     <td>2202.10</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>725</td>
#     <td>2202.10</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4148</td>
#     <td>736.35</td>
#     <td><i>176</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>725</td>
#     <td>190.47</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8764</td>
#     <td>157.79</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>725</td>
#     <td>118.49</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>725</td>
#     <td>56.90</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>46971</td>
#     <td>36.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>725</td>
#     <td>118.49</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>725</td>
#     <td>71.98</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>48688</td>
#     <td>32.42</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>725</td>
#     <td>31.55</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>725</td>
#     <td>31.55</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>725</td>
#     <td>25.35</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13281</td>
#     <td>16.80</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>1</td>
#     <td>15.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>725</td>
#     <td>14.08</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>159403</td>
#     <td>9.90</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>725</td>
#     <td>8.73</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>725</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1450</td>
#     <td>7.82</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>15456</td>
#     <td>7.81</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2175</td>
#     <td>6.52</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>725</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>725</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2082</td>
#     <td>4.31</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>725</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>725</td>
#     <td>2.70</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2175</td>
#     <td>2.69</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>725</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2175</td>
#     <td>1.32</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>metamark</th>
#     <td>3015</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8764</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11822</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1734613</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>suriano - letters/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <span> number of a chunk within a document</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/corresp.tf">corresp</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute corresp</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/date.tf">date</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Date when the letter was sent</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/editorNotes.tf">editorNotes</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Editorial notes and additional information about the letter and its attachments</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/empty.tf">empty</a>
# </div>
# <div class="fmono">int</div>
#
# <span> whether a slot has been inserted in an empty element</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/extraspace.tf">extraspace</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute extraspace</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/facs.tf">facs</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute facs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/file.tf">file</a>
# </
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/thumb</span>
# Found 8766 images<br>

# %% [markdown]
# # Set up corpus for analiticcl

# %%
D = Detect(A)
# Out:
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>
# SHEET data: computing from scratch ...
# --------------
# Reading sheets
# --------------
# Sheet with 845 rows and 18 columns
# r264: newline in trigger string: monsignor di Epernon; duca di epernone; monsignor di Epernone\n
# r566: newline in trigger string: Vanilt sottosecretario; Vanilt sottosecretario già del signor principio Mauritio\n
# 1 row with a duplicate name:
#   r521: () Henry II, Duke of Lorraine also in r21
# 9 rows without triggers:
# 	e.g.: 127, 214, 232, 233, 234, 425, 453, 464, 488
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
# Ambi: 'Gugliemo di Nassau':
#   William, Count of Nassau-Siegen: 8
#   William Louis, Count of Nassau-Dillenburg: 47
# Ambi: 'colonello Broch':
#   Sir William Brog: 45
#   William Brog: 821
# Ambi: 'conte di Candal':
#   Henri de Nogaret de la Valette: 524
#   Henry de Nogaret de La Valette: 781
# Ambi: 'conte di Solms':
#   Count Frederick of Solms-Rödelheim: 358
#   Johann Albrecht I, Count of Solms-Braunfels: 485
# Ambi: 're di Polonia':
#   Ladislaus IV of Poland: 211
#   Sigismund III Vasa: 498
# Ambi: 'signor Marioni':
#   Pier Antonio Mariano: 482
#   Pier Antonio Marioni: 602
# Ambiguous triggers: 6 x
# --
# 02
# --
#
# --
# 03
# --
#
# --
# 04
# --
#
# --
# 05
# --
#
# --
# 06
# --
#
# --
# 07
# --
#
# -------------
# 08.001-08.089
# -------------
#
# ---------
# 08.090-08
# ---------
#
# ---------
# 09-09.021
# ---------
#
# ---------
# 09.022-09
# ---------
#
# ---------
# 10-10.017
# ---------
#
# -------------
# 10.018-10.020
# -------------
#
# ---------
# 10.021-10
# ---------
#
# ------------
# 11-11.026.22
# ------------
#
# ---------
# 11.026.23
# ---------
#
# ------------
# 11.026.24-11
# ------------
#
# ------------
# 12-12.037.27
# ------------
#
# ---------
# 12.037.28
# ---------
#
# ----------------
# 12.037.29-12.041
# ----------------
#
# -------------
# 12.042-12.044
# -------------
#
# ---------
# 12.045-12
# ---------
#   0.00s Looking up occurrences of many candidates ...
#   2.19s done
# done
# Overview of names by length:
#   10 tokens:   2 names e.g.:
#       cavalier inglese , et il fratello del vescovo di Londra
#       signor d ’ Aspri fratello dell ’ ambasciator dei Stati
#   9 tokens:   2 names e.g.:
#       conte d ' Henin , chiamato duca di Bornenvil
#       Proveditor general dell ’ arm [ i ] Priuli
#   8 tokens:  15 names e.g.:
#       Alessandro , Giacomo et Pietr ’ Antonio Guadagni
#       ambasciator del signor Granduca nella corte di Praga
#       ambasciator di Francia residente appresso li serenissimi arciduchi
#       doi altri suoi parenti cognato , et cugino
#       doi altri un maschio , et una femina
#   7 tokens:  17 names e.g.:
#       [ duc ] a d ' Angauleme
#       ambasciator di Spagna residente appresso il Christianissimo
#       Ambasciator straordinario che venne ultimamente di Spagna
#       Ambasciatore , che dal re di Bohemia
#       capitan scocese fratello di quel capitano Seiton
#   6 tokens:  40 names e.g.:
#       al luogotenente di monsignor di Sciatiglione
#       ambasciator Giust ( inia ) no
#       ambasciator Gritti alla corte di Spagna
#       baron di Kessel governator di Husdem
#       baron di Pieterson signor di Meroda
#   5 tokens:  77 names e.g.:
#       A . v . Matenesse
#       accompagnata la sorella di lui
#       Adriano Pieterson Looske da Encusen
#       agente d ’ Inghilterra Trombol
#       agente del re di Marocco
#   4 tokens: 180 names e.g.:
#       agente di quel Principe
#       almirante d ’ Arragona
#       ambasciator Contarini in Francia
#       ambasciator Contarini in Inghilterra
#       ambasciatore Contarini in Inghilterra
#   3 tokens: 467 names e.g.:
#       ' l Chercoven
#       2 da Principessa
#       Adriano Vander Dussen
#       agente del Kerckoven
#       agente di Fiorenza
#   2 tokens: 514 names e.g.:
#       abbate Moronato
#       Abraham Pesini
#       Adam Schivelbergh
#       Adrian Pavoni
#       Adrian Ploos
#   1 tokens: 233 names e.g.:
#       Alagamba
#       Alagambe
#       Alagambre
#       Amstenraedt
#       Amsterraedt

# %% [markdown]
# # Prepare

# %%
D.prepare()
# Out:
# Alphabet written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/alphabet.tsv
# Text written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/text.txt - 8558678 characters
#   0.00s Collecting the triggers for the lexicon
#   0.00s 1398 triggers collected
#   347 x conte di Mansfelt
#   336 x Pasini
#   236 x Bernvel
#   236 x Spinola
#   212 x principe d’Oranges
#   211 x re di Spagna
#   210 x Carleton
#   208 x principe Mauritio
#   194 x duca di Savoia
#   180 x serenissimi arciduchi
#   ...
#     1 x Vimenti
#     1 x visconte di Duncaster
#     1 x visconte di Gantes fratello del principe di Pinoe
#     1 x Wandernoot
#     1 x Wassenhovven
#     1 x Wasson[ hoven]
#     1 x Weesterbeeck
#     1 x Weimar il maggiore
#     1 x zelandese nominato Cornelio
#     1 x Zeno
#     1398 lexicon length
# Lexicon written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/lexicon.tsv
# Set up analiticcl
# Computing anagram values for all items in the lexicon...
#  - Found 1398 instances
# Adding all instances to the index...
#  - Found 1393 anagrams
# Creating sorted secondary index...
# Sorting secondary index...
#  - Found 3 anagrams of length 3
#  - Found 13 anagrams of length 4
#  - Found 22 anagrams of length 5
#  - Found 35 anagrams of length 6
#  - Found 47 anagrams of length 7
#  - Found 40 anagrams of length 8
#  - Found 41 anagrams of length 9
#  - Found 26 anagrams of length 10
#  - Found 43 anagrams of length 11
#  - Found 58 anagrams of length 12
#  - Found 65 anagrams of length 13
#  - Found 79 anagrams of length 14
#  - Found 101 anagrams of length 15
#  - Found 91 anagrams of length 16
#  - Found 93 anagrams of length 17
#  - Found 95 anagrams of length 18
#  - Found 78 anagrams of length 19
#  - Found 69 anagrams of length 20
#  - Found 61 anagrams of length 21
#  - Found 49 anagrams of length 22
#  - Found 31 anagrams of length 23
#  - Found 35 anagrams of length 24
#  - Found 22 anagrams of length 25
#  - Found 20 anagrams of length 26
#  - Found 27 anagrams of length 27
#  - Found 17 anagrams of length 28
#  - Found 15 anagrams of length 29
#  - Found 15 anagrams of length 30
#  - Found 5 anagrams of length 31
#  - Found 14 anagrams of length 32
#  - Found 7 anagrams of length 33
#  - Found 5 anagrams of length 34
#  - Found 10 anagrams of length 35
#  - Found 12 anagrams of length 36
#  - Found 4 anagrams of length 37
#  - Found 6 anagrams of length 38
#  - Found 3 anagrams of length 39
#  - Found 3 anagrams of length 40
#  - Found 5 anagrams of length 41
#  - Found 2 anagrams of length 42
#  - Found 2 anagrams of length 43
#  - Found 6 anagrams of length 44
#  - Found 5 anagrams of length 45
#  - Found 1 anagrams of length 46
#  - Found 2 anagrams of length 47
#  - Found 2 anagrams of length 49
#  - Found 1 anagrams of length 50
#  - Found 1 anagrams of length 52
#  - Found 1 anagrams of length 53
#  - Found 2 anagrams of length 54
#  - Found 1 anagrams of length 57
#  - Found 1 anagrams of length 59
#  - Found 1 anagrams of length 66
# Constructing Language Model...
#  - No language model provided

# %% [markdown]
# # Search

# %%
# %%time

D.search(start=None, end=None, force=1)
# Out:
#  8558678 text  length
#        0 offset in complete text
#   0.00s Read previously computed variants of the lexicon words ...
#   1.16s  1365738 raw   matches
#   1.16s Filter variants of the lexicon words ...
#   3.91s      673 filtered matches
# CPU times: user 3.94 s, sys: 88.1 ms, total: 4.03 s
# Wall time: 4.03 s

# %% [markdown]
# # List

# %%
D.listResults(end=20)
# Out:
#    i | variant                   | score | candidate
# ---- | ------------------------- | ----- | -------------------------
#    0 | a Ferdinando              |  0.87 | re Ferdinando
#    1 | a suo figliolo            |  0.87 | un suo figliolo
#    2 | abbot Moronato            |  0.85 | abbate Moronato
#    3 | Adrian Plois              |  0.88 | Adrian Ploos
#    4 | Adriano Ploos             |  0.85 | Adrian Ploos
#    5 | Adrien Ploos              |  0.86 | Adrian Ploos
#    6 | agente del Kerkoven       |  0.89 | agente del Kerckoven
#    7 | al figliolo               |  0.88 | il figliolo
#    8 | al suo figlio             |  0.89 | il suo figlio
#    9 | Alag]ambe                 |  0.84 | Alagambe
#   10 | Alessandro Vanderberge    |  0.90 | Alessandro Vanderbergh
#   11 | alla moglie               |  0.86 | della moglie
#   12 | alla moglie               |  0.85 | la moglie
#   13 | ambasciator Aghe          |  0.91 | ambasciator Aghes
#   14 | ambasciator Cont          |  0.84 | ambasciator Caron
#   15 | ambasciator de Francia    |  0.85 | ambasciatore di Francia
#   16 | ambasciator della Cueva   |  0.89 | ambasciator della Lueva
#   17 | ambasciator di Francia    |  0.87 | ambasciatore di Francia
#   18 | ambasciator Dighbi        |  0.89 | ambasciator Digbi
#   19 | ambasciator Giust(inia)no |  0.86 | ambasciator Giustiniano
# ---- | ------------------------- | ----- | -------------------------
# 673 variants found and written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/variants.tsv

# %% [markdown]
# # Merge

# %%
D.mergeTriggers()
# Out:
# 149 excluded variants found in ~/gitlab.huc.knaw.nl/suriano/letters/datasource/metadata/novariant.txt
# 148 variants excluded as trigger
# 250 triggersets expanded with 538 triggers
# Wrote merged triggers to sheet ~/gitlab.huc.knaw.nl/suriano/letters/datasource/metadata/persons-merged.xlsx

# %% [markdown]
# # Show

# %%
D.showResults(start=162, end=164)
# Out:
#    1 Variant «Pesini» of 1 candidate
#   Occurrences:
#     11@100:2: further news from Diet in Regensburg. Imprisonement of Abram «Pesini »who was paymaster of John Ernst of Nassau and
#     11@100:23:  Hoggi la mattina è stato condotto et carcerato Abram «Pesini »quello che fu pagatore del già conte di Gio
#   Candidates with score:
# 	0.84 Pasini
# -----
#    2 Variant «Philip Calandrini» of 1 candidate
#   Occurrences:
#     10@099:2: 523v, 525r-526v States General have chosen «Philip Calandrini »as the one to whom the subsidies by Venice
#     11@085:2: French and English ambassadors. The States General have granted «Philip Calandrini »permission to travel to Zurich. Christofforo Suriano The
#   Candidates with score:
# 	0.86 Philippo Calandrini
# -----

# %%
D.displayResults(start=162, end=164)
# Out:
# # 1: 1 x variant `Monteran` on candidate `Monterau`
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">chunk</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.suriano.org/letters/12/032/48&amp;version=0.7.1" title="Show this on the website" sec="12@032:48">12@032:48</a></span></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="txtu"><span class="r_ ">Quelli </span></span><span class="txtu"><span class="r_ ">che </span></span><span class="txtu"><span class="r_ ">intendono </span></span><span class="txtu"><span class="r_ ">bene </span></span><span class="txtu"><span class="r_ ">le </span></span><span class="txtu"><span class="r_ ">cose </span></span><span class="txtu"><span class="r_ ">veggono </span></span><span class="txtu"><span class="r_ ">anco</span></span><span class="txtu"><span class="r_ ">,</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">che </span></span><span class="txtu"><span class="r_ ">francesi </span></span><span class="txtu"><span class="r_ ">si </span></span><span class="txtu"><span class="r_ ">sono </span></span><span class="txtu"><span class="r_ ">condotti </span></span><span class="txtu"><span class="r_ ">in </span></span><span class="txtu"><span class="r_ ">questo </span></span><span class="txtu"><span class="r_ ">affare </span></span><span class="txtu"><span class="r_ ">più</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">per </span></span><span class="txtu"><span class="r_ ">le </span></span><span class="txtu"><span class="r_ ">solicitationi </span></span><span class="txtu"><span class="r_ ">della </span></span><span class="txtu"><span class="r_ ">serenissima </span></span><span class="txtu"><span class="r_ ">Republica</span></span><span class="txtu"><span class="r_ ">, </span></span><span class="txtu"><span class="r_ ">et </span></span><span class="txtu"><span class="r_ ">anco</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">del </span></span><span class="txtu"><span class="r_ ">signor </span></span><span class="txtu"><span class="r_ ">duca </span></span><span class="txtu"><span class="r_ ">di </span></span><span class="txtu"><span class="r_ ">Savoia</span></span><span class="txtu"><span class="r_ ">, </span></span><span class="txtu"><span class="r_ ">che </span></span><span class="txtu"><span class="r_ ">per </span></span><span class="txtu"><span class="r_ ">la </span></span><span class="txtu"><span class="r_ ">volontà</span></span><span class="txtu"><span class="r_ ">, </span></span><span class="txtu"><span class="r_ ">che</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">vengono </span></span><span class="txtu"><span class="r_ ">di </span></span><span class="txtu"><span class="r_ ">Franza </span></span><span class="txtu"><span class="r_ ">si </span></span><span class="txtu"><span class="r_ ">burlano </span></span><span class="txtu"><span class="r_ ">della </span></span><span class="txtu"><span class="r_ ">levata</span></span><span class="txtu"><span class="r_ ">,</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">ma </span></span><span class="txtu"><span class="r_ ">più </span></span><span class="txtu"><span class="r_ ">dei </span></span><span class="txtu"><span class="r_ ">capi</span></span><span class="txtu"><span class="r_ ">, </span></span><span class="plain   hl"  style="background-color: goldenrod;" ><span class="txtu"><span class="r_ ">Monteran </span></span></span><span class="txtu"><span class="r_ ">l</span></span><span class="txtu"><span class="r_ ">’</span></span><span class="txtu"><span class="r_ ">hanno </span></span><span class="txtu"><span class="r_ ">per </span></span><sp ...
# # 2: 1 x variant `Montoreau` on candidate `Montereau`
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">chunk</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.suriano.org/letters/12/006/53&amp;version=0.7.1" title="Show this on the website" sec="12@006:53">12@006:53</a></span></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="plain   hl"  style="background-color: lightgreen;" ><span class="txtu">Montereau </span></span><span class="txtu">in </span><span class="txtu">luogo </span><span class="txtu">di </span><span class="txtu">tirar</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">dritto </span><span class="txtu">a </span><span class="txtu">Cales</span><span class="txtu">, </span><span class="txtu">ha </span><span class="txtu">voluto</span><span class="txtu">, </span><span class="txtu">distor</span><span class="txtu">-</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">nar </span><span class="txtu">lo </span><span class="txtu">camino</span><span class="txtu">, </span><span class="txtu">e </span><span class="txtu">andar </span><span class="txtu">prima</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">in </span><span class="txtu">Sciampagna </span><span class="txtu">a </span><span class="txtu">casa </span><span class="txtu">sua</span><span class="txtu">.</span><span class="break"><br></span><span class="txtu"></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.suriano.org/letters/12/010/185&amp;version=0.7.1" title="Show this on the website" sec="12@010:185">12@010:185</a></span></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="txtu"><span class="r_ ">Dalle </span></span><span class="txtu"><span class="r_ ">parole </span></span><span class="txtu"><span class="r_ ">del </span></span><span class="txtu"><span class="r_ ">generale </span></span><span class="txtu"><span class="r_ ">mi </span></span><span class="txtu"><span class="r_ ">par </span></span><span class="txtu"><span class="r_ ">di </span></span><span class="txtu"><span class="r_ ">cavare </span></span><span class="txtu"><span class="r_ ">che </span></span><span class="txtu"><span class="r_ ">li </span></span><span class="txtu"><span class="r_ ">Spagnoli </span></span><span class="txtu"><span class="r_ ">siano</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">per </span></span><span class="txtu"><span class="r_ ">accomodar </span></span><span class="txtu"><span class="r_ ">li </span></span><span class="txtu"><span class="r_ ">affari </span></span><span class="txtu"><span class="r_ ">della </span></span><span class="txtu"><span class="r_ ">Valtelina </span></span><span class="txtu"><span class="r_ ">quando </span></span><span class="txtu"><span class="r_ ">che </span></span><span class="txtu"><span class="r_ ">esso </span></span><span class="txtu"><span class="r_ ">con </span></span><span class="txtu"><span class="r_ ">la</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"> </span><span class="txtu "><span class=editorial>folio <span title="n">097r</span></span></span> <div><a href="illustrations/folio-12-097r.jpg" target="illustrations/folio-12-097r.jpg title="12_097r">📷</a></div><span class="txtu">​</span><span class="txtu"> </span><span class="txtu"><span class="r_ ">sua </span></span><span class="txtu"><span class="r_ ">armata </span></span><span class="txtu"><span class="r_ ">si </span></span><span class="txtu"><span class="r_ ">meta </span></span><span class="txtu"><span class="r_ ">in </span></span><span class="txtu"><span class="r_ ">servitio </span></span><span class="txtu"><span class="r_ ">della </span></span><span class="txtu"><span class="r_ ">lega</span></span><span class="txtu"><span class="r_ ">, </span></span><span class="txtu"><span class="r_ ">et </span></span><span class="txtu"><span class="r_ ">che </span></span><span class="txtu"><span class="r_ ">perciò </span></span><span class="txtu"><span class="r_ ">egli</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">dimanda </span></span><span class="txtu"><span class="r_ ">l</span></span><span class="txtu"><span class="r_ ">’</span></span><span class="txtu"><span class="r_ ">assicuranza </span></span><span class="txtu"><span class="r_ ">di </span></span><span class="txtu"><span class="r_ ">12 </span></span><span class="txtu"><span class="r_ ">mesi </span></span><span class="txtu"><span class="r_ ">di </span></span><span class="txtu"><span class="r_ ">servitio</span></span><span class="txtu"><span class="r_ ">. </span></span><span class="txtu"><span class="r_ ">Non </span></span><span class="txtu"><span class="r_ ">ho </span></span><span class="txtu"><span class="r_ ">vo</span></span><span class="txtu"><span class="r_ ">-</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">luto </span></span><span class="txtu"><span class="r_ ">toccar </span></span><span class="txtu"><span class="r_ ">questa </span></span><span class="txtu"><span class="r_ ">corda </span></span><span class="txtu"><span class="r_ "> ...
# 11m 27s    2 matches done

# %%
D.displayResults(asFile="variants")
# Out:
#   0.00s Gathering information on extra triggers ...
#   0.56s   10 variants done giving   69 chunks
#   2.43s   20 variants done giving  145 chunks
#   3.24s   30 variants done giving  230 chunks
#   3.61s   40 variants done giving  258 chunks
#   3.99s   50 variants done giving  284 chunks
#   4.33s   60 variants done giving  324 chunks
#   4.73s   70 variants done giving  379 chunks
#   5.15s   80 variants done giving  416 chunks
#   5.44s   90 variants done giving  462 chunks
#   5.81s  100 variants done giving  496 chunks
#   6.01s  110 variants done giving  529 chunks
#   6.46s  120 variants done giving  566 chunks
#   7.05s  130 variants done giving  609 chunks
#   8.02s  140 variants done giving  675 chunks
#     13s  150 variants done giving 1219 chunks
#     14s  160 variants done giving 1253 chunks
#     14s  170 variants done giving 1288 chunks
#     14s  180 variants done giving 1329 chunks
#     15s  190 variants done giving 1368 chunks
#     17s  200 variants done giving 1407 chunks
#     18s  210 variants done giving 1616 chunks
#     19s  220 variants done giving 1670 chunks
#     19s  230 variants done giving 1706 chunks
#     20s  240 variants done giving 1755 chunks
#     20s  250 variants done giving 1778 chunks
#     21s  260 variants done giving 1808 chunks
#     21s  270 variants done giving 1849 chunks
#     23s  280 variants done giving 2051 chunks
#     24s  290 variants done giving 2103 chunks
#     25s  300 variants done giving 2221 chunks
#     27s  310 variants done giving 2256 chunks
#     28s  320 variants done giving 2318 chunks
#     28s  330 variants done giving 2350 chunks
#     28s  340 variants done giving 2380 chunks
#     28s  350 variants done giving 2417 chunks
#     29s  360 variants done giving 2466 chunks
#     29s  370 variants done giving 2511 chunks
#     30s  380 variants done giving 2541 chunks
#     30s  390 variants done giving 2578 chunks
#     30s  400 variants done giving 2615 chunks
#     31s  410 variants done giving 2641 chunks
#     34s  420 variants done giving 2737 chunks
#     41s  430 variants done giving 3274 chunks
#     46s  440 variants done giving 3702 chunks
#     47s  450 variants done giving 3747 chunks
#     48s  460 variants done giving 3806 chunks
#     48s  470 variants done giving 3841 chunks
#     49s  480 variants done giving 3902 chunks
#     50s  490 variants done giving 3947 chunks
#     51s  500 variants done giving 4028 chunks
#     51s  510 variants done giving 4056 chunks
#     51s  520 variants done giving 4086 chunks
#     52s  530 variants done giving 4112 chunks
#     52s  540 variants done giving 4141 chunks
#     52s  550 variants done giving 4177 chunks
#     53s  560 variants done giving 4226 chunks
#     54s  570 variants done giving 4257 chunks
#     54s  580 variants done giving 4294 chunks
#     54s  590 variants done giving 4319 chunks
#     55s  600 variants done giving 4352 chunks
#     55s  610 variants done giving 4404 chunks
#     56s  620 variants done giving 4455 chunks
#     57s  630 variants done giving 4484 chunks
#     59s  640 variants done giving 4538 chunks
#     59s  650 variants done giving 4572 chunks
#  1m 00s  660 variants done giving 4610 chunks
#  1m 01s  670 variants done giving 4644 chunks
#  1m 01s  673 matches done
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants01.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants02.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants03.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants04.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants05.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants06.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants07.html

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from variants import Detect

# %% [markdown]
# # Load TF corpus

# %%
A = use("suriano/letters:clone", checkout="clone", backend="gitlab.huc.knaw.nl")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/ner</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.5.4</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/app" title="suriano/letters app">suriano/letters/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/about.md" title="provenance of suriano - letters/tf">suriano - letters 0.7.1</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="suriano - letters feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>11</td>
#     <td>157692.09</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>725</td>
#     <td>2392.57</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>725</td>
#     <td>2202.10</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>725</td>
#     <td>2202.10</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4148</td>
#     <td>736.35</td>
#     <td><i>176</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>725</td>
#     <td>190.47</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8764</td>
#     <td>157.79</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>725</td>
#     <td>118.49</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>725</td>
#     <td>56.90</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>46971</td>
#     <td>36.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>725</td>
#     <td>118.49</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>725</td>
#     <td>71.98</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>48688</td>
#     <td>32.42</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>725</td>
#     <td>31.55</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>725</td>
#     <td>31.55</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>725</td>
#     <td>25.35</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13281</td>
#     <td>16.80</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>1</td>
#     <td>15.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>725</td>
#     <td>14.08</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>159403</td>
#     <td>9.90</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>725</td>
#     <td>8.73</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>725</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1450</td>
#     <td>7.82</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>15456</td>
#     <td>7.81</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2175</td>
#     <td>6.52</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>725</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>725</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2082</td>
#     <td>4.31</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>725</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>725</td>
#     <td>2.70</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2175</td>
#     <td>2.69</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>725</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2175</td>
#     <td>1.32</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>metamark</th>
#     <td>3015</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8764</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11822</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1734613</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>suriano - letters/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <span> number of a chunk within a document</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/corresp.tf">corresp</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute corresp</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/date.tf">date</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Date when the letter was sent</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/editorNotes.tf">editorNotes</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Editorial notes and additional information about the letter and its attachments</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/empty.tf">empty</a>
# </div>
# <div class="fmono">int</div>
#
# <span> whether a slot has been inserted in an empty element</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/extraspace.tf">extraspace</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute extraspace</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/facs.tf">facs</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute facs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.7.1/file.tf">file</a>
# </
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/thumb</span>
# Found 8766 images<br>

# %% [markdown]
# # Set up corpus for analiticcl

# %%
D = Detect(A)
# Out:
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>
# SHEET data: computing from scratch ...
# --------------
# Reading sheets
# --------------
# Sheet with 832 rows and 18 columns
# r261: newline in trigger string: monsignor di Epernon; duca di epernone; monsignor di Epernone\n
# r555: newline in trigger string: Vanilt sottosecretario; Vanilt sottosecretario già del signor principio Mauritio\n
# 2 rows with a duplicate name:
#   r 32: () Charles of Baden-Durlach also in r31
#   r510: () Henry II, Duke of Lorraine also in r21
# 2 rows with scope mistakes:
#   r321: not a valid location: ADD RANGE
#   r587: not a valid location: ADD RANGE
# 9 rows without triggers:
# 	e.g.: 127, 214, 232, 233, 234, 417, 444, 455, 478
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
# Ambi: 'Gugliemo di Nassau':
#   William, Count of Nassau-Siegen: 8
#   William Louis, Count of Nassau-Dillenburg: 47
# Ambi: 'colonello Broch':
#   Sir William Brog: 45
#   William Brog: 808
# Ambi: 'conte di Candal':
#   Henri de Nogaret de la Valette: 513
#   Henry de Nogaret de La Valette: 768
# Ambi: 'conte di Solms':
#   Count Frederick of Solms-Rödelheim: 353
#   Johann Albrecht I, Count of Solms-Braunfels: 475
# Ambi: 're di Polonia':
#   Ladislaus IV of Poland: 211
#   Sigismund III Vasa: 487
# Ambi: 'signor Marioni':
#   Pier Antonio Mariano: 472
#   Pier Antonio Marioni: 590
# Ambiguous triggers: 6 x
# --
# 02
# --
#
# --
# 03
# --
#
# --
# 04
# --
#
# --
# 05
# --
#
# --
# 06
# --
#
# --
# 07
# --
#
# -------------
# 08.001-08.089
# -------------
#
# ---------
# 08.090-08
# ---------
#
# ---------
# 09-09.021
# ---------
#
# ---------
# 09.022-09
# ---------
#
# ---------
# 10-10.017
# ---------
#
# -------------
# 10.018-10.020
# -------------
#
# ---------
# 10.021-10
# ---------
#
# --
# 11
# --
#
# ------------
# 12-12.037.27
# ------------
#
# ---------
# 12.037.28
# ---------
#
# ----------------
# 12.037.29-12.041
# ----------------
#
# -------------
# 12.042-12.044
# -------------
#
# ---------
# 12.045-12
# ---------
#   0.00s Looking up occurrences of many candidates ...
#   2.21s done
# done
# Overview of names by length:
#   10 tokens:   2 names e.g.:
#       cavalier inglese , et il fratello del vescovo di Londra
#       signor d ’ Aspri fratello dell ’ ambasciator dei Stati
#   9 tokens:   2 names e.g.:
#       conte d ' Henin , chiamato duca di Bornenvil
#       Proveditor general dell ’ arm [ i ] Priuli
#   8 tokens:  15 names e.g.:
#       Alessandro , Giacomo et Pietr ’ Antonio Guadagni
#       ambasciator del signor Granduca nella corte di Praga
#       ambasciator di Francia residente appresso li serenissimi arciduchi
#       doi altri suoi parenti cognato , et cugino
#       doi altri un maschio , et una femina
#   7 tokens:  17 names e.g.:
#       [ duc ] a d ' Angauleme
#       ambasciator di Spagna residente appresso il Christianissimo
#       Ambasciator straordinario che venne ultimamente di Spagna
#       Ambasciatore , che dal re di Bohemia
#       capitan scocese fratello di quel capitano Seiton
#   6 tokens:  40 names e.g.:
#       al luogotenente di monsignor di Sciatiglione
#       ambasciator Giust ( inia ) no
#       ambasciator Gritti alla corte di Spagna
#       baron di Kessel governator di Husdem
#       baron di Pieterson signor di Meroda
#   5 tokens:  76 names e.g.:
#       A . v . Matenesse
#       accompagnata la sorella di lui
#       Adriano Pieterson Looske da Encusen
#       agente d ’ Inghilterra Trombol
#       agente del re di Marocco
#   4 tokens: 181 names e.g.:
#       agente di quel Principe
#       almirante d ’ Arragona
#       ambasciator Contarini in Francia
#       ambasciator Contarini in Inghilterra
#       ambasciatore Contarini in Inghilterra
#   3 tokens: 467 names e.g.:
#       ' l Chercoven
#       2 da Principessa
#       Adriano Vander Dussen
#       agente del Kerckoven
#       agente di Fiorenza
#   2 tokens: 514 names e.g.:
#       abbate Moronato
#       Abraham Pesini
#       Adam Schivelbergh
#       Adrian Pavoni
#       Adrian Ploos
#   1 tokens: 234 names e.g.:
#       Alagamba
#       Alagambe
#       Alagambre
#       Amstenraedt
#       Amsterraedt

# %% [markdown]
# # Prepare

# %%
D.prepare()
# Out:
# Alphabet written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/alphabet.tsv
# Text written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/text.txt - 8558678 characters
#   0.00s Collecting the triggers for the lexicon
#   0.00s 1382 triggers collected
#   347 x conte di Mansfelt
#   336 x Pasini
#   236 x Bernvel
#   236 x Spinola
#   212 x principe d’Oranges
#   211 x re di Spagna
#   210 x Carleton
#   208 x principe Mauritio
#   194 x duca di Savoia
#   180 x serenissimi arciduchi
#   ...
#     1 x Vimenti
#     1 x visconte di Duncaster
#     1 x visconte di Gantes fratello del principe di Pinoe
#     1 x Wandernoot
#     1 x Wassenhovven
#     1 x Wasson[ hoven]
#     1 x Weesterbeeck
#     1 x Weimar il maggiore
#     1 x zelandese nominato Cornelio
#     1 x Zeno
#     1382 lexicon length
# Lexicon written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/lexicon.tsv
# Set up analiticcl
# Computing anagram values for all items in the lexicon...
#  - Found 1382 instances
# Adding all instances to the index...
#  - Found 1377 anagrams
# Creating sorted secondary index...
# Sorting secondary index...
#  - Found 3 anagrams of length 3
#  - Found 13 anagrams of length 4
#  - Found 22 anagrams of length 5
#  - Found 35 anagrams of length 6
#  - Found 47 anagrams of length 7
#  - Found 40 anagrams of length 8
#  - Found 41 anagrams of length 9
#  - Found 26 anagrams of length 10
#  - Found 43 anagrams of length 11
#  - Found 57 anagrams of length 12
#  - Found 64 anagrams of length 13
#  - Found 78 anagrams of length 14
#  - Found 101 anagrams of length 15
#  - Found 90 anagrams of length 16
#  - Found 92 anagrams of length 17
#  - Found 92 anagrams of length 18
#  - Found 77 anagrams of length 19
#  - Found 67 anagrams of length 20
#  - Found 61 anagrams of length 21
#  - Found 46 anagrams of length 22
#  - Found 31 anagrams of length 23
#  - Found 35 anagrams of length 24
#  - Found 22 anagrams of length 25
#  - Found 21 anagrams of length 26
#  - Found 27 anagrams of length 27
#  - Found 15 anagrams of length 28
#  - Found 15 anagrams of length 29
#  - Found 14 anagrams of length 30
#  - Found 5 anagrams of length 31
#  - Found 14 anagrams of length 32
#  - Found 7 anagrams of length 33
#  - Found 5 anagrams of length 34
#  - Found 10 anagrams of length 35
#  - Found 12 anagrams of length 36
#  - Found 4 anagrams of length 37
#  - Found 6 anagrams of length 38
#  - Found 3 anagrams of length 39
#  - Found 3 anagrams of length 40
#  - Found 5 anagrams of length 41
#  - Found 2 anagrams of length 42
#  - Found 2 anagrams of length 43
#  - Found 6 anagrams of length 44
#  - Found 5 anagrams of length 45
#  - Found 1 anagrams of length 46
#  - Found 2 anagrams of length 47
#  - Found 2 anagrams of length 49
#  - Found 1 anagrams of length 50
#  - Found 1 anagrams of length 52
#  - Found 1 anagrams of length 53
#  - Found 2 anagrams of length 54
#  - Found 1 anagrams of length 57
#  - Found 1 anagrams of length 59
#  - Found 1 anagrams of length 66
# Constructing Language Model...
#  - No language model provided

# %% [markdown]
# # Search

# %%
# %%time

D.search(start=None, end=None, force=1)
# Out:
#  8558678 text  length
#        0 offset in complete text
#   0.00s Compute variants of the lexicon words ...
# 10m 44s  1365780 raw   matches
# 10m 44s Filter variants of the lexicon words ...
# 10m 45s      672 filtered matches
# CPU times: user 33min 59s, sys: 3min 40s, total: 37min 40s
# Wall time: 10min 44s

# %% [markdown]
# # List

# %%
D.listResults(end=20)
# Out:
#    i | variant                   | score | candidate
# ---- | ------------------------- | ----- | -------------------------
#    0 | a Ferdinando              |  0.87 | re Ferdinando
#    1 | a suo figliolo            |  0.87 | un suo figliolo
#    2 | abbot Moronato            |  0.85 | abbate Moronato
#    3 | Adrian Plois              |  0.88 | Adrian Ploos
#    4 | Adriano Ploos             |  0.85 | Adrian Ploos
#    5 | Adrien Ploos              |  0.86 | Adrian Ploos
#    6 | agente del Kerkoven       |  0.89 | agente del Kerckoven
#    7 | al figliolo               |  0.88 | il figliolo
#    8 | al suo figlio             |  0.89 | il suo figlio
#    9 | Alag]ambe                 |  0.84 | Alagambe
#   10 | Alessandro Vanderberge    |  0.90 | Alessandro Vanderbergh
#   11 | alla moglie               |  0.86 | della moglie
#   12 | alla moglie               |  0.85 | la moglie
#   13 | ambasciator Aghe          |  0.91 | ambasciator Aghes
#   14 | ambasciator Cont          |  0.84 | ambasciator Caron
#   15 | ambasciator de Francia    |  0.85 | ambasciatore di Francia
#   16 | ambasciator della Cueva   |  0.89 | ambasciator della Lueva
#   17 | ambasciator di Francia    |  0.87 | ambasciatore di Francia
#   18 | ambasciator Dighbi        |  0.89 | ambasciator Digbi
#   19 | ambasciator Giust(inia)no |  0.86 | ambasciator Giustiniano
# ---- | ------------------------- | ----- | -------------------------
# 672 variants found and written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/variants.tsv

# %% [markdown]
# # Merge

# %%
D.mergeTriggers()
# Out:
# 145 excluded variants found in ~/gitlab.huc.knaw.nl/suriano/letters/datasource/metadata/novariant.txt
# 144 variants excluded as trigger
# 250 triggersets expanded with 541 triggers
# Wrote merged triggers to sheet ~/gitlab.huc.knaw.nl/suriano/letters/datasource/metadata/persons-merged.xlsx

# %% [markdown]
# # Show

# %%
D.showResults(start=162, end=164)
# Out:
#    1 Variant «Philip Calandrini» of 1 candidate
#   Occurrences:
#     10@099:2: 523v, 525r-526v States General have chosen «Philip Calandrini »as the one to whom the subsidies by Venice
#     11@085:2: French and English ambassadors. The States General have granted «Philip Calandrini »permission to travel to Zurich. Christofforo Suriano The
#   Candidates with score:
# 	0.86 Philippo Calandrini
# -----
#    2 Variant «Philippi Calandrini» of 1 candidate
#   Occurrences:
#     08@002:80: factum et confirmatum in hac civitate Amstelodamensi in adibus domini «Philippi Calandrini», in presentia mei Ioannis Bruyningh Francisci filii,
#     08@002:136: [a]d[ibus]​ domini «Philippi Calandrini», in presentia mei Ioannis Bruyningh Francisci filii,
#   Candidates with score:
# 	0.87 Philippo Calandrini
# -----

# %%
D.displayResults(start=162, end=164)
# Out:
# # 1: 5 x variant `Murier` on candidate `Maurier`
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">chunk</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.suriano.org/letters/04/037/2&amp;version=0.7.1" title="Show this on the website" sec="04@037:2">04@037:2</a></span></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="txtu"><span class=" is_meta is_note">Ghent </span></span><span class="txtu"><span class=" is_meta is_note">has </span></span><span class="txtu"><span class=" is_meta is_note">moved </span></span><span class="txtu"><span class=" is_meta is_note">to </span></span><span class="txtu"><span class=" is_meta is_note">Sedan</span></span><span class="txtu"><span class=" is_meta is_note">. </span></span><span class="txtu"><span class=" is_meta is_note">question </span></span><span class="txtu"><span class=" is_meta is_note">whether </span></span><span class="txtu"><span class=" is_meta is_note">the </span></span><span class="txtu"><span class=" is_meta is_note">cavalry </span></span><span class="txtu"><span class=" is_meta is_note">in </span></span><span class="txtu"><span class=" is_meta is_note">Cleves</span></span><span class="txtu"><span class=" is_meta is_note">, </span></span><span class="txtu"><span class=" is_meta is_note">Emerich</span></span><span class="txtu"><span class=" is_meta is_note">, </span></span><span class="txtu"><span class=" is_meta is_note">Arhnem </span></span><span class="txtu"><span class=" is_meta is_note">and </span></span><span class="txtu"><span class=" is_meta is_note">Nijmegen </span></span><span class="txtu"><span class=" is_meta is_note">will </span></span><span class="txtu"><span class=" is_meta is_note">go </span></span><span class="txtu"><span class=" is_meta is_note">to </span></span><span class="txtu"><span class=" is_meta is_note">Savoy</span></span><span class="txtu"><span class=" is_meta is_note">. </span></span><span class="txtu"><span class=" is_meta is_note">The </span></span><span class="txtu"><span class=" is_meta is_note">States </span></span><span class="txtu"><span class=" is_meta is_note">are </span></span><span class="txtu"><span class=" is_meta is_note">eager </span></span><span class="txtu"><span class=" is_meta is_note">to </span></span><span class="txtu"><span class=" is_meta is_note">heard </span></span><span class="txtu"><span class=" is_meta is_note">from </span></span><span class="txtu"><span class=" is_meta is_note">Langerack </span></span><span class="txtu"><span class=" is_meta is_note">about </span></span><span class="txtu"><span class=" is_meta is_note">the </span></span><span class="txtu"><span class=" is_meta is_note">decision </span></span><span class="txtu"><span class=" is_meta is_note">of </span></span><span class="txtu"><span class=" is_meta is_note">French </span></span><span class="txtu"><span class=" is_meta is_note">king </span></span><span class="txtu"><span class=" is_meta is_note">regarding </span></span><span class="txtu"><span class=" is_meta is_note">Asti</span></span><span class="txtu"><span class=" is_meta is_note">. </span></span><span class="txtu"><span class=" is_meta is_note">He </span></span><span class="txtu"><span class=" is_meta is_note">has </span></span><span class="txtu"><span class=" is_meta is_note">received </span></span><span class="txtu"><span class=" is_meta is_note">further </span></span><span class="txtu"><span class=" is_meta is_note">news </span></span><span class="txtu"><span class=" is_meta is_note">from </span></span><span class="txtu"><span class=" is_meta is_note">Du </span></span><span class="plain   hl"  style="background-color: cyan;" ><span class="txtu"><span class=" is_meta is_note">Maurier</span></span></span><span class="txtu"><span class=" is_meta is_note">. </span></span><span class="txtu"><span class=" is_meta is_note">The </span></span><span class="txtu"><span class=" is_meta is_note">six </span></span><span class="txtu"><span class=" is_meta is_note">ships </span></span><span class="txt ...
# # 2: 1 x variant `Nidersol` on candidate `Niderzol`
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">chunk</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.suriano.org/letters/10/018/11&amp;version=0.7.1" title="Show this on the website" sec="10@018:11">10@018:11</a></span></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="txtu">Mercordì </span><span class="txtu">questo </span><span class="txtu">Re </span><span class="txtu">ispedì </span><span class="txtu">il </span><span class="txtu">signor </span><span class="plain   hl"  style="background-color: goldenrod;" ><span class="txtu">Nidersol</span></span><span class="txtu">, </span><span class="txtu">che </span><span class="txtu">dalla </span><span class="txtu">maestà </span><span class="txtu">della</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">Gran </span><span class="txtu">Bertagna </span><span class="txtu">fu </span><span class="txtu">già </span><span class="txtu">deputato </span><span class="txtu">per </span><span class="txtu">agente </span><span class="txtu">ai </span><span class="txtu">principi </span><span class="txtu">dell</span><span class="txtu">’</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">Unione</span><span class="txtu">, </span><span class="txtu">perché </span><span class="txtu">in </span><span class="txtu">corte </span><span class="txtu">di </span><span class="txtu">Inghilterra </span><span class="txtu">al </span><span class="txtu">Re</span><span class="txtu">, </span><span class="txtu">et </span><span class="txtu">a</span><span class="txtu">’ </span><span class="txtu">ministri </span><span class="txtu">andasse</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">a </span><span class="txtu">dar </span><span class="txtu">conto </span><span class="txtu">del </span><span class="txtu">successo</span><span class="txtu">, </span><span class="txtu">et </span><span class="txtu">procurar </span><span class="txtu">d</span><span class="txtu">’</span><span class="txtu">imprimer </span><span class="txtu">nell</span><span class="txtu">’</span><span class="txtu">animo </span><span class="txtu">di</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">quella </span><span class="txtu">Maestà </span><span class="txtu">il </span><span class="txtu">pregiudicio</span><span class="txtu">, </span><span class="txtu">che </span><span class="txtu">riceveva </span><span class="txtu">il </span><span class="txtu">suo </span><span class="txtu">sangue </span><span class="txtu">la </span><span class="txtu">sua</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">propria </span><span class="txtu">figliola</span><span class="txtu">, </span><span class="txtu">il </span><span class="txtu">strapazzo </span><span class="txtu">che </span><span class="txtu">si </span><span class="txtu">faceva </span><span class="txtu">dell</span><span class="txtu">’</span><span class="txtu">uno</span><span class="txtu">, </span><span class="txtu">et </span><span class="txtu">dell</span><span class="txtu">’</span><span class="txtu">altro</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">quanto </span><span class="txtu">necessario </span><span class="txtu">fosse</span><span class="txtu">, </span><span class="txtu">che </span><span class="txtu">sua </span><span class="txtu">Maestà </span><span class="txtu">se </span><span class="txtu">ne </span><span class="txtu">riscaldasse</span><span class="txtu">, </span><span class="txtu">et </span><span class="txtu">in </span><span class="txtu">fine </span><span class="txtu">perché</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">procurasse </span><span class="txtu">con </span><span class="txtu">le </span><span class="txtu">proprie</span><span class="txtu">, </span><span class="txtu">et </span><span class="txtu">l</span><span class="txtu">’</span><span  ...
#  2m 43s    2 matches done

# %%
D.displayResults(asFile="variants")
# Out:
#   0.00s Gathering information on extra triggers ...
#   0.70s   10 variants done giving   68 chunks
#   3.10s   20 variants done giving  144 chunks
#   4.08s   30 variants done giving  228 chunks
#   4.57s   40 variants done giving  255 chunks
#   5.25s   50 variants done giving  281 chunks
#   5.51s   60 variants done giving  321 chunks
#   6.13s   70 variants done giving  376 chunks
#   6.64s   80 variants done giving  432 chunks
#   7.02s   90 variants done giving  460 chunks
#   7.41s  100 variants done giving  495 chunks
#   7.90s  110 variants done giving  534 chunks
#   8.38s  120 variants done giving  582 chunks
#   9.01s  130 variants done giving  608 chunks
#     10s  140 variants done giving  680 chunks
#     17s  150 variants done giving 1217 chunks
#     18s  160 variants done giving 1252 chunks
#     18s  170 variants done giving 1289 chunks
#     19s  180 variants done giving 1331 chunks
#     20s  190 variants done giving 1368 chunks
#     24s  200 variants done giving 1590 chunks
#     25s  210 variants done giving 1635 chunks
#     25s  220 variants done giving 1672 chunks
#     26s  230 variants done giving 1712 chunks
#     26s  240 variants done giving 1751 chunks
#     27s  250 variants done giving 1781 chunks
#     27s  260 variants done giving 1814 chunks
#     28s  270 variants done giving 1849 chunks
#     31s  280 variants done giving 2070 chunks
#     32s  290 variants done giving 2109 chunks
#     34s  300 variants done giving 2226 chunks
#     35s  310 variants done giving 2265 chunks
#     36s  320 variants done giving 2318 chunks
#     36s  330 variants done giving 2352 chunks
#     37s  340 variants done giving 2386 chunks
#     37s  350 variants done giving 2416 chunks
#     38s  360 variants done giving 2471 chunks
#     38s  370 variants done giving 2518 chunks
#     39s  380 variants done giving 2548 chunks
#     39s  390 variants done giving 2581 chunks
#     40s  400 variants done giving 2650 chunks
#     41s  410 variants done giving 2676 chunks
#     45s  420 variants done giving 2805 chunks
#     54s  430 variants done giving 3339 chunks
#  1m 01s  440 variants done giving 3740 chunks
#  1m 02s  450 variants done giving 3785 chunks
#  1m 03s  460 variants done giving 3847 chunks
#  1m 04s  470 variants done giving 3884 chunks
#  1m 05s  480 variants done giving 3946 chunks
#  1m 06s  490 variants done giving 3987 chunks
#  1m 07s  500 variants done giving 4079 chunks
#  1m 08s  510 variants done giving 4108 chunks
#  1m 08s  520 variants done giving 4142 chunks
#  1m 08s  530 variants done giving 4168 chunks
#  1m 09s  540 variants done giving 4204 chunks
#  1m 10s  550 variants done giving 4247 chunks
#  1m 10s  560 variants done giving 4287 chunks
#  1m 11s  570 variants done giving 4317 chunks
#  1m 11s  580 variants done giving 4351 chunks
#  1m 12s  590 variants done giving 4377 chunks
#  1m 13s  600 variants done giving 4429 chunks
#  1m 13s  610 variants done giving 4475 chunks
#  1m 15s  620 variants done giving 4514 chunks
#  1m 16s  630 variants done giving 4556 chunks
#  1m 17s  640 variants done giving 4598 chunks
#  1m 18s  650 variants done giving 4629 chunks
#  1m 19s  660 variants done giving 4667 chunks
#  1m 20s  670 variants done giving 4706 chunks
#  1m 20s  671 matches done
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants01.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants02.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants03.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants04.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants05.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants06.html
# Extra triggers written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/extra/variants07.html

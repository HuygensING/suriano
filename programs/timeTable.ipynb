# %% [markdown]
# # Timetable
#
# We want to make a time table of the letters.
#
# Later, we can use it to disambiguate named entities, such as "The Pope".

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tf.core.files import dirNm

# %%
A = use("suriano/letters:clone", checkout="clone", backend="gitlab.huc.knaw.nl", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/tf/0.2.1</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/ner</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.4.6</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/app" title="suriano/letters app">suriano/letters/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
tsv = []

for f in F.otype.s("file"):
    date = F.date.v(f)
    head = T.sectionFromNode(f)
    tsv.append((f, *head, date))

# %%
timeFile = f"{dirNm(A.context.localDir)}/{A.context.extraData}/timetable.tsv"

with open(timeFile, "w") as fh:
    for row in tsv:
        fh.write("\t".join(str(v) for v in row) + "\n")

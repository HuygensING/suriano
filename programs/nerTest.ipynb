# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tf.browser.ner.annotate import Annotate

# %%
A = use("HuygensING/suriano:clone", checkout="clone")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/0.0.2</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 12.0.7</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
Ann = Annotate(A)
# Out:
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# .buckets {
#   padding-left: 2rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0.3rem;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
# ...

# %%
Ann.setNames
# Out:
# {'dirk', 'dirk3', 'power', 'testmod'}

# %%
Ann.setSet("dirk")
# Out:
# Annotation set dirk has 0 annotations

# %%
Ann.setSet("dirk3")
# Out:
# Annotation set dirk3 has 0 annotations

# %%
Ann.setSet("")
# Out:
# Annotation set ent-nodes has 16058 annotations

# %%
qTokens = ("Ernesto", "di", "Nassau")
results = Ann.filterContent(bFind=None, bFindC=False, qTokens=qTokens, showStats=None)
# Out:
# 3 chunks

# %%
Ann.showContent(results)
# Out:
# <div class="buckets"><div class="b"><span node="280935" class="bh" title="show context">3@1:62</span><span class="es" enm="li.stati.generali.de.paesi.bassi.uniti⊙MISC"><span class="lgb">8</span><span class="eid ">li.stati.generali.de.paesi.bassi.uniti</span> <span class="kind ">MISC</span> <span class="n">2</span></span><span class=" ei " t="4433">Li</span> <span class=" ei " t="4434">Stati</span> <span class=" ei " t="4435">Generali</span> <span class=" ei " t="4436">de</span><span class=" ei " t="4437">’</span> <span class=" ei " t="4438">Paesi</span> <span class=" ei " t="4439">Bassi</span> <span class=" ei " t="4440">Uniti</span><span class="ee"><span class="lge">8</span></span><span t="4441">.</span> <span t="4442">Havendo</span> <span t="4443">
# ...

# %%
results = Ann.filterContent(bFind="paesi", bFindC=True, anyEnt=True, showStats=True)
# Out:
# 101 chunks satisfy the search pattern
# Combined features match:
# 101 chunks

# %%
Ann.showContent(results, end=5)
# Out:
# <div class="buckets"><div class="b"><span node="281005" class="bh" title="show context">3@11:6</span><span t="7045">li</span> <span t="7046">signori</span> <span class="es" enm="stati⊙MISC"><span class="lgb">1</span><span class="eid ">stati</span> <span class="kind ">MISC</span> <span class="n">61</span></span><span class=" ei " t="7047">Stati</span> <span class="ee"><span class="lge">1</span></span><span t="7048">col</span> <span t="7049">consiglio</span> <span t="7050">del</span> <span t="7051">signor</span> <span t="7052">principe</span> <span class="es" enm="mauritio⊙PER"><span class="lgb">1</span><span class="eid ">mauritio</span> <span class="kind ">PER</span> <span class="n">135</span></span><span class=" ei " t="7053">Mauritio</span> <span class="ee"><span class="lge">1</span></span><span t="7054">si</span> <span t="7055">
# ...

# %%
results = Ann.filterContent(anyEnt=False, showStats=True)
# Out:
# 1230 chunks satisfy the search pattern
# Combined features match:
# Feature eid: found the following values:
# Feature kind: found the following values:
# 1230 chunks

# %%
Ann.showContent(results, start=1115, end=1125)
# Out:
# <div class="buckets"><div class="b"><span node="286359" class="bh" title="show context">4@63:15</span><span t="246063">1617</span> <span t="246064">a</span><span t="246065">’</span> <span t="246066">2</span> <span t="246067">agosto</span> <span t="246068">ricevute</span> <span t="246069">a</span><span t="246070">’</span> <span t="246071">16</span> <span t="246072">detto</span> <span t="246073">
# </span></div><div class="b"><span node="286363" class="bh" title="show context">4@63:19</span><span t="246093">2</span><span t="246094"> </span><span t="246095">Come</span> <span t="246096">pare</span><span t="246097">.</span><span t="246098">
# </span><span t="246099">
# ...

# %%
results = Ann.filterContent(qTokens=qTokens, anyEnt=False, showStats=True)
# Out:
# 1230 chunks satisfy the search pattern
# Combined features match:
# 	    0 of     3 x
# Feature eid: found the following values:
# 	    0 of    16 x ernesto.di.nassau
# 	    0 of     3 x ⌀
# Feature kind: found the following values:
# 	    0 of    16 x PER
# 	    0 of     3 x ⌀
# 0 chunks

# %%
results = Ann.filterContent(qTokens=qTokens, anyEnt=True, showStats=True)
# Out:
# 4955 chunks satisfy the search pattern
# Combined features match:
# 	    3 of     3 x
# 3 chunks

# %%
results = Ann.filterContent(qTokens=qTokens, anyEnt=None, showStats=True)
# Out:
# 6185 chunks satisfy the search pattern
# Combined features match:
# 	    3 of     3 x
# Feature eid: found the following values:
# 	   16 of    16 x ernesto.di.nassau
# 	    3 of     3 x ⌀
# Feature kind: found the following values:
# 	   16 of    16 x PER
# 	    3 of     3 x ⌀
# 3 chunks

# %%
Ann.showContent(results)
# Out:
# <div class="buckets"><div class="b"><span node="280935" class="bh" title="show context">3@1:62</span><span class="es" enm="li.stati.generali.de.paesi.bassi.uniti⊙MISC"><span class="lgb">8</span><span class="eid ">li.stati.generali.de.paesi.bassi.uniti</span> <span class="kind ">MISC</span> <span class="n">2</span></span><span class=" ei " t="4433">Li</span> <span class=" ei " t="4434">Stati</span> <span class=" ei " t="4435">Generali</span> <span class=" ei " t="4436">de</span><span class=" ei " t="4437">’</span> <span class=" ei " t="4438">Paesi</span> <span class=" ei " t="4439">Bassi</span> <span class=" ei " t="4440">Uniti</span><span class="ee"><span class="lge">8</span></span><span t="4441">.</span> <span t="4442">Havendo</span> <span t="4443">
# ...

# %%
Ann.setSet("power")
# Out:
# Annotation set power has 150 annotations

# %%
results = Ann.filterContent(qTokens=qTokens, anyEnt=False, showStats=True)
# Out:
# 6067 chunks satisfy the search pattern
# Combined features match:
# 	   19 of    19 x
# Feature eid: found the following values:
# 	   19 of    19 x ⌀
# Feature kind: found the following values:
# 	   19 of    19 x ⌀
# 18 chunks

# %%
results = Ann.filterContent(qTokens=qTokens, anyEnt=True, showStats=True)
# Out:
# 118 chunks satisfy the search pattern
# Combined features match:
# 	    0 of    19 x
# 0 chunks

# %%
results = Ann.filterContent(qTokens=qTokens, anyEnt=None, showStats=True)
# Out:
# 6185 chunks satisfy the search pattern
# Combined features match:
# 	   19 of    19 x
# Feature eid: found the following values:
# 	   19 of    19 x ⌀
# Feature kind: found the following values:
# 	   19 of    19 x ⌀
# 18 chunks

# %%
results = Ann.filterContent(bFind="paesi", bFindC=True, anyAnno=True, showStats=True)
# Out:
# 103 chunks satisfy the search pattern
# Combined features match:
# 	   95 of   563 x
# 43 chunks

# %%
Ann.showContent(results, end=5)
# Out:
# <div class="buckets"><div class="b"><span node="281005" class="bh" title="show context">3@11:6</span><span t="7045">li</span> <span t="7046">signori</span> <span t="7047">Stati</span> <span t="7048">col</span> <span t="7049">consiglio</span> <span t="7050">del</span> <span t="7051">signor</span> <span t="7052">principe</span> <span t="7053">Mauritio</span> <span t="7054">si</span> <span t="7055">
# </span><span t="7056"> </span><span t="7057">sono</span> <span t="7058">in</span> <span t="7059">fine</span> <span t="7060">risoluti</span> <span t="7061">di</span> <span t="7062">permetter</span> <span t="7063">a</span> <span t="7064">monsignor</span> <span t="7065">di</span> <span t="7066">Rocalaura</span> <span t="7067">
# ...

# %%
Ann.showEntityOverview()
# Out:
# <p><span><code>  377</code> x <span><span class="kind ">ORG</span></span></span><br><span><code>  186</code> x <span><span class="kind ">PER</span></span></span><br></p>

# %%
Ann.showEntities()
# Out:
# <p class="e " enm="186"><code class="w">  377</code> x <span class="eid ">republica</span> <span class="kind ">ORG</span></p><p class="e " enm="0"><code class="w">  183</code> x <span class="eid ">ernesto.di.nassau</span> <span class="kind ">PER</span></p><p class="e " enm="19"><code class="w">    3</code> x <span class="eid ">conte.henrico</span> <span class="kind ">PER</span></p>

# %%
Ann.setSet("")
# Out:
# Data for dirk3 already loaded
# Data of dirk3 already processed.
# Data of {nodes of type ent} already processed.
# Annotation set {nodes of type ent} has 16058 annotations

# %%
Ann.showEntityOverview()
# Out:
# <p><span><code> 6091</code> x <span><span class="kind ">PER</span></span></span><br><span><code> 5628</code> x <span><span class="kind ">LOC</span></span></span><br><span><code> 3629</code> x <span><span class="kind ">MISC</span></span></span><br><span><code>  710</code> x <span><span class="kind ">ORG</span></span></span><br></p>

# %%
Ann.showEntities(sortKey="sort_kind", cutOffFreq=10)
# Out:
# <p class="e " enm="325283"><code class="w">  406</code> x <span class="eid ">serenità</span> <span class="kind ">LOC</span></p><p class="e " enm="325236"><code class="w">  260</code> x <span class="eid ">christofforo.suriano</span> <span class="kind ">LOC</span></p><p class="e " enm="325971"><code class="w">  185</code> x <span class="eid ">francia</span> <span class="kind ">LOC</span></p><p class="e " enm="325295"><code class="w">  168</code> x <span class="eid ">serenissima.republica</span> <span class="kind ">LOC</span></p><p class="e " enm="325253"><code class="w">  158</code> x <span class="eid ">venetia</span> <span class="kind ">LOC</span></p><p class="e " enm="325346"><code class="w">  157</code> x <span class="eid ">stati</span> <span class="kind ">LOC</span></p><p class="e " enm="325970"><code class="w">  135</code> x <span class="eid ">altezza</span> <span class="kind ">LOC</span></p><p class="e " enm="325238"><code class="w">  130</code> x <span class="eid ">transcription
# ...

# %%
Ann.setSet("testmod")
# Out:
# Data for testmod already loaded
# Data of testmod already processed.
# Annotation set testmod has 17 annotations

# %%
qTokens = ("Gio", ".", "Ernesto", "di", "Nassau")
results = Ann.filterContent(qTokens=qTokens, showStats=None)
# Out:
# 15 chunks

# %%
Ann.addEntityRich([["gio.ernesto.di.nassau"], ["PER"]], results)
# Out:
# Data for testmod already loaded
# Data of testmod already processed.
# Nothing added

# %%
Ann.addEntityRich(("gio.ernesto.di.nassau2", "PER2"), results)
# Out:
# Loading data for testmod ... done.
# Processing data of testmod ... done.
# Added    15 x eid=gio.ernesto.di.nassau2 kind=PER2

# %%
Ann.showEntities()
# Out:
# <p class="e " enm="0"><code class="w">   15</code> x <span class="eid ">gio.ernesto.di.nassau</span> <span class="kind ">PER</span></p><p class="e " enm="15"><code class="w">    2</code> x <span class="eid ">test.xxx</span> <span class="kind ">YYY</span></p>

# %%
Ann.addEntity(("test.xxx", "YYY"), [tuple(range(100, 105)), tuple(range(120, 125))])
# Out:
# Loading data for testmod ... done.
# Processing data of testmod ... done.
# Already present:     0 x
# Added:               2 x

# %%
Ann.showEntities()
# Out:
# <p class="e " enm="0"><code class="w">   15</code> x <span class="eid ">gio.ernesto.di.nassau</span> <span class="kind ">PER</span></p><p class="e " enm="15"><code class="w">    2</code> x <span class="eid ">test.xxx</span> <span class="kind ">YYY</span></p>

# %%
results = Ann.filterContent(anyAnno=True, showStats=True)
# Out:
# 6185 chunks satisfy the search pattern
# Combined features match:
# 	   17 of    17 x
# 15 chunks

# %%
Ann.showContent(results)
# Out:
# <div class="buckets"><div class="b"><span node="280877" class="bh" title="show context">3@1:4</span><span t="79">Havendo</span> <span t="80">il</span> <span t="81">signor</span> <span t="82">conte</span> <span class="es" enm="0"><span class="lgb">5</span><span class="eid ">gio.ernesto.di.nassau</span> <span class="kind ">PER</span> <span class="n">15</span></span><span class=" queried  ei " t="83">Gio</span><span class=" queried  ei " t="84">.</span> <span class=" queried  ei " t="85">Ernesto</span> <span class=" queried  ei " t="86">di</span> <span class=" queried  ei " t="87">Nassau</span><span te="87" st="v"></span> <span class="ee"><span class="lge">5</span></span><span t="88">li</span> <span t="89">giorni</span> <span t="90">passati</span> <span t="91">
# ...

# %%
eVals = ("gio.ernesto.di.nassau2", "PER2")

results = Ann.filterContent(eVals=eVals, showStats=True)
# Out:
# 6185 chunks satisfy the search pattern
# Combined features match:
# 	   15 of    15 x
# Feature eid: found the following values:
# 	   15 of    15 x PER2
# 	   15 of    15 x gio.ernesto.di.nassau2
# Feature kind: found the following values:
# 	   15 of    15 x PER2
# 	   15 of    15 x gio.ernesto.di.nassau2
# 15 chunks

# %%
Ann.delEntityRich(eVals, results)
# Out:
# Loading data for testmod ... done.
# Processing data of testmod ... done.
# Deleted    15 x eid=gio.ernesto.di.nassau2 kind=PER2

# %%
Ann.showEntities()
# Out:
# <p class="e " enm="0"><code class="w">   15</code> x <span class="eid ">gio.ernesto.di.nassau</span> <span class="kind ">PER</span></p><p class="e " enm="15"><code class="w">    2</code> x <span class="eid ">test.xxx</span> <span class="kind ">YYY</span></p>

# %%
Ann.delEntity(("test.xxx", "YYY"), allMatches=[tuple(range(100, 105)), tuple(range(120, 125))])
# Out:
# Loading data for testmod ... done.
# Processing data of testmod ... done.
# Not present:     0 x
# Deleted:         2 x

# %%
Ann.showEntities()
# Out:
# <p class="e " enm="0"><code class="w">   15</code> x <span class="eid ">gio.ernesto.di.nassau</span> <span class="kind ">PER</span></p>

# %%
Ann.delEntity(("test.xxx", "YYY"))
# Out:
# Data for testmod already loaded
# Data of testmod already processed.
# Not present:     0 x
# Deleted:         0 x

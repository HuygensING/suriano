# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("HuygensING/suriano:clone", checkout="clone")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/0.0.2</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">TF API 12.1.2</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/about.md" title="provenance of HuygensING - suriano/tf">HuygensING - suriano 0.0.2</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="HuygensING - suriano feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>2</td>
#     <td>140029.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>130</td>
#     <td>2154.29</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>130</td>
#     <td>2093.35</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>130</td>
#     <td>2093.35</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>756</td>
#     <td>696.82</td>
#     <td><i>188</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>18</td>
#     <td>144.61</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>130</td>
#     <td>60.95</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>6185</td>
#     <td>45.09</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>130</td>
#     <td>48.32</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>6053</td>
#     <td>43.94</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>130</td>
#     <td>28.27</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>135</td>
#     <td>19.15</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>130</td>
#     <td>19.05</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>130</td>
#     <td>19.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>130</td>
#     <td>19.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>16009</td>
#     <td>16.69</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>236</td>
#     <td>14.11</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>130</td>
#     <td>10.63</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>130</td>
#     <td>10.63</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>130</td>
#     <td>10.63</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>130</td>
#     <td>9.27</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>1718</td>
#     <td>9.02</td>
#     <td>6</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>130</td>
#     <td>9.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>295</td>
#     <td>8.73</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>1</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>130</td>
#     <td>7.27</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>130</td>
#     <td>7.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>130</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>130</td>
#     <td>4.05</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>5307</td>
#     <td>3.86</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>130</td>
#     <td>3.63</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>130</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>130</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>260</td>
#     <td>2.52</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>260</td>
#     <td>2.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>260</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>130</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ent</th>
#     <td>16058</td>
#     <td>1.41</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>supplied</th>
#     <td>299</td>
#     <td>1.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>token</th>
#     <td>243694</td>
#     <td>1.00</td>
#     <td>87</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>130</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>17012</td>
#     <td>1.00</td>
#     <td>6</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>1542</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>1718</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>130</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>280058</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - suriano/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.2/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.2/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <span> number of a chunk within a document</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.2/corresp.tf">corresp</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute corresp</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.2/empty.tf">empty</a>
# </div>
# <div class="fmono">int</div>
#
# <span> whether a slot has been inserted in an empty element</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.2/estr.tf">estr</a>
# </div>
# <div class="fmono">str</div>
#
# <span> </span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.2/extraspace.tf">extraspace</a>
# </div>
# <div class="fmono">str</div>
#
# <span> whether a space has been added after a character, when it is in the direct child of a pure XML element</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.2/file.tf">file</a>
# </div>
# <div class="fmono">str</div>
#
# <span> name of source file</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.2/folder.tf">folder</a>
# </div>
# <div class="fmono">str</div>
#
# <span> name of source folder</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.2/id.tf">id</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute id</span>
#
# </div>
#
# <div class=
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-co
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>

# %%
NE = A.makeNer()
# Out:
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0.3rem;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
NE.setNames
# Out:
# {'power', 'test222', 'testmod'}

# %%
NE.setSet("test222")
# Out:
# Annotation set test222 has 19 annotations

# %%
NE.setSet("testmod")
# Out:
# Annotation set testmod has 32 annotations

# %%
NE.setSet("")
# Out:
# Annotation set ent-nodes has 16058 annotations

# %%
qTokens = ("Ernesto", "di", "Nassau")
results = NE.filterContent(bFind=None, bFindC=False, qTokens=qTokens, showStats=None)
# Out:
# 3 chunks

# %%
NE.showContent(results)
# Out:
# <div class="buckets ltr"><div class="b ltr"><span class="bh ltr"><span node="280935" class="bhl ltr" title="show context">3@1:62</span></span> <span class="ltr"><span class="es" enm="li.stati.generali.de.paesi.bassi.uniti⊙MISC"><span class="lgb">8</span><span class="eid ">li.stati.generali.de.paesi.bassi.uniti</span> <span class="kind ">MISC</span> <span class="n">2</span></span><span class=" ei  txtu " t="4433">Li</span> <span class=" ei  txtu " t="4434">Stati</span> <span class=" ei  txtu " t="4435">Generali</span> <span class=" ei  txtu " t="4436">de</span><span class=" ei  txtu " t="4437">’</span> <span class=" ei  txtu " t="4438">Paesi</span> <span class=" ei  txtu " t="4439">Bassi</span> <span class=" ei  txtu " t="4440">Uniti</span><span class="ee"><span class="lge">8</span></span><span class=" txtu " t="4441">.</span> <span class=" txtu " t="4442">Havendo</span> <span class=" txtu " t="4443">
# </span><span class=" txtu " t="4444"> </span><span class=" txtu " t="4445">nella</span> <span class=" txtu " t="4446">loro</span> <span class=" txtu " t="4447">assemblea</span> <span class=" txtu " t="4448">intesa</span> <span class=" txtu " t="4449">la</span> <span class=" txtu " t="4450">relatione</span> <span class=" txtu " t="4451">fatta</span> <span class=" txtu " t="4452">
# </span><span class=" txtu " t="4453"> </span><span class=" txtu " t="4454">alle</span> <span class=" txtu " t="4455">loro</span> <span class="es" enm="signorie⊙LOC"><span class="lgb">1</span><span class="eid ">signorie</span> <span class="kind ">LOC</span> <span class="n">80</span></span><span class=" ei  txtu " t="4456">Signorie</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="4457">il</span> <span class=" txtu " t="4458">giorno</span> <span class=" txtu " t="4459">de</span><span class=" txtu " t="4460">’</span> <span class=" txtu " t="4461">hieri</span> <span class=" txtu " t="4462">per</span> <span class=" txtu " t="4463">ordine</span> <span class=" txtu " t="4464">della</span> <span class=" txtu " t="4465">
# </span><span class=" txtu " t="4466"> </span><span class=" txtu " t="4467">serenissima</span> <span class=" txtu " t="4468">republica</span> <span class=" txtu " t="4469">di</span> <span class="es" enm="venetia⊙LOC"><span class="lgb">1</span><span class="eid ">venetia</span> <span class="kind ">LOC</span> <span class="n">158</span></span><span class=" ei  txtu " t="4470">Venetia</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="4471">dal</span> <span class=" txtu " t="4472">signor</span> <span class="es" enm="christofforo⊙LOC"><span class="lgb">1</span><span class="eid ">christofforo</span> <span class="kind ">LOC</span> <span class="n">1</span></span><span class=" ei  txtu " t="4473">Christofforo</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="4474">
# </span><span class=" txtu " t="4475"> </span><span class="es" enm="suriano⊙LOC"><span class="lgb">1</span><span class="eid ">suriano</span> <span class="kind ">LOC</span> <span class="n">16</span></span><span class=" ei  txtu " t="4476">Suriano</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="4477">residente</span> <span class=" txtu " t="4478">appresso</span> <span class=" txtu " t="4479">di</span> <span class=" txtu " t="4480">loro</span><span class=" txtu " t="4481">,</span> <span class=" txtu " t="4482">et</span> <span class=" txtu " t="4483">secretario</span> <span class=" txtu " t="4484">di</span> <span class=" txtu " t="4485">
# </span><span class=" txtu " t="4486"> </span><span class=" txtu " t="4487">stato</span><span class=" txtu " t="4488">​</span> <span class=" txtu " t="4489">della</span> <span class=" txtu " t="4490">detta</span> <span class="es" enm="serenissima.republica⊙LOC"><span class="lgb">2</span><span class="eid ">serenissima.republica</span> <span class="kind ">LOC</span> <span class="n">168</span></span><span class=" ei  txtu " t="4491">serenissima</span> <span class=" ei  txtu " t="4492">Republica</span> <span class="ee"><span class="lge">2</span></span><span class=" txtu " t="4493">in</span> <span class=" txtu " t="4494">virtù</span> <span class=" txtu " t="4495">delle</span> <span class=" txtu " t="4496">lettere</span> <span class=" txtu " t="4497">sue</span> <span class=" txtu " t="4498">credentiali</span> <span class=" txtu " t="4499">delli</span> <span class=" txtu " t="4500">15</span> <span class=" txtu " t="4501">del</span> <span class=" txtu " t="4502">mese</span> <span class=" txtu " t="4503">
# </span><span class=" txtu " t="4504"> </span><span class=" txtu " t="4505">presente</span><span class=" txtu " t="4506">,</span> <span class=" txtu " t="4507">dello</span> <span class=" txtu " t="4508">stato</span> <span class=" txtu " t="4509">degl’</span><span class=" txtu " t="4510">affari</span> <span class=" txtu " t="4511">di</span> <span class=" txtu " t="4512">lei</span> <span class=" txtu " t="4513">intorno</span> <span class=" txtu " t="4514">
# </span><span class=" txtu " t="4515"> </span><span class=" txtu " t="4516">alla</span> <span class=" txtu " t="4517">guerra</span><span class=" txtu " t="4518">,</span> <span class=" txtu " t="4519">ch’</span><span class=" txtu " t="4520">ella</span> <span class=" txtu " t="4521">sostiene</span> <span class=" txtu " t="4522">contra</span> <span class=" txtu " t="4523">il</span> <span class=" txtu " t="4524">serenissimo</span> <span class=" txtu " t="4525">
# </span><span class=" txtu " t="4526"> </span><span class=" txtu " t="4527">arciduca</span> <span class="es" enm="ferdinando.daustria⊙PER"><span class="lgb">3</span><span class="eid ">ferdinando.daustria</span> <span class="kind ">PER</span> <span class="n">2</span></span><span class=" ei  txtu " t="4528">Ferdinando</span> <span class=" ei  txtu " t="4529">d’</span><span class=" ei  txtu " t="4530">Austria</span><span class="ee"><span class="lge">3</span></span><span class=" txtu " t="4531">,</span> <span class=" txtu " t="4532">ringratiano</span> <span class=" txtu " t="4533">
# </span><span class=" txtu " t="4534"> </span><span class=" txtu " t="4535">affettuosamente</span> <span class=" txtu " t="4536">la</span> <span class=" txtu " t="4537">detta</span> <span class=" txtu " t="4538">serenissima</span> <span class="es" enm="republica⊙LOC"><span class="lgb">1</span><span class="eid ">republica</span> <span class="kind ">LOC</span> <span class="n">115</span></span><span class=" ei  txtu " t="4539">Republica</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="4540">della</span> <span class=" txtu " t="4541">
# </span><span class=" txtu " t="4542"> </span><span class=" txtu " t="4543">continuatione</span> <span class=" txtu " t="4544">di</span> <span class=" txtu " t="4545">questa</span> <span class=" txtu " t="4546">buona</span> <span class=" txtu " t="4547">corrispondenza</span> <span class=" txtu " t="4548">
# </span><span class=" txtu " t="4549"> </span><span class=" txtu " t="4550">rallegrandosi</span> <span class=" txtu " t="4551">del</span> <span class=" txtu " t="4552">buon</span> <span class=" txtu " t="4553">successo</span> <span class=" txtu " t="4554">del</span> <span class=" txtu " t="4555">detto</span> <span class=" txtu " t="4556">suo</span> <span class=" txtu " t="4557">affare</span> <span class=" txtu " t="4558">
# </span><span class=" txtu " t="4559"> </span><span class=" txtu " t="4560">fino</span> <span class=" txtu " t="4561">al</span> <span class=" txtu " t="4562">presente</span><span class=" txtu " t="4563">;</span> <span class=" txtu " t="4564">sperando</span><span class=" txtu " t="4565">,</span> <span class=" txtu " t="4566">come</span> <span class=" txtu " t="4567">lo</span> <span class=" txtu " t="4568">bramavano</span> <span class=" txtu " t="4569">
# </span><span class=" txtu " t="4570"> </span><span class=" txtu " t="4571">di</span> <span class=" txtu " t="4572">tutto</span> <span class=" txtu " t="4573">buon</span> <span class="

# %%
results = NE.filterContent(bFind="paesi", bFindC=True, anyEnt=True, showStats=True)
# Out:
# 101 chunks satisfy the filter
# Combined features match:
# 101 chunks

# %%
NE.showContent(results, end=5)
# Out:
# <div class="buckets ltr"><div class="b ltr"><span class="bh ltr"><span node="281005" class="bhl ltr" title="show context">3@11:6</span></span> <span class="ltr"><span class=" txtu " t="7045">li</span> <span class=" txtu " t="7046">signori</span> <span class="es" enm="stati⊙MISC"><span class="lgb">1</span><span class="eid ">stati</span> <span class="kind ">MISC</span> <span class="n">61</span></span><span class=" ei  txtu " t="7047">Stati</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="7048">col</span> <span class=" txtu " t="7049">consiglio</span> <span class=" txtu " t="7050">del</span> <span class=" txtu " t="7051">signor</span> <span class=" txtu " t="7052">principe</span> <span class="es" enm="mauritio⊙PER"><span class="lgb">1</span><span class="eid ">mauritio</span> <span class="kind ">PER</span> <span class="n">135</span></span><span class=" ei  txtu " t="7053">Mauritio</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="7054">si</span> <span class=" txtu " t="7055">
# </span><span class=" txtu " t="7056"> </span><span class=" txtu " t="7057">sono</span> <span class=" txtu " t="7058">in</span> <span class=" txtu " t="7059">fine</span> <span class=" txtu " t="7060">risoluti</span> <span class=" txtu " t="7061">di</span> <span class=" txtu " t="7062">permetter</span> <span class=" txtu " t="7063">a</span> <span class=" txtu " t="7064">monsignor</span> <span class=" txtu " t="7065">di</span> <span class="es" enm="rocalaura⊙LOC"><span class="lgb">1</span><span class="eid ">rocalaura</span> <span class="kind ">LOC</span> <span class="n">31</span></span><span class=" ei  txtu " t="7066">Rocalaura</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="7067">
# </span><span class=" txtu " t="7068"> </span><span class=" txtu " t="7069">et</span> <span class=" txtu " t="7070">a</span> <span class="es" enm="monsignor.gulena⊙PER"><span class="lgb">2</span><span class="eid ">monsignor.gulena</span> <span class="kind ">PER</span> <span class="n">8</span></span><span class=" ei  txtu " t="7071">monsignor</span> <span class=" ei  txtu " t="7072">Gulena</span> <span class="ee"><span class="lge">2</span></span><span class=" txtu " t="7073">francesi</span><span class=" txtu " t="7074">​</span> <span class=" txtu " t="7075">di</span> <span class=" txtu " t="7076">poter</span> <span class=" txtu " t="7077">andare</span> <span class=" txtu " t="7078">col</span> <span class=" txtu " t="7079">signor</span> <span class="es" enm="conte⊙PER"><span class="lgb">1</span><span class="eid ">conte</span> <span class="kind ">PER</span> <span class="n">374</span></span><span class=" ei  txtu " t="7080">Conte</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="7081">
# </span><span class=" txtu " t="7082"> </span><span class=" txtu " t="7083">in</span> <span class=" txtu " t="7084">servitio</span> <span class=" txtu " t="7085">di</span> <span class=" txtu " t="7086">vostra</span> <span class="es" enm="serenità⊙LOC"><span class="lgb">1</span><span class="eid ">serenità</span> <span class="kind ">LOC</span> <span class="n">406</span></span><span class=" ei  txtu " t="7087">Serenità</span><span class="ee"><span class="lge">1</span></span><span class=" txtu " t="7088">,</span> <span class=" txtu " t="7089">et</span> <span class=" txtu " t="7090">la</span> <span class=" txtu " t="7091">licenza</span> <span class=" txtu " t="7092">non</span> <span class=" txtu " t="7093">serve</span><span class=" txtu " t="7094">,</span> <span class=" txtu " t="7095">che</span> <span class=" txtu " t="7096">
# </span><span class=" txtu " t="7097"> </span><span class=" txtu " t="7098">sino</span> <span class=" txtu " t="7099">a</span> <span class=" txtu " t="7100">maggio</span> <span class=" txtu " t="7101">venturo</span><span class=" txtu " t="7102">,</span> <span class=" txtu " t="7103">che</span> <span class=" txtu " t="7104">doveranno</span> <span class=" txtu " t="7105">ritornar</span> <span class=" txtu " t="7106">
# </span><span class=" txtu " t="7107"> </span><span class=" txtu " t="7108">qui</span> <span class=" txtu " t="7109">alle</span> <span class=" txtu " t="7110">sue</span> <span class=" txtu " t="7111">cariche</span><span class=" txtu " t="7112">,</span> <span class=" txtu " t="7113">o</span> <span class=" txtu " t="7114">chieder</span> <span class=" txtu " t="7115">nuova</span> <span class=" txtu " t="7116">licenza</span><span class=" txtu " t="7117">,</span> <span class=" txtu " t="7118">
# </span><span class=" txtu " t="7119"> </span><span class=" txtu " t="7120">o</span> <span class=" txtu " t="7121">rinontiar</span> <span class=" txtu " t="7122">a</span> <span class=" txtu " t="7123">questo</span> <span class=" txtu " t="7124">servitio</span> <span class=" txtu " t="7125">totalmente</span><span class=" txtu " t="7126">.</span> <span class=" txtu " t="7127">Sua</span> <span class="es" enm="eccellenza⊙MISC"><span class="lgb">1</span><span class="eid ">eccellenza</span> <span class="kind ">MISC</span> <span class="n">180</span></span><span class=" ei  txtu " t="7128">Eccellenza</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="7129">
# </span><span class=" txtu " t="7130"> </span><span class=" txtu " t="7131">ha</span> <span class=" txtu " t="7132">posta</span> <span class=" txtu " t="7133">la</span> <span class=" txtu " t="7134">mano</span> <span class=" txtu " t="7135">con</span> <span class=" txtu " t="7136">gran</span> <span class=" txtu " t="7137">cuore</span> <span class=" txtu " t="7138">a</span> <span class=" txtu " t="7139">questo</span> <span class=" txtu " t="7140">servitio</span> <span class=" txtu " t="7141">
# </span><span class=" txtu " t="7142"> </span><span class=" txtu " t="7143">eccitato</span> <span class=" txtu " t="7144">dirò</span> <span class=" txtu " t="7145">così</span> <span class=" txtu " t="7146">anco</span> <span class=" txtu " t="7147">dalle</span> <span class=" txtu " t="7148">mie</span> <span class=" txtu " t="7149">instanze</span> <span class=" txtu " t="7150">perché</span> <span class=" txtu " t="7151">
# </span><span class=" txtu " t="7152"> </span><span class=" txtu " t="7153">il</span> <span class=" txtu " t="7154">signor</span> <span class="es" enm="conte.gio⊙PER"><span class="lgb">2</span><span class="eid ">conte.gio</span> <span class="kind ">PER</span> <span class="n">102</span></span><span class=" ei  txtu " t="7155">conte</span> <span class=" ei  txtu " t="7156">Gio</span><span class="ee"><span class="lge">2</span></span><span class=" txtu " t="7157">.</span> <span class="es" enm="ernesto⊙PER"><span class="lgb">1</span><span class="eid ">ernesto</span> <span class="kind ">PER</span> <span class="n">84</span></span><span class=" ei  txtu " t="7158">Ernesto</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="7159">potesse</span> <span class=" txtu " t="7160">haver</span> <span class=" txtu " t="7161">appresso</span> <span class=" txtu " t="7162">di</span> <span class=" txtu " t="7163">
# </span><span class=" txtu " t="7164"> </span><span class=" txtu " t="7165">lui</span> <span class=" txtu " t="7166">soggetto</span><span class=" txtu " t="7167">,</span> <span class=" txtu " t="7168">che</span> <span class=" txtu " t="7169">valesse</span> <span class=" txtu " t="7170">ad</span> <span class=" txtu " t="7171">assistergli</span> <span class=" txtu " t="7172">per</span> <span class=" txtu " t="7173">ogni</span> <span class=" txtu " t="7174">
# </span><span class=" txtu " t="7175"> </span><span class=" txtu " t="7176">accidente</span><span class=" txtu " t="7177">,</span> <span class=" txtu " t="7178">come</span> <span class=" txtu " t="7179">spero</span> <span class=" txtu " t="7180">che</span> <span class=" txtu " t="7181">valerà</span> <span class=" txtu " t="7182">esso</span> <span class=" txtu " t="7183">monsignor</span> <span class=" txtu " t="7184">di</span> <span class=" txtu " t="7185">

# %%
results = NE.filterContent(anyEnt=False, showStats=True)
# Out:
# 1230 chunks satisfy the filter
# Combined features match:
# Feature eid: found the following values:
# Feature kind: found the following values:
# 1230 chunks

# %%
NE.showContent(results, start=1115, end=1125)
# Out:
# <div class="buckets ltr"><div class="b ltr"><span class="bh ltr"><span node="286359" class="bhl ltr" title="show context">4@63:15</span></span> <span class="ltr"><span class=" txtu " t="246063">1617</span> <span class=" txtu " t="246064">a</span><span class=" txtu " t="246065">’</span> <span class=" txtu " t="246066">2</span> <span class=" txtu " t="246067">agosto</span> <span class=" txtu " t="246068">ricevute</span> <span class=" txtu " t="246069">a</span><span class=" txtu " t="246070">’</span> <span class=" txtu " t="246071">16</span> <span class=" txtu " t="246072">detto</span> <span class=" txtu " t="246073">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="286363" class="bhl ltr" title="show context">4@63:19</span></span> <span class="ltr"><span class=" txtu " t="246093">2</span><span class=" txtu " t="246094"> </span><span class=" txtu " t="246095">Come</span> <span class=" txtu " t="246096">pare</span><span class=" txtu " t="246097">.</span><span class=" txtu " t="246098">
# </span><span class=" txtu " t="246099">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="286365" class="bhl ltr" title="show context">4@63:21</span></span> <span class="ltr"><span class=" txtu " t="246108">4</span><span class=" txtu " t="246109"> </span><span class=" txtu " t="246110">Seguono</span> <span class=" txtu " t="246111">parole</span> <span class=" txtu " t="246112">depennate</span><span class=" txtu " t="246113">,</span> <span class=" txtu " t="246114">la</span> <span class=" txtu " t="246115">seconda</span> <span class=" txtu " t="246116">aggiunta</span> <span class=" txtu " t="246117">in</span> <span class=" txtu " t="246118">sopralinea</span> <span class=" txtu " t="246119">con</span> <span class=" txtu " t="246120">segno</span> <span class=" txtu " t="246121">di</span> <span class=" txtu " t="246122">inserimento</span><span class=" txtu " t="246123">.</span><span class=" txtu " t="246124">
# </span><span class=" txtu " t="246125">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="286385" class="bhl ltr" title="show context">4@64:14</span></span> <span class="ltr"><span class=" txtu " t="247790">humilissimo</span><span class=" txtu " t="247791">,</span> <span class=" txtu " t="247792">et</span> <span class=" txtu " t="247793">devotissimo</span> <span class=" txtu " t="247794">servitore</span> <span class=" txtu " t="247795">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="286388" class="bhl ltr" title="show context">4@64:17</span></span> <span class="ltr"><span class=" txtu " t="247806">prima</span> <span class=" txtu " t="247807">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="286391" class="bhl ltr" title="show context">4@64:20</span></span> <span class="ltr"><span class=" txtu " t="247814">8</span> <span class=" txtu " t="247815">agosto</span> <span class=" txtu " t="247816">1617</span> <span class=" txtu " t="247817">ricevute</span> <span class=" txtu " t="247818">a</span><span class=" txtu " t="247819">’</span> <span class=" txtu " t="247820">23</span> <span class=" txtu " t="247821">detto</span> <span class=" txtu " t="247822">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="286395" class="bhl ltr" title="show context">4@64:24</span></span> <span class="ltr"><span class=" txtu " t="247852">Segue</span> <span class=" txtu " t="247853">decodifica</span> <span class=" txtu " t="247854">di</span> <span class=" txtu " t="247855">testo</span> <span class=" txtu " t="247856">cifrato</span><span class=" txtu " t="247857">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="286398" class="bhl ltr" title="show context">4@64:27</span></span> <span class="ltr"><span class=" txtu " t="247890">3</span><span class=" txtu " t="247891"> </span><span class=" txtu " t="247892">seben</span> <span class=" txtu " t="247893">…</span> <span class=" txtu " t="247894">sodamente</span> <span class=" txtu " t="247895">il</span> <span class=" txtu " t="247896">zotto</span> <span class=" txtu " t="247897">decodifica</span> <span class=" txtu " t="247898">di</span> <span class=" txtu " t="247899">testo</span> <span class=" txtu " t="247900">cifrato</span> <span class=" txtu " t="247901">presente</span> <span class=" txtu " t="247902">a</span> <span class=" txtu " t="247903">c.</span> <span class=" txtu " t="247904">343r</span><span class=" txtu " t="247905">;</span> <span class=" txtu " t="247906">con</span> <span class=" txtu " t="247907">segno</span> <span class=" txtu " t="247908">di</span> <span class=" txtu " t="247909">rimando</span><span class=" txtu " t="247910">.</span><span class=" txtu " t="247911">
# </span><span class=" txtu " t="247912">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="286414" class="bhl ltr" title="show context">4@65:4</span></span> <span class="ltr"><span class=" txtu " t="248109">2</span><span class=" txtu " t="248110">da</span><span class=" txtu " t="248111">​</span> <span class=" txtu " t="248112">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="286424" class="bhl ltr" title="show context">4@65:14</span></span> <span class="ltr"><span class=" txtu " t="249889">humilissimo</span><span class=" txtu " t="249890">,</span> <span class=" txtu " t="249891">et</span> <span class=" txtu " t="249892">devotissimo</span> <span class=" txtu " t="249893">servitore</span> <span class=" txtu " t="249894">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="286428" class="bhl ltr" title="show context">4@65:18</span></span> <span class="ltr"><span class=" txtu " t="249908">2</span><span class=" txtu " t="249909">da</span> <span class=" txtu " t="249910">
# </span></span></div></div>

# %%
results = NE.filterContent(qTokens=qTokens, anyEnt=False, showStats=True)
# Out:
# 1230 chunks satisfy the filter
# Combined features match:
# 	    0 of     3 x
# Feature eid: found the following values:
# 	    0 of    16 x ernesto.di.nassau
# 	    0 of     3 x ⌀
# Feature kind: found the following values:
# 	    0 of    16 x PER
# 	    0 of     3 x ⌀
# 0 chunks

# %%
results = NE.filterContent(qTokens=qTokens, anyEnt=True, showStats=True)
# Out:
# 4955 chunks satisfy the filter
# Combined features match:
# 	    3 of     3 x
# 3 chunks

# %%
results = NE.filterContent(qTokens=qTokens, anyEnt=None, showStats=True)
# Out:
# 6185 chunks satisfy the filter
# Combined features match:
# 	    3 of     3 x
# Feature eid: found the following values:
# 	   16 of    16 x ernesto.di.nassau
# 	    3 of     3 x ⌀
# Feature kind: found the following values:
# 	   16 of    16 x PER
# 	    3 of     3 x ⌀
# 3 chunks

# %%
NE.showContent(results)
# Out:
# <div class="buckets ltr"><div class="b ltr"><span class="bh ltr"><span node="280935" class="bhl ltr" title="show context">3@1:62</span></span> <span class="ltr"><span class="es" enm="li.stati.generali.de.paesi.bassi.uniti⊙MISC"><span class="lgb">8</span><span class="eid ">li.stati.generali.de.paesi.bassi.uniti</span> <span class="kind ">MISC</span> <span class="n">2</span></span><span class=" ei  txtu " t="4433">Li</span> <span class=" ei  txtu " t="4434">Stati</span> <span class=" ei  txtu " t="4435">Generali</span> <span class=" ei  txtu " t="4436">de</span><span class=" ei  txtu " t="4437">’</span> <span class=" ei  txtu " t="4438">Paesi</span> <span class=" ei  txtu " t="4439">Bassi</span> <span class=" ei  txtu " t="4440">Uniti</span><span class="ee"><span class="lge">8</span></span><span class=" txtu " t="4441">.</span> <span class=" txtu " t="4442">Havendo</span> <span class=" txtu " t="4443">
# </span><span class=" txtu " t="4444"> </span><span class=" txtu " t="4445">nella</span> <span class=" txtu " t="4446">loro</span> <span class=" txtu " t="4447">assemblea</span> <span class=" txtu " t="4448">intesa</span> <span class=" txtu " t="4449">la</span> <span class=" txtu " t="4450">relatione</span> <span class=" txtu " t="4451">fatta</span> <span class=" txtu " t="4452">
# </span><span class=" txtu " t="4453"> </span><span class=" txtu " t="4454">alle</span> <span class=" txtu " t="4455">loro</span> <span class="es" enm="signorie⊙LOC"><span class="lgb">1</span><span class="eid ">signorie</span> <span class="kind ">LOC</span> <span class="n">80</span></span><span class=" ei  txtu " t="4456">Signorie</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="4457">il</span> <span class=" txtu " t="4458">giorno</span> <span class=" txtu " t="4459">de</span><span class=" txtu " t="4460">’</span> <span class=" txtu " t="4461">hieri</span> <span class=" txtu " t="4462">per</span> <span class=" txtu " t="4463">ordine</span> <span class=" txtu " t="4464">della</span> <span class=" txtu " t="4465">
# </span><span class=" txtu " t="4466"> </span><span class=" txtu " t="4467">serenissima</span> <span class=" txtu " t="4468">republica</span> <span class=" txtu " t="4469">di</span> <span class="es" enm="venetia⊙LOC"><span class="lgb">1</span><span class="eid ">venetia</span> <span class="kind ">LOC</span> <span class="n">158</span></span><span class=" ei  txtu " t="4470">Venetia</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="4471">dal</span> <span class=" txtu " t="4472">signor</span> <span class="es" enm="christofforo⊙LOC"><span class="lgb">1</span><span class="eid ">christofforo</span> <span class="kind ">LOC</span> <span class="n">1</span></span><span class=" ei  txtu " t="4473">Christofforo</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="4474">
# </span><span class=" txtu " t="4475"> </span><span class="es" enm="suriano⊙LOC"><span class="lgb">1</span><span class="eid ">suriano</span> <span class="kind ">LOC</span> <span class="n">16</span></span><span class=" ei  txtu " t="4476">Suriano</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="4477">residente</span> <span class=" txtu " t="4478">appresso</span> <span class=" txtu " t="4479">di</span> <span class=" txtu " t="4480">loro</span><span class=" txtu " t="4481">,</span> <span class=" txtu " t="4482">et</span> <span class=" txtu " t="4483">secretario</span> <span class=" txtu " t="4484">di</span> <span class=" txtu " t="4485">
# </span><span class=" txtu " t="4486"> </span><span class=" txtu " t="4487">stato</span><span class=" txtu " t="4488">​</span> <span class=" txtu " t="4489">della</span> <span class=" txtu " t="4490">detta</span> <span class="es" enm="serenissima.republica⊙LOC"><span class="lgb">2</span><span class="eid ">serenissima.republica</span> <span class="kind ">LOC</span> <span class="n">168</span></span><span class=" ei  txtu " t="4491">serenissima</span> <span class=" ei  txtu " t="4492">Republica</span> <span class="ee"><span class="lge">2</span></span><span class=" txtu " t="4493">in</span> <span class=" txtu " t="4494">virtù</span> <span class=" txtu " t="4495">delle</span> <span class=" txtu " t="4496">lettere</span> <span class=" txtu " t="4497">sue</span> <span class=" txtu " t="4498">credentiali</span> <span class=" txtu " t="4499">delli</span> <span class=" txtu " t="4500">15</span> <span class=" txtu " t="4501">del</span> <span class=" txtu " t="4502">mese</span> <span class=" txtu " t="4503">
# </span><span class=" txtu " t="4504"> </span><span class=" txtu " t="4505">presente</span><span class=" txtu " t="4506">,</span> <span class=" txtu " t="4507">dello</span> <span class=" txtu " t="4508">stato</span> <span class=" txtu " t="4509">degl’</span><span class=" txtu " t="4510">affari</span> <span class=" txtu " t="4511">di</span> <span class=" txtu " t="4512">lei</span> <span class=" txtu " t="4513">intorno</span> <span class=" txtu " t="4514">
# </span><span class=" txtu " t="4515"> </span><span class=" txtu " t="4516">alla</span> <span class=" txtu " t="4517">guerra</span><span class=" txtu " t="4518">,</span> <span class=" txtu " t="4519">ch’</span><span class=" txtu " t="4520">ella</span> <span class=" txtu " t="4521">sostiene</span> <span class=" txtu " t="4522">contra</span> <span class=" txtu " t="4523">il</span> <span class=" txtu " t="4524">serenissimo</span> <span class=" txtu " t="4525">
# </span><span class=" txtu " t="4526"> </span><span class=" txtu " t="4527">arciduca</span> <span class="es" enm="ferdinando.daustria⊙PER"><span class="lgb">3</span><span class="eid ">ferdinando.daustria</span> <span class="kind ">PER</span> <span class="n">2</span></span><span class=" ei  txtu " t="4528">Ferdinando</span> <span class=" ei  txtu " t="4529">d’</span><span class=" ei  txtu " t="4530">Austria</span><span class="ee"><span class="lge">3</span></span><span class=" txtu " t="4531">,</span> <span class=" txtu " t="4532">ringratiano</span> <span class=" txtu " t="4533">
# </span><span class=" txtu " t="4534"> </span><span class=" txtu " t="4535">affettuosamente</span> <span class=" txtu " t="4536">la</span> <span class=" txtu " t="4537">detta</span> <span class=" txtu " t="4538">serenissima</span> <span class="es" enm="republica⊙LOC"><span class="lgb">1</span><span class="eid ">republica</span> <span class="kind ">LOC</span> <span class="n">115</span></span><span class=" ei  txtu " t="4539">Republica</span> <span class="ee"><span class="lge">1</span></span><span class=" txtu " t="4540">della</span> <span class=" txtu " t="4541">
# </span><span class=" txtu " t="4542"> </span><span class=" txtu " t="4543">continuatione</span> <span class=" txtu " t="4544">di</span> <span class=" txtu " t="4545">questa</span> <span class=" txtu " t="4546">buona</span> <span class=" txtu " t="4547">corrispondenza</span> <span class=" txtu " t="4548">
# </span><span class=" txtu " t="4549"> </span><span class=" txtu " t="4550">rallegrandosi</span> <span class=" txtu " t="4551">del</span> <span class=" txtu " t="4552">buon</span> <span class=" txtu " t="4553">successo</span> <span class=" txtu " t="4554">del</span> <span class=" txtu " t="4555">detto</span> <span class=" txtu " t="4556">suo</span> <span class=" txtu " t="4557">affare</span> <span class=" txtu " t="4558">
# </span><span class=" txtu " t="4559"> </span><span class=" txtu " t="4560">fino</span> <span class=" txtu " t="4561">al</span> <span class=" txtu " t="4562">presente</span><span class=" txtu " t="4563">;</span> <span class=" txtu " t="4564">sperando</span><span class=" txtu " t="4565">,</span> <span class=" txtu " t="4566">come</span> <span class=" txtu " t="4567">lo</span> <span class=" txtu " t="4568">bramavano</span> <span class=" txtu " t="4569">
# </span><span class=" txtu " t="4570"> </span><span class=" txtu " t="4571">di</span> <span class=" txtu " t="4572">tutto</span> <span class=" txtu " t="4573">buon</span> <span class="

# %%
A = use("HuygensING/suriano")
NE = A.makeNer()
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv0.2=#g8629c73dfb877c14f87f7a1a19a326112de52bf0 offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/HuygensING/suriano/app</span>
# <b title="local release">data:</b> <span title="rv0.2=#g8629c73dfb877c14f87f7a1a19a326112de52bf0 offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/HuygensING/suriano/tf/0.0.2</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">TF API 12.1.2</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/about.md" title="provenance of HuygensING - suriano/tf">HuygensING - suriano 0.0.2</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="HuygensING - suriano feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>2</td>
#     <td>140029.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>130</td>
#     <td>2154.29</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>130</td>
#     <td>2093.35</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>130</td>
#     <td>2093.35</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>756</td>
#     <td>696.82</td>
#     <td><i>188</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>18</td>
#     <td>144.61</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>130</td>
#     <td>60.95</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>6185</td>
#     <td>45.09</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>130</td>
#     <td>48.32</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>6053</td>
#     <td>43.94</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>130</td>
#     <td>28.27</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>135</td>
#     <td>19.15</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>130</td>
#     <td>19.05</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>130</td>
#     <td>19.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>130</td>
#     <td>19.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>16009</td>
#     <td>16.69</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>236</td>
#     <td>14.11</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>130</td>
#     <td>10.63</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>130</td>
#     <td>10.63</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>130</td>
#     <td>10.63</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>130</td>
#     <td>9.27</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>1718</td>
#     <td>9.02</td>
#     <td>6</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>130</td>
#     <td>9.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>295</td>
#     <td>8.73</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>1</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>130</td>
#     <td>7.27</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>130</td>
#     <td>7.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>130</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>130</td>
#     <td>4.05</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>5307</td>
#     <td>3.86</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>130</td>
#     <td>3.63</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>130</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>130</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>260</td>
#     <td>2.52</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>260</td>
#     <td>2.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>260</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>130</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ent</th>
#     <td>16058</td>
#     <td>1.41</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>supplied</th>
#     <td>299</td>
#     <td>1.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>token</th>
#     <td>243694</td>
#     <td>1.00</td>
#     <td>87</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>130</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>17012</td>
#     <td>1.00</td>
#     <td>6</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>1542</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>1718</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>130</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>280058</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - suriano/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/text-fabric-data/github/HuygensING/suriano/tf/0.0.2/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/text-fabric-data/github/HuygensING/suriano/tf/0.0.2/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <span> number of a chunk within a document</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/text-fabric-data/github/HuygensING/suriano/tf/0.0.2/corresp.tf">corresp</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute corresp</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/text-fabric-data/github/HuygensING/suriano/tf/0.0.2/empty.tf">empty</a>
# </div>
# <div class="fmono">int</div>
#
# <span> whether a slot has been inserted in an empty element</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/text-fabric-data/github/HuygensING/suriano/tf/0.0.2/estr.tf">estr</a>
# </div>
# <div class="fmono">str</div>
#
# <span> </span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/text-fabric-data/github/HuygensING/suriano/tf/0.0.2/extraspace.tf">extraspace</a>
# </div>
# <div class="fmono">str</div>
#
# <span> whether a space has been added after a character, when it is in the direct child of a pure XML element</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/text-fabric-data/github/HuygensING/suriano/tf/0.0.2/file.tf">file</a>
# </div>
# <div class="fmono">str</div>
#
# <span> name of source file</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/text-fabric-data/github/HuygensING/suriano/tf/0.0.2/folder.tf">folder</a>
# </div>
# <div class="fmono">str</div>
#
# <span> name of source folder</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/text-fabr
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-co
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0.3rem;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
NE.setSet("power")
# Out:
# Annotation set power has 150 annotations

# %%
results = NE.filterContent(qTokens=qTokens, anyEnt=False, showStats=True)
# Out:
# 6067 chunks satisfy the filter
# Combined features match:
# 	   19 of    19 x
# Feature eid: found the following values:
# 	   19 of    19 x ⌀
# Feature kind: found the following values:
# 	   19 of    19 x ⌀
# 18 chunks

# %%
results = NE.filterContent(qTokens=qTokens, anyEnt=True, showStats=True)
# Out:
# 118 chunks satisfy the filter
# Combined features match:
# 	    0 of    19 x
# 0 chunks

# %%
results = NE.filterContent(qTokens=qTokens, anyEnt=None, showStats=True)
# Out:
# 6185 chunks satisfy the filter
# Combined features match:
# 	   19 of    19 x
# Feature eid: found the following values:
# 	   19 of    19 x ⌀
# Feature kind: found the following values:
# 	   19 of    19 x ⌀
# 18 chunks

# %%
results = NE.filterContent(bFind="paesi", bFindC=True, anyEnt=True, showStats=True)
# Out:
# 15 chunks satisfy the filter
# Combined features match:
# 15 chunks

# %%
NE.showContent(results, end=5)
# Out:
# <div class="buckets ltr"><div class="b ltr"><span class="bh ltr"><span node="281043" class="bhl ltr" title="show context">3@12:6</span></span> <span class="ltr"><span class=" txtu " t="8991">il</span> <span class=" txtu " t="8992">signor</span> <span class=" txtu " t="8993">Gio</span><span class=" txtu " t="8994">.</span> <span class=" txtu " t="8995">Battista</span> <span class=" txtu " t="8996">Pasini</span> <span class=" txtu " t="8997">mosso</span> <span class=" txtu " t="8998">dalla</span> <span class=" txtu " t="8999">riverente</span> <span class=" txtu " t="9000">devotione</span> <span class=" txtu " t="9001">
# </span><span class=" txtu " t="9002"> </span><span class=" txtu " t="9003">che</span> <span class=" txtu " t="9004">come</span> <span class=" txtu " t="9005">humilissimo</span> <span class=" txtu " t="9006">suddito</span> <span class=" txtu " t="9007">della</span> <span class=" txtu " t="9008">Serenità</span> <span class=" txtu " t="9009">vostra</span> <span class=" txtu " t="9010">le</span> <span class=" txtu " t="9011">professa</span> <span class=" txtu " t="9012">è</span> <span class=" txtu " t="9013">
# </span><span class=" txtu " t="9014"> </span><span class=" txtu " t="9015">venuto</span> <span class=" txtu " t="9016">a</span> <span class=" txtu " t="9017">me</span> <span class=" txtu " t="9018">da</span> <span class=" txtu " t="9019">Brusseles</span> <span class=" txtu " t="9020">per</span> <span class=" txtu " t="9021">darmi</span> <span class=" txtu " t="9022">notitia</span> <span class=" txtu " t="9023">a</span> <span class=" txtu " t="9024">bocca</span> <span class=" txtu " t="9025">
# </span><span class=" txtu " t="9026"> </span><span class=" txtu " t="9027">di</span> <span class=" txtu " t="9028">alcuni</span> <span class=" txtu " t="9029">soggetti</span><span class=" txtu " t="9030">,</span> <span class=" txtu " t="9031">che</span> <span class=" txtu " t="9032">hanno</span> <span class=" txtu " t="9033">attualmente</span> <span class=" txtu " t="9034">servito</span><span class=" txtu " t="9035">,</span> <span class=" txtu " t="9036">et</span> <span class=" txtu " t="9037">tuttora</span> <span class=" txtu " t="9038">
# </span><span class=" txtu " t="9039"> </span><span class=" txtu " t="9040">sono</span> <span class=" txtu " t="9041">trattenuti</span> <span class=" txtu " t="9042">dai</span> <span class=" txtu " t="9043">serenissimi</span> <span class="es" enm="isabella.clara.eugenia⊙PER"><span class="lgb">1</span><span class="eid ">isabella.clara.eugenia</span> <span class="kind ">PER</span> <span class="n">52</span></span><span class=" ei  txtu " t="9044">arciduchi</span><span class="ee"><span class="lge">1</span></span><span class=" txtu " t="9045">,</span> <span class=" txtu " t="9046">et</span> <span class=" txtu " t="9047">vivono</span> <span class=" txtu " t="9048">con</span> <span class=" txtu " t="9049">
# </span><span class=" txtu " t="9050"> </span><span class=" txtu " t="9051">desiderio</span> <span class=" txtu " t="9052">di</span><span class=" txtu " t="9053">​</span> <span class=" txtu " t="9054">impiegarsi</span><span class=" txtu " t="9055">​</span> <span class=" txtu " t="9056">per</span> <span class=" txtu " t="9057">quella</span> <span class=" txtu " t="9058">serenissima</span> <span class=" txtu " t="9059">Republica</span><span class=" txtu " t="9060">.</span> <span class=" txtu " t="9061">
# </span><span class=" txtu " t="9062"> </span><span class=" txtu " t="9063">Tra</span> <span class=" txtu " t="9064">questi</span> <span class=" txtu " t="9065">vi</span> <span class=" txtu " t="9066">è</span> <span class=" txtu " t="9067">un</span> <span class=" txtu " t="9068">cavallier</span> <span class=" txtu " t="9069">inglese</span> <span class=" txtu " t="9070">di</span> <span class=" txtu " t="9071">religione</span> <span class=" txtu " t="9072">
# </span><span class=" txtu " t="9073"> </span><span class=" txtu " t="9074">catholico</span> <span class=" txtu " t="9075">huomo</span> <span class=" txtu " t="9076">di</span> <span class=" txtu " t="9077">43</span> <span class=" txtu " t="9078">anni</span> <span class=" txtu " t="9079">in</span> <span class=" txtu " t="9080">circa</span> <span class=" txtu " t="9081">che</span> <span class=" txtu " t="9082">altre</span> <span class=" txtu " t="9083">volte</span> <span class=" txtu " t="9084">
# </span><span class=" txtu " t="9085"> </span><span class=" txtu " t="9086">ha</span> <span class=" found  txtu " t="9087">travagliato</span> <span class=" txtu " t="9088">in</span> <span class=" txtu " t="9089">questi</span> <span class=" txtu " t="9090">paesi</span> <span class=" txtu " t="9091">sotto</span> <span class=" txtu " t="9092">la</span> <span class=" txtu " t="9093">condotta</span> <span class=" txtu " t="9094">
# </span><span class=" txtu " t="9095"> </span><span class=" txtu " t="9096">di</span> <span class=" txtu " t="9097">quel</span> <span class=" txtu " t="9098">valoroso</span> <span class=" txtu " t="9099">colonello</span> <span class=" txtu " t="9100">Francesco</span> <span class=" txtu " t="9101">Ver</span><span class=" txtu " t="9102">.</span> <span class=" txtu " t="9103">Fu</span> <span class=" txtu " t="9104">
# </span><span class=" txtu " t="9105"> </span><span class=" txtu " t="9106">luogotenente</span> <span class=" txtu " t="9107">del</span> <span class=" txtu " t="9108">suo</span> <span class=" txtu " t="9109">colonellato</span><span class=" txtu " t="9110">;</span> <span class=" txtu " t="9111">servì</span> <span class=" txtu " t="9112">in</span> <span class=" txtu " t="9113">esso</span> <span class=" txtu " t="9114">per</span> <span class=" txtu " t="9115">
# </span><span class=" txtu " t="9116"> </span><span class=" txtu " t="9117">sergente</span> <span class=" txtu " t="9118">maggiore</span><span class=" txtu " t="9119">,</span> <span class=" txtu " t="9120">et</span> <span class=" txtu " t="9121">in</span> <span class=" txtu " t="9122">fine</span> <span class=" txtu " t="9123">n’</span><span class=" txtu " t="9124">hebbe</span> <span class=" txtu " t="9125">si</span> <span class=" txtu " t="9126">può</span> <span class=" txtu " t="9127">dir</span> <span class=" txtu " t="9128">
# </span><span class=" txtu " t="9129"> </span><span class=" txtu " t="9130">l’</span><span class=" txtu " t="9131">assoluto</span> <span class=" txtu " t="9132">commando</span> <span class=" txtu " t="9133">in</span> <span class=" txtu " t="9134">absenza</span> <span class=" txtu " t="9135">del</span> <span class=" txtu " t="9136">medesimo</span> <span class=" txtu " t="9137">Ver</span><span class=" txtu " t="9138">.</span> <span class=" txtu " t="9139">
# </span><span class=" txtu " t="9140"> </span><span class=" txtu " t="9141">Mosso</span> <span class=" txtu " t="9142">poi</span> <span class=" txtu " t="9143">da</span> <span class=" txtu " t="9144">qualche</span> <span class=" txtu " t="9145">alletamento</span> <span class=" txtu " t="9146">di</span> <span class=" txtu " t="9147">maggior</span> <span class=" txtu " t="9148">
# </span><span class=" txtu " t="9149"> </span><span class=" txtu " t="9150">avanzo</span><span class=" txtu " t="9151">,</span> <span class=" txtu " t="9152">che</span> <span class=" txtu " t="9153">gli</span> <span class=" txtu " t="9154">fu</span> <span class=" txtu " t="9155">proposto</span> <span class=" txtu " t="9156">dalla</span> <span class=" txtu " t="9157">parte</span> <span class=" txtu " t="9158">de-</span><span class=" txtu " t="9159">
# </span><span class=" txtu " t="9160"> </span><span class=" txtu " t="9161">gl’</span><span class="es" enm="isabella.clara.eugenia⊙PER"><span class="lgb">1</span><span class="eid ">isabella.clara.eugenia</span> <span class="kind ">PER</span> <span class="n">52</span></span><span class=" ei  txtu " t="9162">arciduchi</span><span class="ee"><span class="lge">1</span></span><span class=" txtu " t="9163">,</span> <span class=" txtu " t="9164">et</span> <span class=" txtu " t="9165">stimolato</span> <span class=" txtu " t="9

# %%
NE.showEntityOverview()
# Out:
# <p><span><code>  150</code> x <span><span class="kind ">PER</span></span></span><br></p>

# %%
NE.showEntities()
# Out:
# <p class="e " enm="isabella.clara.eugenia⊙PER"><code class="w">   52</code> x <span class="eid ">isabella.clara.eugenia</span> <span class="kind ">PER</span></p><p class="e " enm="john.vere⊙PER"><code class="w">   16</code> x <span class="eid ">john.vere</span> <span class="kind ">PER</span></p><p class="e " enm="francesco.giustiniani⊙PER"><code class="w">   11</code> x <span class="eid ">francesco.giustiniani</span> <span class="kind ">PER</span></p><p class="e " enm="erick.dimmer⊙PER"><code class="w">   11</code> x <span class="eid ">erick.dimmer</span> <span class="kind ">PER</span></p><p class="e " enm="leonardo.westerbeeck⊙PER"><code class="w">    8</code> x <span class="eid ">leonardo.westerbeeck</span> <span class="kind ">PER</span></p><p class="e " enm="pieter.adriaensz.pack⊙PER"><code class="w">    7</code> x <span class="eid ">pieter.adriaensz.pack</span> <span class="kind ">PER</span></p><p class="e " enm="cornelis.adriaensz⊙PER"><code class="w">    7</code> x <span class="eid ">cornelis.adriaensz</span> <span class="kind ">PER</span></p><p class="e " enm="bernard.scheffalitzky⊙PER"><code class="w">    4</code> x <span class="eid ">bernard.scheffalitzky</span> <span class="kind ">PER</span></p><p class="e " enm="anton.gunther.count⊙PER"><code class="w">    4</code> x <span class="eid ">anton.gunther.count</span> <span class="kind ">PER</span></p><p class="e " enm="philippe.bethune⊙PER"><code class="w">    3</code> x <span class="eid ">philippe.bethune</span> <span class="kind ">PER</span></p><p class="e " enm="gaspar.iii.coligny⊙PER"><code class="w">    3</code> x <span class="eid ">gaspar.iii.coligny</span> <span class="kind ">PER</span></p><p class="e " enm="steven.knoop⊙PER"><code class="w">    2</code> x <span class="eid ">steven.knoop</span> <span class="kind ">PER</span></p><p class="e " enm="simone.contarini⊙PER"><code class="w">    2</code> x <span class="eid ">simone.contarini</span> <span class="kind ">PER</span></p><p class="e " enm="michiel.pagani⊙PER"><code class="w">    2</code> x <span class="eid ">michiel.pagani</span> <span class="kind ">PER</span></p><p class="e " enm="johan.mario.genaamd⊙PER"><code class="w">    2</code> x <span class="eid ">johan.mario.genaamd</span> <span class="kind ">PER</span></p><p class="e " enm="francois.doubleth⊙PER"><code class="w">    2</code> x <span class="eid ">francois.doubleth</span> <span class="kind ">PER</span></p><p class="e " enm="erycius.puteanus⊙PER"><code class="w">    2</code> x <span class="eid ">erycius.puteanus</span> <span class="kind ">PER</span></p><p class="e " enm="volrat.plessen⊙PER"><code class="w">    1</code> x <span class="eid ">volrat.plessen</span> <span class="kind ">PER</span></p><p class="e " enm="sir.william.brog⊙PER"><code class="w">    1</code> x <span class="eid ">sir.william.brog</span> <span class="kind ">PER</span></p><p class="e " enm="philips.levin.heer⊙PER"><code class="w">    1</code> x <span class="eid ">philips.levin.heer</span> <span class="kind ">PER</span></p><p class="e " enm="jacobus.arminius⊙PER"><code class="w">    1</code> x <span class="eid ">jacobus.arminius</span> <span class="kind ">PER</span></p><p class="e " enm="hans.meinhard⊙PER"><code class="w">    1</code> x <span class="eid ">hans.meinhard</span> <span class="kind ">PER</span></p><p class="e " enm="david.marlot⊙PER"><code class="w">    1</code> x <span class="eid ">david.marlot</span> <span class="kind ">PER</span></p><p class="e " enm="cesar.vendome⊙PER"><code class="w">    1</code> x <span class="eid ">cesar.vendome</span> <span class="kind ">PER</span></p><p class="e " enm="captain.seton⊙PER"><code class="w">    1</code> x <span class="eid ">captain.seton</span> <span class="kind ">PER</span></p><p class="e " enm="antonio.maria.vincenti⊙PER"><code class="w">    1</code> x <span class="eid ">antonio.maria.vincenti</span> <span class="kind ">PER</span></p><p class="e " enm="antonio.lando⊙PER"><code class="w">    1</code> x <span class="eid ">antonio.lando< ...

# %%
NE.setSet("")
# Out:
# Annotation set ent-nodes has 16058 annotations

# %%
NE.showEntityOverview()
# Out:
# <p><span><code> 6091</code> x <span><span class="kind ">PER</span></span></span><br><span><code> 5628</code> x <span><span class="kind ">LOC</span></span></span><br><span><code> 3629</code> x <span><span class="kind ">MISC</span></span></span><br><span><code>  710</code> x <span><span class="kind ">ORG</span></span></span><br></p>

# %%
NE.showEntities(sortKey="sort_kind", cutOffFreq=10)
# Out:
# <p class="e " enm="serenità⊙LOC"><code class="w">  406</code> x <span class="eid ">serenità</span> <span class="kind ">LOC</span></p><p class="e " enm="christofforo.suriano⊙LOC"><code class="w">  260</code> x <span class="eid ">christofforo.suriano</span> <span class="kind ">LOC</span></p><p class="e " enm="francia⊙LOC"><code class="w">  185</code> x <span class="eid ">francia</span> <span class="kind ">LOC</span></p><p class="e " enm="serenissima.republica⊙LOC"><code class="w">  168</code> x <span class="eid ">serenissima.republica</span> <span class="kind ">LOC</span></p><p class="e " enm="venetia⊙LOC"><code class="w">  158</code> x <span class="eid ">venetia</span> <span class="kind ">LOC</span></p><p class="e " enm="stati⊙LOC"><code class="w">  157</code> x <span class="eid ">stati</span> <span class="kind ">LOC</span></p><p class="e " enm="altezza⊙LOC"><code class="w">  135</code> x <span class="eid ">altezza</span> <span class="kind ">LOC</span></p><p class="e " enm="transcription⊙LOC"><code class="w">  130</code> x <span class="eid ">transcription</span> <span class="kind ">LOC</span></p><p class="e " enm="venice⊙LOC"><code class="w">  130</code> x <span class="eid ">venice</span> <span class="kind ">LOC</span></p><p class="e " enm="stato.di.venezia⊙LOC"><code class="w">  130</code> x <span class="eid ">stato.di.venezia</span> <span class="kind ">LOC</span></p><p class="e " enm="senato⊙LOC"><code class="w">  130</code> x <span class="eid ">senato</span> <span class="kind ">LOC</span></p><p class="e " enm="dispacci⊙LOC"><code class="w">  130</code> x <span class="eid ">dispacci</span> <span class="kind ">LOC</span></p><p class="e " enm="dallhaya⊙LOC"><code class="w">  121</code> x <span class="eid ">dallhaya</span> <span class="kind ">LOC</span></p><p class="e " enm="amsterdam⊙LOC"><code class="w">  117</code> x <span class="eid ">amsterdam</span> <span class="kind ">LOC</span></p><p class="e " enm="republica⊙LOC"><code class="w">  115</code> x <span class="eid ">republica</span> <span class="kind ">LOC</span></p><p class="e " enm="inghilterra⊙LOC"><code class="w">  101</code> x <span class="eid ">inghilterra</span> <span class="kind ">LOC</span></p><p class="e " enm="spagna⊙LOC"><code class="w">   95</code> x <span class="eid ">spagna</span> <span class="kind ">LOC</span></p><p class="e " enm="signorie⊙LOC"><code class="w">   80</code> x <span class="eid ">signorie</span> <span class="kind ">LOC</span></p><p class="e " enm="paese⊙LOC"><code class="w">   77</code> x <span class="eid ">paese</span> <span class="kind ">LOC</span></p><p class="e " enm="italia⊙LOC"><code class="w">   76</code> x <span class="eid ">italia</span> <span class="kind ">LOC</span></p><p class="e " enm="haya⊙LOC"><code class="w">   75</code> x <span class="eid ">haya</span> <span class="kind ">LOC</span></p><p class="e " enm="stato⊙LOC"><code class="w">   64</code> x <span class="eid ">stato</span> <span class="kind ">LOC</span></p><p class="e " enm="foro⊙LOC"><code class="w">   60</code> x <span class="eid ">foro</span> <span class="kind ">LOC</span></p><p class="e " enm="m⊙LOC"><code class="w">   57</code> x <span class="eid ">m</span> <span class="kind ">LOC</span></p><p class="e " enm="spagnoli⊙LOC"><code class="w">   57</code> x <span class="eid ">spagnoli</span> <span class="kind ">LOC</span></p><p class="e " enm="tessel⊙LOC"><code class="w">   54</code> x <span class="eid ">tessel</span> <span class="kind ">LOC</span></p><p class="e " enm="spagnuoli⊙LOC"><code class="w">   50</code> x <span class="eid ">spagnuoli</span> <span class="kind ">LOC</span></p><p class="e " enm="alemagna⊙LOC"><code class="w">   49</code> x <span class="eid ">alemagna</span> <span class="kind ">LOC</span></p><p class="e " enm="wassonhoven⊙LOC"><code class="w">   45</code> x <span class="eid ">wassonhoven</span> <span class="kind ">LOC</span></p><p class="e " enm="ghent⊙LOC"><code class="w">   37</code> x <span class="eid ">ghent</span> <span class="kind ">LOC</span> ...

# %%
NE.setSet("testmod")
NE.resetSet()
# Out:
# Annotation set testmod has 15 annotations
# Annotation set testmod has 0 annotations

# %%
qTokens = ("Gio", ".", "Ernesto", "di", "Nassau")
results = NE.filterContent(qTokens=qTokens, showStats=None)
# Out:
# 15 chunks

# %%
NE.addEntityRich([["gio.ernesto.di.nassau"], ["PER"]], results)
# Out:
# Added    15 x eid=gio.ernesto.di.nassau kind=PER

# %%
NE.addEntityRich(("gio.ernesto.di.nassau2", "PER2"), results)
# Out:
# Added    15 x eid=gio.ernesto.di.nassau2 kind=PER2

# %%
NE.showEntities()
# Out:
# <p class="e " enm="gio.ernesto.di.nassau2⊙PER2"><code class="w">   15</code> x <span class="eid ">gio.ernesto.di.nassau2</span> <span class="kind ">PER2</span></p><p class="e " enm="gio.ernesto.di.nassau⊙PER"><code class="w">   15</code> x <span class="eid ">gio.ernesto.di.nassau</span> <span class="kind ">PER</span></p>

# %%
NE.addEntity(("test.xxx", "YYY"), [tuple(range(100, 105)), tuple(range(120, 125))], silent=False)
# Out:
# Already present:     0 x
# Added:               2 x

# %%
NE.showEntities()
# Out:
# <p class="e " enm="gio.ernesto.di.nassau2⊙PER2"><code class="w">   15</code> x <span class="eid ">gio.ernesto.di.nassau2</span> <span class="kind ">PER2</span></p><p class="e " enm="gio.ernesto.di.nassau⊙PER"><code class="w">   15</code> x <span class="eid ">gio.ernesto.di.nassau</span> <span class="kind ">PER</span></p><p class="e " enm="test.xxx⊙YYY"><code class="w">    2</code> x <span class="eid ">test.xxx</span> <span class="kind ">YYY</span></p>

# %%
results = NE.filterContent(anyEnt=True, showStats=True)
# Out:
# 15 chunks satisfy the filter
# Combined features match:
# 15 chunks

# %%
NE.showContent(results)
# Out:
# <div class="buckets ltr"><div class="b ltr"><span class="bh ltr"><span node="280877" class="bhl ltr" title="show context">3@1:4</span></span> <span class="ltr"><span class=" txtu " t="79">Havendo</span> <span class=" txtu " t="80">il</span> <span class=" txtu " t="81">signor</span> <span class=" txtu " t="82">conte</span> <span class="es" enm="gio.ernesto.di.nassau⊙PER"><span class="lgb">5</span><span class="eid ">gio.ernesto.di.nassau</span> <span class="kind ">PER</span> <span class="n">15</span></span><span class="es" enm="gio.ernesto.di.nassau2⊙PER2"><span class="lgb">5</span><span class="eid ">gio.ernesto.di.nassau2</span> <span class="kind ">PER2</span> <span class="n">15</span></span><span class=" ei  txtu " t="83">Gio</span><span class=" ei  txtu " t="84">.</span> <span class=" ei  txtu " t="85">Ernesto</span> <span class=" ei  txtu " t="86">di</span> <span class=" ei  txtu " t="87">Nassau</span> <span class="ee"><span class="lge">5</span></span><span class="ee"><span class="lge">5</span></span><span class=" txtu " t="88">li</span> <span class=" txtu " t="89">giorni</span> <span class=" txtu " t="90">passati</span> <span class=" txtu " t="91">
# </span><span class=" txtu " t="92"> </span><span class=" txtu " t="93">fatto</span> <span class=" txtu " t="94">offerta</span> <span class=" txtu " t="95">al</span> <span class=" txtu " t="96">clarissimo</span> <span class=" txtu " t="97">signor</span> <span class=" txtu " t="98">Christofforo</span> <span class=" txtu " t="99">Suriano</span> <span class="es" enm="test.xxx⊙YYY"><span class="lgb">5</span><span class="eid ">test.xxx</span> <span class="kind ">YYY</span> <span class="n">2</span></span><span class=" ei  txtu " t="100">secretario</span> <span class=" ei  txtu " t="101">della</span> <span class=" ei  txtu " t="102">serenissima</span> <span class=" ei  txtu " t="103">
# </span><span class=" ei  txtu " t="104"> </span><span class="ee"><span class="lge">5</span></span><span class=" txtu " t="105">republica</span> <span class=" txtu " t="106">di</span> <span class=" txtu " t="107">Venetia</span> <span class=" txtu " t="108">residente</span> <span class=" txtu " t="109">per</span> <span class=" txtu " t="110">essa</span> <span class=" txtu " t="111">appresso</span> <span class=" txtu " t="112">li</span> <span class=" txtu " t="113">signori</span> <span class=" txtu " t="114">Stati</span> <span class=" txtu " t="115">Generali</span> <span class=" txtu " t="116">
# </span><span class=" txtu " t="117"> </span><span class=" txtu " t="118">dello</span> <span class=" txtu " t="119">Provincie</span> <span class="es" enm="test.xxx⊙YYY"><span class="lgb">5</span><span class="eid ">test.xxx</span> <span class="kind ">YYY</span> <span class="n">2</span></span><span class=" ei  txtu " t="120">Unite</span> <span class=" ei  txtu " t="121">de</span><span class=" ei  txtu " t="122">’</span> <span class=" ei  txtu " t="123">Paesi</span> <span class=" ei  txtu " t="124">Bassi</span> <span class="ee"><span class="lge">5</span></span><span class=" txtu " t="125">di</span> <span class=" txtu " t="126">andar</span> <span class=" txtu " t="127">in</span> <span class=" txtu " t="128">persona</span> <span class=" txtu " t="129">al</span> <span class=" txtu " t="130">servitio</span> <span class=" txtu " t="131">
# </span><span class=" txtu " t="132"> </span><span class=" txtu " t="133">di</span> <span class=" txtu " t="134">detta</span> <span class=" txtu " t="135">serenissima</span> <span class=" txtu " t="136">Republica</span> <span class=" txtu " t="137">colla</span> <span class=" txtu " t="138">condotta</span> <span class=" txtu " t="139">di</span> <span class=" txtu " t="140">quel</span> <span class=" txtu " t="141">numero</span> <span class=" txtu " t="142">di</span> <span class=" txtu " t="143">genti</span> <span class=" txtu " t="144">da</span> <span class=" txtu " t="145">
# </span><span class=" txtu " t="146"> </span><span class=" txtu " t="147">piedi</span><span class=" txtu " t="148">,</span> <span class=" txtu " t="149">che</span> <span class=" txtu " t="150">fusse</span> <span class=" txtu " t="151">stabilita</span> <span class=" txtu " t="152">et</span> <span class=" txtu " t="153">aggradita</span> <span class=" txtu " t="154">da</span> <span class=" txtu " t="155">sua</span> <span class=" txtu " t="156">Serenità</span><span class=" txtu " t="157">,</span> <span class=" txtu " t="158">alla</span> <span class=" txtu " t="159">quale</span> <span class=" txtu " t="160">
# </span><span class=" txtu " t="161"> </span><span class=" txtu " t="162">havendo</span> <span class=" txtu " t="163">il</span> <span class=" txtu " t="164">medesimo</span> <span class=" txtu " t="165">signor</span> <span class=" txtu " t="166">secretario</span> <span class=" txtu " t="167">rappresentato</span> <span class=" txtu " t="168">il</span> <span class=" txtu " t="169">tutto</span><span class=" txtu " t="170">,</span> <span class=" txtu " t="171">et</span> <span class=" txtu " t="172">mandate</span> <span class=" txtu " t="173">
# </span><span class=" txtu " t="174"> </span><span class=" txtu " t="175">diverse</span> <span class=" txtu " t="176">conditioni</span><span class=" txtu " t="177">,</span> <span class=" txtu " t="178">colle</span> <span class=" txtu " t="179">quali</span> <span class=" txtu " t="180">il</span> <span class=" txtu " t="181">detto</span> <span class=" txtu " t="182">signor</span> <span class=" txtu " t="183">Conte</span> <span class=" txtu " t="184">intendeva</span><span class=" txtu " t="185">,</span> <span class=" txtu " t="186">et</span> <span class=" txtu " t="187">s’</span><span class=" txtu " t="188">obli-</span><span class=" txtu " t="189">
# </span><span class=" txtu " t="190"> </span><span class=" txtu " t="191">gava</span> <span class=" txtu " t="192">di</span> <span class=" txtu " t="193">passar</span> <span class=" txtu " t="194">a</span> <span class=" txtu " t="195">quel</span> <span class=" txtu " t="196">servitio</span><span class=" txtu " t="197">,</span> <span class=" txtu " t="198">col</span> <span class=" txtu " t="199">ritorno</span> <span class=" txtu " t="200">della</span> <span class=" txtu " t="201">risposta</span> <span class=" txtu " t="202">esso</span> <span class=" txtu " t="203">
# </span><span class=" txtu " t="204"> </span><span class=" txtu " t="205">signor</span> <span class=" txtu " t="206">secretario</span> <span class=" txtu " t="207">facendo</span> <span class=" txtu " t="208">per</span> <span class=" txtu " t="209">nome</span> <span class=" txtu " t="210">della</span> <span class=" txtu " t="211">detta</span> <span class=" txtu " t="212">serenissima</span> <span class=" txtu " t="213">Republica</span> <span class=" txtu " t="214">et</span> <span class=" txtu " t="215">detto</span> <span class=" txtu " t="216">signor</span> <span class=" txtu " t="217">
# </span><span class=" txtu " t="218"> </span><span class=" txtu " t="219">Conte</span> <span class=" txtu " t="220">per</span> <span class=" txtu " t="221">nome</span> <span class=" txtu " t="222">de</span> <span class=" txtu " t="223">sé</span> <span class=" txtu " t="224">stesso</span><span class=" txtu " t="225">,</span> <span class=" txtu " t="226">hanno</span> <span class=" txtu " t="227">insieme</span> <span class=" txtu " t="228">concluso</span> <span class=" txtu " t="229">et</span> <span class=" txtu " t="230">stabilito</span> <span class=" txtu " t="231">
# </span><span class=" txtu " t="232"> </span><span class=" txtu " t="233">gl’</span><span class=" txtu " t="234">articoli</span><span class=" txtu " t="235">,</span> <span class=" txtu " t="236">conditioni</span> <span class=" txtu " t="237">et</span> <span class=" txtu " t="238">oblighi</span> <span class=" txtu " t="239">reciprocamente</span> <span class=" txtu " t="240">come</span> <span class=" txtu " t="241">segue</span><span class=" txtu " t="242">.</span> <span class=" txtu " t="243">
# </span></span></div><div class="b ltr"><span class="bh ltr"><span node="280900" class="bhl

# %%
eVals = ("gio.ernesto.di.nassau2", "PER2")

results = NE.filterContent(eVals=eVals, showStats=True)
# Out:
# 6185 chunks satisfy the filter
# Combined features match:
# 	   15 of    15 x
# Feature eid: found the following values:
# 	   15 of    15 x PER2
# 	   15 of    15 x gio.ernesto.di.nassau2
# Feature kind: found the following values:
# 	   15 of    15 x PER2
# 	   15 of    15 x gio.ernesto.di.nassau2
# 15 chunks

# %%
NE.delEntityRich(eVals, results)
# Out:
# Deleted    15 x eid=gio.ernesto.di.nassau2 kind=PER2

# %%
NE.showEntities()
# Out:
# <p class="e " enm="gio.ernesto.di.nassau⊙PER"><code class="w">   15</code> x <span class="eid ">gio.ernesto.di.nassau</span> <span class="kind ">PER</span></p><p class="e " enm="test.xxx⊙YYY"><code class="w">    2</code> x <span class="eid ">test.xxx</span> <span class="kind ">YYY</span></p>

# %%
NE.delEntity(
    ("test.xxx", "YYY"),
    allMatches=[tuple(range(100, 105)), tuple(range(120, 125))],
    silent=False
)
# Out:
# Not present:     0 x
# Deleted:         2 x

# %%
NE.showEntities()
# Out:
# <p class="e " enm="gio.ernesto.di.nassau⊙PER"><code class="w">   15</code> x <span class="eid ">gio.ernesto.di.nassau</span> <span class="kind ">PER</span></p>

# %%
NE.delEntity(("test.xxx", "YYY"), silent=False)
# Out:
# Not present:     0 x
# Deleted:         0 x

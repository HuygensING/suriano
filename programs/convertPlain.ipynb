# %% [markdown]
# # Convert from DOCX to TEI to TF to WATM
#
# We convert Suriano DOCX to TEI to TF and then to WATM.
#
# This notebook provides three levels of refinement in the execution. They all have the same outcome,
# but they differ in the level of detail they provide on the conversion.
#
# These are the levels:
#
# * **Debugging**: all the commands directly in Python, the intermediate data remains in memory and can  be inspected.
# * **Step by step**: one command for each main step of the conversion;
# * **Express**: one single command on the command line for the complete conversion;

# %% [markdown]
# # Production or development
#
# Mosts steps are unaffected by the production/development setting.
#
# In the first steps of the pipeline (*ingest* and *scan processing*) we prepare both the dev and the prod data.
#
# The intermediate steps (*from DOCX to TEI*, *from TEI to TF*, *mark named entities*) are identical for prod and dev.
#
# Only for the latter steps (*convert TF to WATM*, generate IIIF manifests*, *deploy to k8s*) there is a distinction between prod and dev.
#
# For these steps we have commented out the line that does the dev version.

# %% [markdown]
# # Requirements
#
# * zsh as command line shell (as in macOS);
# * access to suitable k8s clusters, streamlined by the
#   [k-suite](https://code.huc.knaw.nl/tt/smart-k8s/-/blob/main/docs/k-suite.md);
# * [Pandoc](https://pandoc.org)
# * [Imagemagick](https://imagemagick.org)
# * [Python](https://www.python.org) (3.12 or higher) with additional pip-installable modules:
#   * text-fabric
#   * doc2python
#   * openpyxl

# %% [markdown]
# # Declare the version
#
# Always set the version before running any cell in this notebook!

# %%
VERSION = "2.1.0"

# %% [markdown]
# # In debugging mode.
#
# Now we dig a bit deeper, en do all the steps while keeping the program in memory.
# Now it becomes doable to inspect all intermediate results.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tff.convert.tei import TEI
from tff.convert.watm import WATM
from tff.convert.iiif import IIIF
from tf.advanced.helpers import dm

from processscans import Scans
from processdocs import TeiFromDocx
from bakeEntTei import BakeEntTei
from processhelpers import setStage, nerMeta, NER_NAME, SOURCEBASE, REPORT_PAGESDIR, REPORT_TEIDIR

# %% [markdown]
# ## Step 1: Scan processing

# %%
SC = Scans(silent=False, force=False)

# %%
SC.process()
# Out:
# Already present: sizes file originals (covers)
# Already present: sizes file originals (pages)
# Already present: thumbnails (covers)
# Already present: sizes file thumbnails (covers)
# Already present: thumbnails (pages)
# Already present: sizes file thumbnails (pages)

# %% [markdown]
# ## Step 2: From DOCX to TEI

# %% [markdown]
# You might need to do
#
# ```
# pip install docx2python
# ```

# %%
TFD = TeiFromDocx(silent=False)

# %%
TFD.task("pandoc")
# Out:
# DOCX => simple TEI per filza ...
# 	02.docx ... uptodate
# 	03.docx ... uptodate
# 	04.docx ... uptodate
# 	05.docx ... uptodate
# 	06.docx ... uptodate
# 	07.docx ... uptodate
# 	08.docx ... uptodate
# 	09.docx ... uptodate
# 	09b.docx ... uptodate
# 	10.docx ... uptodate
# 	11.docx ... uptodate
# 	12.docx ... uptodate

# %%
TFD.task("headers")
# Out:
# DOCX => headers ...
# 	02.docx
# 	03.docx
# 	04.docx
# 	05.docx
# 	06.docx
# 	07.docx
# 	08.docx
# 	09.docx
# 	09b.docx
# 	10.docx
# 	11.docx
# 	12.docx
# 	OK: All headers are OK
# Angelo              : 1181 pages in 11 filzas
# Cristina            : 1034 pages in 10 filzas
# Federica            : 684 pages in  7 filzas
# Filippo             : 1084 pages in  9 filzas
# Flavia              : 1282 pages in 11 filzas
# Giorgia             : 934 pages in  9 filzas
# Renzo               :  56 pages in  1 filza
# Ruben               : 1162 pages in 10 filzas
# Vera                : 966 pages in 10 filzas
# Vera, Federica      : 210 pages in  1 filza
# uuu_vvv             :  60 pages in  1 filza
# xxx_yyy             : 122 pages in  1 filza

# %%
TFD.task("tei")
# Out:
# Collecting transcribers ...
# Collecting page scans ...
#   0 x error
# 8952 x good
# Collecting excel metadata ...
# 	found metadata for 750 letters
# 	in filzas 02, 03, 04, 05, 06, 07, 08, 09, 09b, 10, 11, 12
# simple TEI per filza => enriched TEI per letter ...
# 	02.xml
# 	03.xml
# 	04.xml
# 	05.xml
# 	06.xml
# 	07.xml
# 	08.xml
# 	09.xml
# 	09b.xml
# 	10.xml
# 	11.xml
# 	12.xml
# Translated italian editorial phrases (218 x 14369)
# Metadata in summary file corresponds to transcribed letters
# 0 page warnings
# 0 warnings
# 09b: 025bisr: transcription but no scan
# 09b: 025bisv: transcription but no scan
# 09b: 059bisr: transcription but no scan
# 09b: 059bisv: transcription but no scan
# 09b: 078bisr: transcription but no scan
# 09b: 078bisv: transcription but no scan
# Pages with    transcription and    scan:       8948
# Pages with    transcription and missing scan:     6
# Pages with    transcription and no scan:          0
# Pages with no transcription and    scan:          0
# See ~/github/HuygensING/suriano/report/pages/pagescan.tsv

# %% [markdown]
# ## Step 3: From TEI to TF
#
# ### Check the validity of the TEI.

# %%
Tei = TEI(verbose=-1, sourceBase=SOURCEBASE, teiDir="tei-bare", reportDir=REPORT_TEIDIR, tei="", tf=VERSION)

# %%
Tei.task(check=1, verbose=1, validate=True)
# Out:
# TEI to TF checking: ~/github/HuygensING/suriano/datasource/tei-bare => ~/github/HuygensING/suriano/report/tei
# Processing instructions are ignored
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# INFO: Needs dcr.xsd (exists)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   1 changing override(s)
# 	metamark mixed ==> pure
# Section model I
# 	Start folder 02
# 	Start folder 03
# 	Start folder 04
# 	Start folder 05
# 	Start folder 06
# 	Start folder 07
# 	Start folder 08
# 	Start folder 09
# 	Start folder 09b
# 	Start folder 10
# 	Start folder 11
# 	Start folder 12
# 750 suriano file(s) ...
# 	Validating ...
# 	Making inventory ...
#
# 584 tag(s) type info written to ~/github/HuygensING/suriano/report/tei/types.txt
# Validation OK
# 0 pagebreaks without facs attribute.
# 8952 pagebreaks encountered.
# 8952 distinct scans referred to by pagebreaks.
# 41 tags of which 0 with multiple namespaces written to ~/github/HuygensING/suriano/report/tei/namespaces.txt
# 9184 info line(s) written to ~/github/HuygensING/suriano/report/tei/elements.txt
# Refs written to ~/github/HuygensING/suriano/report/tei/refs.txt
# 	resolvable: 11991 in 11991
# 	dangling:      0 in    0
# 	ALL:        11991 in 11991
# Ids written to ~/github/HuygensING/suriano/report/tei/ids.txt
# 	referenced: 11991 by 11991
# 	non-unique:    0
# 	unused:     1509
# 	ALL:        13500 in 13500
# lb-parent info written to ~/github/HuygensING/suriano/report/tei/lb-parents.txt
# True

# %% [markdown]
# ### Convert the data

# %%
Tei.good = True
Tei.task(convert=True, verbose=0)
# Out:
# Line model II with ln nodes for lines between lb elements
# Page model II with page nodes for pages started by pb elements  keeping the pb elements
# Section model I
# Processing instructions are ignored
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   1 changing override(s)
# 	metamark mixed ==> pure
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# 	Start folder 02:
# 		   1 suriano                                001.xml
# 		   2 suriano                                002.xml
# 		   3 suriano                                003.xml
# 		   4 suriano                                004.xml
# 		   5 suriano                                005.xml
# 		  19 suriano                                019.xml
# End   folder 02
# 	Start folder 03:
# 		  20 suriano                                001.xml
# 		  21 suriano                                002.xml
# 		  22 suriano                                003.xml
# 		  23 suriano                                004.xml
# 		  24 suriano                                005.xml
# 		  74 suriano                                055.xml
# End   folder 03
# 	Start folder 04:
# 		  75 suriano                                001.xml
# 		  76 suriano                                002.xml
# 		  77 suriano                                003.xml
# 		  78 suriano                                004.xml
# 		  79 suriano                                005.xml
# 		 149 suriano                                075.xml
# End   folder 04
# 	Start folder 05:
# 		 150 suriano                                001.xml
# 		 151 suriano                                002.xml
# 		 152 suriano                                003.xml
# 		 153 suriano                                004.xml
# 		 154 suriano                                005.xml
# 		 206 suriano                                057.xml
# End   folder 05
# 	Start folder 06:
# 		 207 suriano                                001.xml
# 		 208 suriano                                002.xml
# 		 209 suriano                                003.xml
# 		 210 suriano                                004.xml
# 		 211 suriano                                005.xml
# 		 246 suriano                                040.xml
# End   folder 06
# 	Start folder 07:
# 		 247 suriano                                001.xml
# 		 248 suriano                                002.xml
# 		 249 suriano                                003.xml
# 		 250 suriano                                004.xml
# 		 251 suriano                                005.xml
# 		 293 suriano                                047.xml
# End   folder 07
# 	Start folder 08:
# 		 294 suriano                                001.xml
# 		 295 suriano                                002.xml
# 		 296 suriano                                003.xml
# 		 297 suriano                                004.xml
# 		 298 suriano                                005.xml
# 		 384 suriano                                091.xml
# End   folder 08
# 	Start folder 09:
# 		 385 suriano                                001.xml
# 		 386 suriano                                002.xml
# 		 387 suriano                                003.xml
# 		 388 suriano                                004.xml
# 		 389 suriano                                005.xml
# 		 478 suriano                                094.xml
# End   folder 09
# 	Start folder 09b:
# 		 479 suriano                                001.xml
# 		 480 suriano                                002.xml
# 		 481 suriano                                003.xml
# 		 482 suriano                                004.xml
# 		 483 suriano                                005.xml
# 		 503 suriano                                025.xml
# End   folder 09b
# 	Start folder 10:
# 		 504 suriano                                001.xml
# 		 505 suriano                                002.xml
# 		 506 suriano                                003.xml
# 		 507 suriano                                004.xml
# 		 508 suriano                                005.xml
# 		 603 suriano                                100.xml
# End   folder 10
# 	Start folder 11:
# 		 604 suriano                                001.xml
# 		 605 suriano                                002.xml
# 		 606 suriano                                003.xml
# 		 607 suriano                                004.xml
# 		 608 suriano                                005.xml
# 		 704 suriano                                101.xml
# End   folder 11
# 	Start folder 12:
# 		 705 suriano                                001.xml
# 		 706 suriano                                002.xml
# 		 707 suriano                                003.xml
# 		 708 suriano                                004.xml
# 		 709 suriano                                005.xml
# 		 750 suriano                                046.xml
# End   folder 12
#
# Resolving links into edges ...
# 	3941 in 11991 reference(s) resolved
#    |       11s "delete" actions: 0
#    |       11s "edge" actions: 11991
#    |       11s "feature" actions: 2806779
#    |       11s "node" actions: 373133
#    |       11s "resume" actions: 0
#    |       11s "slot" actions: 1779039
#    |       11s "terminate" actions: 373883
#    |    2152172 nodes of all types
#    |       11s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.01s OK
#    |     0.00s checking (section) features ...
#    |     0.04s OK
#    |     0.00s reordering nodes ...
#    |     1.36s Max node = 2152172
#    |     1.36s OK
#    |     0.00s reassigning feature values ...
#    |     0.85s OK
# True

# %% [markdown]
# ### Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# True

# %% [markdown]
# ### Use the new dataset
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and pre-computations are performed.
# Next time the loading will be much quicker.

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/2.1.0</span>
# This is Text-Fabric 13.0.19
# 37 features found and 0 ignored
#    |     0.24s T otype                from ~/github/HuygensING/suriano/tf/2.1.0
#    |     3.95s T oslots               from ~/github/HuygensING/suriano/tf/2.1.0
#   4.20s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.00s T folder               from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T file                 from ~/github/HuygensING/suriano/tf/2.1.0
#    |     1.77s T str                  from ~/github/HuygensING/suriano/tf/2.1.0
#    |     1.27s T after                from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.02s T chunk                from ~/github/HuygensING/suriano/tf/2.1.0
#    |      |     0.09s C __levels__           from otype, oslots, otext
#    |      |       13s C __order__            from otype, oslots, __levels__
#    |      |     0.41s C __rank__             from otype, __order__
#    |      |       11s C __levUp__            from otype, oslots, __rank__
#    |      |     1.40s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.35s C __characters__       from otext
#    |      |     1.26s C __boundary__         from otype, oslots, __rank__
#    |      |     0.15s C __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, folder, file, chunk
#     35s All features loaded / computed - for details use TF.isLoaded()
#    |     0.00s T corresp              from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T date                 from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T editorNotes          from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.03s T empty                from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.04s T extraspace           from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.02s T facs                 from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.01s T id                   from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.12s T is_meta              from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.20s T is_note              from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.01s T link_target          from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.03s T n                    from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T recipient            from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T recipientLoc         from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T ref                  from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.03s T rend                 from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.05s T rend_decoded         from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T rend_displaced       from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.01s T rend_footnote        from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T rend_superscript     from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T role                 from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T sender               from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T senderLoc            from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T shelfmark            from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T source               from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.01s T summary              from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.01s T target               from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.01s T type                 from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T unit                 from ~/github/HuygensING/suriano/tf/2.1.0
#    |     0.00s T when                 from ~/github/HuygensING/suriano/tf/2.1.0
#   0.62s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.19</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/about.md" title="provenance of HuygensING - suriano/tf">HuygensING - suriano 2.1.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="HuygensING - suriano feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>12</td>
#     <td>148253.25</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>750</td>
#     <td>2372.05</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>750</td>
#     <td>2180.19</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>750</td>
#     <td>2180.19</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4247</td>
#     <td>736.20</td>
#     <td><i>176</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>750</td>
#     <td>191.87</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8952</td>
#     <td>158.08</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>750</td>
#     <td>126.11</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>750</td>
#     <td>50.61</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>47924</td>
#     <td>37.11</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>750</td>
#     <td>126.11</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>750</td>
#     <td>65.75</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>49473</td>
#     <td>32.66</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>750</td>
#     <td>31.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>750</td>
#     <td>31.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>750</td>
#     <td>19.11</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13500</td>
#     <td>17.20</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>1</td>
#     <td>15.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>750</td>
#     <td>14.15</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>163123</td>
#     <td>9.91</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>750</td>
#     <td>8.55</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>750</td>
#     <td>8.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1500</td>
#     <td>7.79</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>15679</td>
#     <td>7.72</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2250</td>
#     <td>6.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>750</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>750</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2131</td>
#     <td>4.30</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>750</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2250</td>
#     <td>2.69</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>750</td>
#     <td>2.64</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>750</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>750</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>750</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2250</td>
#     <td>1.31</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>metamark</th>
#     <td>3072</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8952</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11991</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>750</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>750</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1779039</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - suriano/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/2.1.0/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2025-12-15T14:02:41+00:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>2.1.0</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/2.1.0/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <details>
#     <summary>number of a chunk within a document</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/thumb</span>
# Found 8953 images<br>

# %% [markdown]
# ## Step 4: Mark named entities

# %% [markdown]
# First stage: we use the human-crafted triggers as is.
#
# In the separate notebook [nerCorrect](nerCorrect.ipynb) you can then collect
# additional spelling variants of the triggers.
#
# Some of these triggers are not fit to be used, you have to make a list of variants that are not valid triggers
# and store them in the file `persons-notmerged.txt`, one per line.
#
# Then you can merge the new valid variants automatically with the human-crafted triggers, and
# the result is a new spreadsheet, `persons-merged`.
#
# Second stage: use the merged spreadsheet.

# %% [markdown]
# ### Stage 1
#
# We need to copy the relevant spreadsheet from the `datasource/metadata` directory to the `ner` directory where TF expects it.

# %%
nerStage = 1
nerName, nerOutFile = setStage(nerStage)
# Out:
# Stage 1: working with sheet persons

# %%
NE = A.makeNer(caseSensitive=False, silent=False)
# Out:
# normalizeChars() loaded from ~/github/HuygensING/suriano/ner/code.py
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
NE.setTask(f".{nerName}", force=True)
# Out:
# Annotation set 🧾 persons has 0 annotations

# %%
NE.triggerInterference()
# Out:
# Looking up 28 potential interferences in 2 passes over the corpus ..
# 2 potential conflicting trigger pairs with 2 conflicts
# ----------
# different rows (0 pairs)
# ----------
# Diagnostic trigger interferences written to ~/github/HuygensING/suriano/_temp/ner/2.1.0/.persons/interference.txt

# %%
NE.reportHits(showNoHits=True)
# Out:
# No slot is covered by more than one trigger
# Triggers without hits: 96x:
# Looking up 96 triggers in 2 passes over the corpus ..
# Entities targeted:            818
# Triggers searched for:       1666
# Triggers without hits:         96
#  - completely covered:         96
#  - missing hits:                0
# Triggers with hits:          1570
# Total hits:                 10614
#
# All hits in report file:      ~/github/HuygensING/suriano/_temp/ner/2.1.0/.persons/hits.tsv
# Triggers by slot in file:     ~/github/HuygensING/suriano/_temp/ner/2.1.0/.persons/triggerBySlot.tsv

# %%
NE.makeSheetOfSingleTokens()
NE.setTask(f".{NER_NAME}-single", caseSensitive=False, force=True)
NE.reportHits(showNoHits=True)
# Out:
# Annotation set 🧾 persons-single has 0 annotations
# No slot is covered by more than one trigger
# Triggers without hits: 13x:
# Looking up 13 triggers in 1 pass over the corpus .
# Entities targeted:           1523
# Triggers searched for:       1523
# Triggers without hits:         13
#  - completely covered:         13
#  - missing hits:                0
# Triggers with hits:          1510
# Total hits:                 513993
#
# All hits in report file:      ~/github/HuygensING/suriano/_temp/ner/2.1.0/.persons-single/hits.tsv
# Triggers by slot in file:     ~/github/HuygensING/suriano/_temp/ner/2.1.0/.persons-single/triggerBySlot.tsv

# %%
NE.setTask(f".{NER_NAME}", caseSensitive=False)
# Out:
# Annotation set 🧾 persons has 10614 annotations

# %% [markdown]
# ### Prepare for stage 2: search variants

# %%
D = NE.variantDetection()
# Out:
# Overview of names by length:
#   10 tokens:   2 names e.g.:
#       cavalier inglese , et il fratello del vescovo di Londra
#       signor d ’ Aspri fratello dell ’ ambasciator dei Stati
#   9 tokens:   2 names e.g.:
#       conte d ’ Henin , chiamato duca di Bornenvil
#       Proveditor general dell ’ arm [ i ] Priuli
#   8 tokens:  15 names e.g.:
#       Alessandro , Giacomo et Pietr ’ Antonio Guadagni
#       ambasciator del signor Granduca nella corte di Praga
#       ambasciator di Francia residente appresso li serenissimi arciduchi
#       doi altri suoi parenti cognato , et cugino
#       doi altri un maschio , et una femina
#   7 tokens:  21 names e.g.:
#       [ duc ] a d ’ Angauleme
#       ambasciator di Spagna residente appresso il Christianissimo
#       Ambasciator straordinario che venne ultimamente di Spagna
#       Ambasciatore , che dal re di Bohemia
#       capitan scocese fratello di quel capitano Seiton
#   6 tokens:  45 names e.g.:
#       al luogotenente di monsignor di Sciatiglione
#       ambasciator Giust ( inia ) no
#       ambasciator Gritti alla corte di Spagna
#       baron di Kessel governator di Husdem
#       baron di Pieterson signor di Meroda
#   5 tokens:  83 names e.g.:
#       A . v . Matenesse
#       accompagnata la sorella di lui
#       Adriano Pieterson Looske da Encusen
#       agente d ’ Inghilterra Trombol
#       agente del re di Marocco
#   4 tokens: 193 names e.g.:
#       agente di quel Principe
#       almirante d ’ Arragona
#       ambasciator Contarini in Francia
#       ambasciator Contarini in Inghilterra
#       ambasciatore Contarini in Inghilterra
#   3 tokens: 497 names e.g.:
#       2 da Principessa
#       Adriano Vander Dussen
#       agente del Kerckoven
#       agente di Fiorenza
#       ambasciator a Constantinopoli
#   2 tokens: 564 names e.g.:
#       abbate Moronato
#       Abraham Pesini
#       Adam Schivelbergh
#       Adrian Pavoni
#       Adrian Ploos
#   1 tokens: 234 names e.g.:
#       Alagamba
#       Alagambe
#       Alagambre
#       Amstenraedt
#       Amsterraedt

# %%
D.prepare()
# Out:
# Alphabet written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/alphabet.tsv
# Text written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/text.txt - 8783050 characters
#   0.00s Collecting the triggers for the lexicon
#   0.00s 1507 triggers collected
#   346 x conte di Mansfelt
#   338 x Pasini
#   289 x Spinola
#   236 x Bernvel
#   217 x principe Mauritio
#   216 x Carleton
#   212 x principe d’Oranges
#   211 x re di Spagna
#   193 x duca di Savoia
#   180 x serenissimi arciduchi
#   ...
#     1 x visconte di Duncaster
#     1 x visconte di Gantes fratello del principe di Pinoe
#     1 x Vuandermil
#     1 x Wandernoot
#     1 x Wassenhovven
#     1 x Wasson[ hoven]
#     1 x Weesterbeeck
#     1 x Weimar il maggiore
#     1 x zelandese nominato Cornelio
#     1 x Zeno
#     1507 lexicon length
# Lexicon written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/lexicon.tsv
# Set up analiticcl
# Computing anagram values for all items in the lexicon...
#  - Found 1507 instances
# Adding all instances to the index...
#  - Found 1502 anagrams
# Creating sorted secondary index...
# Sorting secondary index...
#  - Found 3 anagrams of length 3
#  - Found 13 anagrams of length 4
#  - Found 23 anagrams of length 5
#  - Found 38 anagrams of length 6
#  - Found 49 anagrams of length 7
#  - Found 41 anagrams of length 8
#  - Found 41 anagrams of length 9
#  - Found 29 anagrams of length 10
#  - Found 47 anagrams of length 11
#  - Found 61 anagrams of length 12
#  - Found 70 anagrams of length 13
#  - Found 90 anagrams of length 14
#  - Found 107 anagrams of length 15
#  - Found 103 anagrams of length 16
#  - Found 103 anagrams of length 17
#  - Found 100 anagrams of length 18
#  - Found 83 anagrams of length 19
#  - Found 74 anagrams of length 20
#  - Found 67 anagrams of length 21
#  - Found 54 anagrams of length 22
#  - Found 35 anagrams of length 23
#  - Found 36 anagrams of length 24
#  - Found 25 anagrams of length 25
#  - Found 23 anagrams of length 26
#  - Found 27 anagrams of length 27
#  - Found 18 anagrams of length 28
#  - Found 15 anagrams of length 29
#  - Found 15 anagrams of length 30
#  - Found 6 anagrams of length 31
#  - Found 14 anagrams of length 32
#  - Found 10 anagrams of length 33
#  - Found 5 anagrams of length 34
#  - Found 10 anagrams of length 35
#  - Found 13 anagrams of length 36
#  - Found 4 anagrams of length 37
#  - Found 6 anagrams of length 38
#  - Found 4 anagrams of length 39
#  - Found 3 anagrams of length 40
#  - Found 5 anagrams of length 41
#  - Found 2 anagrams of length 42
#  - Found 4 anagrams of length 43
#  - Found 6 anagrams of length 44
#  - Found 5 anagrams of length 45
#  - Found 1 anagrams of length 46
#  - Found 2 anagrams of length 47
#  - Found 2 anagrams of length 49
#  - Found 1 anagrams of length 50
#  - Found 1 anagrams of length 52
#  - Found 2 anagrams of length 53
#  - Found 2 anagrams of length 54
#  - Found 1 anagrams of length 56
#  - Found 1 anagrams of length 57
#  - Found 1 anagrams of length 59
#  - Found 1 anagrams of length 66
# Constructing Language Model...
#  - No language model provided

# %%
# %%time

# !date

D.search(start=None, end=None, force=1)
# Out:
# Mon Dec 15 15:09:04 CET 2025
#  8783050 text  length
#        0 offset in complete text
#   0.00s Read previously computed variants of the lexicon words ...
#   5.61s  1404058 raw   matches
#   5.61s Filter variants of the lexicon words ...
#   6.68s      712 filtered matches
# 712 variants found
# CPU times: user 6.38 s, sys: 386 ms, total: 6.76 s
# Wall time: 6.88 s

# %%
D.listVariants(end=10)
D.listVariants(start=-10)
# Out:
#    i | variant                   | score | candidate
# ---- | ------------------------- | ----- | -------------------------
#    0 | a Ferdinando              |  0.87 | re Ferdinando
#    1 | a suo figliolo            |  0.87 | un suo figliolo
#    2 | abbot Moronato            |  0.85 | abbate Moronato
#    3 | Adrian Plois              |  0.88 | Adrian Ploos
#    4 | Adriano Ploos             |  0.85 | Adrian Ploos
#    5 | Adrien Ploos              |  0.86 | Adrian Ploos
#    6 | agente del Kerkoven       |  0.89 | agente del Kerckoven
#    7 | al figliolo               |  0.88 | il figliolo
#    8 | al suo figlio             |  0.89 | il suo figlio
#    9 | Alag]ambe                 |  0.84 | Alagambe
# ---- | ------------------------- | ----- | -------------------------
# 712 variants found and written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/variants.tsv
#    i | variant                   | score | candidate
# ---- | ------------------------- | ----- | -------------------------
#  -10 | Vorberghen                |  0.86 | Vosberghen
#   -9 | Vosbergen                 |  0.88 | Vosberghen
#   -8 | Wassnhoven                |  0.86 | Wassonhoven
#   -7 | Wassomhovem               |  0.85 | Wassonhovem
#   -6 | Wasson[hoven              |  0.85 | Wassonhoven
#   -5 | Wassonhove                |  0.90 | Wassonhoven
#   -4 | Wassonoven                |  0.86 | Wassonhoven
#   -3 | Willem Pietersen          |  0.90 | Willem Pieterssen
#   -2 | è figliolo                |  0.86 | il figliolo
#   -1 | è figliolo                |  0.86 | un figliolo
# ---- | ------------------------- | ----- | -------------------------
# 712 variants found and written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/variants.tsv

# %%
D.mergeTriggers()
# Out:
# 218 excluded variants found in ~/github/HuygensING/suriano/ner/specs/persons-notmerged.txt
# 211 variants excluded as trigger
# row  trigger                                  ~> variant                                  = occurences
# 8    Guglielmo di Nassau                      ~> Guglielmo de Nassau                      = 09x1
# 8    Guglielmo di Nassau                      ~> Guglielmo di Nansau                      = 08x1
# 8    conte Guglielmo suo figlio               ~> conte Guglielmo suo figliolo             = 08x1
# 13   vescovo di Paterborn                     ~> vescovo di Paterbon                      = 07x1
# 14   duca di Nevers                           ~> duca di Nivers                           = 11x1
# 15   Massimiliano                             ~> Massimilia                               = 11x1
# 18   duca di Guisa                            ~> duca di Guesa                            = 07x1
# 19   cardinal Lodovisio                       ~> card(ina)l Lodovisio                     = 10x1
# 20   cardinal Lodovisio                       ~> card(ina)l Lodovisio                     = 10x1
# 871  Miller                                   ~> Moller                                   = 06x1
# 871  Miller                                   ~> Miler                                    = 11x1
# 871  Miller                                   ~> Miler                                    = 12x1
# 871  Miller                                   ~> Muller                                   = 06x5
# 871  Miller                                   ~> Mille                                    = 07x1
# 871  Miller                                   ~> Mille                                    = 08x2
# 871  Miller                                   ~> Mille                                    = 09x1
# 871  Miller                                   ~> Mille                                    = 11x1
# 873  un moscovita                             ~> moscovita                                = 06x2
# 243 triggersets expanded with 500 triggers
# Wrote merge report to file ~/github/HuygensING/suriano/ner/specs/persons-merged-report.tsv
# Wrote merged triggers to sheet ~/github/HuygensING/suriano/ner/specs/persons-merged.xlsx

# %% [markdown]
# ### Stage 2

# %%
nerStage = 2
nerName, nerOutFile = setStage(nerStage)
# Out:
# Stage 2: working with sheet persons-merged

# %%
NE = A.makeNer(caseSensitive=False, silent=False)
# Out:
# normalizeChars() loaded from ~/github/HuygensING/suriano/ner/code.py
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
NE.setTask(f".{nerName}", force=True)
# Out:
# Annotation set 🧾 persons-merged has 0 annotations

# %%
NE.triggerInterference()
# Out:
# Looking up 29 potential interferences in 2 passes over the corpus ..
# 2 potential conflicting trigger pairs with 2 conflicts
# ----------
# different rows (0 pairs)
# ----------
# Diagnostic trigger interferences written to ~/github/HuygensING/suriano/_temp/ner/2.1.0/.persons-merged/interference.txt

# %%
NE.reportHits(showNoHits=True)
# Out:
# No slot is covered by more than one trigger
# Triggers without hits: 163x:
# Looking up 163 triggers in 2 passes over the corpus ..
# durante di prignì                        ()          : 03@011:9 x 1, 03@018:11 x 1
# henrico di nassau                        ()          : 07@045:86 x 1, 08@087:14 x 1
# smit                                     (02)        : 06@028:132 x 2, 06@028:134 x 1, 06@028:175 x 1, 06@034:74 x 1
# signor conte gioan                       (02-05)     : 06@034:160 x 1
# ambasciator de francia                   (03)        : 12@030:25 x 1
# ambasciatore di franza                   (03)        : 02@012:15 x 1, 08@059:18 x 1
# ambasciatori francia                     (03)        : 04@036:9 x 1
# ambasciator inglese straordinario        (04)        : 08@067:14 x 1
# signor di bredevod                       (04, 11)    : 09b@021:13 x 1
# conte gio ernesto                        (06, 08, 09, 11): 04@026:7 x 1
# figliolo maggiore                        (08)        : 04@016:7 x 1, 11@100:23 x 1
# ambasciator in londra                    (08-11)     : 05@049:16 x 1
# al suo figlio                            (09)        : 04@019:8 x 1
# ambasciatore di danimarca                (10)        : 12@036:93 x 2
# presidenti di gheldria                   (10)        : 04@031:13 x 1
# deputati della rocella                   (11)        : 10@058:27 x 1, 10@098:13 x 1
# un figliol maschio                       (11)        : 09@090:8 x 1
# moller                                   (12)        : 06@034:106 x 1
# moscovita                                (12)        : 05@021:7 x 1, 05@043:9 x 1, 06@031:14 x 1, 06@032:16 x 1, 06@035:25 x 1
#                                                        10@060:11 x 1
# muller                                   (12)        : 06@028:132 x 1, 06@028:134 x 1, 06@028:137 x 1, 06@028:197 x 2
# Entities targeted:            819
# Triggers searched for:       2159
# Triggers without hits:        163
#  - completely covered:        143
#  - missing hits:               20
# Triggers with hits:          1996
# Total hits:                 12218
#
# All hits in report file:      ~/github/HuygensING/suriano/_temp/ner/2.1.0/.persons-merged/hits.tsv
# Triggers by slot in file:     ~/github/HuygensING/suriano/_temp/ner/2.1.0/.persons-merged/triggerBySlot.tsv

# %%
nerMeta(*NE.getMeta(), silent=False)

# %%
NE.bakeEntities()
# Out:
# Entity consolidation for 12218 entity occurrences into version 2.1.0e
#  12218 entity occurrences
#    788 distinct entities
#   0.00s Creating a dataset with entity nodes ...
#   0.00s preparing and checking ...
#   0.00s Feature overview: 34 for nodes; 2 for edges; 1 configs; 9 computed
#    |     0.83s done
#    |   Delete types: t                   : keep:   shift  nodes       1-1779039 to         1-1779039
#    |   Delete types: author              : keep:   shift  nodes 1779040-1779789 to   1779040-1779789
#    |   Delete types: bibl                : keep:   shift  nodes 1779790-1780539 to   1779790-1780539
#    |   Delete types: biblScope           : keep:   shift  nodes 1780540-1781289 to   1780540-1781289
#    |   Delete types: body                : keep:   shift  nodes 1781290-1782039 to   1781290-1782039
#    |   Delete types: cell                : keep:   shift  nodes 1782040-1796374 to   1782040-1796374
#    |   Delete types: chunk               : keep:   shift  nodes 1796375-1844298 to   1796375-1844298
#    |   Delete types: collection          : keep:   shift  nodes 1844299-1845048 to   1844299-1845048
#    |   Delete types: correspAction       : keep:   shift  nodes 1845049-1846548 to   1845049-1846548
#    |   Delete types: correspDesc         : keep:   shift  nodes 1846549-1847298 to   1846549-1847298
#    |   Delete types: date                : keep:   shift  nodes 1847299-1848048 to   1847299-1848048
#    |   Delete types: div                 : keep:   shift  nodes 1848049-1852295 to   1848049-1852295
#    |   Delete types: editor              : keep:   shift  nodes 1852296-1853045 to   1852296-1853045
#    |   Delete types: file                : keep:   shift  nodes 1853046-1853795 to   1853046-1853795
#    |   Delete types: fileDesc            : keep:   shift  nodes 1853796-1854545 to   1853796-1854545
#    |   Delete types: folder              : keep:   shift  nodes 1854546-1854557 to   1854546-1854557
#    |   Delete types: head                : keep:   shift  nodes 1854558-1856688 to   1854558-1856688
#    |   Delete types: hi                  : keep:   shift  nodes 1856689-1872367 to   1856689-1872367
#    |   Delete types: idno                : keep:   shift  nodes 1872368-1874617 to   1872368-1874617
#    |   Delete types: institution         : keep:   shift  nodes 1874618-1875367 to   1874618-1875367
#    |   Delete types: ln                  : keep:   shift  nodes 1875368-2038490 to   1875368-2038490
#    |   Delete types: metamark            : keep:   shift  nodes 2038491-2041562 to   2038491-2041562
#    |   Delete types: msDesc              : keep:   shift  nodes 2041563-2042312 to   2041563-2042312
#    |   Delete types: msIdentifier        : keep:   shift  nodes 2042313-2043062 to   2042313-2043062
#    |   Delete types: name                : keep:   shift  nodes 2043063-2045312 to   2043063-2045312
#    |   Delete types: note                : keep:   shift  nodes 2045313-2058812 to   2045313-2058812
#    |   Delete types: num                 : keep:   shift  nodes 2058813-2059562 to   2058813-2059562
#    |   Delete types: p                   : keep:   shift  nodes 2059563-2109035 to   2059563-2109035
#    |   Delete types: page                : keep:   shift  nodes 2109036-2117987 to   2109036-2117987
#    |   Delete types: pb                  : keep:   shift  nodes 2117988-2126939 to   2117988-2126939
#    |   Delete types: profileDesc         : keep:   shift  nodes 2126940-2127689 to   2126940-2127689
#    |   Delete types: ptr                 : keep:   shift  nodes 2127690-2139680 to   2127690-2139680
#    |   Delete types: publicationStmt     : keep:   shift  nodes 2139681-2140430 to   2139681-2140430
#    |   Delete types: quote               : keep:   shift  nodes 2140431-2140440 to   2140431-2140440
#    |   Delete types: ref                 : keep:   shift  nodes 2140441-2140441 to   2140441-2140441
#    |   Delete types: resp                : keep:   shift  nodes 2140442-2141191 to   2140442-2141191
#    |   Delete types: respStmt            : keep:   shift  nodes 2141192-2141941 to   2141192-2141941
#    |   Delete types: row                 : keep:   shift  nodes 2141942-2145929 to   2141942-2145929
#    |   Delete types: settlement          : keep:   shift  nodes 2145930-2148179 to   2145930-2148179
#    |   Delete types: sourceDesc          : keep:   shift  nodes 2148180-2148929 to   2148180-2148929
#    |   Delete types: table               : keep:   shift  nodes 2148930-2149172 to   2148930-2149172
#    |   Delete types: teiHeader           : keep:   shift  nodes 2149173-2149922 to   2149173-2149922
#    |   Delete types: text                : keep:   shift  nodes 2149923-2150672 to   2149923-2150672
#    |   Delete types: title               : keep:   shift  nodes 2150673-2151422 to   2150673-2151422
#    |   Delete types: titleStmt           : keep:   shift  nodes 2151423-2152172 to   2151423-2152172
#    |   Delete types: max node: shifted from 2152172 to 2152172
#   0.99s add types ...
#    |     0.01s done (2 types)
#    |      |   ent, entity
#   1.00s applying updates ...
#   1.27s write TF data as version 2.1.0e ...
#   0.00s Not all of the warp features otype and oslots are present in
# ~/github/HuygensING/suriano/tf/2.1.0e
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Exporting 37 node and 3 edge and 1 configuration features to ~/github/HuygensING/suriano/tf/2.1.0e:
#   0.00s VALIDATING oslots feature
#   0.12s VALIDATING oslots feature
#   0.12s maxSlot=    1779039
#   0.12s maxNode=    2165178
#   0.15s OK: oslots is valid
#    |     0.65s T after                to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.02s T chunk                to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T corresp              to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T date                 to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T editorNotes          to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T eid                  to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T empty                to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T ename                to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T extraspace           to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T facs                 to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T file                 to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T folder               to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T id                   to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.05s T is_meta              to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.08s T is_note              to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T kind                 to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T n                    to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.24s T otype                to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T recipient            to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T recipientLoc         to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T ref                  to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T rend                 to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.04s T rend_decoded         to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T rend_displaced       to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T rend_footnote        to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T rend_superscript     to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T role                 to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T sender               to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T senderLoc            to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T shelfmark            to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T source               to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.75s T str                  to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T summary              to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T target               to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T type                 to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T unit                 to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T when                 to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T eoccs                to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T link_target          to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.96s T oslots               to ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s M otext                to ~/github/HuygensING/suriano/tf/2.1.0e
#   3.08s Exported 37 node features and 3 edge features and 1 config features to ~/github/HuygensING/suriano/tf/2.1.0e
#   4.35s all done
#   4.44s Done
# The dataset with entities is now in version 2.1.0e
# The dataset with entities is now the standard version
# True

# %% [markdown]
# We load the new data:

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/2.1.0e</span>
# This is Text-Fabric 13.0.19
# 41 features found and 0 ignored
#    |     0.24s T otype                from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     4.91s T oslots               from ~/github/HuygensING/suriano/tf/2.1.0e
#   5.16s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.00s T folder               from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T file                 from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     1.82s T str                  from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     1.58s T after                from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.04s T chunk                from ~/github/HuygensING/suriano/tf/2.1.0e
#    |      |     0.12s C __levels__           from otype, oslots, otext
#    |      |       14s C __order__            from otype, oslots, __levels__
#    |      |     0.44s C __rank__             from otype, __order__
#    |      |       13s C __levUp__            from otype, oslots, __rank__
#    |      |     1.64s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.44s C __characters__       from otext
#    |      |     1.25s C __boundary__         from otype, oslots, __rank__
#    |      |     0.19s C __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, folder, file, chunk
#     39s All features loaded / computed - for details use TF.isLoaded()
#    |     0.00s T corresp              from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T date                 from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T editorNotes          from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T eid                  from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.03s T empty                from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T ename                from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T eoccs                from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.04s T extraspace           from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.03s T facs                 from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T id                   from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.14s T is_meta              from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.21s T is_note              from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T kind                 from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.02s T link_target          from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.03s T n                    from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T recipient            from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T recipientLoc         from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T ref                  from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.03s T rend                 from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.08s T rend_decoded         from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T rend_displaced       from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T rend_footnote        from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T rend_superscript     from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T role                 from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T sender               from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T senderLoc            from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T shelfmark            from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T source               from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T summary              from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T target               from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.01s T type                 from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T unit                 from ~/github/HuygensING/suriano/tf/2.1.0e
#    |     0.00s T when                 from ~/github/HuygensING/suriano/tf/2.1.0e
#   0.74s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.19</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/about.md" title="provenance of HuygensING - suriano/tf">HuygensING - suriano 2.1.0e</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="HuygensING - suriano feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>12</td>
#     <td>148253.25</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>750</td>
#     <td>2372.05</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>750</td>
#     <td>2180.19</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>750</td>
#     <td>2180.19</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4247</td>
#     <td>736.20</td>
#     <td><i>176</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>750</td>
#     <td>191.87</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8952</td>
#     <td>158.08</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>750</td>
#     <td>126.11</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>750</td>
#     <td>50.61</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>47924</td>
#     <td>37.11</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>750</td>
#     <td>126.11</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>750</td>
#     <td>65.75</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>entity</th>
#     <td>788</td>
#     <td>35.41</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>49473</td>
#     <td>32.66</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>750</td>
#     <td>31.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>750</td>
#     <td>31.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>750</td>
#     <td>19.11</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13500</td>
#     <td>17.20</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>1</td>
#     <td>15.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>750</td>
#     <td>14.15</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>163123</td>
#     <td>9.91</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>750</td>
#     <td>8.55</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>750</td>
#     <td>8.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1500</td>
#     <td>7.79</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>15679</td>
#     <td>7.72</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2250</td>
#     <td>6.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>750</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>750</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2131</td>
#     <td>4.30</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>750</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2250</td>
#     <td>2.69</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>750</td>
#     <td>2.64</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ent</th>
#     <td>12218</td>
#     <td>2.28</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>750</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>750</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>750</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2250</td>
#     <td>1.31</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>metamark</th>
#     <td>3072</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8952</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11991</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>750</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>750</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1779039</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - suriano/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/2.1.0e/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2025-12-15T14:09:54+00:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>2.1.0e</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/2.1.0e/chunk.tf">chunk</a>
# </
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/thumb</span>
# Found 8953 images<br>

# %% [markdown]
# # Step 5: Transport the entities to the TEI
#
# The entities have been baked into the TF dataset, but we want to bake them into the earlier generated TEI
# as well.
#
# In order to do that, we must align the slots in TF with the text content of the TEI.
#
# Our conversion from TEI to TF has not preserved all characters of the TEI text 1-1.
# Additional whitespace may have been added, superfluous whitespace may have been stripped.
#
# We make a mapping that maps each slot that has non-white text content to a corresponding position in a TEI source file.

# %%
BE = BakeEntTei(A)
# Out:
# Making entity index ...
# 788 entities with 12218 occurrences

# %%
BE.bakeCorpus(filza=12, file=None)
# Out:
# Bake entities into TEI in ~/github/HuygensING/suriano/datasource/tei-bare (filza 12 only) ...
# 	filza 12
# 		letter 001 ( 32 entities)
# 		letter 002 ( 11 entities)
# 		letter 003 ( 49 entities)
# 		letter 004 ( 14 entities)
# 		letter 005 ( 30 entities)
# 		letter 005 ( 30 entities: correction(s): hi+ptr crossing 1 applied, 0 failed
# 		letter 008 ( 16 entities: correction(s): hi+ptr crossing 1 applied, 0 failed
# 		letter 016 ( 46 entities: correction(s): hi+ptr crossing 1 applied, 0 failed
# 		letter 024 ( 56 entities: correction(s): hi+ptr crossing 1 applied, 0 failed
# 		letter 027 ( 26 entities: correction(s): hi+ptr crossing 1 applied, 0 failed
# 		letter 032 ( 51 entities: correction(s): hi+ptr crossing 1 applied, 0 failed
# 		letter 046 (104 entities: correction(s): hi+ptr crossing 1 applied, 0 failed
#
# 	filza 12, all good
# Done, all good

# %% [markdown]
# We check whether the resulting XML is valid:

# %%
Tei = TEI(verbose=-1, sourceBase=SOURCEBASE, teiDir="tei", reportDir=REPORT_TEIDIR, tei="", tf=VERSION)

# %%
Tei.task(check=1, verbose=1, validate=True)
# Out:
# TEI to TF checking: ~/github/HuygensING/suriano/datasource/tei => ~/github/HuygensING/suriano/report/tei
# Processing instructions are ignored
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# INFO: Needs dcr.xsd (exists)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   1 changing override(s)
# 	metamark mixed ==> pure
# Section model I
# 	Start folder 02
# 	Start folder 03
# 	Start folder 04
# 	Start folder 05
# 	Start folder 06
# 	Start folder 07
# 	Start folder 08
# 	Start folder 09
# 	Start folder 09b
# 	Start folder 10
# 	Start folder 11
# 	Start folder 12
# 750 suriano file(s) ...
# 	Validating ...
# 	Making inventory ...
#
# 584 tag(s) type info written to ~/github/HuygensING/suriano/report/tei/types.txt
# Validation OK
# 0 pagebreaks without facs attribute.
# 8952 pagebreaks encountered.
# 8952 distinct scans referred to by pagebreaks.
# 41 tags of which 0 with multiple namespaces written to ~/github/HuygensING/suriano/report/tei/namespaces.txt
# 9974 info line(s) written to ~/github/HuygensING/suriano/report/tei/elements.txt
# Refs written to ~/github/HuygensING/suriano/report/tei/refs.txt
# 	resolvable: 11991 in 11991
# 	dangling:      0 in    0
# 	ALL:        11991 in 11991
# Ids written to ~/github/HuygensING/suriano/report/tei/ids.txt
# 	referenced: 11991 by 11991
# 	non-unique:    0
# 	unused:     1509
# 	ALL:        13500 in 13500
# lb-parent info written to ~/github/HuygensING/suriano/report/tei/lb-parents.txt
# True

# %% [markdown]
# ## Step 5: Convert TF to WATM
#
# N.B. For docs click the WATM link in the output cell.

# %%
# WA = WATM(A, "tei", skipMeta=False, prod="dev")
WA = WATM(A, "tei", skipMeta=False, prod="prod")
# Out:
# conversion settings read from ~/github/HuygensING/suriano/config/watm.yml
# IIIF settings read from ~/github/HuygensING/suriano/config/iiif.yml
# Manifestlevel = folder
# textRepoLevel is section level 'folder'
# No instructions to exclude toplevel section nodes
# Excluded nodes: 0 from 2165178 nodes
# [WATM exporter documentation](https://annotation.github.io/text-fabric-factory/tff/convert/watm.html)
# Found covers in directory: ~/github/HuygensING/suriano/scans/covers
# Maximum dimensions: W = 8504 H = 5976
# Average dimensions: W = 4138 H = 4869
# Average deviation:  W = 1038 H =  660
# Maximum dimensions: W = 5600 H = 5786
# Average dimensions: W = 3262 H = 4375
# Average deviation:  W =  479 H =  617

# %%
WA.makeText()
WA.makeAnno()
WA.writeAll()
WA.testAll()
# Out:
# 	Writing WATM ...
# Writing production data to ~/github/HuygensING/suriano/watm/2.1.0e/prod
# Text file    0:    44361 segments to ~/github/HuygensING/suriano/watm/2.1.0e/prod/text-0.tsv
# Text file    1:   117973 segments to ~/github/HuygensING/suriano/watm/2.1.0e/prod/text-1.tsv
# Text file    2:   147815 segments to ~/github/HuygensING/suriano/watm/2.1.0e/prod/text-2.tsv
# Text file    3:   109694 segments to ~/github/HuygensING/suriano/watm/2.1.0e/prod/text-3.tsv
# Text file    4:   154990 segments to ~/github/HuygensING/suriano/watm/2.1.0e/prod/text-4.tsv
# Text file   11:   132417 segments to ~/github/HuygensING/suriano/watm/2.1.0e/prod/text-11.tsv
# Text files all:  1779039 segments to 12 files
# Anno file    1:   400000 annotations written to ~/github/HuygensING/suriano/watm/2.1.0e/prod/anno-1.tsv
# Anno file    2:   400000 annotations written to ~/github/HuygensING/suriano/watm/2.1.0e/prod/anno-2.tsv
# Anno file    3:   269024 annotations written to ~/github/HuygensING/suriano/watm/2.1.0e/prod/anno-3.tsv
# Inherited annotations: 0
# Anno files all:  1069024 annotations to 3 files
# Slot mapping written to ~/github/HuygensING/suriano/watm/2.1.0e/prod/pos2node.tsv
# Node mapping written to ~/github/HuygensING/suriano/watm/2.1.0e/prod/anno2node.tsv
# Logical pairs (6952) written to ~/github/HuygensING/suriano/watm/2.1.0e/prod/logicalpairs.tsv
# Extra file datasource/entities/entitymeta.json copied to the WATM directory
# 	Testing WATM ...
# Excluded nodes: 0 from 2165178 nodes
# Testing the text ...
# 	TF: 1779039
# 	WA: 1779039
# OK - whether the amounts of tokens agree
# 	TF: Letter 02.001 date 1 ... "corrected on "23."
# 	WA: Letter 02.001 date 1 ... "corrected on "23."
# OK - whether the text is the same
# Testing the elements ...
# 	TF: 328475
# 	WA: 328475
# OK - whether the amounts of elements and nodes agree
# Testing the processing instructions ...
# 	TF:      0
# 	WA:      0
# OK - whether the amounts of processing instructions agree
# Testing the element/pi annotations ...
# 	328475 element/pi annotations
# 	Element      : 328475 x
# 	Pi           :      0 x
# 	Good name    : 328475 x
# 	Wrong name   :      0 x
# 	Good target  : 328475 x
# 	Wrong target :      0 x
# 	Unmapped     :      0 x
# OK - whether all element/pi annotations have good bodies
# OK - whether all element/pi annotations have good targets
# Testing the attributes ...
# 	337320 attribute values
# 	Good:     337320 x
# 	Wrong:        0 x
# OK - whether annotations are consistent with features
# 	WA attributes: 337320
# 	TF attributes: 337320
# OK - whether annotations are complete w.r.t. features
# Testing the format attributes ...
# 	120978 format values
# 	formatting attributes:
# 		107671 x decoded
# 		 12000 x footnote
# 		  1120 x superscript
# 		   187 x displaced
# 	Good:     120978 x
# 	Wrong:        0 x
# OK - whether format annotations are consistent with features
# 	WA format attributes: 120978
# 	TF format attributes: 120978
# OK - whether format annotations are complete w.r.t. features
# Testing the extra annotations ...
# 	0 extra feature values
# 	0 extra annotations
# OK - whether the extra annotations agree
# Testing the edges ...
# 	Found: 1 edges in annotations
# 		edge link_target with 11991 starting nodes
# 	Found: 1 edges in annotations
# 		edge link_target with 11991 starting nodes
# 	Checking edge link_target
# 		same 11991 fromNodes
# 		OK - 11991 toNodes checked
# OK - whether all edges agree
# Overall outcome ...
# OK - whether all tests passed

# %% [markdown]
# ## Step 6: Generate IIIF manifests

# %%
II = IIIF(Tei.teiVersion, A, REPORT_PAGESDIR, prod="prod", silent=False)
# II = IIIF(Tei.teiVersion, A, REPORT_PAGESDIR, prod="dev", silent=False)
II.manifests()
# Out:
# Found covers in directory: ~/github/HuygensING/suriano/scans/covers
# Scan images taken from ~/github/HuygensING/suriano/scans
# IIIF settings read from ~/github/HuygensING/suriano/config/iiif.yml
# Manifestlevel = folder
# All generated urls are for a prod deployment on https:/data.suriano.huygens.knaw.nl
# Maximum dimensions: W = 8504 H = 5976
# Average dimensions: W = 4138 H = 4869
# Average deviation:  W = 1038 H =  660
# Maximum dimensions: W = 5600 H = 5786
# Average dimensions: W = 3262 H = 4375
# Average deviation:  W =  479 H =  617
# Using page info file ~/github/HuygensING/suriano/report/pages/pageseq.json
# Collections:
#         02 with  262 pages
#         03 with  660 pages
#         04 with  806 pages
#         05 with  688 pages
#         06 with  684 pages
#         07 with  628 pages
#         08 with  988 pages
#         09 with  944 pages
#        09b with  188 pages
#         10 with 1062 pages
#         11 with 1116 pages
#         12 with  928 pages
# Missing image files:
# 	pages:
# 		None:
# 			  1 x 09b_025bisr
# 			  1 x 09b_025bisv
# 			  1 x 09b_059bisr
# 			  1 x 09b_059bisv
# 			  1 x 09b_078bisr
# 			  1 x 09b_078bisv
# 	total occurrences of a missing file: 6
# 12 IIIF manifests with 8949 items for 8954 pages generated in ~/github/HuygensING/suriano/static/prod/manifests

# %% [markdown]
# ## Step 7: Deploy to k8s and TeamText VM

# %% [markdown]
# NB: you need to have access to the k8s cluster and to the team text VM.
#
# That means:
#
# * The LDAP of the relevant k8s clusters know you
# * You have an ssh key-based login on the Team Text VPN
# * You work inside the firewall

# %%
# !./provision.sh watm
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# WATM export version: 1.0.1e-029
# anno-1.tsv                                    100%   17MB   5.9MB/s   00:02
# anno-3.tsv                                    100%   10MB   6.4MB/s   00:01
# anno-2.tsv                                    100%   15MB   6.6MB/s   00:02
# anno2node.tsv                                 100% 5658KB   5.9MB/s   00:00
# text-6.tsv                                    100% 1228KB   4.3MB/s   00:00
# text-7.tsv                                    100% 1196KB   4.1MB/s   00:00
# text-5.tsv                                    100% 1018KB   6.0MB/s   00:00
# text-4.tsv                                    100%  914KB   5.8MB/s   00:00
# text-0.tsv                                    100%  267KB   4.3MB/s   00:00
# text-1.tsv                                    100%  705KB   6.2MB/s   00:00
# text-3.tsv                                    100%  655KB   6.0MB/s   00:00
# text-2.tsv                                    100%  879KB   6.3MB/s   00:00
# text-9.tsv                                    100% 1337KB   6.0MB/s   00:00
# text-8.tsv                                    100% 1389KB   5.3MB/s   00:00
# entitymeta.json                               100%  339KB   5.3MB/s   00:00
# pos2node.tsv                                  100%   26MB   6.2MB/s   00:04
# text-10.tsv                                   100%  776KB   5.2MB/s   00:00
# logicalpairs.tsv                              100%  177KB   4.7MB/s   00:00

# %%
# !./provision.sh files
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# copying to pod: prod/covers.html
# copying to pod: prod/logo
# copying to pod: prod/manifests
# copying to pod: both/metadata

# %%
# !./provision.sh prod images

# %% [markdown]
# ## Step 8: Test the images

# %% [markdown]
# * [covers](https://data.suriano.huygens.knaw.nl/files/covers.html)
#
# * [02.json](https://data.suriano.huygens.knaw.nl/files/manifests/02.json)
#
# * [page 02_171r](https://data.suriano.huygens.knaw.nl/iiif/3/pages%2F02_071r.jpg/full/max/0/default.jpg)

# %% [markdown]
# # Convert from DOCX to TEI to TF to WATM
#
# We convert Suriano DOCX to TEI to TF and then to WATM.
#
# This notebook provides three levels of refinement in the execution. They all have the same outcome,
# but they differ in the level of detail they provide on the conversion.
#
# These are the levels:
#
# * **Debugging**: all the commands directly in Python, the intermediate data remains in memory and can  be inspected.
# * **Step by step**: one command for each main step of the conversion;
# * **Express**: one single command on the command line for the complete conversion;

# %% [markdown]
# # Production or development
#
# Mosts steps are unaffected by the production/development setting.
#
# In the first steps of the pipeline (*ingest* and *scan processing*) we prepare both the dev and the prod data.
#
# The intermediate steps (*from DOCX to TEI*, *from TEI to TF*, *mark named entities*) are identical for prod and dev.
#
# Only for the latter steps (*convert TF to WATM*, generate IIIF manifests*, *deploy to k8s*) there is a distinction between prod and dev.
#
# For these steps we have commented out the line that does the dev version.

# %% [markdown]
# # Requirements
#
# * zsh as command line shell (as in macOS);
# * access to suitable k8s clusters, streamlined by the
#   [k-suite](https://code.huc.knaw.nl/tt/smart-k8s/-/blob/main/docs/k-suite.md);
# * [Pandoc](https://pandoc.org)
# * [Imagemagick](https://imagemagick.org)
# * [Python](https://www.python.org) (3.12 or higher) with additional pip-installable modules:
#   * text-fabric
#   * doc2python
#   * openpyxl

# %% [markdown]
# # Declare the version
#
# Always set the version before running any cell in this notebook!

# %%
VERSION = "1.0.3"

# %% [markdown]
# # In debugging mode.
#
# Now we dig a bit deeper, en do all the steps while keeping the program in memory.
# Now it becomes doable to inspect all intermediate results.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tff.convert.tei import TEI
from tff.convert.watm import WATM
from tff.convert.iiif import IIIF
from tf.advanced.helpers import dm

from processscans import Scans
from processdocs import TeiFromDocx
from processhelpers import setStage, nerMeta, NER_NAME, SOURCEBASE, REPORT_PAGESDIR, REPORT_TEIDIR

# %% [markdown]
# ## Step 1: Scan ingest

# %%
SC = Scans(silent=False, force=False)

# %%
SC.ingest(dry=False)
# Out:
# 	Already ingested pages. Remove ~/github/HuygensING/suriano/scans/pages or pass --force to ingest again

# %% [markdown]
# ## Step 2: Scan processing

# %%
SC.process()
# Out:
# Already present: sizes file originals (covers)
# Already present: sizes file originals (pages)
# 	Convert 48 originals to thumbnails (covers)
# 		100% done
# 	Get sizes of 48 thumbnails (covers)
# 		100% done
# 	Convert 8904 originals to thumbnails (pages)
# 		 11% done
# 		 22% done
# 		 34% done
# 		 45% done
# 		 56% done
# 		 67% done
# 		 79% done
# 		 90% done
# 		100% done
# 	Get sizes of 8904 thumbnails (pages)
# 		 11% done
# 		 22% done
# 		 34% done
# 		 45% done
# 		 56% done
# 		 67% done
# 		 79% done
# 		 90% done
# 		100% done

# %% [markdown]
# ## Step 3: From DOCX to TEI

# %% [markdown]
# You might need to do
#
# ```
# pip install docx2python
# ```

# %%
TFD = TeiFromDocx(silent=False)

# %%
TFD.task("pandoc")
# Out:
# DOCX => simple TEI per filza ...
# 	02.docx ... uptodate
# 	03.docx ... uptodate
# 	04.docx ... uptodate
# 	05.docx ... uptodate
# 	06.docx ... uptodate
# 	07.docx ... uptodate
# 	08.docx ... uptodate
# 	09.docx ... uptodate
# 	10.docx ... uptodate
# 	11.docx ... uptodate
# 	12.docx ... uptodate

# %%
TFD.task("headers")
# Out:
# DOCX => headers ...
# 	02.docx
# 	03.docx
# 	04.docx
# 	05.docx
# 	06.docx
# 	07.docx
# 	08.docx
# 	09.docx
# 	10.docx
# 	11.docx
# 	12.docx
# 	OK: All headers are OK
# Angelo              : 1181 pages in 11 filzas
# Cristina            : 1034 pages in 10 filzas
# Federica            : 684 pages in  7 filzas
# Filippo             : 1084 pages in  9 filzas
# Flavia              : 1282 pages in 11 filzas
# Giorgia             : 934 pages in  9 filzas
# Renzo               :  56 pages in  1 filza
# Ruben               : 1162 pages in 10 filzas
# Vera                : 966 pages in 10 filzas
# Vera, Federica      : 210 pages in  1 filza

# %%
TFD.task("tei")
# Out:
# Collecting transcribers ...
# Collecting page scans ...
#   0 x error
# 8766 x good
# Collecting excel metadata ...
# 	found metadata for 725 letters
# simple TEI per filza => enriched TEI per letter ...
# 	02.xml
# 	03.xml
# 	04.xml
# 	05.xml
# 	06.xml
# 	07.xml
# 	08.xml
# 	09.xml
# 	10.xml
# 	11.xml
# 	12.xml
# Translated italian editorial phrases (218 x 14157)
# Metadata in summary file corresponds to transcribed letters
# 0 page warnings
# 0 warnings
# Pages with    transcription and    scan:       8766
# Pages with    transcription and missing scan:     0
# Pages with    transcription and no scan:          0
# Pages with no transcription and    scan:          0
# See ~/github/HuygensING/suriano/report/pages/pagescan.tsv

# %% [markdown]
# ## Step 4: From TEI to TF
#
# ### Check the validity of the TEI.

# %%
Tei = TEI(verbose=-1, sourceBase=SOURCEBASE, reportDir=REPORT_TEIDIR, tei="", tf=VERSION)

# %%
Tei.task(check=1, verbose=1, validate=True)
# Out:
# TEI to TF checking: ~/github/HuygensING/suriano/datasource/tei => ~/github/HuygensING/suriano/report/tei
# Processing instructions are ignored
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# INFO: Needs dcr.xsd (exists)
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   1 changing override(s)
# 	metamark mixed ==> pure
# Section model I
# 	Start folder 02
# 	Start folder 03
# 	Start folder 04
# 	Start folder 05
# 	Start folder 06
# 	Start folder 07
# 	Start folder 08
# 	Start folder 09
# 	Start folder 10
# 	Start folder 11
# 	Start folder 12
# 725 suriano file(s) ...
# 	Validating ...
# 	Making inventory ...
#
# 584 tag(s) type info written to ~/github/HuygensING/suriano/report/tei/types.txt
# Validation OK
# 0 pagebreaks without facs attribute.
# 8764 pagebreaks encountered.
# 8764 distinct scans referred to by pagebreaks.
# 41 tags of which 0 with multiple namespaces written to ~/github/HuygensING/suriano/report/tei/namespaces.txt
# 8995 info line(s) written to ~/github/HuygensING/suriano/report/tei/elements.txt
# Refs written to ~/github/HuygensING/suriano/report/tei/refs.txt
# 	resolvable: 11821 in 11821
# 	dangling:      0 in    0
# 	ALL:        11821 in 11821
# Ids written to ~/github/HuygensING/suriano/report/tei/ids.txt
# 	referenced: 11821 by 11821
# 	non-unique:    0
# 	unused:      735
# 	ALL:        12556 in 12556
# lb-parent info written to ~/github/HuygensING/suriano/report/tei/lb-parents.txt
# True

# %% [markdown]
# ### Convert the data

# %%
Tei.good = True
Tei.task(convert=True, verbose=0)
# Out:
# Line model II with ln nodes for lines between lb elements
# Page model II with page nodes for pages started by pb elements  keeping the pb elements
# Section model I
# Processing instructions are ignored
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   1 changing override(s)
# 	metamark mixed ==> pure
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# 	Start folder 02:
# 		   1 suriano                                001.xml
# 		   2 suriano                                002.xml
# 		   3 suriano                                003.xml
# 		   4 suriano                                004.xml
# 		   5 suriano                                005.xml
#
# End   folder 02
# 	Start folder 03:
# 		  20 suriano                                001.xml
# 		  21 suriano                                002.xml
# 		  22 suriano                                003.xml
# 		  23 suriano                                004.xml
# 		  24 suriano                                005.xml
#
# End   folder 03
# 	Start folder 04:
# 		  75 suriano                                001.xml
# 		  76 suriano                                002.xml
# 		  77 suriano                                003.xml
# 		  78 suriano                                004.xml
# 		  79 suriano                                005.xml
#
# End   folder 04
# 	Start folder 05:
# 		 150 suriano                                001.xml
# 		 151 suriano                                002.xml
# 		 152 suriano                                003.xml
# 		 153 suriano                                004.xml
# 		 154 suriano                                005.xml
#
# End   folder 05
# 	Start folder 06:
# 		 207 suriano                                001.xml
# 		 208 suriano                                002.xml
# 		 209 suriano                                003.xml
# 		 210 suriano                                004.xml
# 		 211 suriano                                005.xml
#
# End   folder 06
# 	Start folder 07:
# 		 247 suriano                                001.xml
# 		 248 suriano                                002.xml
# 		 249 suriano                                003.xml
# 		 250 suriano                                004.xml
# 		 251 suriano                                005.xml
#
# End   folder 07
# 	Start folder 08:
# 		 294 suriano                                001.xml
# 		 295 suriano                                002.xml
# 		 296 suriano                                003.xml
# 		 297 suriano                                004.xml
# 		 298 suriano                                005.xml
#
# End   folder 08
# 	Start folder 09:
# 		 385 suriano                                001.xml
# 		 386 suriano                                002.xml
# 		 387 suriano                                003.xml
# 		 388 suriano                                004.xml
# 		 389 suriano                                005.xml
#
# End   folder 09
# 	Start folder 10:
# 		 479 suriano                                001.xml
# 		 480 suriano                                002.xml
# 		 481 suriano                                003.xml
# 		 482 suriano                                004.xml
# 		 483 suriano                                005.xml
#
# End   folder 10
# 	Start folder 11:
# 		 579 suriano                                001.xml
# 		 580 suriano                                002.xml
# 		 581 suriano                                003.xml
# 		 582 suriano                                004.xml
# 		 583 suriano                                005.xml
#
# End   folder 11
# 	Start folder 12:
# 		 680 suriano                                001.xml
# 		 681 suriano                                002.xml
# 		 682 suriano                                003.xml
# 		 683 suriano                                004.xml
# 		 684 suriano                                005.xml
#
# End   folder 12
#
# Resolving links into edges ...
# 	3917 in 11821 reference(s) resolved
#    |       11s "delete" actions: 0
#    |       11s "edge" actions: 11821
#    |       11s "feature" actions: 2744566
#    |       11s "node" actions: 365637
#    |       11s "resume" actions: 0
#    |       11s "slot" actions: 1738519
#    |       11s "terminate" actions: 366362
#    |    2104156 nodes of all types
#    |       11s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.04s OK
#    |     0.00s reordering nodes ...
#    |     1.16s Max node = 2104156
#    |     1.16s OK
#    |     0.00s reassigning feature values ...
#    |     0.81s OK
# True

# %% [markdown]
# ### Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# True

# %% [markdown]
# ### Use the new dataset
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and pre-computations are performed.
# Next time the loading will be much quicker.

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/1.0.3</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/ner</span>
# This is Text-Fabric 12.6.4
# 37 features found and 0 ignored
#    |     0.48s T otype                from ~/github/HuygensING/suriano/tf/1.0.3
#    |     6.56s T oslots               from ~/github/HuygensING/suriano/tf/1.0.3
#   7.04s Dataset without structure sections in otext:no structure functions in the T-API
#    |     3.46s T after                from ~/github/HuygensING/suriano/tf/1.0.3
#    |     4.12s T str                  from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.08s T chunk                from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T folder               from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T file                 from ~/github/HuygensING/suriano/tf/1.0.3
#    |      |     0.11s C __levels__           from otype, oslots, otext
#    |      |       16s C __order__            from otype, oslots, __levels__
#    |      |     0.39s C __rank__             from otype, __order__
#    |      |       16s C __levUp__            from otype, oslots, __rank__
#    |      |     3.35s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.35s C __characters__       from otext
#    |      |     3.82s C __boundary__         from otype, oslots, __rank__
#    |      |     0.52s C __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, folder, file, chunk
#     55s All features loaded / computed - for details use TF.isLoaded()
#    |     0.00s T corresp              from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T date                 from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T editorNotes          from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.06s T empty                from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.07s T extraspace           from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.06s T facs                 from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.03s T id                   from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.28s T is_meta              from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.51s T is_note              from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.04s T link_target          from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.08s T n                    from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T recipient            from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T recipientLoc         from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T ref                  from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.07s T rend                 from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.19s T rend_decoded         from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T rend_displaced       from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.03s T rend_footnote        from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T rend_superscript     from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T role                 from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T sender               from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T senderLoc            from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T shelfmark            from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T source               from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.01s T summary              from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.03s T target               from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.02s T type                 from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T unit                 from ~/github/HuygensING/suriano/tf/1.0.3
#    |     0.00s T when                 from ~/github/HuygensING/suriano/tf/1.0.3
#   1.51s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.6.4</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/about.md" title="provenance of HuygensING - suriano/tf">HuygensING - suriano 1.0.3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="HuygensING - suriano feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>11</td>
#     <td>158047.18</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>725</td>
#     <td>2397.96</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>725</td>
#     <td>2206.00</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>725</td>
#     <td>2206.00</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4148</td>
#     <td>737.03</td>
#     <td><i>176</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>725</td>
#     <td>191.96</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8764</td>
#     <td>157.79</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>725</td>
#     <td>125.82</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>725</td>
#     <td>51.06</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>46970</td>
#     <td>37.01</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>725</td>
#     <td>125.82</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>725</td>
#     <td>66.14</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>48687</td>
#     <td>32.48</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>725</td>
#     <td>31.56</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>725</td>
#     <td>31.56</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>725</td>
#     <td>19.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13280</td>
#     <td>17.09</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>1</td>
#     <td>15.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>725</td>
#     <td>14.08</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>159402</td>
#     <td>9.92</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>725</td>
#     <td>8.73</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>725</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1450</td>
#     <td>7.82</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>15454</td>
#     <td>7.81</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2175</td>
#     <td>6.52</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>725</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>725</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2082</td>
#     <td>4.31</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>725</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>725</td>
#     <td>2.70</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2175</td>
#     <td>2.69</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>725</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2175</td>
#     <td>1.32</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>metamark</th>
#     <td>3027</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8764</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11821</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1738519</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - suriano/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/1.0.3/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2025-03-12T09:19:34+00:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>1.0.3</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/1.0.3/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <details>
#     <summary>number of a chunk within a document</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="f
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/thumb</span>
# Found 8766 images<br>

# %% [markdown]
# ## Step 5: Mark named entities

# %% [markdown]
# First stage: we use the human-crafted triggers as is.
#
# In the separate notebook [nerCorrect](nerCorrect.ipynb) you can then collect
# additional spelling variants of the triggers.
#
# Some of these triggers are not fit to be used, you have to make a list of variants that are not valid triggers
# and store them in the file `persons-notmerged.txt`, one per line.
#
# Then you can merge the new valid variants automatically with the human-crafted triggers, and
# the result is a new spreadsheet, `persons-merged`.
#
# Second stage: use the merged spreadsheet.

# %% [markdown]
# ### Stage 1
#
# We need to copy the relevant spreadsheet from the `datasource/metadata` directory to the `ner` directory where TF expects it.

# %%
nerStage = 1
nerName, nerOutFile = setStage(nerStage)
# Out:
# Stage 1: working with sheet persons

# %%
NE = A.makeNer(caseSensitive=False, silent=False)
# Out:
# normalizeChars() loaded from ~/github/HuygensING/suriano/ner/code.py
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
NE.setTask(f".{nerName}", force=True)
# Out:
# Annotation set 🧾 persons has 10279 annotations

# %%
NE.triggerInterference()
# Out:
# Looking up 28 potential interferences in 2 passes over the corpus ..
# 2 potential conflicting trigger pairs with 2 conflicts
# ----------
# different rows (0 pairs)
# ----------
# Diagnostic trigger interferences written to ~/github/HuygensING/suriano/_temp/ner/1.0.3/.persons/interference.txt

# %%
NE.reportHits(showNoHits=True)
# Out:
# No slot is covered by more than one trigger
# Triggers without hits: 106x:
# Looking up 106 triggers in 2 passes over the corpus ..
# Entities targeted:            818
# Triggers searched for:       1666
# Triggers without hits:        106
#  - completely covered:        106
#  - missing hits:                0
# Triggers with hits:          1560
# Total hits:                 10426
#
# All hits in report file:      ~/github/HuygensING/suriano/_temp/ner/1.0.3/.persons/hits.tsv
# Triggers by slot in file:     ~/github/HuygensING/suriano/_temp/ner/1.0.3/.persons/triggerBySlot.tsv

# %%
NE.makeSheetOfSingleTokens()
NE.setTask(f".{NER_NAME}-single", caseSensitive=False, force=True)
NE.reportHits(showNoHits=True)
# Out:
# Annotation set 🧾 persons-single has 502815 annotations
# No slot is covered by more than one trigger
# Triggers without hits: 14x:
# Looking up 14 triggers in 1 pass over the corpus .
# Entities targeted:           1523
# Triggers searched for:       1523
# Triggers without hits:         14
#  - completely covered:         14
#  - missing hits:                0
# Triggers with hits:          1509
# Total hits:                 502726
#
# All hits in report file:      ~/github/HuygensING/suriano/_temp/ner/1.0.3/.persons-single/hits.tsv
# Triggers by slot in file:     ~/github/HuygensING/suriano/_temp/ner/1.0.3/.persons-single/triggerBySlot.tsv

# %%
NE.setTask(f".{NER_NAME}", caseSensitive=False)
# Out:
# Annotation set 🧾 persons has 10426 annotations

# %% [markdown]
# ### Prepare for stage 2: search variants

# %%
D = NE.variantDetection()
# Out:
# Overview of names by length:
#   10 tokens:   2 names e.g.:
#       cavalier inglese , et il fratello del vescovo di Londra
#       signor d ’ Aspri fratello dell ’ ambasciator dei Stati
#   9 tokens:   2 names e.g.:
#       conte d ’ Henin , chiamato duca di Bornenvil
#       Proveditor general dell ’ arm [ i ] Priuli
#   8 tokens:  15 names e.g.:
#       Alessandro , Giacomo et Pietr ’ Antonio Guadagni
#       ambasciator del signor Granduca nella corte di Praga
#       ambasciator di Francia residente appresso li serenissimi arciduchi
#       doi altri suoi parenti cognato , et cugino
#       doi altri un maschio , et una femina
#   7 tokens:  21 names e.g.:
#       [ duc ] a d ’ Angauleme
#       ambasciator di Spagna residente appresso il Christianissimo
#       Ambasciator straordinario che venne ultimamente di Spagna
#       Ambasciatore , che dal re di Bohemia
#       capitan scocese fratello di quel capitano Seiton
#   6 tokens:  45 names e.g.:
#       al luogotenente di monsignor di Sciatiglione
#       ambasciator Giust ( inia ) no
#       ambasciator Gritti alla corte di Spagna
#       baron di Kessel governator di Husdem
#       baron di Pieterson signor di Meroda
#   5 tokens:  83 names e.g.:
#       A . v . Matenesse
#       accompagnata la sorella di lui
#       Adriano Pieterson Looske da Encusen
#       agente d ’ Inghilterra Trombol
#       agente del re di Marocco
#   4 tokens: 193 names e.g.:
#       agente di quel Principe
#       almirante d ’ Arragona
#       ambasciator Contarini in Francia
#       ambasciator Contarini in Inghilterra
#       ambasciatore Contarini in Inghilterra
#   3 tokens: 497 names e.g.:
#       2 da Principessa
#       Adriano Vander Dussen
#       agente del Kerckoven
#       agente di Fiorenza
#       ambasciator a Constantinopoli
#   2 tokens: 564 names e.g.:
#       abbate Moronato
#       Abraham Pesini
#       Adam Schivelbergh
#       Adrian Pavoni
#       Adrian Ploos
#   1 tokens: 234 names e.g.:
#       Alagamba
#       Alagambe
#       Alagambre
#       Amstenraedt
#       Amsterraedt

# %%
D.prepare()
# Out:
# Alphabet written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/alphabet.tsv
# Text written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/text.txt - 8582308 characters
#   0.00s Collecting the triggers for the lexicon
#   0.00s 1498 triggers collected
#   346 x conte di Mansfelt
#   336 x Pasini
#   236 x Bernvel
#   236 x Spinola
#   212 x principe d’Oranges
#   211 x re di Spagna
#   210 x Carleton
#   208 x principe Mauritio
#   193 x duca di Savoia
#   180 x serenissimi arciduchi
#   ...
#     1 x visconte di Duncaster
#     1 x visconte di Gantes fratello del principe di Pinoe
#     1 x Vuandermil
#     1 x Wandernoot
#     1 x Wassenhovven
#     1 x Wasson[ hoven]
#     1 x Weesterbeeck
#     1 x Weimar il maggiore
#     1 x zelandese nominato Cornelio
#     1 x Zeno
#     1498 lexicon length
# Lexicon written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/lexicon.tsv
# Set up analiticcl
# Computing anagram values for all items in the lexicon...
#  - Found 1498 instances
# Adding all instances to the index...
#  - Found 1493 anagrams
# Creating sorted secondary index...
# Sorting secondary index...
#  - Found 3 anagrams of length 3
#  - Found 13 anagrams of length 4
#  - Found 23 anagrams of length 5
#  - Found 38 anagrams of length 6
#  - Found 49 anagrams of length 7
#  - Found 41 anagrams of length 8
#  - Found 41 anagrams of length 9
#  - Found 29 anagrams of length 10
#  - Found 47 anagrams of length 11
#  - Found 61 anagrams of length 12
#  - Found 70 anagrams of length 13
#  - Found 90 anagrams of length 14
#  - Found 106 anagrams of length 15
#  - Found 103 anagrams of length 16
#  - Found 102 anagrams of length 17
#  - Found 100 anagrams of length 18
#  - Found 83 anagrams of length 19
#  - Found 72 anagrams of length 20
#  - Found 66 anagrams of length 21
#  - Found 53 anagrams of length 22
#  - Found 34 anagrams of length 23
#  - Found 36 anagrams of length 24
#  - Found 25 anagrams of length 25
#  - Found 22 anagrams of length 26
#  - Found 27 anagrams of length 27
#  - Found 18 anagrams of length 28
#  - Found 15 anagrams of length 29
#  - Found 15 anagrams of length 30
#  - Found 6 anagrams of length 31
#  - Found 14 anagrams of length 32
#  - Found 10 anagrams of length 33
#  - Found 5 anagrams of length 34
#  - Found 10 anagrams of length 35
#  - Found 13 anagrams of length 36
#  - Found 4 anagrams of length 37
#  - Found 6 anagrams of length 38
#  - Found 4 anagrams of length 39
#  - Found 3 anagrams of length 40
#  - Found 5 anagrams of length 41
#  - Found 2 anagrams of length 42
#  - Found 3 anagrams of length 43
#  - Found 6 anagrams of length 44
#  - Found 5 anagrams of length 45
#  - Found 1 anagrams of length 46
#  - Found 2 anagrams of length 47
#  - Found 2 anagrams of length 49
#  - Found 1 anagrams of length 50
#  - Found 1 anagrams of length 52
#  - Found 2 anagrams of length 53
#  - Found 2 anagrams of length 54
#  - Found 1 anagrams of length 56
#  - Found 1 anagrams of length 57
#  - Found 1 anagrams of length 59
#  - Found 1 anagrams of length 66
# Constructing Language Model...
#  - No language model provided

# %%
# %%time

# !date

D.search(start=None, end=None, force=1)
# Out:
# Wed Mar 12 10:22:16 CET 2025
#  8582308 text  length
#        0 offset in complete text
#   0.00s Read previously computed variants of the lexicon words ...
#   8.34s  1375523 raw   matches
#   8.34s Filter variants of the lexicon words ...
#   9.35s      697 filtered matches
# 697 variants found
# CPU times: user 9.06 s, sys: 381 ms, total: 9.44 s
# Wall time: 9.55 s

# %%
D.listVariants(end=10)
D.listVariants(start=-10)
# Out:
#    i | variant                   | score | candidate
# ---- | ------------------------- | ----- | -------------------------
#    0 | a Ferdinando              |  0.87 | re Ferdinando
#    1 | a suo figliolo            |  0.87 | un suo figliolo
#    2 | abbot Moronato            |  0.85 | abbate Moronato
#    3 | Adrian Plois              |  0.88 | Adrian Ploos
#    4 | Adriano Ploos             |  0.85 | Adrian Ploos
#    5 | Adrien Ploos              |  0.86 | Adrian Ploos
#    6 | agente del Kerkoven       |  0.89 | agente del Kerckoven
#    7 | al figliolo               |  0.88 | il figliolo
#    8 | al suo figlio             |  0.89 | il suo figlio
#    9 | Alag]ambe                 |  0.84 | Alagambe
# ---- | ------------------------- | ----- | -------------------------
# 697 variants found and written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/variants.tsv
#    i | variant                   | score | candidate
# ---- | ------------------------- | ----- | -------------------------
#  -10 | Vorberghen                |  0.86 | Vosberghen
#   -9 | Vosbergen                 |  0.88 | Vosberghen
#   -8 | Wassnhoven                |  0.86 | Wassonhoven
#   -7 | Wassomhovem               |  0.85 | Wassonhovem
#   -6 | Wasson[hoven              |  0.85 | Wassonhoven
#   -5 | Wassonhove                |  0.90 | Wassonhoven
#   -4 | Wassonoven                |  0.86 | Wassonhoven
#   -3 | Willem Pietersen          |  0.90 | Willem Pieterssen
#   -2 | è figliolo                |  0.86 | il figliolo
#   -1 | è figliolo                |  0.86 | un figliolo
# ---- | ------------------------- | ----- | -------------------------
# 697 variants found and written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/variants.tsv

# %%
D.mergeTriggers()
# Out:
# 218 excluded variants found in ~/github/HuygensING/suriano/ner/specs/persons-notmerged.txt
# 213 variants excluded as trigger
# row  trigger                                  ~> variant                                  = occurences
# 8    Guglielmo di Nassau                      ~> Guglielmo de Nassau                      = 09x1
# 8    Guglielmo di Nassau                      ~> Guglielmo di Nansau                      = 08x1
# 8    conte Guglielmo suo figlio               ~> conte Guglielmo suo figliolo             = 08x1
# 13   vescovo di Paterborn                     ~> vescovo di Paterbon                      = 07x1
# 14   duca di Nevers                           ~> duca di Nivers                           = 11x1
# 15   Massimiliano                             ~> Massimilia                               = 11x1
# 18   duca di Guisa                            ~> duca di Guesa                            = 07x1
# 19   cardinal Lodovisio                       ~> card(ina)l Lodovisio                     = 10x1
# 20   cardinal Lodovisio                       ~> card(ina)l Lodovisio                     = 10x1
# 871  Miller                                   ~> Moller                                   = 06x1
# 871  Miller                                   ~> Mille                                    = 07x1
# 871  Miller                                   ~> Mille                                    = 08x2
# 871  Miller                                   ~> Mille                                    = 09x1
# 871  Miller                                   ~> Mille                                    = 11x1
# 871  Miller                                   ~> Muller                                   = 06x5
# 871  Miller                                   ~> Miler                                    = 11x1
# 871  Miller                                   ~> Miler                                    = 12x1
# 873  un moscovita                             ~> moscovita                                = 06x2
# 238 triggersets expanded with 481 triggers
# Wrote merge report to file ~/github/HuygensING/suriano/ner/specs/persons-merged-report.tsv
# Wrote merged triggers to sheet ~/github/HuygensING/suriano/ner/specs/persons-merged.xlsx

# %% [markdown]
# ### Stage 2

# %%
nerStage = 2
nerName, nerOutFile = setStage(nerStage)
# Out:
# Stage 2: working with sheet persons-merged

# %%
NE = A.makeNer(caseSensitive=False, silent=False)
# Out:
# normalizeChars() loaded from ~/github/HuygensING/suriano/ner/code.py
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
NE.setTask(f".{nerName}", force=True)
# Out:
# Annotation set 🧾 persons-merged has 11821 annotations

# %%
NE.triggerInterference()
# Out:
# Looking up 29 potential interferences in 2 passes over the corpus ..
# 2 potential conflicting trigger pairs with 2 conflicts
# ----------
# different rows (0 pairs)
# ----------
# Diagnostic trigger interferences written to ~/github/HuygensING/suriano/_temp/ner/1.0.3/.persons-merged/interference.txt

# %%
NE.reportHits(showNoHits=True)
# Out:
# No slot is covered by more than one trigger
# Triggers without hits: 173x:
# Looking up 173 triggers in 2 passes over the corpus ..
# durante di prignì                        ()          : 03@011:9 x 1, 03@018:11 x 1
# smit                                     (02)        : 06@028:132 x 2, 06@028:134 x 1, 06@028:175 x 1, 06@034:74 x 1
# signor conte gioan                       (02-05)     : 06@034:160 x 1
# ambasciator de francia                   (03)        : 12@030:25 x 1
# ambasciatore di franza                   (03)        : 02@012:15 x 1, 08@059:18 x 1
# ambasciatori francia                     (03)        : 04@036:9 x 1
# ambasciator inglese straordinario        (04)        : 08@067:14 x 1
# conte gio ernesto                        (06, 08, 09, 11): 04@026:7 x 1
# figliolo maggiore                        (08)        : 04@016:7 x 1, 11@100:23 x 1
# al suo figlio                            (09)        : 04@019:8 x 1
# ambasciatore di danimarca                (10)        : 12@036:93 x 2
# presidenti di gheldria                   (10)        : 04@031:13 x 1
# deputati della rocella                   (11)        : 10@058:27 x 1, 10@098:13 x 1
# un figliol maschio                       (11)        : 09@090:8 x 1
# moller                                   (12)        : 06@034:106 x 1
# moscovita                                (12)        : 05@021:7 x 1, 05@043:9 x 1, 06@031:14 x 1, 06@032:16 x 1, 06@035:25 x 1
#                                                        10@060:11 x 1
# muller                                   (12)        : 06@028:132 x 1, 06@028:134 x 1, 06@028:137 x 1, 06@028:197 x 2
# Entities targeted:            819
# Triggers searched for:       2142
# Triggers without hits:        173
#  - completely covered:        156
#  - missing hits:               17
# Triggers with hits:          1969
# Total hits:                 11962
#
# All hits in report file:      ~/github/HuygensING/suriano/_temp/ner/1.0.3/.persons-merged/hits.tsv
# Triggers by slot in file:     ~/github/HuygensING/suriano/_temp/ner/1.0.3/.persons-merged/triggerBySlot.tsv

# %%
nerMeta(*NE.getMeta(), silent=False)

# %%
NE.bakeEntities()
# Out:
# Entity consolidation for 11962 entity occurrences into version 1.0.3e
#  11962 entity occurrences
#    786 distinct entities
#   0.00s Creating a dataset with entity nodes ...
#   0.00s preparing and checking ...
#   0.00s Feature overview: 34 for nodes; 2 for edges; 1 configs; 9 computed
#    |     3.90s done
#    |   Delete types: t                   : keep:   shift  nodes       1-1738519 to         1-1738519
#    |   Delete types: author              : keep:   shift  nodes 1738520-1739244 to   1738520-1739244
#    |   Delete types: bibl                : keep:   shift  nodes 1739245-1739969 to   1739245-1739969
#    |   Delete types: biblScope           : keep:   shift  nodes 1739970-1740694 to   1739970-1740694
#    |   Delete types: body                : keep:   shift  nodes 1740695-1741419 to   1740695-1741419
#    |   Delete types: cell                : keep:   shift  nodes 1741420-1755754 to   1741420-1755754
#    |   Delete types: chunk               : keep:   shift  nodes 1755755-1802724 to   1755755-1802724
#    |   Delete types: collection          : keep:   shift  nodes 1802725-1803449 to   1802725-1803449
#    |   Delete types: correspAction       : keep:   shift  nodes 1803450-1804899 to   1803450-1804899
#    |   Delete types: correspDesc         : keep:   shift  nodes 1804900-1805624 to   1804900-1805624
#    |   Delete types: date                : keep:   shift  nodes 1805625-1806349 to   1805625-1806349
#    |   Delete types: div                 : keep:   shift  nodes 1806350-1810497 to   1806350-1810497
#    |   Delete types: editor              : keep:   shift  nodes 1810498-1811222 to   1810498-1811222
#    |   Delete types: file                : keep:   shift  nodes 1811223-1811947 to   1811223-1811947
#    |   Delete types: fileDesc            : keep:   shift  nodes 1811948-1812672 to   1811948-1812672
#    |   Delete types: folder              : keep:   shift  nodes 1812673-1812683 to   1812673-1812683
#    |   Delete types: head                : keep:   shift  nodes 1812684-1814765 to   1812684-1814765
#    |   Delete types: hi                  : keep:   shift  nodes 1814766-1830219 to   1814766-1830219
#    |   Delete types: idno                : keep:   shift  nodes 1830220-1832394 to   1830220-1832394
#    |   Delete types: institution         : keep:   shift  nodes 1832395-1833119 to   1832395-1833119
#    |   Delete types: ln                  : keep:   shift  nodes 1833120-1992521 to   1833120-1992521
#    |   Delete types: metamark            : keep:   shift  nodes 1992522-1995548 to   1992522-1995548
#    |   Delete types: msDesc              : keep:   shift  nodes 1995549-1996273 to   1995549-1996273
#    |   Delete types: msIdentifier        : keep:   shift  nodes 1996274-1996998 to   1996274-1996998
#    |   Delete types: name                : keep:   shift  nodes 1996999-1999173 to   1996999-1999173
#    |   Delete types: note                : keep:   shift  nodes 1999174-2012453 to   1999174-2012453
#    |   Delete types: num                 : keep:   shift  nodes 2012454-2013178 to   2012454-2013178
#    |   Delete types: p                   : keep:   shift  nodes 2013179-2061865 to   2013179-2061865
#    |   Delete types: page                : keep:   shift  nodes 2061866-2070629 to   2061866-2070629
#    |   Delete types: pb                  : keep:   shift  nodes 2070630-2079393 to   2070630-2079393
#    |   Delete types: profileDesc         : keep:   shift  nodes 2079394-2080118 to   2079394-2080118
#    |   Delete types: ptr                 : keep:   shift  nodes 2080119-2091939 to   2080119-2091939
#    |   Delete types: publicationStmt     : keep:   shift  nodes 2091940-2092664 to   2091940-2092664
#    |   Delete types: quote               : keep:   shift  nodes 2092665-2092674 to   2092665-2092674
#    |   Delete types: ref                 : keep:   shift  nodes 2092675-2092675 to   2092675-2092675
#    |   Delete types: resp                : keep:   shift  nodes 2092676-2093400 to   2092676-2093400
#    |   Delete types: respStmt            : keep:   shift  nodes 2093401-2094125 to   2093401-2094125
#    |   Delete types: row                 : keep:   shift  nodes 2094126-2098113 to   2094126-2098113
#    |   Delete types: settlement          : keep:   shift  nodes 2098114-2100288 to   2098114-2100288
#    |   Delete types: sourceDesc          : keep:   shift  nodes 2100289-2101013 to   2100289-2101013
#    |   Delete types: table               : keep:   shift  nodes 2101014-2101256 to   2101014-2101256
#    |   Delete types: teiHeader           : keep:   shift  nodes 2101257-2101981 to   2101257-2101981
#    |   Delete types: text                : keep:   shift  nodes 2101982-2102706 to   2101982-2102706
#    |   Delete types: title               : keep:   shift  nodes 2102707-2103431 to   2102707-2103431
#    |   Delete types: titleStmt           : keep:   shift  nodes 2103432-2104156 to   2103432-2104156
#    |   Delete types: max node: shifted from 2104156 to 2104156
#   4.00s add types ...
#    |     0.01s done (2 types)
#    |      |   ent, entity
#   4.02s applying updates ...
#   4.28s write TF data as version 1.0.3e ...
#   0.00s Not all of the warp features otype and oslots are present in
# ~/github/HuygensING/suriano/tf/1.0.3e
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Exporting 37 node and 3 edge and 1 configuration features to ~/github/HuygensING/suriano/tf/1.0.3e:
#   0.00s VALIDATING oslots feature
#   0.09s VALIDATING oslots feature
#   0.09s maxSlot=    1738519
#   0.09s maxNode=    2116904
#   0.12s OK: oslots is valid
#    |     0.60s T after                to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.02s T chunk                to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T corresp              to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T date                 to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T editorNotes          to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T eid                  to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T empty                to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T ename                to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T extraspace           to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T facs                 to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T file                 to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T folder               to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T id                   to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.05s T is_meta              to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.08s T is_note              to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T kind                 to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T n                    to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.19s T otype                to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T recipient            to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T recipientLoc         to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T ref                  to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T rend                 to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.04s T rend_decoded         to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T rend_displaced       to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T rend_footnote        to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T rend_superscript     to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T role                 to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T sender               to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T senderLoc            to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T shelfmark            to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T source               to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.66s T str                  to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T summary              to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T target               to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T type                 to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T unit                 to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T when                 to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T eoccs                to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T link_target          to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     1.04s T oslots               to ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s M otext                to ~/github/HuygensING/suriano/tf/1.0.3e
#   2.92s Exported 37 node features and 3 edge features and 1 config features to ~/github/HuygensING/suriano/tf/1.0.3e
#   7.21s all done
#   7.26s Done
# The dataset with entities is now in version 1.0.3e
# The dataset with entities is now the standard version
# True

# %% [markdown]
# We load the new data:

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/1.0.3e</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/ner</span>
# This is Text-Fabric 12.6.4
# 41 features found and 0 ignored
#    |     0.48s T otype                from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     6.13s T oslots               from ~/github/HuygensING/suriano/tf/1.0.3e
#   6.62s Dataset without structure sections in otext:no structure functions in the T-API
#    |     3.40s T after                from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     4.04s T str                  from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.08s T chunk                from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T folder               from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T file                 from ~/github/HuygensING/suriano/tf/1.0.3e
#    |      |     0.12s C __levels__           from otype, oslots, otext
#    |      |       15s C __order__            from otype, oslots, __levels__
#    |      |     0.39s C __rank__             from otype, __order__
#    |      |       17s C __levUp__            from otype, oslots, __rank__
#    |      |     3.48s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.34s C __characters__       from otext
#    |      |     3.58s C __boundary__         from otype, oslots, __rank__
#    |      |     0.52s C __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, folder, file, chunk
#     54s All features loaded / computed - for details use TF.isLoaded()
#    |     0.00s T corresp              from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T date                 from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T editorNotes          from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.03s T eid                  from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.06s T empty                from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T ename                from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T eoccs                from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.07s T extraspace           from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.06s T facs                 from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.03s T id                   from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.28s T is_meta              from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.46s T is_note              from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.03s T kind                 from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.04s T link_target          from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.07s T n                    from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T recipient            from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T recipientLoc         from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T ref                  from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.07s T rend                 from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.18s T rend_decoded         from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T rend_displaced       from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.02s T rend_footnote        from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T rend_superscript     from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T role                 from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T sender               from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T senderLoc            from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T shelfmark            from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T source               from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.01s T summary              from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.03s T target               from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.02s T type                 from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T unit                 from ~/github/HuygensING/suriano/tf/1.0.3e
#    |     0.00s T when                 from ~/github/HuygensING/suriano/tf/1.0.3e
#   1.52s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.6.4</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/about.md" title="provenance of HuygensING - suriano/tf">HuygensING - suriano 1.0.3e</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="HuygensING - suriano feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>11</td>
#     <td>158047.18</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>725</td>
#     <td>2397.96</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>725</td>
#     <td>2206.00</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>725</td>
#     <td>2206.00</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4148</td>
#     <td>737.03</td>
#     <td><i>176</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>725</td>
#     <td>191.96</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8764</td>
#     <td>157.79</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>725</td>
#     <td>125.82</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>725</td>
#     <td>51.06</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>46970</td>
#     <td>37.01</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>725</td>
#     <td>125.82</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>725</td>
#     <td>66.14</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>entity</th>
#     <td>786</td>
#     <td>34.77</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>48687</td>
#     <td>32.48</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>725</td>
#     <td>31.56</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>725</td>
#     <td>31.56</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>725</td>
#     <td>19.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13280</td>
#     <td>17.09</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>1</td>
#     <td>15.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>725</td>
#     <td>14.08</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>159402</td>
#     <td>9.92</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>725</td>
#     <td>8.73</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>725</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1450</td>
#     <td>7.82</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>15454</td>
#     <td>7.81</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2175</td>
#     <td>6.52</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>725</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>725</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2082</td>
#     <td>4.31</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>725</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>725</td>
#     <td>2.70</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2175</td>
#     <td>2.69</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ent</th>
#     <td>11962</td>
#     <td>2.28</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>725</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2175</td>
#     <td>1.32</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>metamark</th>
#     <td>3027</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8764</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11821</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1738519</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - suriano/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/1.0.3e/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2025-03-12T09:23:11+00:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>1.0.3e</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/1.0.3e/chunk.tf">chunk</a>
# </d
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/thumb</span>
# Found 8766 images<br>

# %% [markdown]
# ## Step 6: Convert TF to WATM
#
# N.B. For docs click the WATM link in the output cell.

# %%
WA = WATM(A, "tei", skipMeta=False, prod=True)
# WA = WATM(A, "tei", skipMeta=False, prod=False)
WA.makeText()
WA.makeAnno()
WA.writeAll()
WA.testAll()
# Out:
# conversion settings read from ~/github/HuygensING/suriano/config/watm.yml
# IIIF settings read from ~/github/HuygensING/suriano/config/iiif.yml
# textRepoLevel is section level 'folder'
# [WATM exporter documentation](https://annotation.github.io/text-fabric/tf/convert/watm.html)
# 	Writing WATM ...
# Writing production data to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod
# Text file    0:    44343 segments to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/text-0.tsv
# Text file    1:   117901 segments to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/text-1.tsv
# Text file    2:   147685 segments to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/text-2.tsv
# Text file    3:   109425 segments to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/text-3.tsv
# Text file    4:   154932 segments to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/text-4.tsv
#
# Text files all:  1738519 segments to 11 files
# Anno file    1:   400000 annotations written to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/anno-1.tsv
# Anno file    2:   400000 annotations written to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/anno-2.tsv
# Anno file    3:   246988 annotations written to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/anno-3.tsv
# Inherited annotations: 0
# Anno files all:  1046988 annotations to 3 files
# Slot mapping written to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/pos2node.tsv
# Node mapping written to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/anno2node.tsv
# Logical pairs (6908) written to ~/github/HuygensING/suriano/watm/1.0.3e-031/prod/logicalpairs.tsv
# Extra file datasource/entities/entitymeta.json copied to the WATM directory
# 	Testing WATM ...
# Testing the text ...
# 	TF: 1738519
# 	WA: 1738519
# OK - whether the amounts of tokens agree
# 	TF: Letter 02.001 date 1 ... "corrected on "23."
# 	WA: Letter 02.001 date 1 ... "corrected on "23."
# OK - whether the text is the same
# Testing the elements ...
# 	TF: 321865
# 	WA: 321865
# OK - whether the amounts of elements and nodes agree
# Testing the processing instructions ...
# 	TF:      0
# 	WA:      0
# OK - whether the amounts of processing instructions agree
# Testing the element/pi annotations ...
# 	2060384 element/pi annotations
# 	Element      : 321865 x
# 	Pi           :      0 x
# 	Other        : 687885 x
# 	Good name    : 321865 x
# 	Wrong name   :      0 x
# 	Good target  : 321865 x
# 	Wrong target :      0 x
# 	Unmapped     :      0 x
# OK - whether all element/pi annotations have good bodies
# OK - whether all element/pi annotations have good targets
# Testing the attributes ...
# 	328337 attribute values
# 	Good:     328337 x
# 	Wrong:        0 x
# OK - whether annotations are consistent with features
# 	WA attributes: 328337
# 	TF attributes: 328337
# OK - whether annotations are complete w.r.t. features
# Testing the format attributes ...
# 	120735 format values
# 	formatting attributes:
# 		107647 x decoded
# 		 11830 x footnote
# 		  1071 x superscript
# 		   187 x displaced
# 	Good:     120735 x
# 	Wrong:        0 x
# OK - whether format annotations are consistent with features
# 	WA format attributes: 120735
# 	TF format attributes: 120735
# OK - whether format annotations are complete w.r.t. features
# Testing the extra annotations ...
# 	0 extra feature values
# 	0 extra annotations
# OK - whether the extra annotations agree
# Testing the edges ...
# 	Found: 2060384 nodes
# 	Found edge link_target with 11821 starting nodes
# 	Checking edge link_target
# 		same 11821 fromNodes
# 	OK - 11821 toNodes checked
# OK - whether all edges agree
# Overall outcome ...
# OK - whether all tests passed

# %% [markdown]
# ## Step 7: Generate IIIF manifests

# %%
# II = IIIF(Tei.teiVersion, A, REPORT_PAGESDIR, prod=True, silent=False)
II = IIIF(Tei.teiVersion, A, REPORT_PAGESDIR, prod=False, silent=False)
II.manifests()
# Out:
# Found covers in directory: ~/github/HuygensING/suriano/scans/covers
# IIIF settings read from ~/github/HuygensING/suriano/config/iiif.yml
# Maximum dimensions: W = 1871 H = 1315
# Average dimensions: W =  910 H = 1071
# Average deviation:  W =  228 H =  145
# Maximum dimensions: W = 1232 H = 1273
# Average dimensions: W =  716 H =  959
# Average deviation:  W =  105 H =  133
# Using page info file ~/github/HuygensING/suriano/report/pages/pageseq.json
# Collections:
#    02 with  262 pages
#    03 with  660 pages
#    04 with  806 pages
#    05 with  688 pages
#    06 with  684 pages
#    07 with  628 pages
#    08 with  988 pages
#    09 with  944 pages
#    10 with 1062 pages
#    11 with 1116 pages
#    12 with  928 pages
# IIIF manifests generated in ~/github/HuygensING/suriano/static/dev/manifests

# %% [markdown]
# ## Step 8: Deploy to k8s and TeamText VM

# %% [markdown]
# NB: you need to have access to the k8s cluster and to the team text VM.
#
# That means:
#
# * The LDAP of the relevant k8s clusters know you
# * You have an ssh key-based login on the Team Text VPN
# * You work inside the firewall

# %%
# !./provision.sh watm
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# WATM export version: 1.0.1e-029
# anno-1.tsv                                    100%   17MB   5.9MB/s   00:02
# anno-3.tsv                                    100%   10MB   6.4MB/s   00:01
# anno-2.tsv                                    100%   15MB   6.6MB/s   00:02
# anno2node.tsv                                 100% 5658KB   5.9MB/s   00:00
# text-6.tsv                                    100% 1228KB   4.3MB/s   00:00
# text-7.tsv                                    100% 1196KB   4.1MB/s   00:00
# text-5.tsv                                    100% 1018KB   6.0MB/s   00:00
# text-4.tsv                                    100%  914KB   5.8MB/s   00:00
# text-0.tsv                                    100%  267KB   4.3MB/s   00:00
# text-1.tsv                                    100%  705KB   6.2MB/s   00:00
# text-3.tsv                                    100%  655KB   6.0MB/s   00:00
# text-2.tsv                                    100%  879KB   6.3MB/s   00:00
# text-9.tsv                                    100% 1337KB   6.0MB/s   00:00
# text-8.tsv                                    100% 1389KB   5.3MB/s   00:00
# entitymeta.json                               100%  339KB   5.3MB/s   00:00
# pos2node.tsv                                  100%   26MB   6.2MB/s   00:04
# text-10.tsv                                   100%  776KB   5.2MB/s   00:00
# logicalpairs.tsv                              100%  177KB   4.7MB/s   00:00

# %%
# !./provision.sh files
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# copying to pod: prod/covers.html
# copying to pod: prod/logo
# copying to pod: prod/manifests
# copying to pod: both/metadata

# %%
# !./provision.sh prod images

# %% [markdown]
# ## Step 9: Test the images

# %% [markdown]
# * [covers](https://data.suriano.huygens.knaw.nl/files/covers.html)
#
# * [02.json](https://data.suriano.huygens.knaw.nl/files/manifests/02.json)
#
# * [page 02_171r](https://data.suriano.huygens.knaw.nl/iiif/3/pages%2F02_071r.jpg/full/max/0/default.jpg)

# %% [markdown]
# # On the command line: Step by step
#
# Here we do the main steps of the conversion.
#
# Every step is a separate run of a python program.
# After completion of a step, all information to run a next step, is saved to disk in the form
# of result files and report files.
#
# If the results of earlier steps are present, you can just do the following step.

# %% [markdown]
# ## Step 0: Initialization
#
# **N.B.** Check the VERSION variable here!

# %%
VERSION
# Out:
# '1.0.2'

# %% [markdown]
# ## Step1: Scan ingest

# %%
# %%time

# !python make.py ingest -
# Out:
# Ingest scans ...
# CPU times: user 9.15 ms, sys: 7.67 ms, total: 16.8 ms
# Wall time: 1.29 s

# %% [markdown]
# ## Step 2: Scan processing

# %%
# %%time

# !python make.py scans
# Out:
# Process scans ...
# CPU times: user 6.13 ms, sys: 7.51 ms, total: 13.6 ms
# Wall time: 615 ms

# %% [markdown]
# ## Step 3: From DOCX to TEI

# %%
# %%time

# !python make.py docx2tei $VERSION
# Out:
# DOCX ==> TEI files ...
# DOCX => simple TEI per filza ...
# DOCX => headers ...
# Collecting transcribers ...
# Collecting page scans ...
# Collecting excel metadata ...
# simple TEI per filza => enriched TEI per letter ...
# 	There were 542 warnings.
# CPU times: user 12.8 ms, sys: 9.18 ms, total: 22 ms
# Wall time: 1.66 s

# %% [markdown]
# ## Step 4: From TEI to TF

# %%
# %%time

# !python make.py tei2tf - $VERSION
# Out:
# TEI => TF ...
# 	Validating TEI ...
# 	Converting TEI ...
# 	Loading TF ...
# CPU times: user 322 ms, sys: 119 ms, total: 441 ms
# Wall time: 1min 9s

# %% [markdown]
# ## Step 5: Mark named entities

# %%
# %%time

# !python make.py ner $VERSION
# Out:
# Annotate named entities ...
# 	Loading TF  ...
# 5 rows with a duplicate name:
#   r305: William, Count of Nassau-Siegen
#   r359: William of Orange
#   r361: Maurice of Nassau
#   r506: Henry II, Duke of Lorraine
#   r645: Guillaume III de Melun
# 1 row without a name:
# 	e.g.: 365
# 149 rows without triggers:
# 	e.g.: 6, 8, 16, 21, 24, 26, 29, 30, 32, 34
# Clash: Gugliemo di Nassau: r9 vs r50
# Clash: Nicolò Perez: r75 vs r571
# Clash: conte di Frusten: r148 vs r149
# Clash: conte di Wanderlip: r150 vs r151
# Clash: colonello Sciombergh: r253 vs r352
# Clash: colonnello Sciombergh: r253 vs r352
# Clash: signor di Rocalaura: r386 vs r459
# Clash: colonel Rocalaura: r386 vs r459
# Clash: monsignor di Rocalaura: r386 vs r459
# Clash: colonello Rocalaura: r386 vs r459
# 	491 entities targeted with 6063 occurrences. See ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/0.4.3/.people.0.6/hits.tsv
# 	Loading TF with entities ...
# CPU times: user 306 ms, sys: 107 ms, total: 413 ms
# Wall time: 1min 3s

# %% [markdown]
# ## Step 6: Convert TF to WATM

# %%
# %%time

# !python make.py watm "$VERSION"e
#!python make.py watm "$VERSION"e --no-prod
# Out:
# TF => WATM ...
# 	Loading TF ...
# 	Making WATM for version 0.4.3e
# 	Writing WATM ...
# 	Testing WATM ...
# 	OK - whether all tests passed
# CPU times: user 45.9 ms, sys: 20.7 ms, total: 66.7 ms
# Wall time: 9.3 s

# %% [markdown]
# ## Step 7: Generate IIIF manifests

# %% [markdown]
# ### Development

# %%
# %%time

# !python make.py iiif "$VERSION"e
#!python make.py iiif "$VERSION"e --no-prod
# Out:
# Generate IIIF manifests ...
# CPU times: user 13.7 ms, sys: 13.1 ms, total: 26.8 ms
# Wall time: 2.24 s

# %% [markdown]
# ## Step 8: Deploy to k8s and TeamText VM

# %%
# %%time

# !python make.py deploy
#!python make.py deploy --no-prod

# %% [markdown]
# # Express: One shot
#
# Here is the express, mindless way to convert the corpus.
# If something goes wrong, you can follow the step-by-step section or the debugging section.

# %% [markdown]
# **N.B.** Check the VERSION variable here!

# %%
VERSION
# Out:
# '0.7.1'

# %%
# %%time

# !python make.py all $VERSION
# !python make.py all $VERSION --no-prod

# %% [markdown]
# # Convert from TEI to TF
#
# We convert Suriano TEI to TF.
#
# This notebook is bare, no explanations, nu illustrations, no checks.
# For more documentation, try any of the following variants:
#
# * *convertExpress* : as few commands/feedback/interaction as possible,
# * [convertSteps](convertSteps.ipynb): broken down in a few command line commands, more feedback
# * [convertDetails](convertDetails.ipynb): run from Python with full control

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tf.convert.tei import TEI
from tf.convert.addnlp import NLPipeline
from tf.advanced.helpers import dm

# %%
ORG = "HuygensING"
REPO = "suriano"

# %% [markdown]
# ### Step 1: Check

# %%
Tei = TEI(verbose=-1, tei=0, tf="0.0.1pre")

# %%
Tei.task(check=True, verbose=1, validate=True)
# Out:
# TEI to TF checking: ~/github/HuygensING/suriano/tei/2023-07-13 => ~/github/HuygensING/suriano/report/2023-07-13
# Processing instructions are ignored
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# INFO: Needs dcr.xsd (exists)
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   0 changing override(s)
# Section model I
# Start folder filza2:
#    1 suriano                                1.xml
#    2 suriano                                10.xml
#    3 suriano                                11.xml
#    4 suriano                                12.xml
#    5 suriano                                13.xml
#    6 suriano                                14.xml
#    7 suriano                                15.xml
#    8 suriano                                16.xml
#    9 suriano                                17.xml
#   10 suriano                                18.xml
#   11 suriano                                19.xml
#   12 suriano                                2.xml
#   13 suriano                                3.xml
#   14 suriano                                4.xml
#   15 suriano                                5.xml
#   16 suriano                                6.xml
#   17 suriano                                7.xml
#   18 suriano                                8.xml
#   19 suriano                                9.xml
#
# End   folder filza2
# Start folder filza3:
#   20 suriano                                1.xml
#   21 suriano                                10.xml
#   22 suriano                                11.xml
#   23 suriano                                12.xml
#   24 suriano                                13.xml
#   25 suriano                                14.xml
#   26 suriano                                15.xml
#   27 suriano                                16.xml
#   28 suriano                                17.xml
#   29 suriano                                18.xml
#   30 suriano                                19.xml
#   31 suriano                                2.xml
#   32 suriano                                20.xml
#   33 suriano                                21.xml
#   34 suriano                                22.xml
#   35 suriano                                23.xml
#   36 suriano                                24.xml
#   37 suriano                                25.xml
#   38 suriano                                26.xml
#   39 suriano                                27.xml
#   74 suriano                                9.xml
# End   folder filza3
# Start folder filza4:
#   75 suriano                                1.xml
#   76 suriano                                10.xml
#   77 suriano                                11.xml
#   78 suriano                                12.xml
#   79 suriano                                13.xml
#   80 suriano                                14.xml
#   81 suriano                                15.xml
#   82 suriano                                16.xml
#   83 suriano                                17.xml
#   84 suriano                                18.xml
#   85 suriano                                19.xml
#   86 suriano                                2.xml
#   87 suriano                                20.xml
#   88 suriano                                21.xml
#   89 suriano                                22.xml
#   90 suriano                                23.xml
#   91 suriano                                24.xml
#   92 suriano                                25.xml
#   93 suriano                                26.xml
#   94 suriano                                27.xml
#  149 suriano                                9.xml
# End   folder filza4
# 149 suriano file(s) ...
# 	Validating ...
# 		Elapsed time 501+710=1211 milliseconds
# 	Making inventory ...
#
# 143 validation error(s) in 143 file(s) written to ~/github/HuygensING/suriano/report/2023-07-13/errors.txt
# 109 info line(s) written to ~/github/HuygensING/suriano/report/2023-07-13/elements.txt
# 584 tag(s) type info written to ~/github/HuygensING/suriano/report/2023-07-13/types.txt
# 40 tags of which 0 with multiple namespaces written to ~/github/HuygensING/suriano/report/2023-07-13/namespaces.txt
# Refs written to ~/github/HuygensING/suriano/report/2023-07-13/refs.txt
# 	resolvable: 1351 in 1956
# 	dangling:      0 in    0
# 	ALL:        1351 in 1956
# Ids written to ~/github/HuygensING/suriano/report/2023-07-13/ids.txt
# 	referenced: 1351 by 1956
# 	non-unique: 2143
# 	unused:     4918
# 	ALL:        4126 in 6269
# False

# %% [markdown]
# ### Step 2: Convert

# %%
Tei.good = True
Tei.task(convert=True, verbose=0)
# Out:
# Processing instructions are ignored
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   0 changing override(s)
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# Start folder filza2:
#    1 suriano                                1.xml
#    2 suriano                                10.xml
#    3 suriano                                11.xml
#    4 suriano                                12.xml
#    5 suriano                                13.xml
#    6 suriano                                14.xml
#    7 suriano                                15.xml
#    8 suriano                                16.xml
#    9 suriano                                17.xml
#   10 suriano                                18.xml
#   11 suriano                                19.xml
#   12 suriano                                2.xml
#   13 suriano                                3.xml
#   14 suriano                                4.xml
#   15 suriano                                5.xml
#   16 suriano                                6.xml
#   17 suriano                                7.xml
#   18 suriano                                8.xml
#   19 suriano                                9.xml
#
# End   folder filza2
# Start folder filza3:
#   20 suriano                                1.xml
#   21 suriano                                10.xml
#   22 suriano                                11.xml
#   23 suriano                                12.xml
#   24 suriano                                13.xml
#   25 suriano                                14.xml
#   26 suriano                                15.xml
#   27 suriano                                16.xml
#   28 suriano                                17.xml
#   29 suriano                                18.xml
#   30 suriano                                19.xml
#   31 suriano                                2.xml
#   32 suriano                                20.xml
#   33 suriano                                21.xml
#   34 suriano                                22.xml
#   35 suriano                                23.xml
#   36 suriano                                24.xml
#   37 suriano                                25.xml
#   38 suriano                                26.xml
#   39 suriano                                27.xml
#   74 suriano                                9.xml
# End   folder filza3
# Start folder filza4:
#   75 suriano                                1.xml
#   76 suriano                                10.xml
#   77 suriano                                11.xml
#   78 suriano                                12.xml
#   79 suriano                                13.xml
#   80 suriano                                14.xml
#   81 suriano                                15.xml
#   82 suriano                                16.xml
#   83 suriano                                17.xml
#   84 suriano                                18.xml
#   85 suriano                                19.xml
#   86 suriano                                2.xml
#   87 suriano                                20.xml
#   88 suriano                                21.xml
#   89 suriano                                22.xml
#   90 suriano                                23.xml
#   91 suriano                                24.xml
#   92 suriano                                25.xml
#   93 suriano                                26.xml
#   94 suriano                                27.xml
#  149 suriano                                9.xml
# End   folder filza4
#
# Resolving links into edges ...
# 	1351 in 1956 reference(s) resolved
#    |     4.95s "delete" actions: 0
#    |     4.95s "edge" actions: 1956
#    |     4.95s "feature" actions: 2190047
#    |     4.95s "node" actions: 280465
#    |     4.95s "resume" actions: 0
#    |     4.95s "slot" actions: 1451327
#    |     4.95s "terminate" actions: 280465
#    |    1731792 nodes of all types
#    |     5.03s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.02s OK
#    |     0.00s reordering nodes ...
#    |     1.19s Max node = 1731792
#    |     1.19s OK
#    |     0.00s reassigning feature values ...
#    |     0.44s OK
# True

# %% [markdown]
# ### Step 3: Load the TF data
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and precomputations are performed.
# Next time the loading will be much quicker.

# %%
Tei.task(load=True)
# Out:
# True

# %% [markdown]
# ### Step 4: Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# App updated
# True

# %% [markdown]
# ### Step 5: Add tokens and sentences

# %%
Apre = use(f"{ORG}/{REPO}:clone", checkout="clone", hoist=globals())
NLP = NLPipeline(lang="en", verbose=0, write=True)
NLP.loadApp(Apre)

(text, positions) = NLP.task(plaintext=True)
(tokens, sentences) = NLP.task(lingo=True, text=text)
newVersion = NLP.task(
    ingest=True,
    positions=positions,
    tokens=tokens,
    sentences=sentences,
)
Tei.task(apptoken=True)
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/0.0.1pre</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 12.0.5</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/about.md" title="provenance of HuygensING - suriano/tf">HuygensING - suriano 0.0.1pre</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="HuygensING - suriano feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>3</td>
#     <td>483775.67</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>149</td>
#     <td>9740.45</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>149</td>
#     <td>9509.26</td>
#     <td>98</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>149</td>
#     <td>9509.26</td>
#     <td>98</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>596</td>
#     <td>2435.11</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>895</td>
#     <td>3165.57</td>
#     <td><i>195</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>26</td>
#     <td>897.42</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>149</td>
#     <td>231.19</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>149</td>
#     <td>184.21</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>7798</td>
#     <td>180.64</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>136</td>
#     <td>171.38</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>149</td>
#     <td>95.64</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>149</td>
#     <td>87.57</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>282</td>
#     <td>82.61</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>149</td>
#     <td>78.62</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>149</td>
#     <td>78.62</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>149</td>
#     <td>44.98</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>149</td>
#     <td>44.98</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>149</td>
#     <td>44.98</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>149</td>
#     <td>33.81</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>2002</td>
#     <td>33.35</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>149</td>
#     <td>32.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>3950</td>
#     <td>30.26</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>149</td>
#     <td>29.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>1</td>
#     <td>27.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>149</td>
#     <td>21.77</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>149</td>
#     <td>21.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>149</td>
#     <td>17.03</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>149</td>
#     <td>15.48</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>298</td>
#     <td>14.38</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>149</td>
#     <td>14.03</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>149</td>
#     <td>14.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>145</td>
#     <td>12.45</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>149</td>
#     <td>11.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>298</td>
#     <td>6.75</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>299</td>
#     <td>5.29</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>232854</td>
#     <td>4.87</td>
#     <td>78</td>
# </tr>
#
# <tr>
#     <th>supplied</th>
#     <td>396</td>
#     <td>2.23</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>149</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>23706</td>
#     <td>1.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>1248</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>1956</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>149</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>char</i></th>
#     <td>1451327</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - suriano/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1pre/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1pre/ch.tf">ch</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the unicode character of a slot</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1pre/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <span> number of a chunk within a document</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1pre/empty.tf">empty</a>
# </div>
# <div class="fmono">int</div>
#
# <span> whether a slot has been inserted in an empty element</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1pre/extraspace.tf">extraspace</a>
# </div>
# <div class="fmono">str</div>
#
# <span> whether a space has been added after a character, when it is in the direct child of a pure XML element</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1pre/file.tf">file</a>
# </div>
# <div class="fmono">str</div>
#
# <span> name of source file</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1pre/folder.tf">folder</a>
# </div>
# <div class="fmono">str</div>
#
# <span> name of source folder</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1pre/id.tf">id</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute id</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1pre/is_meta.tf">is_meta</a>
# </div>
# <div class="fmono">str</div>
#
# <span> whether a slot or word is in the teiHeader element</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-co
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# Input data has version 0.0.1pre
# Compute element boundaries
#  43104 start postions
#  44447 end postions
# Input data has version 0.0.1pre
# Compute element boundaries
#  43104 start postions
#  44447 end postions
#   0.00s Generating a plain text with positions ...
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
#    |   Found 2012 empty slots
#    |   recorded flow main       with 4168434 items
#    |   recorded flow note       with 206451 items
#   3.56s Done. Generated text and positions written to ~/github/HuygensING/suriano/_temp/txt/plain.txt
# Input data has version 0.0.1pre
# Compute element boundaries
#  43104 start postions
#  44447 end postions
#   0.00s Using NLP pipeline Spacy (en) ...
#  1m 09s Atomic tokens written to ~/github/HuygensING/suriano/_temp/txt/tokens.tsv
#  1m 09s Sentences written to ~/github/HuygensING/suriano/_temp/txt/sentences.tsv
#  1m 09s NLP done
# Input data has version 0.0.1pre
# Compute element boundaries
#  43104 start postions
#  44447 end postions
#   0.00s Ingesting tokens, and sentences into the dataset ...
#    |    1m 13s Mapping NLP data to nodes and features ...
#    |      |     0.00s generating t-nodes with features str, after, empty
#    |      |      |     0.00s 319431 t nodes have values assigned for str, after
#    |      |      |     0.00s 0 empty slots are properly contained in a token
#    |      |      |     0.00s 25956 space slots have split into chars
#    |      |      |     0.00s 21600 slots have split around an element boundary
#    |      |      |     0.00s 107979x Items contained in extra generated text
#    |      |     1.73s 263971 tokens
#    |      |     1.73s 319431 ts
#    |      |     1.73s generating sentence-nodes with features nsent
#    |      |      |     0.53s 12740 sentence nodes have values assigned for nsent
#    |      |      |     0.53s 15842x Items contained in extra generated text
#    |      |      |     0.53s  4354x Items with empty final text
#    |      |     2.26s 12740 sentences
#    |    1m 15s Make a modified dataset ...
#   0.00s Feature overview: 25 for nodes; 2 for edges; 1 configs; 9 computed
#    |    1m 24s Done
#     11s Enriched data is available in version 0.0.1
# You may need to adapt this TF app and its documentation:
# please run: python tfFromTei.py apptoken
# App updated with tokens and sentences
# True

# %% [markdown]
# ### Step 6: Use the new dataset

# %%
A = use(f"{ORG}/{REPO}:clone", checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/0.0.1</span>
# This is Text-Fabric 12.0.5
# 28 features found and 0 ignored
#    |     0.36s T otype                from ~/github/HuygensING/suriano/tf/0.0.1
#    |     4.27s T oslots               from ~/github/HuygensING/suriano/tf/0.0.1
#   4.64s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.00s T folder               from ~/github/HuygensING/suriano/tf/0.0.1
#    |     1.77s T str                  from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T file                 from ~/github/HuygensING/suriano/tf/0.0.1
#    |     1.37s T after                from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T chunk                from ~/github/HuygensING/suriano/tf/0.0.1
#    |      |     0.11s C __levels__           from otype, oslots, otext
#    |      |     4.75s C __order__            from otype, oslots, __levels__
#    |      |     0.14s C __rank__             from otype, __order__
#    |      |     6.80s C __levUp__            from otype, oslots, __rank__
#    |      |     4.17s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.14s C __characters__       from otext
#    |      |     2.10s C __boundary__         from otype, oslots, __rank__
#    |      |     0.00s C __sections__         from otype, oslots, otext, __levUp__, __levels__, folder, file, chunk
#     26s All features loaded/computed - for details use TF.isLoaded()
#    |     0.01s T empty                from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.12s T extraspace           from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.03s T id                   from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.02s T is_meta              from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.06s T is_note              from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T key                  from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.01s T link_target          from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.01s T n                    from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.03s T nsent                from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T ref                  from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.01s T rend                 from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T rend_bold            from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.06s T rend_italic          from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T rend_smallcaps       from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T rend_superscript     from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T role                 from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.01s T target               from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T type                 from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T unit                 from ~/github/HuygensING/suriano/tf/0.0.1
#    |     0.00s T when                 from ~/github/HuygensING/suriano/tf/0.0.1
#   0.38s All additional features loaded - for details use TF.isLoaded()
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 12.0.5</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/about.md" title="provenance of HuygensING - suriano/tf">HuygensING - suriano 0.0.1</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="HuygensING - suriano feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>3</td>
#     <td>106477.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>149</td>
#     <td>2143.83</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>149</td>
#     <td>2088.25</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>149</td>
#     <td>2088.25</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>596</td>
#     <td>535.96</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>895</td>
#     <td>694.66</td>
#     <td><i>195</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>26</td>
#     <td>230.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>149</td>
#     <td>55.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>136</td>
#     <td>43.88</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>149</td>
#     <td>42.46</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>7798</td>
#     <td>38.85</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>149</td>
#     <td>24.13</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>12740</td>
#     <td>23.05</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>282</td>
#     <td>21.12</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>149</td>
#     <td>19.01</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>149</td>
#     <td>19.01</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>149</td>
#     <td>17.33</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>149</td>
#     <td>11.13</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>149</td>
#     <td>11.13</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>149</td>
#     <td>11.13</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>2002</td>
#     <td>10.81</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>1</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>149</td>
#     <td>7.32</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>149</td>
#     <td>7.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>3949</td>
#     <td>6.14</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>149</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>149</td>
#     <td>5.11</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>149</td>
#     <td>4.11</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>149</td>
#     <td>4.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>149</td>
#     <td>3.11</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>149</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>149</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>298</td>
#     <td>2.51</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>298</td>
#     <td>2.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>299</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>149</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>149</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>145</td>
#     <td>1.93</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>supplied</th>
#     <td>396</td>
#     <td>1.09</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>token</th>
#     <td>263971</td>
#     <td>1.00</td>
#     <td>83</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>23706</td>
#     <td>1.00</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>1248</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>1956</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>149</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>319431</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - suriano/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2023-07-13T13:59:22Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>2023-07-13</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>0.0.1</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/0.0.1/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <details>
#     <summary>number of a chunk within a document</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey"
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-co
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %%
c = F.otype.s("chunk")[110]
A.pretty(c)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.HuygensING.org/suriano/filza3/17/3&amp;version=0.0.1" title="Show this on the website" sec="filza3@17:3">filza3@17:3</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">chunk </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">div </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">div </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">p </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"> </span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">hi </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class="r_italic ">Bianche </span></span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><br></span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">p </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">n. </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">36</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><br></span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">p </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">30 </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">novembre </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">1616</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">, </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="tx ...

# %% [markdown]
# # Convert from TEI to TF to WATM
#
# We convert Suriano TEI to TF and then to WATM.
#
# This notebook provides three levels of refinement in the execution. They all have the same outcome,
# but they differ in the level of detail they provide on the conversion.
#
# These are the levels:
#
# * **Express**: one single command on the command line for the complete conversion;
# * **Step by step**: one command for each main step of the conversion;
# * **Debugging**: all the commands directly in Python, the intermediate data remains in memory and can be inspected.

# %% [markdown]
# # Production or development
#
# Mosts steps are unaffected by the production/development setting.
#
# In the first steps of the pipeline (*ingest* and *scan processing*) we prepare both the dev and the prod data.
#
# The intermediate steps (*from DOCX to TEI*, *from TEI to TF*, *mark named entities*) are identical for prod and dev.
#
# Only for the latter steps (*convert TF to WATM*, generate IIIF manifests*, *deploy to k8s*) there is a distinction between prod and dev.
#
# For these steps we have commented out the line that does the dev version.

# %% [markdown]
# # Requirements
#
# * zsh as command line shell (as in macOS);
# * access to suitable k8s clusters, streamlined by the
#   [k-suite](https://code.huc.knaw.nl/tt/smart-k8s/-/blob/main/docs/k-suite.md);
# * [Pandoc](https://pandoc.org)
# * [Imagemagick](https://imagemagick.org)
# * [Python](https://www.python.org) (3.12 or higher) with additional pip-installable modules:
#   * text-fabric
#   * doc2python
#   * openpyxl

# %% [markdown]
# # Declare the version
#
# Always set the version before running any cell in this notebook!

# %%
VERSION = "1.0.1"

# %% [markdown]
# # In debugging mode.
#
# Now we dig a bit deeper, en do all the steps while keeping the program in memory.
# Now it becomes doable to inspect all intermediate results.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tf.app import use
from tf.convert.tei import TEI
from tf.convert.addnlp import NLPipeline
from tf.convert.watm import WATM
from tf.convert.iiif import IIIF
from tf.advanced.helpers import dm

from processscans import Scans
from processdocs import TeiFromDocx
from processhelpers import nerMeta, NER_NAME, SOURCEBASE, PAGESEQ_JSON

# %% [markdown]
# ## Step 1: Scan ingest

# %%
SC = Scans(silent=False, force=False)

# %%
SC.ingest(dry=False)
# Out:
# 	Already ingested covers. Remove ~/gitlab.huc.knaw.nl/suriano/letters/scans/covers or pass --force to ingest again
# 	Already ingested pages. Remove ~/gitlab.huc.knaw.nl/suriano/letters/scans/pages or pass --force to ingest again

# %% [markdown]
# ## Step 2: Scan processing

# %%
SC.process()
# Out:
# Already present: sizes file originals (covers)
# Already present: sizes file originals (pages)
# Already present: thumbnails (covers)
# Already present: sizes file thumbnails (covers)
# Already present: thumbnails (pages)
# Already present: sizes file thumbnails (pages)

# %% [markdown]
# ## Step 3: From DOCX to TEI

# %% [markdown]
# You might need to do
#
# ```
# pip install docx2python
# ```

# %%
TFD = TeiFromDocx(silent=False)

# %%
TFD.task("pandoc")
# Out:
# DOCX => simple TEI per filza ...
# 	02.docx ... uptodate
# 	03.docx ... uptodate
# 	04.docx ... uptodate
# 	05.docx ... uptodate
# 	06.docx ... uptodate
# 	07.docx ... uptodate
# 	08.docx ... uptodate
# 	09.docx ... uptodate
# 	10.docx ... uptodate
# 	11.docx ... uptodate
# 	12.docx ... uptodate

# %%
TFD.task("headers")
# Out:
# DOCX => headers ...
# 	02.docx
# 	03.docx
# 	04.docx
# 	05.docx
# 	06.docx
# 	07.docx
# 	08.docx
# 	09.docx
# 	10.docx
# 	11.docx
# 	12.docx
# 	OK: All headers are OK
# Angelo              : 1181 pages in 11 filzas
# Cristina            : 1034 pages in 10 filzas
# Federica            : 684 pages in  7 filzas
# Filippo             : 1084 pages in  9 filzas
# Flavia              : 1282 pages in 11 filzas
# Giorgia             : 934 pages in  9 filzas
# Renzo               :  56 pages in  1 filza
# Ruben               : 1162 pages in 10 filzas
# Vera                : 966 pages in 10 filzas
# Vera, Federica      : 210 pages in  1 filza

# %%
TFD.task("tei")
# Out:
# Collecting transcribers ...
# Collecting page scans ...
#   0 x error
# 8766 x good
# Collecting excel metadata ...
# 	found metadata for 725 letters
# simple TEI per filza => enriched TEI per letter ...
# 	02.xml
# 	03.xml
# 	04.xml
# 	05.xml
# 	06.xml
# 	07.xml
# 	08.xml
# 	09.xml
# 	10.xml
# 	11.xml
# 	12.xml
# Translated italian editorial phrases (219 x 14158)
# Metadata in summary file corresponds to transcribed letters
# 0 page warnings
# 0 warnings
# Pages with    transcription and    scan:       8766
# Pages with    transcription and missing scan:     0
# Pages with    transcription and no scan:          0
# Pages with no transcription and    scan:          0
# See ~/gitlab.huc.knaw.nl/suriano/letters/datasource/transcriptions/report/scantrans.tsv

# %% [markdown]
# ## Step 4: From TEI to TF
#
# ### Check the validity of the TEI.

# %%
Tei = TEI(verbose=-1, sourceBase=SOURCEBASE, tei="", tf=VERSION)

# %%
Tei.task(check=True, verbose=1, validate=True)
# Out:
# TEI to TF checking: ~/gitlab.huc.knaw.nl/suriano/letters/datasource/tei => ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report
# Processing instructions are ignored
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# INFO: Needs dcr.xsd (exists)
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/suriano/letters/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   1 changing override(s)
# 	metamark mixed ==> pure
# Section model I
# 	Start folder 02:
# 		   1 suriano                                001.xml
# 		   2 suriano                                002.xml
# 		   3 suriano                                003.xml
# 		   4 suriano                                004.xml
# 		   5 suriano                                005.xml
#   19 suriano                                019.xml
# End   folder 02
# 	Start folder 03:
# 		  20 suriano                                001.xml
# 		  21 suriano                                002.xml
# 		  22 suriano                                003.xml
# 		  23 suriano                                004.xml
# 		  24 suriano                                005.xml
#   74 suriano                                055.xml
# End   folder 03
# 	Start folder 04:
# 		  75 suriano                                001.xml
# 		  76 suriano                                002.xml
# 		  77 suriano                                003.xml
# 		  78 suriano                                004.xml
# 		  79 suriano                                005.xml
#  149 suriano                                075.xml
# End   folder 04
# 	Start folder 05:
# 		 150 suriano                                001.xml
# 		 151 suriano                                002.xml
# 		 152 suriano                                003.xml
# 		 153 suriano                                004.xml
# 		 154 suriano                                005.xml
#  206 suriano                                057.xml
# End   folder 05
# 	Start folder 06:
# 		 207 suriano                                001.xml
# 		 208 suriano                                002.xml
# 		 209 suriano                                003.xml
# 		 210 suriano                                004.xml
# 		 211 suriano                                005.xml
#  246 suriano                                040.xml
# End   folder 06
# 	Start folder 07:
# 		 247 suriano                                001.xml
# 		 248 suriano                                002.xml
# 		 249 suriano                                003.xml
# 		 250 suriano                                004.xml
# 		 251 suriano                                005.xml
#  293 suriano                                047.xml
# End   folder 07
# 	Start folder 08:
# 		 294 suriano                                001.xml
# 		 295 suriano                                002.xml
# 		 296 suriano                                003.xml
# 		 297 suriano                                004.xml
# 		 298 suriano                                005.xml
#  384 suriano                                091.xml
# End   folder 08
# 	Start folder 09:
# 		 385 suriano                                001.xml
# 		 386 suriano                                002.xml
# 		 387 suriano                                003.xml
# 		 388 suriano                                004.xml
# 		 389 suriano                                005.xml
#  478 suriano                                094.xml
# End   folder 09
# 	Start folder 10:
# 		 479 suriano                                001.xml
# 		 480 suriano                                002.xml
# 		 481 suriano                                003.xml
# 		 482 suriano                                004.xml
# 		 483 suriano                                005.xml
#  578 suriano                                100.xml
# End   folder 10
# 	Start folder 11:
# 		 579 suriano                                001.xml
# 		 580 suriano                                002.xml
# 		 581 suriano                                003.xml
# 		 582 suriano                                004.xml
# 		 583 suriano                                005.xml
#  679 suriano                                101.xml
# End   folder 11
# 	Start folder 12:
# 		 680 suriano                                001.xml
# 		 681 suriano                                002.xml
# 		 682 suriano                                003.xml
# 		 683 suriano                                004.xml
# 		 684 suriano                                005.xml
#  725 suriano                                046.xml
# End   folder 12
# 725 suriano file(s) ...
# 	Validating ...
# 		Elapsed time 170+359=529 milliseconds
# 	Making inventory ...
#
# Validation OK
# 8989 info line(s) written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/elements.txt
# 584 tag(s) type info written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/types.txt
# 41 tags of which 0 with multiple namespaces written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/namespaces.txt
# Refs written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/refs.txt
# 	resolvable: 3918 in 11822
# 	dangling:      0 in    0
# 	ALL:        3918 in 11822
# Ids written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/ids.txt
# 	referenced: 3918 by 11822
# 	non-unique: 2332
# 	unused:      202
# 	ALL:        1788 in 4120
# lb-parent info written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/lb-parents.txt
# True

# %% [markdown]
# ### Convert the data

# %%
Tei.good = True
Tei.task(convert=True, verbose=0)
# Out:
# Line model II with ln nodes for lines between lb elements
# Page model II with page nodes for pages started by pb elements  keeping the pb elements
# Section model I
# Processing instructions are ignored
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/suriano/letters/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   1 changing override(s)
# 	metamark mixed ==> pure
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# 	Start folder 02:
# 		   1 suriano                                001.xml
# 		   2 suriano                                002.xml
# 		   3 suriano                                003.xml
# 		   4 suriano                                004.xml
# 		   5 suriano                                005.xml
#   19 suriano                                019.xml
# End   folder 02
# 	Start folder 03:
# 		  20 suriano                                001.xml
# 		  21 suriano                                002.xml
# 		  22 suriano                                003.xml
# 		  23 suriano                                004.xml
# 		  24 suriano                                005.xml
#   74 suriano                                055.xml
# End   folder 03
# 	Start folder 04:
# 		  75 suriano                                001.xml
# 		  76 suriano                                002.xml
# 		  77 suriano                                003.xml
# 		  78 suriano                                004.xml
# 		  79 suriano                                005.xml
#  149 suriano                                075.xml
# End   folder 04
# 	Start folder 05:
# 		 150 suriano                                001.xml
# 		 151 suriano                                002.xml
# 		 152 suriano                                003.xml
# 		 153 suriano                                004.xml
# 		 154 suriano                                005.xml
#  206 suriano                                057.xml
# End   folder 05
# 	Start folder 06:
# 		 207 suriano                                001.xml
# 		 208 suriano                                002.xml
# 		 209 suriano                                003.xml
# 		 210 suriano                                004.xml
# 		 211 suriano                                005.xml
#  246 suriano                                040.xml
# End   folder 06
# 	Start folder 07:
# 		 247 suriano                                001.xml
# 		 248 suriano                                002.xml
# 		 249 suriano                                003.xml
# 		 250 suriano                                004.xml
# 		 251 suriano                                005.xml
#  293 suriano                                047.xml
# End   folder 07
# 	Start folder 08:
# 		 294 suriano                                001.xml
# 		 295 suriano                                002.xml
# 		 296 suriano                                003.xml
# 		 297 suriano                                004.xml
# 		 298 suriano                                005.xml
#  384 suriano                                091.xml
# End   folder 08
# 	Start folder 09:
# 		 385 suriano                                001.xml
# 		 386 suriano                                002.xml
# 		 387 suriano                                003.xml
# 		 388 suriano                                004.xml
# 		 389 suriano                                005.xml
#  478 suriano                                094.xml
# End   folder 09
# 	Start folder 10:
# 		 479 suriano                                001.xml
# 		 480 suriano                                002.xml
# 		 481 suriano                                003.xml
# 		 482 suriano                                004.xml
# 		 483 suriano                                005.xml
#  578 suriano                                100.xml
# End   folder 10
# 	Start folder 11:
# 		 579 suriano                                001.xml
# 		 580 suriano                                002.xml
# 		 581 suriano                                003.xml
# 		 582 suriano                                004.xml
# 		 583 suriano                                005.xml
#  679 suriano                                101.xml
# End   folder 11
# 	Start folder 12:
# 		 680 suriano                                001.xml
# 		 681 suriano                                002.xml
# 		 682 suriano                                003.xml
# 		 683 suriano                                004.xml
# 		 684 suriano                                005.xml
#  725 suriano                                046.xml
# End   folder 12
#
# Resolving links into edges ...
# 	3918 in 11822 reference(s) resolved
#    |       13s "delete" actions: 0
#    |       13s "edge" actions: 11822
#    |       13s "feature" actions: 2728208
#    |       13s "node" actions: 365632
#    |       13s "resume" actions: 0
#    |       13s "slot" actions: 1733245
#    |       13s "terminate" actions: 366357
#    |    2098877 nodes of all types
#    |       13s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.01s OK
#    |     0.00s checking (section) features ...
#    |     0.06s OK
#    |     0.00s reordering nodes ...
#    |     1.98s Max node = 2098877
#    |     1.98s OK
#    |     0.00s reassigning feature values ...
#    |     0.96s OK
# True

# %% [markdown]
# ### Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# True

# %% [markdown]
# ### Use the new dataset
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and pre-computations are performed.
# Next time the loading will be much quicker.

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/ner</span>
# This is Text-Fabric 12.5.5
# 37 features found and 0 ignored
#   0.28s Dataset without structure sections in otext:no structure functions in the T-API
#   1.03s All features loaded / computed - for details use TF.isLoaded()
#   0.05s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.5.5</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/app" title="suriano/letters app">suriano/letters/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/about.md" title="provenance of suriano - letters/tf">suriano - letters 1.0.1</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="suriano - letters feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>11</td>
#     <td>157567.73</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>725</td>
#     <td>2390.68</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>725</td>
#     <td>2206.02</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>725</td>
#     <td>2206.02</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4148</td>
#     <td>737.03</td>
#     <td><i>176</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>725</td>
#     <td>184.67</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8764</td>
#     <td>157.79</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>725</td>
#     <td>118.53</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>725</td>
#     <td>51.05</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>46971</td>
#     <td>36.90</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>725</td>
#     <td>66.13</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>725</td>
#     <td>118.53</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>48688</td>
#     <td>32.48</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>725</td>
#     <td>31.56</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>725</td>
#     <td>31.56</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>725</td>
#     <td>19.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13281</td>
#     <td>16.69</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>1</td>
#     <td>15.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>725</td>
#     <td>14.08</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>159403</td>
#     <td>9.92</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>725</td>
#     <td>8.73</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>725</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1450</td>
#     <td>7.82</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>15456</td>
#     <td>7.81</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2175</td>
#     <td>6.52</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>725</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>725</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2082</td>
#     <td>4.31</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>725</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>725</td>
#     <td>2.70</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2175</td>
#     <td>2.69</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>725</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2175</td>
#     <td>1.32</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>metamark</th>
#     <td>3015</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8764</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11822</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1733245</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>suriano - letters/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2024-10-10T17:47:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>1.0.1</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <details>
#     <summary>number of a chunk within a document</summary>
#     <div class="fmeta">
#
# <div class="fmetarow"
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/thumb</span>
# Found 8766 images<br>

# %% [markdown]
# ## Step 5: Mark named entities

# %% [markdown]
# First stage: we use the human-crafted triggers as is.
#
# In the separate notebook [nerCorrect](nerCorrect.ipynb) you can then collect
# additional spelling variants of the triggers.
#
# Some of these triggers are not fit to be used, you have to make a list of variants that are not valid triggers
# and store them in the file `persons-notmerged.txt`, one per line.
#
# Then you can merge the new valid variants automatically with the human-crafted triggers, and
# the result is a new spreadsheet, `persons-merged`.
#
# Second stage: use the merged spreadsheet.

# %% [markdown]
# ### Stage 1
#
# We need to copy the relevant spreadsheet from the `datasource/metadata` directory to the `ner` directory where TF expects it.

# %%
nerStage = 1
nerName, nerOutFile = setStage(nerStage)
# Out:
# Stage 1: working with sheet persons

# %%
NE = A.makeNer(caseSensitive=False, silent=False)
# Out:
# normalizeChars() loaded from ~/gitlab.huc.knaw.nl/suriano/letters/ner/code.py
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
NE.setTask(f".{nerName}", force=True)
# Out:
# Annotation set 🧾 persons has 10645 annotations
# SHEET data: computing from scratch ...
# --------------
# Reading sheets
# --------------
# Sheet with 871 rows and 18 columns
# 9 rows without triggers:
# 	e.g.: 129, 216, 234, 235, 236, 424, 452, 464, 488
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
#
# --
# 02
# --
#
# --
# 03
# --
#
# --
# 04
# --
#
# --
# 05
# --
#
# --
# 06
# --
#
# --
# 07
# --
#
# -------------
# 08@001-08@089
# -------------
#
# ---------
# 08@090-08
# ---------
#
# ---------
# 09-09@021
# ---------
#
# ---------
# 09@022-09
# ---------
#
# ---------
# 10-10@017
# ---------
#
# -------------
# 10@018-10@020
# -------------
#
# ---------
# 10@021-10
# ---------
#
# ------------
# 11-11@026:22
# ------------
#
# ---------
# 11@026:23
# ---------
#
# ------------
# 11@026:24-11
# ------------
#
# ------------
# 12-12@037:27
# ------------
#
# ---------
# 12@037:28
# ---------
#
# ----------------
# 12@037:29-12@041
# ----------------
#
# -------------
# 12@042-12@044
# -------------
#
# ---------
# 12@045-12
# ---------
#   0.00s Looking up occurrences of many candidates ...
#   2.28s done
# done

# %%
NE.triggerInterference()
# Out:
# Looking up 26 potential interferences in 2 passes over the corpus ..
# 2 potential conflicting trigger pairs with 2 conflicts
# ----------
# different rows (0 pairs)
# ----------
# Diagnostic trigger interferences written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/1.0.1/.persons/interference.txt

# %%
NE.reportHits(showNoHits=True)
# Out:
# No slot is covered by more than one trigger
# Triggers without hits: 102x:
# Looking up 102 triggers in 2 passes over the corpus ..
# Entities targeted:            811
# Triggers searched for:       1622
# Triggers without hits:        102
#  - completely covered:        102
#  - missing hits:                0
# Triggers with hits:          1520
# Total hits:                 10645
#
# All hits in report file:      ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/1.0.1/.persons/hits.tsv
# Triggers by slot in file:     ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/1.0.1/.persons/triggerBySlot.tsv

# %%
NE.makeSheetOfSingleTokens()
NE.setTask(f".{NER_NAME}-single", caseSensitive=False, force=True)
NE.reportHits(showNoHits=True)
NE.setTask(f".{NER_NAME}", caseSensitive=False)
# Out:
# Annotation set 🧾 persons-single has 0 annotations
# SHEET data: computing from scratch ...
# --------------
# Reading sheets
# --------------
# Sheet with 1504 rows and 6 columns
#
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
#   0.00s Looking up occurrences of many candidates ...
#   2.30s done
# done
# No slot is covered by more than one trigger
# Triggers without hits: 14x:
# Looking up 14 triggers in 1 pass over the corpus .
# Entities targeted:           1502
# Triggers searched for:       1502
# Triggers without hits:         14
#  - completely covered:         14
#  - missing hits:                0
# Triggers with hits:          1488
# Total hits:                 499902
#
# All hits in report file:      ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/1.0.1/.persons-single/hits.tsv
# Triggers by slot in file:     ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/1.0.1/.persons-single/triggerBySlot.tsv
# Annotation set 🧾 persons has 10645 annotations
# SHEET data: already in memory and uptodate
#
# --------------
# Reading sheets
# --------------
# 9 rows without triggers:
# 	e.g.: 129, 216, 234, 235, 236, 424, 452, 464, 488
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
#
# --
# 02
# --
#
# --
# 03
# --
#
# --
# 04
# --
#
# --
# 05
# --
#
# --
# 06
# --
#
# --
# 07
# --
#
# -------------
# 08@001-08@089
# -------------
#
# ---------
# 08@090-08
# ---------
#
# ---------
# 09-09@021
# ---------
#
# ---------
# 09@022-09
# ---------
#
# ---------
# 10-10@017
# ---------
#
# -------------
# 10@018-10@020
# -------------
#
# ---------
# 10@021-10
# ---------
#
# ------------
# 11-11@026:22
# ------------
#
# ---------
# 11@026:23
# ---------
#
# ------------
# 11@026:24-11
# ------------
#
# ------------
# 12-12@037:27
# ------------
#
# ---------
# 12@037:28
# ---------
#
# ----------------
# 12@037:29-12@041
# ----------------
#
# -------------
# 12@042-12@044
# -------------
#
# ---------
# 12@045-12
# ---------

# %% [markdown]
# ### Prepare for stage 2: search variants

# %%
nerStage = 1
nerName, nerOutFile = setStage(nerStage)
# Out:
# Stage 1: working with sheet persons

# %%
NE = A.makeNer(caseSensitive=False, silent=False)
# Out:
# normalizeChars() loaded from ~/gitlab.huc.knaw.nl/suriano/letters/ner/code.py
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
NE.setTask(f".{nerName}", force=True)
# Out:
# Annotation set 🧾 persons has 10112 annotations
# SHEET data: computing from scratch ...
# --------------
# Reading sheets
# --------------
# Sheet with 871 rows and 18 columns
# 9 rows without triggers:
# 	e.g.: 129, 216, 234, 235, 236, 424, 452, 464, 488
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
#
# --
# 02
# --
#
# --
# 03
# --
#
# --
# 04
# --
#
# --
# 05
# --
#
# --
# 06
# --
#
# --
# 07
# --
#
# -------------
# 08@001-08@089
# -------------
#
# ---------
# 08@090-08
# ---------
#
# ---------
# 09-09@021
# ---------
#
# ---------
# 09@022-09
# ---------
#
# ---------
# 10-10@017
# ---------
#
# -------------
# 10@018-10@020
# -------------
#
# ---------
# 10@021-10
# ---------
#
# ------------
# 11-11@026:22
# ------------
#
# ---------
# 11@026:23
# ---------
#
# ------------
# 11@026:24-11
# ------------
#
# ------------
# 12-12@037:27
# ------------
#
# ---------
# 12@037:28
# ---------
#
# ----------------
# 12@037:29-12@041
# ----------------
#
# -------------
# 12@042-12@044
# -------------
#
# ---------
# 12@045-12
# ---------
#   0.00s Looking up occurrences of many candidates ...
#   2.28s done
# done

# %%
D = NE.variantDetection()
# Out:
# SHEET data: computing from scratch ...
# --------------
# Reading sheets
# --------------
# Sheet with 871 rows and 18 columns
# 9 rows without triggers:
# 	e.g.: 129, 216, 234, 235, 236, 424, 452, 464, 488
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
#
# --
# 02
# --
#
# --
# 03
# --
#
# --
# 04
# --
#
# --
# 05
# --
#
# --
# 06
# --
#
# --
# 07
# --
#
# -------------
# 08@001-08@089
# -------------
#
# ---------
# 08@090-08
# ---------
#
# ---------
# 09-09@021
# ---------
#
# ---------
# 09@022-09
# ---------
#
# ---------
# 10-10@017
# ---------
#
# -------------
# 10@018-10@020
# -------------
#
# ---------
# 10@021-10
# ---------
#
# ------------
# 11-11@026:22
# ------------
#
# ---------
# 11@026:23
# ---------
#
# ------------
# 11@026:24-11
# ------------
#
# ------------
# 12-12@037:27
# ------------
#
# ---------
# 12@037:28
# ---------
#
# ----------------
# 12@037:29-12@041
# ----------------
#
# -------------
# 12@042-12@044
# -------------
#
# ---------
# 12@045-12
# ---------
#   0.00s Looking up occurrences of many candidates ...
#   2.16s done
# done
# SHEET data: computing from scratch ...
# --------------
# Reading sheets
# --------------
# Sheet with 871 rows and 18 columns
# 9 rows without triggers:
# 	e.g.: 129, 216, 234, 235, 236, 424, 452, 464, 488
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
#
# --
# 02
# --
#
# --
# 03
# --
#
# --
# 04
# --
#
# --
# 05
# --
#
# --
# 06
# --
#
# --
# 07
# --
#
# -------------
# 08@001-08@089
# -------------
#
# ---------
# 08@090-08
# ---------
#
# ---------
# 09-09@021
# ---------
#
# ---------
# 09@022-09
# ---------
#
# ---------
# 10-10@017
# ---------
#
# -------------
# 10@018-10@020
# -------------
#
# ---------
# 10@021-10
# ---------
#
# ------------
# 11-11@026:22
# ------------
#
# ---------
# 11@026:23
# ---------
#
# ------------
# 11@026:24-11
# ------------
#
# ------------
# 12-12@037:27
# ------------
#
# ---------
# 12@037:28
# ---------
#
# ----------------
# 12@037:29-12@041
# ----------------
#
# -------------
# 12@042-12@044
# -------------
#
# ---------
# 12@045-12
# ---------
#   0.00s Looking up occurrences of many candidates ...
#   2.16s done
# done
# Overview of names by length:
#   10 tokens:   2 names e.g.:
#       cavalier inglese , et il fratello del vescovo di Londra
#       signor d ’ Aspri fratello dell ’ ambasciator dei Stati
#   9 tokens:   2 names e.g.:
#       conte d ’ Henin , chiamato duca di Bornenvil
#       Proveditor general dell ’ arm [ i ] Priuli
#   8 tokens:  15 names e.g.:
#       Alessandro , Giacomo et Pietr ’ Antonio Guadagni
#       ambasciator del signor Granduca nella corte di Praga
#       ambasciator di Francia residente appresso li serenissimi arciduchi
#       doi altri suoi parenti cognato , et cugino
#       doi altri un maschio , et una femina
#   7 tokens:  20 names e.g.:
#       [ duc ] a d ’ Angauleme
#       ambasciator di Spagna residente appresso il Christianissimo
#       Ambasciator straordinario che venne ultimamente di Spagna
#       Ambasciatore , che dal re di Bohemia
#       capitan scocese fratello di quel capitano Seiton
#   6 tokens:  42 names e.g.:
#       al luogotenente di monsignor di Sciatiglione
#       ambasciator Giust ( inia ) no
#       ambasciator Gritti alla corte di Spagna
#       baron di Kessel governator di Husdem
#       baron di Pieterson signor di Meroda
#   5 tokens:  80 names e.g.:
#       A . v . Matenesse
#       accompagnata la sorella di lui
#       Adriano Pieterson Looske da Encusen
#       agente d ’ Inghilterra Trombol
#       agente del re di Marocco
#   4 tokens: 188 names e.g.:
#       agente di quel Principe
#       almirante d ’ Arragona
#       ambasciator Contarini in Francia
#       ambasciator Contarini in Inghilterra
#       ambasciatore Contarini in Inghilterra
#   3 tokens: 487 names e.g.:
#       2 da Principessa
#       Adriano Vander Dussen
#       agente del Kerckoven
#       agente di Fiorenza
#       ambasciator a Constantinopoli
#   2 tokens: 540 names e.g.:
#       abbate Moronato
#       Abraham Pesini
#       Adam Schivelbergh
#       Adrian Pavoni
#       Adrian Ploos
#   1 tokens: 237 names e.g.:
#       Alagamba
#       Alagambe
#       Alagambre
#       Amstenraedt
#       Amsterraedt

# %%
D.prepare()
# Out:
# Alphabet written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/alphabet.tsv
# Text written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/text.txt - 8554012 characters
#   0.00s Collecting the triggers for the lexicon
#   0.00s 1460 triggers collected
#   345 x conte di Mansfelt
#   329 x Pasini
#   236 x Bernvel
#   236 x Spinola
#   211 x principe d’Oranges
#   211 x re di Spagna
#   209 x Carleton
#   207 x principe Mauritio
#   191 x duca di Savoia
#   180 x serenissimi arciduchi
#   ...
#     1 x visconte di Duncaster
#     1 x visconte di Gantes fratello del principe di Pinoe
#     1 x Vuandermil
#     1 x Wandernoot
#     1 x Wassenhovven
#     1 x Wasson[ hoven]
#     1 x Weesterbeeck
#     1 x Weimar il maggiore
#     1 x zelandese nominato Cornelio
#     1 x Zeno
#     1460 lexicon length
# Lexicon written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/lexicon.tsv
# Set up analiticcl
# Computing anagram values for all items in the lexicon...
#  - Found 1460 instances
# Adding all instances to the index...
#  - Found 1455 anagrams
# Creating sorted secondary index...
# Sorting secondary index...
#  - Found 3 anagrams of length 3
#  - Found 13 anagrams of length 4
#  - Found 23 anagrams of length 5
#  - Found 39 anagrams of length 6
#  - Found 46 anagrams of length 7
#  - Found 41 anagrams of length 8
#  - Found 41 anagrams of length 9
#  - Found 27 anagrams of length 10
#  - Found 45 anagrams of length 11
#  - Found 61 anagrams of length 12
#  - Found 67 anagrams of length 13
#  - Found 84 anagrams of length 14
#  - Found 106 anagrams of length 15
#  - Found 99 anagrams of length 16
#  - Found 99 anagrams of length 17
#  - Found 98 anagrams of length 18
#  - Found 82 anagrams of length 19
#  - Found 71 anagrams of length 20
#  - Found 65 anagrams of length 21
#  - Found 51 anagrams of length 22
#  - Found 34 anagrams of length 23
#  - Found 35 anagrams of length 24
#  - Found 23 anagrams of length 25
#  - Found 22 anagrams of length 26
#  - Found 27 anagrams of length 27
#  - Found 17 anagrams of length 28
#  - Found 14 anagrams of length 29
#  - Found 15 anagrams of length 30
#  - Found 5 anagrams of length 31
#  - Found 13 anagrams of length 32
#  - Found 8 anagrams of length 33
#  - Found 5 anagrams of length 34
#  - Found 10 anagrams of length 35
#  - Found 13 anagrams of length 36
#  - Found 4 anagrams of length 37
#  - Found 6 anagrams of length 38
#  - Found 4 anagrams of length 39
#  - Found 3 anagrams of length 40
#  - Found 5 anagrams of length 41
#  - Found 2 anagrams of length 42
#  - Found 3 anagrams of length 43
#  - Found 6 anagrams of length 44
#  - Found 5 anagrams of length 45
#  - Found 1 anagrams of length 46
#  - Found 2 anagrams of length 47
#  - Found 2 anagrams of length 49
#  - Found 1 anagrams of length 50
#  - Found 1 anagrams of length 52
#  - Found 2 anagrams of length 53
#  - Found 2 anagrams of length 54
#  - Found 1 anagrams of length 56
#  - Found 1 anagrams of length 57
#  - Found 1 anagrams of length 59
#  - Found 1 anagrams of length 66
# Constructing Language Model...
#  - No language model provided

# %%
# %%time

# !date

D.search(start=None, end=None, force=1)
# Out:
# Mon Oct 14 13:01:05 CEST 2024
#  8554012 text  length
#        0 offset in complete text
#   0.00s Read previously computed variants of the lexicon words ...
#     11s  1371254 raw   matches
#     11s Filter variants of the lexicon words ...
#     12s      694 filtered matches
# CPU times: user 11.5 s, sys: 374 ms, total: 11.9 s
# Wall time: 12 s

# %%
D.listResults(end=20)
# Out:
#    i | variant                   | score | candidate
# ---- | ------------------------- | ----- | -------------------------
#    0 | a Ferdinando              |  0.87 | re Ferdinando
#    1 | a suo figliolo            |  0.87 | un suo figliolo
#    2 | abbot Moronato            |  0.85 | abbate Moronato
#    3 | Adrian Plois              |  0.88 | Adrian Ploos
#    4 | Adriano Ploos             |  0.85 | Adrian Ploos
#    5 | Adrien Ploos              |  0.86 | Adrian Ploos
#    6 | agente del Kerkoven       |  0.89 | agente del Kerckoven
#    7 | al figliolo               |  0.88 | il figliolo
#    8 | al suo figlio             |  0.89 | il suo figlio
#    9 | Alag]ambe                 |  0.84 | Alagambe
#   10 | Alessandro Vanderberge    |  0.90 | Alessandro Vanderbergh
#   11 | alla moglie               |  0.86 | della moglie
#   12 | alla moglie               |  0.85 | la moglie
#   13 | ambasciator Aghe          |  0.91 | ambasciator Aghes
#   14 | ambasciator Cont          |  0.84 | ambasciator Caron
#   15 | ambasciator de Francia    |  0.85 | ambasciatore di Francia
#   16 | ambasciator della Cueva   |  0.89 | ambasciator della Lueva
#   17 | ambasciator di Francia    |  0.87 | ambasciatore di Francia
#   18 | ambasciator Dighbi        |  0.89 | ambasciator Digbi
#   19 | ambasciator Giust(inia)no |  0.86 | ambasciator Giustiniano
# ---- | ------------------------- | ----- | -------------------------
# 694 variants found and written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/analyticcl/variants.tsv

# %%
D.mergeTriggers()
# Out:
# 155 excluded variants found in ~/gitlab.huc.knaw.nl/suriano/letters/ner/specs/persons-notmerged.txt
# 152 variants excluded as trigger
# 254 triggersets expanded with 552 triggers
# Wrote merged triggers to sheet ~/gitlab.huc.knaw.nl/suriano/letters/ner/specs/persons-merged.xlsx

# %%
D.showResults(start=162, end=164)
# Out:
#    1 Variant «Pauls» of 1 candidate
#   Occurrences:
#     07@005:110: 581, 1, 8 La nave Menonisterkerch capitano Peter «Pauls »Quakes 149 2550 1020 [1]431​
#   Candidates with score:
# 	0.84 Pauli
# -----
#    2 Variant «Pelicard» of 1 candidate
#   Occurrences:
#     09@081:2: the Moraves have defeated Bocqouy, and opposite reports from «Pelicard »in Bxl. Fears in Dutch Republic for the
#   Candidates with score:
# 	0.87 Pelicart
# -----

# %%
D.displayResults(start=162, end=164)
# Out:
# # 1: 1 x variant `Monteneau` on candidate `Montereau`
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">chunk</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.suriano.org/letters/12/010/197&amp;version=1.0.1" title="Show this on the website" sec="12@010:197">12@010:197</a></span></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="txtu">Il </span><span class="txtu">Tenente </span><span class="txtu">cattolico </span><span class="txtu">che </span><span class="txtu">già </span><span class="txtu">scrissi </span><span class="txtu">esser </span><span class="txtu">il </span><span class="txtu">mezettino </span><span class="txtu">di </span><span class="txtu">quelli </span><span class="txtu">che</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">vorriano </span><span class="txtu">tirar </span><span class="txtu">a </span><span class="txtu">sé </span><span class="txtu">il </span><span class="txtu">Generale </span><span class="txtu">seguita </span><span class="txtu">continuamente </span><span class="txtu">la </span><span class="txtu">corte</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">perché </span><span class="txtu">hieri </span><span class="txtu">l</span><span class="txtu">’</span><span class="txtu">altro </span><span class="txtu">partì </span><span class="txtu">sua </span><span class="txtu">Eccellenza </span><span class="txtu">con </span><span class="txtu">li </span><span class="txtu">ambasciatori </span><span class="txtu">da </span><span class="txtu">Stichausen</span><span class="txtu">, </span><span class="txtu">et </span><span class="txtu">venne</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">a</span><span class="txtu "><span class=editorial>note <span title="n">65</span></span></span><span class="txtu">​</span><span class="txtu"> </span><span class="txtu">Oldenham </span><span class="txtu">una </span><span class="txtu">lega </span><span class="txtu">discosto </span><span class="txtu">da </span><span class="txtu">Embdem </span><span class="txtu">castello</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">di </span><span class="txtu">un </span><span class="txtu">barone </span><span class="txtu">di </span><span class="txtu">Suart </span><span class="txtu">Zionbergh </span><span class="txtu">qui </span><span class="txtu">hoggi </span><span class="txtu">veniranno </span><span class="txtu">li</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">deputati </span><span class="txtu">delli </span><span class="txtu">signori </span><span class="txtu">Stati</span><span class="txtu">, </span><span class="txtu">et </span><span class="txtu">quelli </span><span class="txtu">di </span><span class="txtu">questo </span><span class="txtu">Paese </span><span class="txtu">a </span><span class="txtu">portar </span><span class="txtu">al</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">Generale </span><span class="txtu">la </span><span class="txtu">conclusione </span><span class="txtu">dei </span><span class="txtu">loro </span><span class="txtu">negotii</span><span class="txtu">, </span><span class="txtu">et </span><span class="txtu">per </span><span class="txtu">quel </span><span class="txtu">che </span><span class="txtu">ho</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">inteso </span><span class="txtu">daranno </span><span class="txtu">la </span><span class="txtu">summa </span><span class="txtu">delli </span><span class="txtu">denari </span><span class="txtu">concertati </span><span class="txtu">d</span><span class="txtu">’</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">accordo </span><span class="txtu">contandogli </span><span class="txtu">di </span><span class="txtu">presente </span><span class="txtu">46 </span><span class="txtu">mila </span><span class="txtu">raistaleri </span><span clas ...
# # 2: 1 x variant `Monteran` on candidate `Monterau`
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">chunk</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.suriano.org/letters/12/032/48&amp;version=1.0.1" title="Show this on the website" sec="12@032:48">12@032:48</a></span></span></td><td class="tf ltr"><span class=" ubd pl-mode"><span class="txtu"><span class="r_ ">Quelli </span></span><span class="txtu"><span class="r_ ">che </span></span><span class="txtu"><span class="r_ ">intendono </span></span><span class="txtu"><span class="r_ ">bene </span></span><span class="txtu"><span class="r_ ">le </span></span><span class="txtu"><span class="r_ ">cose </span></span><span class="txtu"><span class="r_ ">veggono </span></span><span class="txtu"><span class="r_ ">anco</span></span><span class="txtu"><span class="r_ ">,</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">che </span></span><span class="txtu"><span class="r_ ">francesi </span></span><span class="txtu"><span class="r_ ">si </span></span><span class="txtu"><span class="r_ ">sono </span></span><span class="txtu"><span class="r_ ">condotti </span></span><span class="txtu"><span class="r_ ">in </span></span><span class="txtu"><span class="r_ ">questo </span></span><span class="txtu"><span class="r_ ">affare </span></span><span class="txtu"><span class="r_ ">più</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">per </span></span><span class="txtu"><span class="r_ ">le </span></span><span class="txtu"><span class="r_ ">solicitationi </span></span><span class="txtu"><span class="r_ ">della </span></span><span class="txtu"><span class="r_ ">serenissima </span></span><span class="txtu"><span class="r_ ">Republica</span></span><span class="txtu"><span class="r_ ">, </span></span><span class="txtu"><span class="r_ ">et </span></span><span class="txtu"><span class="r_ ">anco</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">del </span></span><span class="txtu"><span class="r_ ">signor </span></span><span class="txtu"><span class="r_ ">duca </span></span><span class="txtu"><span class="r_ ">di </span></span><span class="txtu"><span class="r_ ">Savoia</span></span><span class="txtu"><span class="r_ ">, </span></span><span class="txtu"><span class="r_ ">che </span></span><span class="txtu"><span class="r_ ">per </span></span><span class="txtu"><span class="r_ ">la </span></span><span class="txtu"><span class="r_ ">volontà</span></span><span class="txtu"><span class="r_ ">, </span></span><span class="txtu"><span class="r_ ">che</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">vengono </span></span><span class="txtu"><span class="r_ ">di </span></span><span class="txtu"><span class="r_ ">Franza </span></span><span class="txtu"><span class="r_ ">si </span></span><span class="txtu"><span class="r_ ">burlano </span></span><span class="txtu"><span class="r_ ">della </span></span><span class="txtu"><span class="r_ ">levata</span></span><span class="txtu"><span class="r_ ">,</span></span><span class="break"><br></span><span class="txtu"><span class="r_ "></span></span><span class="txtu"><span class="r_ ">ma </span></span><span class="txtu"><span class="r_ ">più </span></span><span class="txtu"><span class="r_ ">dei </span></span><span class="txtu"><span class="r_ ">capi</span></span><span class="txtu"><span class="r_ ">, </span></span><span class="plain   hl"  style="background-color: goldenrod;" ><span class="txtu"><span class="r_ ">Monteran </span></span></span><span class="txtu"><span class="r_ ">l</span></span><span class="txtu"><span class="r_ ">’</span></span><span class="txtu"><span class="r_ ">hanno </span></span><span class="txtu"><span class="r_ ">per </span></span><sp ...
#  1m 21s    2 matches done

# %%
# D.displayResults(asFile="variants")

# %% [markdown]
# ### Stage 2

# %%
nerStage = 2
nerName, nerOutFile = setStage(nerStage)
# Out:
# Stage 2: working with sheet persons-merged

# %%
NE = A.makeNer(caseSensitive=False, silent=False)
# Out:
# normalizeChars() loaded from ~/gitlab.huc.knaw.nl/suriano/letters/ner/code.py
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
NE.setTask(f".{nerName}", force=True)
# Out:
# Annotation set 🧾 persons-merged has 12632 annotations
# SHEET data: computing from scratch ...
# --------------
# Reading sheets
# --------------
# Sheet with 871 rows and 18 columns
# 9 rows without triggers:
# 	e.g.: 129, 216, 234, 235, 236, 424, 452, 464, 488
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
#
# --
# 02
# --
#
# --
# 03
# --
#
# --
# 04
# --
#
# --
# 05
# --
#
# --
# 06
# --
#
# --
# 07
# --
#
# -------------
# 08@001-08@089
# -------------
#
# ---------
# 08@090-08
# ---------
#
# ---------
# 09-09@021
# ---------
#
# ---------
# 09@022-09
# ---------
#
# ---------
# 10-10@017
# ---------
#
# -------------
# 10@018-10@020
# -------------
#
# ---------
# 10@021-10
# ---------
#
# ------------
# 11-11@026:22
# ------------
#
# ---------
# 11@026:23
# ---------
#
# ------------
# 11@026:24-11
# ------------
#
# ------------
# 12-12@037:27
# ------------
#
# ---------
# 12@037:28
# ---------
#
# ----------------
# 12@037:29-12@041
# ----------------
#
# -------------
# 12@042-12@044
# -------------
#
# ---------
# 12@045-12
# ---------
#   0.00s Looking up occurrences of many candidates ...
#   2.35s done
# done

# %%
NE.triggerInterference()
# Out:
# Looking up 27 potential interferences in 2 passes over the corpus ..
# 2 potential conflicting trigger pairs with 2 conflicts
# ----------
# different rows (0 pairs)
# ----------
# Diagnostic trigger interferences written to ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/1.0.1/.persons-merged/interference.txt

# %%
NE.reportHits(showNoHits=True)
# Out:
# No slot is covered by more than one trigger
# Triggers without hits: 154x:
# Looking up 154 triggers in 2 passes over the corpus ..
# durante di prignì                        ()          : 03@011:9 x 1, 03@018:11 x 1
# jan janson linden                        ()          : 07@005:69 x 1
# jan janson vander linden                 ()          : 07@018:50 x 1
# jan janssoon van linden                  ()          : 06@028:181 x 1
# signor conte gioan                       (02-05)     : 06@034:160 x 1
# ambasciator de francia                   (03)        : 12@030:25 x 1
# ambasciatore di franza                   (03)        : 02@012:15 x 1, 08@059:18 x 1
# ambasciatori francia                     (03)        : 04@036:9 x 1
# ambasciator inglese straordinario        (04)        : 08@067:14 x 1
# maximiliano                              (04)        : 10@081:93 x 1
# conte gio ernesto                        (06, 08, 09, 11): 04@026:7 x 1
# figliolo maggiore                        (08)        : 04@016:7 x 1, 11@100:23 x 1
# eccellentissimo signor general           (08@001-08@089): 03@018:7 x 1, 04@060:7 x 1, 04@071:7 x 1, 04@075:7 x 1, 05@003:12 x 1
#                                                        05@009:13 x 1, 05@042:14 x 1, 05@048:20 x 1, 11@066:13 x 1, 12@002:8 x 1
# al suo figlio                            (09)        : 04@019:8 x 1
# ambasciatore di danimarca                (10)        : 12@036:93 x 2
# presidenti di gheldria                   (10)        : 04@031:13 x 1
# deputati della rocella                   (11)        : 10@058:27 x 1, 10@098:13 x 1
# un figliol maschio                       (11)        : 09@090:8 x 1
# al figliolo                              (11@026:23) : 05@049:36 x 1, 11@039:9 x 1, 12@010:18 x 1
# guler                                    (12)        : 08@083:42 x 1, 09@023:72 x 1
# moller                                   (12)        : 06@034:106 x 1
# moscovita                                (12)        : 05@021:7 x 1, 05@043:9 x 1, 06@031:14 x 1, 06@032:16 x 1, 06@035:25 x 1
#                                                        10@060:11 x 1
# muller                                   (12)        : 06@028:132 x 1, 06@028:134 x 1, 06@028:137 x 1, 06@028:197 x 2
# Entities targeted:            812
# Triggers searched for:       2154
# Triggers without hits:        154
#  - completely covered:        131
#  - missing hits:               23
# Triggers with hits:          2000
# Total hits:                 12636
#
# All hits in report file:      ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/1.0.1/.persons-merged/hits.tsv
# Triggers by slot in file:     ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/1.0.1/.persons-merged/triggerBySlot.tsv

# %%
nerMeta(*NE.getMeta(), silent=False)

# %%
NE.bakeEntities()
# Out:
# Entity consolidation for 12636 entity occurrences into version 1.0.1e
#  12636 entity occurrences
#    780 distinct entities
#   0.00s Creating a dataset with entity nodes ...
#   0.00s preparing and checking ...
#   0.00s Feature overview: 34 for nodes; 2 for edges; 1 configs; 9 computed
#    |     0.95s done
#    |   Delete types: t                   : keep:   shift  nodes       1-1733245 to         1-1733245
#    |   Delete types: author              : keep:   shift  nodes 1733246-1733970 to   1733246-1733970
#    |   Delete types: bibl                : keep:   shift  nodes 1733971-1734695 to   1733971-1734695
#    |   Delete types: biblScope           : keep:   shift  nodes 1734696-1735420 to   1734696-1735420
#    |   Delete types: body                : keep:   shift  nodes 1735421-1736145 to   1735421-1736145
#    |   Delete types: cell                : keep:   shift  nodes 1736146-1750480 to   1736146-1750480
#    |   Delete types: chunk               : keep:   shift  nodes 1750481-1797451 to   1750481-1797451
#    |   Delete types: collection          : keep:   shift  nodes 1797452-1798176 to   1797452-1798176
#    |   Delete types: correspAction       : keep:   shift  nodes 1798177-1799626 to   1798177-1799626
#    |   Delete types: correspDesc         : keep:   shift  nodes 1799627-1800351 to   1799627-1800351
#    |   Delete types: date                : keep:   shift  nodes 1800352-1801076 to   1800352-1801076
#    |   Delete types: div                 : keep:   shift  nodes 1801077-1805224 to   1801077-1805224
#    |   Delete types: editor              : keep:   shift  nodes 1805225-1805949 to   1805225-1805949
#    |   Delete types: file                : keep:   shift  nodes 1805950-1806674 to   1805950-1806674
#    |   Delete types: fileDesc            : keep:   shift  nodes 1806675-1807399 to   1806675-1807399
#    |   Delete types: folder              : keep:   shift  nodes 1807400-1807410 to   1807400-1807410
#    |   Delete types: head                : keep:   shift  nodes 1807411-1809492 to   1807411-1809492
#    |   Delete types: hi                  : keep:   shift  nodes 1809493-1824948 to   1809493-1824948
#    |   Delete types: idno                : keep:   shift  nodes 1824949-1827123 to   1824949-1827123
#    |   Delete types: institution         : keep:   shift  nodes 1827124-1827848 to   1827124-1827848
#    |   Delete types: ln                  : keep:   shift  nodes 1827849-1987251 to   1827849-1987251
#    |   Delete types: metamark            : keep:   shift  nodes 1987252-1990266 to   1987252-1990266
#    |   Delete types: msDesc              : keep:   shift  nodes 1990267-1990991 to   1990267-1990991
#    |   Delete types: msIdentifier        : keep:   shift  nodes 1990992-1991716 to   1990992-1991716
#    |   Delete types: name                : keep:   shift  nodes 1991717-1993891 to   1991717-1993891
#    |   Delete types: note                : keep:   shift  nodes 1993892-2007172 to   1993892-2007172
#    |   Delete types: num                 : keep:   shift  nodes 2007173-2007897 to   2007173-2007897
#    |   Delete types: p                   : keep:   shift  nodes 2007898-2056585 to   2007898-2056585
#    |   Delete types: page                : keep:   shift  nodes 2056586-2065349 to   2056586-2065349
#    |   Delete types: pb                  : keep:   shift  nodes 2065350-2074113 to   2065350-2074113
#    |   Delete types: profileDesc         : keep:   shift  nodes 2074114-2074838 to   2074114-2074838
#    |   Delete types: ptr                 : keep:   shift  nodes 2074839-2086660 to   2074839-2086660
#    |   Delete types: publicationStmt     : keep:   shift  nodes 2086661-2087385 to   2086661-2087385
#    |   Delete types: quote               : keep:   shift  nodes 2087386-2087395 to   2087386-2087395
#    |   Delete types: ref                 : keep:   shift  nodes 2087396-2087396 to   2087396-2087396
#    |   Delete types: resp                : keep:   shift  nodes 2087397-2088121 to   2087397-2088121
#    |   Delete types: respStmt            : keep:   shift  nodes 2088122-2088846 to   2088122-2088846
#    |   Delete types: row                 : keep:   shift  nodes 2088847-2092834 to   2088847-2092834
#    |   Delete types: settlement          : keep:   shift  nodes 2092835-2095009 to   2092835-2095009
#    |   Delete types: sourceDesc          : keep:   shift  nodes 2095010-2095734 to   2095010-2095734
#    |   Delete types: table               : keep:   shift  nodes 2095735-2095977 to   2095735-2095977
#    |   Delete types: teiHeader           : keep:   shift  nodes 2095978-2096702 to   2095978-2096702
#    |   Delete types: text                : keep:   shift  nodes 2096703-2097427 to   2096703-2097427
#    |   Delete types: title               : keep:   shift  nodes 2097428-2098152 to   2097428-2098152
#    |   Delete types: titleStmt           : keep:   shift  nodes 2098153-2098877 to   2098153-2098877
#    |   Delete types: max node: shifted from 2098877 to 2098877
#   1.06s add types ...
#    |     0.01s done (2 types)
#    |      |   ent, entity
#   1.07s applying updates ...
#   1.38s write TF data as version 1.0.1e ...
#   0.00s Not all of the warp features otype and oslots are present in
# ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Exporting 36 node and 3 edge and 1 configuration features to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e:
#   0.00s VALIDATING oslots feature
#   0.10s VALIDATING oslots feature
#   0.10s maxSlot=    1733245
#   0.10s maxNode=    2112293
#   0.12s OK: oslots is valid
#    |     0.53s T after                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T chunk                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T corresp              to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T date                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T editorNotes          to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T eid                  to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T empty                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T extraspace           to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T facs                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T file                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T folder               to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T id                   to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.04s T is_meta              to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.07s T is_note              to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T kind                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T n                    to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.16s T otype                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T recipient            to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T recipientLoc         to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T ref                  to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T rend                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.03s T rend_decoded         to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T rend_displaced       to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T rend_footnote        to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T rend_superscript     to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T role                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T sender               to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T senderLoc            to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T shelfmark            to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T source               to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.62s T str                  to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T summary              to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T target               to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T type                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T unit                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T when                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T eoccs                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T link_target          to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     1.01s T oslots               to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s M otext                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#   2.73s Exported 36 node features and 3 edge features and 1 config features to ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#   4.10s all done
#   4.16s Done
# The dataset with entities is now in version 1.0.1e
# The dataset with entities is now the standard version
# True

# %% [markdown]
# We load the new data:

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/ner</span>
# This is Text-Fabric 12.5.5
# 40 features found and 0 ignored
#    |     0.43s T otype                from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     5.86s T oslots               from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#   6.29s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.08s T chunk                from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     3.90s T str                  from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T folder               from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T file                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     3.23s T after                from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |      |     0.11s C __levels__           from otype, oslots, otext
#    |      |       19s C __order__            from otype, oslots, __levels__
#    |      |     0.40s C __rank__             from otype, __order__
#    |      |       17s C __levUp__            from otype, oslots, __rank__
#    |      |     3.32s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.37s C __characters__       from otext
#    |      |     3.49s C __boundary__         from otype, oslots, __rank__
#    |      |     0.50s C __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, folder, file, chunk
#     57s All features loaded / computed - for details use TF.isLoaded()
#    |     0.00s T corresp              from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T date                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T editorNotes          from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.03s T eid                  from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.06s T empty                from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T eoccs                from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.07s T extraspace           from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.06s T facs                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.03s T id                   from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.26s T is_meta              from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.43s T is_note              from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.03s T kind                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.04s T link_target          from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.07s T n                    from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T recipient            from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T recipientLoc         from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T ref                  from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.06s T rend                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.18s T rend_decoded         from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T rend_displaced       from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.02s T rend_footnote        from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T rend_superscript     from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T role                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T sender               from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T senderLoc            from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T shelfmark            from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T source               from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.01s T summary              from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.02s T target               from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.02s T type                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T unit                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#    |     0.00s T when                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e
#   1.43s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.5.5</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/app" title="suriano/letters app">suriano/letters/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/about.md" title="provenance of suriano - letters/tf">suriano - letters 1.0.1e</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="suriano - letters feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>11</td>
#     <td>157567.73</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>725</td>
#     <td>2390.68</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>725</td>
#     <td>2206.02</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>725</td>
#     <td>2206.02</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4148</td>
#     <td>737.03</td>
#     <td><i>176</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>725</td>
#     <td>184.67</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8764</td>
#     <td>157.79</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>725</td>
#     <td>118.53</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>725</td>
#     <td>51.05</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>46971</td>
#     <td>36.90</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>725</td>
#     <td>66.13</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>725</td>
#     <td>118.53</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>entity</th>
#     <td>780</td>
#     <td>35.87</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>48688</td>
#     <td>32.48</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>725</td>
#     <td>31.56</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>725</td>
#     <td>31.56</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>725</td>
#     <td>19.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13281</td>
#     <td>16.69</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>1</td>
#     <td>15.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>725</td>
#     <td>14.08</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>159403</td>
#     <td>9.92</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>725</td>
#     <td>8.73</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>725</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1450</td>
#     <td>7.82</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>15456</td>
#     <td>7.81</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2175</td>
#     <td>6.52</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>725</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>725</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2082</td>
#     <td>4.31</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>725</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>725</td>
#     <td>2.70</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2175</td>
#     <td>2.69</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ent</th>
#     <td>12636</td>
#     <td>2.21</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>725</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>725</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2175</td>
#     <td>1.32</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>metamark</th>
#     <td>3015</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8764</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11822</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>725</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1733245</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>suriano - letters/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2024-10-14T11:07:11Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>1.0.1e</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/1.0.1e/chun
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/thumb</span>
# Found 8766 images<br>

# %% [markdown]
# ## Step 6: Convert TF to WATM
#
# N.B. For docs click the WATM link in the output cell.

# %%
WA = WATM(A, "tei", skipMeta=False, prod=True)
# WA = WATM(A, "tei", skipMeta=False, prod=False)
WA.makeText()
WA.makeAnno()
WA.writeAll()
WA.testAll()
# Out:
# textRepoLevel is section level 'folder'
# [WATM exporter documentation](https://annotation.github.io/text-fabric/tf/convert/watm.html)
# 	Writing WATM ...
# Writing production data to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod
# Text file    0:    44211 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/text-0.tsv
# Text file    1:   117416 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/text-1.tsv
# Text file    2:   146993 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/text-2.tsv
# Text file    3:   109061 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/text-3.tsv
# Text file    4:   154304 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/text-4.tsv
# Text file   10:   132103 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/text-10.tsv
# Text files all:  1733245 segments to 11 files
# Anno file    1:   400000 annotations written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/anno-1.tsv
# Anno file    2:   400000 annotations written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/anno-2.tsv
# Anno file    3:   238194 annotations written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/anno-3.tsv
# Anno files all:  1038194 annotations to 3 files
# Slot mapping written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/pos2node.tsv
# Node mapping written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/anno2node.tsv
# Logical pairs (6908) written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/1.0.0e-028/prod/logicalpairs.tsv
# Extra file datasource/entities/entitymeta.json copied to the WATM directory
# 	Testing WATM ...
# Testing the text ...
# 	TF: 1733245
# 	WA: 1733245
# OK - whether the amounts of tokens agree
# 	TF: Letter 02.001 date 1 ... "corrected on "23."
# 	WA: Letter 02.001 date 1 ... "corrected on "23."
# OK - whether the text is the same
# Testing the elements ...
# 	TF: 322455
# 	WA: 322455
# OK - whether the amounts of elements and nodes agree
# Testing the processing instructions ...
# 	TF:      0
# 	WA:      0
# OK - whether the amounts of processing instructions agree
# Testing the element/pi annotations ...
# 	2055700 element/pi annotations
# 	Element      : 322455 x
# 	Pi           :      0 x
# 	Other        : 678501 x
# 	Good name    : 322455 x
# 	Wrong name   :      0 x
# 	Good target  : 322455 x
# 	Wrong target :      0 x
# 	Unmapped     :      0 x
# OK - whether all element/pi annotations have good bodies
# OK - whether all element/pi annotations have good targets
# Testing the attributes ...
# 	324224 attribute values
# 	Good:     324224 x
# 	Wrong:        0 x
# OK - whether annotations are consistent with features
# 	WA attributes: 324224
# 	TF attributes: 324224
# OK - whether annotations are complete w.r.t. features
# Testing the format attributes ...
# 	120737 format values
# 	formatting attributes:
# 		107648 x decoded
# 		 11831 x footnote
# 		  1071 x superscript
# 		   187 x displaced
# 	Good:     120737 x
# 	Wrong:        0 x
# OK - whether format annotations are consistent with features
# 	WA format attributes: 120737
# 	TF format attributes: 120737
# OK - whether format annotations are complete w.r.t. features
# Testing the extra annotations ...
# 	0 extra feature values
# 	0 extra annotations
# OK - whether the extra annotations agree
# Testing the edges ...
# 	Found: 2055700 nodes
# 	Found edge link_target with 11822 starting nodes
# 	Checking edge link_target
# 		same 11822 fromNodes
# 	OK - 11822 toNodes checked
# OK - whether all edges agree
# Overall outcome ...
# OK - whether all tests passed

# %% [markdown]
# ## Step 7: Generate IIIF manifests

# %%
II = IIIF(Tei.teiVersion, A, PAGESEQ_JSON, prod=True, silent=False)
# II = IIIF(Tei.teiVersion, A, prod=False, silent=False)
II.manifests()
# Out:
# Maximum dimensions: W = 8504 H = 5976
# Average dimensions: W = 4138 H = 4869
# Average deviation:  W = 1038 H =  660
# Maximum dimensions: W = 5600 H = 5786
# Average dimensions: W = 3253 H = 4359
# Average deviation:  W =  477 H =  607
# Collections:
#    02 with  262 pages
#    03 with  660 pages
#    04 with  806 pages
#    05 with  688 pages
#    06 with  684 pages
#    07 with  628 pages
#    08 with  988 pages
#    09 with  944 pages
#    10 with 1062 pages
#    11 with 1116 pages
#    12 with  928 pages
# IIIF manifests generated in ~/gitlab.huc.knaw.nl/suriano/letters/static/prod/manifests

# %% [markdown]
# ## Step 8: Deploy to k8s and TeamText VM

# %% [markdown]
# NB: you need to have access to the k8s cluster and to the team text VM.
#
# That means:
#
# * The LDAP of the relevant k8s clusters know you
# * You have an ssh key-based login on the Team Text VPN
# * You work inside the firewall

# %%
# !./provision.sh watm
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# WATM export version: 1.0.0e-028
# anno-1.tsv                                    100%   17MB   5.9MB/s   00:02
# anno-3.tsv                                    100% 9773KB   6.2MB/s   00:01
# anno-2.tsv                                    100%   15MB   6.9MB/s   00:02
# anno2node.tsv                                 100% 5668KB   6.5MB/s   00:00
# text-6.tsv                                    100% 1224KB   6.0MB/s   00:00
# text-7.tsv                                    100% 1192KB   6.0MB/s   00:00
# text-5.tsv                                    100% 1014KB   5.8MB/s   00:00
# text-4.tsv                                    100%  910KB   6.1MB/s   00:00
# text-0.tsv                                    100%  266KB   5.5MB/s   00:00
# text-1.tsv                                    100%  702KB   5.7MB/s   00:00
# text-3.tsv                                    100%  652KB   5.3MB/s   00:00
# text-2.tsv                                    100%  875KB   5.8MB/s   00:00
# text-9.tsv                                    100% 1335KB   6.1MB/s   00:00
# text-8.tsv                                    100% 1386KB   5.8MB/s   00:00
# entitymeta.json                               100%  327KB   5.2MB/s   00:00
# pos2node.tsv                                  100%   26MB   5.9MB/s   00:04
# text-10.tsv                                   100%  775KB   4.3MB/s   00:00
# logicalpairs.tsv                              100%  177KB   5.0MB/s   00:00

# %%
# !./provision.sh files
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# copying to pod: prod/covers.html
# copying to pod: prod/logo
# copying to pod: prod/manifests
# copying to pod: both/metadata

# %%
# !./provision.sh prod images

# %% [markdown]
# ## Step 9: Test the images

# %% [markdown]
# * [covers](https://data.suriano.huygens.knaw.nl/files/covers.html)
#
# * [02.json](https://data.suriano.huygens.knaw.nl/files/manifests/02.json)
#
# * [page 02_171r](https://data.suriano.huygens.knaw.nl/iiif/3/pages%2F02_071r.jpg/full/max/0/default.jpg)

# %% [markdown]
# # On the command line: Step by step
#
# Here we do the main steps of the conversion.
#
# Every step is a separate run of a python program.
# After completion of a step, all information to run a next step, is saved to disk in the form
# of result files and report files.
#
# If the results of earlier steps are present, you can just do the following step.

# %% [markdown]
# ## Step 0: Initialization
#
# **N.B.** Check the VERSION variable here!

# %%
VERSION
# Out:
# '0.7.1'

# %% [markdown]
# ## Step1: Scan ingest

# %%
# %%time

# !python make.py ingest -
# Out:
# Ingest scans ...
# CPU times: user 9.15 ms, sys: 7.67 ms, total: 16.8 ms
# Wall time: 1.29 s

# %% [markdown]
# ## Step 2: Scan processing

# %%
# %%time

# !python make.py scans
# Out:
# Process scans ...
# CPU times: user 6.13 ms, sys: 7.51 ms, total: 13.6 ms
# Wall time: 615 ms

# %% [markdown]
# ## Step 3: From DOCX to TEI

# %%
# %%time

# !python make.py docx2tei $VERSION
# Out:
# DOCX ==> TEI files ...
# DOCX => simple TEI per filza ...
# DOCX => headers ...
# Collecting transcribers ...
# Collecting page scans ...
# Collecting excel metadata ...
# simple TEI per filza => enriched TEI per letter ...
# 	There were 542 warnings.
# CPU times: user 12.8 ms, sys: 9.18 ms, total: 22 ms
# Wall time: 1.66 s

# %% [markdown]
# ## Step 4: From TEI to TF

# %%
# %%time

# !python make.py tei2tf - $VERSION
# Out:
# TEI => TF ...
# 	Validating TEI ...
# 	Converting TEI ...
# 	Loading TF ...
# CPU times: user 322 ms, sys: 119 ms, total: 441 ms
# Wall time: 1min 9s

# %% [markdown]
# ## Step 5: Mark named entities

# %%
# %%time

# !python make.py ner $VERSION
# Out:
# Annotate named entities ...
# 	Loading TF  ...
# 5 rows with a duplicate name:
#   r305: William, Count of Nassau-Siegen
#   r359: William of Orange
#   r361: Maurice of Nassau
#   r506: Henry II, Duke of Lorraine
#   r645: Guillaume III de Melun
# 1 row without a name:
# 	e.g.: 365
# 149 rows without triggers:
# 	e.g.: 6, 8, 16, 21, 24, 26, 29, 30, 32, 34
# Clash: Gugliemo di Nassau: r9 vs r50
# Clash: Nicolò Perez: r75 vs r571
# Clash: conte di Frusten: r148 vs r149
# Clash: conte di Wanderlip: r150 vs r151
# Clash: colonello Sciombergh: r253 vs r352
# Clash: colonnello Sciombergh: r253 vs r352
# Clash: signor di Rocalaura: r386 vs r459
# Clash: colonel Rocalaura: r386 vs r459
# Clash: monsignor di Rocalaura: r386 vs r459
# Clash: colonello Rocalaura: r386 vs r459
# 	491 entities targeted with 6063 occurrences. See ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/0.4.3/.people.0.6/hits.tsv
# 	Loading TF with entities ...
# CPU times: user 306 ms, sys: 107 ms, total: 413 ms
# Wall time: 1min 3s

# %% [markdown]
# ## Step 6: Convert TF to WATM

# %%
# %%time

# !python make.py watm "$VERSION"e
#!python make.py watm "$VERSION"e --no-prod
# Out:
# TF => WATM ...
# 	Loading TF ...
# 	Making WATM for version 0.4.3e
# 	Writing WATM ...
# 	Testing WATM ...
# 	OK - whether all tests passed
# CPU times: user 45.9 ms, sys: 20.7 ms, total: 66.7 ms
# Wall time: 9.3 s

# %% [markdown]
# ## Step 7: Generate IIIF manifests

# %% [markdown]
# ### Development

# %%
# %%time

# !python make.py iiif "$VERSION"e
#!python make.py iiif "$VERSION"e --no-prod
# Out:
# Generate IIIF manifests ...
# CPU times: user 13.7 ms, sys: 13.1 ms, total: 26.8 ms
# Wall time: 2.24 s

# %% [markdown]
# ## Step 8: Deploy to k8s and TeamText VM

# %%
# %%time

# !python make.py deploy
#!python make.py deploy --no-prod

# %% [markdown]
# # Express: One shot
#
# Here is the express, mindless way to convert the corpus.
# If something goes wrong, you can follow the step-by-step section or the debugging section.

# %% [markdown]
# **N.B.** Check the VERSION variable here!

# %%
VERSION
# Out:
# '0.7.1'

# %%
# %%time

# !python make.py all $VERSION
# !python make.py all $VERSION --no-prod

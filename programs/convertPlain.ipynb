# %% [markdown]
# # Convert from TEI to TF
#
# We convert Suriano TEI to TF.
#
# This notebook is bare, no explanations, nu illustrations, no checks.
# For more documentation, try any of the following variants:
#
# * *convertExpress* : as few commands/feedback/interaction as possible,
# * [convertSteps](convertSteps.ipynb): broken down in a few command line commands, more feedback
# * [convertDetails](convertDetails.ipynb): run from Python with full control

# %%
from tf.app import use
from tf.convert.tei import TEI
from tf.convert.addnlp import NLPipeline
from tf.advanced.helpers import dm

# %%
ORG = "HuygensING"
REPO = "suriano"

# %% [markdown]
# ### Step 0: From docx to TEI

# %% [markdown]
# You might need to do
#
# ```
# pip install docx2python
# ```

# %%
# !python processdocs.py headers tei
# Out:
# TASK headers
# DOCX => headers
# 	Filza_3_Uniformata_xml.docx
# 	Filza_4_uniformata_xml.docx
# Angelo              : 105 pages in  2 filzas
# Cristina            : 111 pages in  2 filzas
# Federica            :  25 pages in  1 filza
# Filippo             :  70 pages in  1 filza
# Flavia              : 117 pages in  2 filzas
# Giorgia             :  90 pages in  2 filzas
# Ruben               : 123 pages in  2 filzas
# Vera                :  89 pages in  2 filzas
# TASK tei
# TEI simple => TEI enriched
# 	Filza_3_Uniformata_xml.xml
# 		letter 36: extra pages: 237
# 	Filza_4_uniformata_xml.xml
# 		letter 48: missing pages: 259-266
# 		letter 49: extra pages: 259-266
# 		letter 50: missing pages: 267
# 0 warnings

# %%
# !t=2023-11-01; mkdir ../tei/$t; rm -rf ../tei/$t/* ; mv ../data/tei/* ../tei/$t
# Out:
# zsh:1: no matches found: ../tei/2023-11-01/*

# %% [markdown]
# ### Step 1: Check

# %%
Tei = TEI(verbose=-1, tei=0, tf="0.0.3pre")

# %%
Tei.task(check=True, verbose=1, validate=True)
# Out:
# TEI to TF checking: ~/github/HuygensING/suriano/tei/2023-11-01 => ~/github/HuygensING/suriano/report/2023-11-01
# Processing instructions are ignored
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# INFO: Needs dcr.xsd (exists)
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   0 changing override(s)
# Section model I
# Start folder 3:
#    1 suriano                                1.xml
#    2 suriano                                10.xml
#    3 suriano                                11.xml
#    4 suriano                                12.xml
#    5 suriano                                13.xml
#    6 suriano                                14.xml
#    7 suriano                                15.xml
# ...

# %% [markdown]
# ### Step 2: Convert

# %%
Tei.good = True
Tei.task(convert=True, verbose=0)
# Out:
# Processing instructions are ignored
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   0 changing override(s)
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# Start folder 3:
#    1 suriano                                1.xml
#    2 suriano                                10.xml
#    3 suriano                                11.xml
#    4 suriano                                12.xml
#    5 suriano                                13.xml
#    6 suriano                                14.xml
#    7 suriano                                15.xml
#    8 suriano                                16.xml
# ...

# %% [markdown]
# ### Step 3: Load the TF data
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and precomputations are performed.
# Next time the loading will be much quicker.

# %%
Tei.task(load=True, verbose=1)
# Out:
#    |     0.35s T otype                from ~/github/HuygensING/suriano/tf/0.0.3pre
#    |     4.49s T oslots               from ~/github/HuygensING/suriano/tf/0.0.3pre
#    |     0.01s T chunk                from ~/github/HuygensING/suriano/tf/0.0.3pre
#    |     0.00s T folder               from ~/github/HuygensING/suriano/tf/0.0.3pre
#    |     0.00s T file                 from ~/github/HuygensING/suriano/tf/0.0.3pre
#    |     2.50s T ch                   from ~/github/HuygensING/suriano/tf/0.0.3pre
#    |      |     0.08s C __levels__           from otype, oslots, otext
#    |      |       11s C __order__            from otype, oslots, __levels__
#    |      |     0.28s C __rank__             from otype, __order__
#    |      |     9.85s C __levUp__            from otype, oslots, __rank__
#    |      |     2.07s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.13s C __characters__       from otext
# ...

# %% [markdown]
# ### Step 4: Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# App updated
# True

# %% [markdown]
# ### Step 5: Add tokens and sentences

# %%
Apre = use(f"{ORG}/{REPO}:clone", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/0.0.3pre</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">TF API 12.1.2</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
NLP = NLPipeline(lang="it", ner=True, parser=True, verbose=0, write=True)
NLP.loadApp(Apre)
# Out:
# Input data has version 0.0.3pre
# Compute element boundaries
#  32214 start postions
#  36549 end postions

# %%
(text, positions) = NLP.task(plaintext=True)
# Out:
# Input data has version 0.0.3pre
# Compute element boundaries
#  32214 start postions
#  36549 end postions
#   0.00s Generating a plain text with positions ...
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
#    |   Found 3072 empty slots
#    |   recorded flow main       with 3643749 items
#    |   recorded flow note       with 170311 items
#   2.56s Done. Generated text and positions written to ~/github/HuygensING/suriano/_temp/txt/plain.txt

# %%
(tokens, sentences, entities) = NLP.task(lingo=True, text=text)
# Out:
# Input data has version 0.0.3pre
# Compute element boundaries
#  32214 start postions
#  36549 end postions
#   0.00s Using NLP pipeline Spacy (it) ...
# NLP with language model it True
# This language supports tagging
# This language supports morphologizing
# This language supports lemmatizing
#  1m 18s Tokens written to ~/github/HuygensING/suriano/_temp/txt/tokens.tsv
#  1m 18s Sentences written to ~/github/HuygensING/suriano/_temp/txt/sentences.tsv
#  1m 18s Entities written to ~/github/HuygensING/suriano/_temp/txt/entities.tsv
#  1m 18s NLP done

# %%
newVersion = NLP.task(
    ingest=True,
    positions=positions,
    tokens=tokens,
    sentences=sentences,
    entities=entities,
)
# Out:
# Input data has version 0.0.3pre
# Compute element boundaries
#  32214 start postions
#  36549 end postions
#   0.00s Ingesting NLP output into the dataset ...
#    |    2m 31s Mapping NLP data to nodes and features ...
#    |      |     0.00s generating t-nodes with features str, after, empty
#    |      |      |     0.00s 280058 t nodes have values assigned for str, after, pos, morph, lemma
#    |      |      |     0.00s 0 empty slots are properly contained in a token
#    |      |      |     0.00s 17896 space slots have split into chars
#    |      |      |     0.00s 21281 slots have split around an element boundary
#    |      |      |     0.00s 216213x Items contained in extra generated text
#    |      |     0.97s 243694 tokens
#    |      |     0.97s 280058 ts
#    |      |     0.97s generating sentence-nodes with features nsent
#    |      |      |     0.39s 16009 sentence nodes have values assigned for nsent
# ...

# %%
Tei.task(apptoken=True)
# Out:
# App updated with NLP output
# True

# %% [markdown]
# ### Step 6: Use the new dataset

# %%
A = use(f"{ORG}/{REPO}:clone", checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/0.0.3</span>
# This is Text-Fabric 12.1.2
# 36 features found and 0 ignored
#    |     0.27s T otype                from ~/github/HuygensING/suriano/tf/0.0.3
#    |     2.83s T oslots               from ~/github/HuygensING/suriano/tf/0.0.3
#   3.10s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.00s T file                 from ~/github/HuygensING/suriano/tf/0.0.3
#    |     0.01s T chunk                from ~/github/HuygensING/suriano/tf/0.0.3
#    |     0.00s T folder               from ~/github/HuygensING/suriano/tf/0.0.3
#    |     1.16s T str                  from ~/github/HuygensING/suriano/tf/0.0.3
# ...

# %%
c = F.otype.s("chunk")[110]
A.pretty(c)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.HuygensING.org/suriano/3/10/16&amp;version=0.0.3" title="Show this on the website" sec="3@10:16">3@10:16</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">chunk </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">p </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">humilissimo </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><s
# ...

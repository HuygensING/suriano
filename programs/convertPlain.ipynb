# %% [markdown]
# # Convert from TEI to TF to WATM
#
# We convert Suriano TEI to TF and then to WATM.
#
# This notebook provides three levels of refinement in the execution. They all have the same outcome,
# but they differ in the level of detail they provide on the conversion.
#
# These are the levels:
#
# * **Express**: one single command on the command line for the complete conversion;
# * **Step by step**: one command for each main step of the conversion;
# * **Debugging**: all the commands directly in Python, the intermediate data remains in memory and can be inspected.

# %% [markdown]
# # Production or development
#
# Mosts steps are unaffected by the production/development setting.
#
# In the first steps of the pipeline (*ingest* and *scan processing*) we prepare both the dev and the prod data.
#
# The intermediate steps (*from DOCX to TEI*, *from TEI to TF*, *mark named entities*) are identical for prod and dev.
#
# Only for the latter steps (*convert TF to WATM*, generate IIIF manifests*, *deploy to k8s*) there is a distinction between prod and dev.
#
# For these steps we have commented out the line that does the dev version.

# %% [markdown]
# # Requirements
#
# * zsh as command line shell (as in macOS);
# * access to suitable k8s clusters, streamlined by the
#   [k-suite](https://code.huc.knaw.nl/tt/smart-k8s/-/blob/main/docs/k-suite.md);
# * [Pandoc](https://pandoc.org)
# * [Imagemagick](https://imagemagick.org)
# * [Python](https://www.python.org) (3.12 or higher) with additional pip-installable modules:
#   * text-fabric
#   * doc2python
#   * openpyxl

# %% [markdown]
# # Declare the version
#
# Always set the version before running any cell in this notebook!

# %%
VERSION = "0.4.3"

# %% [markdown]
# # Express: One shot
#
# Here is the express, mindless way to convert the corpus.
# If something goes wrong, you can follow the step-by-step section or the debugging section.

# %%
# %%time

# !python make.py all $VERSION
# !python make.py all $VERSION --no-prod
# Out:
# DOCX ==> TEI files ...
# DOCX => simple TEI per filza ...
# DOCX => headers ...
# Collecting transcribers ...
# Collecting page scans ...
# Collecting excel metadata ...
# simple TEI per filza => enriched TEI per letter ...
# 	There were 5234 page warnings.
# 	There were 541 warnings.
# 	Pages with    transcription and no scan:  4675
# 	Pages with no transcription and    scan:   331
# TEI => TF ...
# 	Validating TEI ...
# 	Converting TEI ...
# 	Loading TF ...
# Annotate named entities ...
# 	Loading TF  ...
# 	489 entities targeted with 6220 occurrences. See ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/0.4.1/.people.0.5/hits.tsv
# 	Loading TF with entities ...
# TF => WATM ...
# 	Loading TF ...
# 	Making WATM for version 0.4.1e
# 	Writing WATM ...
# 	Testing WATM ...
# 	OK - whether all tests passed
# Process images ...
# Generate IIIF manifests ...
# CPU times: user 623 ms, sys: 219 ms, total: 842 ms
# Wall time: 2min 19s

# %% [markdown]
# # Still on the command line: Step by step
#
# Here we do the main steps of the conversion.
#
# Every step is a separate run of a python program.
# After completion of a step, all information to run a next step, is saved to disk in the form
# of result files and report files.
#
# If the results of earlier steps are present, you can just do the following step.

# %% [markdown]
# ## Step1: Scan ingest

# %%
# %%time

# !python make.py ingest -
# Out:
# Ingest scans ...
# CPU times: user 9.15 ms, sys: 7.67 ms, total: 16.8 ms
# Wall time: 1.29 s

# %% [markdown]
# ## Step 2: Scan processing

# %%
# %%time

# !python make.py scans
# Out:
# Process scans ...
# CPU times: user 6.13 ms, sys: 7.51 ms, total: 13.6 ms
# Wall time: 615 ms

# %% [markdown]
# ## Step 3: From DOCX to TEI

# %%
# %%time

# !python make.py docx2tei $VERSION
# Out:
# DOCX ==> TEI files ...
# DOCX => simple TEI per filza ...
# DOCX => headers ...
# Collecting transcribers ...
# Collecting page scans ...
# Collecting excel metadata ...
# simple TEI per filza => enriched TEI per letter ...
# 	There were 542 warnings.
# CPU times: user 12.8 ms, sys: 9.18 ms, total: 22 ms
# Wall time: 1.66 s

# %% [markdown]
# ## Step 4: From TEI to TF

# %%
# %%time

# !python make.py tei2tf - $VERSION
# Out:
# TEI => TF ...
# 	Validating TEI ...
# 	Converting TEI ...
# 	Loading TF ...
# CPU times: user 322 ms, sys: 119 ms, total: 441 ms
# Wall time: 1min 9s

# %% [markdown]
# ## Step 5: Mark named entities

# %%
# %%time

# !python make.py ner $VERSION
# Out:
# Annotate named entities ...
# 	Loading TF  ...
# 5 rows with a duplicate name:
#   r305: William, Count of Nassau-Siegen
#   r359: William of Orange
#   r361: Maurice of Nassau
#   r506: Henry II, Duke of Lorraine
#   r645: Guillaume III de Melun
# 1 row without a name:
# 	e.g.: 365
# 149 rows without triggers:
# 	e.g.: 6, 8, 16, 21, 24, 26, 29, 30, 32, 34
# Clash: Gugliemo di Nassau: r9 vs r50
# Clash: Nicolò Perez: r75 vs r571
# Clash: conte di Frusten: r148 vs r149
# Clash: conte di Wanderlip: r150 vs r151
# Clash: colonello Sciombergh: r253 vs r352
# Clash: colonnello Sciombergh: r253 vs r352
# Clash: signor di Rocalaura: r386 vs r459
# Clash: colonel Rocalaura: r386 vs r459
# Clash: monsignor di Rocalaura: r386 vs r459
# Clash: colonello Rocalaura: r386 vs r459
# 	491 entities targeted with 6063 occurrences. See ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/0.4.3/.people.0.6/hits.tsv
# 	Loading TF with entities ...
# CPU times: user 306 ms, sys: 107 ms, total: 413 ms
# Wall time: 1min 3s

# %% [markdown]
# ## Step 6: Convert TF to WATM

# %%
# %%time

# !python make.py watm "$VERSION"e
#!python make.py watm "$VERSION"e --no-prod
# Out:
# TF => WATM ...
# 	Loading TF ...
# 	Making WATM for version 0.4.3e
# 	Writing WATM ...
# 	Testing WATM ...
# 	OK - whether all tests passed
# CPU times: user 45.9 ms, sys: 20.7 ms, total: 66.7 ms
# Wall time: 9.3 s

# %% [markdown]
# ## Step 7: Generate IIIF manifests

# %% [markdown]
# ### Development

# %%
# %%time

# !python make.py iiif "$VERSION"e
#!python make.py iiif "$VERSION"e --no-prod
# Out:
# Generate IIIF manifests ...
# CPU times: user 13.7 ms, sys: 13.1 ms, total: 26.8 ms
# Wall time: 2.24 s

# %% [markdown]
# ## Step 8: Deploy to k8s and TeamText VM

# %%
# %%time

# !python make.py deploy
#!python make.py deploy --no-prod

# %% [markdown]
# # In debugging mode.
#
# Now we dig a bit deeper, en do all the steps while keeping the program in memory.
# Now it becomes doable to inspect all intermediate results.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tf.convert.tei import TEI
from tf.convert.addnlp import NLPipeline
from tf.convert.watm import WATM
from tf.convert.iiif import IIIF
from tf.advanced.helpers import dm
from tf.core.files import fileCopy

from processscans import Scans
from processdocs import TeiFromDocx, normalizeChars
from processhelpers import nerMeta, NER_NAME, NERIN_FILE, NEROUT_FILE, SOURCEBASE, PAGESEQ_JSON

# %% [markdown]
# ## Step 0: Initialization
#
# **N.B.** Check the VERSION variable here!

# %%
VERSION = "0.4.4"

# %% [markdown]
# ## Step 1: Scan ingest

# %%
SC = Scans(silent=False, force=False)

# %%
SC.ingest(dry=False)
# Out:
# 	Already ingested covers. Remove ~/gitlab.huc.knaw.nl/suriano/letters/scans/covers or pass --force to ingest again
# 	Already ingested pages. Remove ~/gitlab.huc.knaw.nl/suriano/letters/scans/pages or pass --force to ingest again

# %% [markdown]
# ## Step 2: Scan processing

# %%
SC = Scans(silent=False, force=False)
SC.process()
# Out:
# Already present: sizes file originals (covers)
# Already present: sizes file originals (pages)
# Already present: thumbnails (covers)
# Already present: sizes file thumbnails (covers)
# Already present: thumbnails (pages)
# Already present: sizes file thumbnails (pages)

# %% [markdown]
# ## Step 3: From DOCX to TEI

# %% [markdown]
# You might need to do
#
# ```
# pip install docx2python
# ```

# %%
TFD = TeiFromDocx(silent=False)

# %%
TFD.task("pandoc")
# Out:
# DOCX => simple TEI per filza ...
# 	02.docx ... uptodate
# 	03.docx ... uptodate
# 	04.docx ... uptodate
# 	05.docx ... uptodate
# 	06.docx ... uptodate
# 	07.docx ... uptodate
# 	08.docx ... uptodate
# 	09.docx ... uptodate
# 	10.docx ... uptodate
# 	11.docx ... uptodate
# 	12.docx ... uptodate

# %%
TFD.task("headers")
# Out:
# DOCX => headers ...
# 	02.docx
# 	03.docx
# 	04.docx
# 	05.docx
# 	06.docx
# 	07.docx
# 	08.docx
# 	09.docx
# 	10.docx
# 	11.docx
# 	12.docx
# 	OK: All headers are OK
# Angelo              : 1181 pages in 11 filzas
# Cristina            : 1034 pages in 10 filzas
# Federica            : 684 pages in  7 filzas
# Filippo             : 1084 pages in  9 filzas
# Flavia              : 1282 pages in 11 filzas
# Giorgia             : 992 pages in  9 filzas
# Renzo               :  56 pages in  1 filza
# Ruben               : 1162 pages in 10 filzas
# Vera                : 966 pages in 10 filzas
# Vera, Federica      : 210 pages in  1 filza

# %%
TFD.task("tei")
# Out:
# Collecting transcribers ...
# Collecting page scans ...
#   0 x error
# 8766 x good
# Collecting excel metadata ...
# 	found metadata for 71 letters
# simple TEI per filza => enriched TEI per letter ...
# 	02.xml
# 	03.xml
# 	04.xml
# 	05.xml
# 	06.xml
# 	07.xml
# 	08.xml
# 	09.xml
# 	10.xml
# 	11.xml
# 	12.xml
# 0 page warnings
#   542 x      no extra letter data in xls. See extrainfo.txt
#
# 542 warnings
# Pages with    transcription and    scan:  8766
# Pages with    transcription and no scan:     0
# Pages with no transcription and    scan:     0
# See ~/gitlab.huc.knaw.nl/suriano/letters/datasource/transcriptions/report/scantrans.tsv

# %% [markdown]
# ## Step 4: From TEI to TF
#
# ### Check the validity of the TEI.

# %%
Tei = TEI(verbose=-1, sourceBase=SOURCEBASE, tei="", tf=VERSION)

# %%
Tei.task(check=True, verbose=1, validate=True)
# Out:
# TEI to TF checking: ~/gitlab.huc.knaw.nl/suriano/letters/datasource/tei => ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report
# Processing instructions are ignored
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# INFO: Needs dcr.xsd (exists)
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/suriano/letters/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   0 changing override(s)
# Section model I
# 	Start folder 02:
# 		   1 suriano                                001.xml
# 		   2 suriano                                002.xml
# 		   3 suriano                                003.xml
# 		   4 suriano                                004.xml
# 		   5 suriano                                005.xml
#   15 suriano                                015.xml
# End   folder 02
# 	Start folder 03:
# 		  16 suriano                                001.xml
# 		  17 suriano                                002.xml
# 		  18 suriano                                003.xml
# 		  19 suriano                                004.xml
# 		  20 suriano                                005.xml
#   67 suriano                                052.xml
# End   folder 03
# 	Start folder 04:
# 		  68 suriano                                001.xml
# 		  69 suriano                                002.xml
# 		  70 suriano                                003.xml
# 		  71 suriano                                004.xml
# 		  72 suriano                                005.xml
#  141 suriano                                074.xml
# End   folder 04
# 	Start folder 05:
# 		 142 suriano                                001.xml
# 		 143 suriano                                002.xml
# 		 144 suriano                                003.xml
# 		 145 suriano                                004.xml
# 		 146 suriano                                005.xml
#  198 suriano                                057.xml
# End   folder 05
# 	Start folder 06:
# 		 199 suriano                                001.xml
# 		 200 suriano                                002.xml
# 		 201 suriano                                003.xml
# 		 202 suriano                                004.xml
# 		 203 suriano                                005.xml
#  235 suriano                                037.xml
# End   folder 06
# 	Start folder 07:
# 		 236 suriano                                001.xml
# 		 237 suriano                                002.xml
# 		 238 suriano                                003.xml
# 		 239 suriano                                004.xml
# 		 240 suriano                                005.xml
#  278 suriano                                043.xml
# End   folder 07
# 	Start folder 08:
# 		 279 suriano                                001.xml
# 		 280 suriano                                002.xml
# 		 281 suriano                                003.xml
# 		 282 suriano                                004.xml
# 		 283 suriano                                005.xml
#  367 suriano                                089.xml
# End   folder 08
# 	Start folder 09:
# 		 368 suriano                                001.xml
# 		 369 suriano                                002.xml
# 		 370 suriano                                003.xml
# 		 371 suriano                                004.xml
# 		 372 suriano                                005.xml
#  448 suriano                                081.xml
# End   folder 09
# 	Start folder 10:
# 		 449 suriano                                001.xml
# 		 450 suriano                                002.xml
# 		 451 suriano                                003.xml
# 		 452 suriano                                004.xml
# 		 453 suriano                                005.xml
#  547 suriano                                099.xml
# End   folder 10
# 	Start folder 11:
# 		 548 suriano                                001.xml
# 		 549 suriano                                002.xml
# 		 550 suriano                                003.xml
# 		 551 suriano                                004.xml
# 		 552 suriano                                005.xml
#  637 suriano                                090.xml
# End   folder 11
# 	Start folder 12:
# 		 638 suriano                                001.xml
# 		 639 suriano                                002.xml
# 		 640 suriano                                003.xml
# 		 641 suriano                                004.xml
# 		 642 suriano                                005.xml
#  681 suriano                                044.xml
# End   folder 12
# 681 suriano file(s) ...
# 	Validating ...
# 		Elapsed time 135+296=431 milliseconds
# 	Making inventory ...
#
# Validation OK
# 8931 info line(s) written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/elements.txt
# 584 tag(s) type info written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/types.txt
# 38 tags of which 0 with multiple namespaces written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/namespaces.txt
# Refs written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/refs.txt
# 	resolvable: 4141 in 11716
# 	dangling:      0 in    0
# 	ALL:        4141 in 11716
# Ids written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/ids.txt
# 	referenced: 4141 by 11716
# 	non-unique: 2213
# 	unused:      198
# 	ALL:        2126 in 4339
# lb-parent info written to ~/gitlab.huc.knaw.nl/suriano/letters/datasource/report/lb-parents.txt
# True

# %% [markdown]
# ### Convert the data

# %%
Tei.good = True
Tei.task(convert=True, verbose=0)
# Out:
# Line model II with ln nodes for lines between lb elements
# Page model II with page nodes for pages started by pb elements  keeping the pb elements
# Section model I
# Processing instructions are ignored
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/suriano/letters/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   0 changing override(s)
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# 	Start folder 02:
# 		   1 suriano                                001.xml
# 		   2 suriano                                002.xml
# 		   3 suriano                                003.xml
# 		   4 suriano                                004.xml
# 		   5 suriano                                005.xml
#   15 suriano                                015.xml
# End   folder 02
# 	Start folder 03:
# 		  16 suriano                                001.xml
# 		  17 suriano                                002.xml
# 		  18 suriano                                003.xml
# 		  19 suriano                                004.xml
# 		  20 suriano                                005.xml
#   67 suriano                                052.xml
# End   folder 03
# 	Start folder 04:
# 		  68 suriano                                001.xml
# 		  69 suriano                                002.xml
# 		  70 suriano                                003.xml
# 		  71 suriano                                004.xml
# 		  72 suriano                                005.xml
#  141 suriano                                074.xml
# End   folder 04
# 	Start folder 05:
# 		 142 suriano                                001.xml
# 		 143 suriano                                002.xml
# 		 144 suriano                                003.xml
# 		 145 suriano                                004.xml
# 		 146 suriano                                005.xml
#  198 suriano                                057.xml
# End   folder 05
# 	Start folder 06:
# 		 199 suriano                                001.xml
# 		 200 suriano                                002.xml
# 		 201 suriano                                003.xml
# 		 202 suriano                                004.xml
# 		 203 suriano                                005.xml
#  235 suriano                                037.xml
# End   folder 06
# 	Start folder 07:
# 		 236 suriano                                001.xml
# 		 237 suriano                                002.xml
# 		 238 suriano                                003.xml
# 		 239 suriano                                004.xml
# 		 240 suriano                                005.xml
#  278 suriano                                043.xml
# End   folder 07
# 	Start folder 08:
# 		 279 suriano                                001.xml
# 		 280 suriano                                002.xml
# 		 281 suriano                                003.xml
# 		 282 suriano                                004.xml
# 		 283 suriano                                005.xml
#  367 suriano                                089.xml
# End   folder 08
# 	Start folder 09:
# 		 368 suriano                                001.xml
# 		 369 suriano                                002.xml
# 		 370 suriano                                003.xml
# 		 371 suriano                                004.xml
# 		 372 suriano                                005.xml
#  448 suriano                                081.xml
# End   folder 09
# 	Start folder 10:
# 		 449 suriano                                001.xml
# 		 450 suriano                                002.xml
# 		 451 suriano                                003.xml
# 		 452 suriano                                004.xml
# 		 453 suriano                                005.xml
#  547 suriano                                099.xml
# End   folder 10
# 	Start folder 11:
# 		 548 suriano                                001.xml
# 		 549 suriano                                002.xml
# 		 550 suriano                                003.xml
# 		 551 suriano                                004.xml
# 		 552 suriano                                005.xml
#  637 suriano                                090.xml
# End   folder 11
# 	Start folder 12:
# 		 638 suriano                                001.xml
# 		 639 suriano                                002.xml
# 		 640 suriano                                003.xml
# 		 641 suriano                                004.xml
# 		 642 suriano                                005.xml
#  681 suriano                                044.xml
# End   folder 12
#
# Resolving links into edges ...
# 	4141 in 11716 reference(s) resolved
#    |     9.93s "delete" actions: 0
#    |     9.93s "edge" actions: 11716
#    |     9.93s "feature" actions: 2430949
#    |     9.93s "node" actions: 372508
#    |     9.93s "resume" actions: 0
#    |     9.93s "slot" actions: 1607126
#    |     9.93s "terminate" actions: 373189
#    |    1979634 nodes of all types
#    |       10s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.05s OK
#    |     0.00s reordering nodes ...
#    |     1.23s Max node = 1979634
#    |     1.23s OK
#    |     0.00s reassigning feature values ...
#    |     0.81s OK
# True

# %% [markdown]
# ### Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# True

# %% [markdown]
# ### Use the new dataset
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and pre-computations are performed.
# Next time the loading will be much quicker.

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/ner</span>
# This is Text-Fabric 12.5.3
# 40 features found and 0 ignored
#   0.32s Dataset without structure sections in otext:no structure functions in the T-API
#   1.02s All features loaded / computed - for details use TF.isLoaded()
#   0.04s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.5.3</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/app" title="suriano/letters app">suriano/letters/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/about.md" title="provenance of suriano - letters/tf">suriano - letters 0.4.4</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="suriano - letters feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>11</td>
#     <td>146102.36</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>681</td>
#     <td>2359.95</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>681</td>
#     <td>2281.52</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>681</td>
#     <td>2281.52</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4099</td>
#     <td>733.15</td>
#     <td><i>187</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.66</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8766</td>
#     <td>157.23</td>
#     <td>86</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>681</td>
#     <td>78.43</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>44484</td>
#     <td>36.13</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>681</td>
#     <td>48.30</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>681</td>
#     <td>33.22</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>48318</td>
#     <td>31.96</td>
#     <td>96</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>681</td>
#     <td>30.13</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>681</td>
#     <td>30.13</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>681</td>
#     <td>18.01</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>681</td>
#     <td>18.01</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>681</td>
#     <td>15.21</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>681</td>
#     <td>14.08</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>158860</td>
#     <td>9.72</td>
#     <td>96</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>681</td>
#     <td>9.36</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13087</td>
#     <td>8.82</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>681</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1362</td>
#     <td>6.84</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>681</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>32671</td>
#     <td>5.25</td>
#     <td>11</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>681</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>681</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>681</td>
#     <td>2.94</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>681</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2043</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>681</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>681</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2043</td>
#     <td>1.64</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2043</td>
#     <td>1.63</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8766</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11716</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>681</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>681</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1607126</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>suriano - letters/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2024-08-08T10:59:01Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>0.4.4</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <details>
#     <summary>number of a chunk within a document</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda<
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/thumb</span>
# Found 8766 images<br>

# %%
n = F.otype.s("pb")[1]
A.plain(n)
A.pretty(n)
# Out:
# <div class=" pl-mode"><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.suriano.org/letters/02/001/6&amp;version=0.4.4" title="Show this on the website" sec="02@001:6">02@001:6</a></span></span>  <span class="txtu ">folio <span title="n">071v</span></span> <div><a href="illustrations/folio-02-071v.jpg" target="illustrations/folio-02-071v.jpg title="02_071v">📷</a></div><span class="txtu">​</span></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.suriano.org/letters/02/001/6&amp;version=0.4.4" title="Show this on the website" sec="02@001:6">02@001:6</a></span></div><div class=" children pr-mode"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">pb </span> <span class="txtu">folio <span title="facs">02_071v</span></span></div><div><div><a href="illustrations/folio-02-071v.jpg" target="illustrations/folio-02-071v.jpg title="02_071v">📷</a></div></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div></div></div></div></div>

# %% [markdown]
# ## Step 5: Mark named entities

# %%
fileCopy(NERIN_FILE, NEROUT_FILE)
NE = A.makeNer(normalizeChars=normalizeChars, silent=False)
# Out:
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
# NE.setTask(f".{NER_NAME}.{NER_VERSION}", caseSensitive=True, force=True)
NE.setTask(f".{NER_NAME}", force=True)
# Out:
# Annotation set 🧾 persons has 0 annotations
# SHEET data: computing from scratch ...
# --------------
# Reading sheets
# --------------
# Sheet with 640 rows and 18 columns
# 1 row with a duplicate name:
#   r481: () Henry II, Duke of Lorraine also in r21
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
# Ambi: 'gugliemo di nassau':
#   William, Count of Nassau-Siegen: 8
#   William Louis, Count of Nassau-Dillenburg: 46
# Ambi: 'jacob janson da hoorn':
#   Jacob Meeusen van Hoorn: 431
#   Jacob Jansz. van Hoorn: 572
# Ambi: 'signor marioni':
#   Pier Antonio Mariano: 448
#   Pier Antonio Marioni: 562
# Ambiguous triggers: 3 x
# --
# 02
# --
#
# --
# 03
# --
#
# --
# 04
# --
#
# --
# 05
# --
#
# --
# 06
# --
#
# --
# 07
# --
#
# --
# 08
# --
#
# --
# 09
# --
#
# ---------
# 10-10.017
# ---------
#
# -------------
# 10.018-10.020
# -------------
#
# ---------
# 10.021-10
# ---------
#
# --
# 11
# --
#
# ---------
# 12-12.041
# ---------
#
# ---------
# 12.042-12
# ---------
#   0.00s Looking up occurrences of many candidates ...
#   2.32s done
# done

# %%
inventory = NE.getSheetData().inventory

# %%
triggerData = inventory[('johan.van.groesbek', 'PER')]

# %%
triggerData['il baron di grusberch']
# Out:
# {'': [(1498187, 1498188, 1498189, 1498190, 1498191, 1498192)]}

# %%
triggerData.get('baron di grusberch', None)

# %%
NE.reportHits(showNoHits=True)
# Out:
# Triggers without hits: 157x:
#   triggers without hits:
#     2da principessa
#     [ umena ] figlio
#     amsterreadt
#     arrigo
#     baron di grusberch
#     bartoloti
#     bernvil
#     bilderbeek
#     bilderbeke
#     brogh
#     capitano vassenoven
#     cardinal della rosciafucò
#     cardinal gleselio
#     cent alles
#     christiano di bransvich
#     collonello vassenoven
#     colonello sciomburgh
#     consigliero dimer
#     conte di ortembourgh
#     conte henrico di berghen
#     conte nicola governator a verona
#     conte nicolo gualdo governatore di verona
#     curtlano
#     dal presidente di settimana
#     dardano
#     don luigi di velasco
#     duca de wimaer o di sassonia
#     duca di bavaria
#     duca di holstein
#     duca do lunemburg
#     duchessa di sassonia
#     duci di dupont
#     emmanuel filiberto
#     ernesto casimiro di nansau
#     federigo di solms
#     filiberto vernati
#     frans boels
#     gaffier
#     geffier
#     geraerdt
#     gerbrantssen
#     gerritsz .
#     giacomo nicheeti
#     gio . andrea calandrini
#     gio . casimiro di levestein
#     gio battista pasini
#     gio della gamba
#     gio ernesto di nassau
#     giovane duca di branuich
#     giovane duca di holstein
#     giovanni casimiro di levenstein
#     giuseppe gomorini
#     godfried
#     goedefroy
#     gormorin
#     governatore di nimeghen
#     gren
#     havert
#     henrico padri di lei
#     hertocson
#     herve
#     hillebrandt
#     huyn d ’ amstenreadt
#     il dimer
#     il gré
#     il lantgravio di hassia
#     il pontefice
#     il principe d ’ inghilterra
#     il principe di epinoi valore
#     il principe maggiore figliolo del re di boemia
#     il quast
#     il signor marchese elettore di brandemburgh
#     il vanilt sottosecretario
#     ioost adriaanson da roterdam
#     jan piettersen block
#     joan au [ . . . ] entros
#     johannes bartholomeus
#     l ’ almirante d ’ arragona
#     l ’ ambasciator aghes
#     l ’ ambasciator langarauh
#     la madre del re di boemia
#     la mogle del re di boemia
#     la moglie del re di boemia
#     ladislaus iv of poland
#     lambert charles
#     langravio di hassia
#     liévin
#     luigi d ’ este
#     m . de gulena
#     m antonio de dominis
#     marada o pieterson
#     marchese di iegerdorf
#     marchese di trever
#     mechior quingetti
#     monsieur pisieurs
#     monsieur sciomburgh
#     monsignor di epernon
#     monsù di alincurt
#     monsù di alincurt figliolo
#     muley zidan
#     nicolo de bucorst
#     ogley
#     onderson
#     padavino da zurich
#     padre gio . andrea calandrii
#     padre umena
#     plugen
#     pressidente di frisia
#     principe [ di conti ]
#     principe d ’ aranges
#     principe di neuburgh
#     principe di pinoi
#     principe di pinoi vallore
#     principe henrico di nansau
#     principe mauricio
#     principe maurizio
#     principessa di conti
#     principessa di ligni
#     proet
#     proveditor paruta
#     regina di francia
#     rutghertins
#     sciombergh
#     secretario de stati di quella provincie
#     sidan
#     signor brin
#     signor de villeroi
#     signor di clutin secondogenito della casa di brederod
#     signor pauli
#     silvius
#     simon contareni
#     skyt
#     skyte
#     solari
#     sorella del figlio di berneuelt
#     stakenbroeck
#     starckenborch
#     sterckenborch
#     sterkenburch
#     sterreburch
#     steven janssen coop
#     steven knoop
#     stotenburgh
#     taecke
#     taffin
#     terzo genito del re di danimarca
#     thomas hele
#     udson
#     un capitan scocese fratello di quel capitano seiton
#     un duca di holstain
#     un luocotenente del capitan schiavelinch
#     van den kerckhoven
#     veit
#     volbergen
#     volrad
#     woodhuysen
#     émile
# Entities targeted:       623
# Triggers searched for:  1320
# Triggers without hits:   157
# Triggers with hits:     1163
# Total hits:             8415
#
# All hits in report file: ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/0.4.4/.persons/hits.tsv

# %%
NE.findTrigger("baron di grusberch")
# Out:
# **1 occurrence**
# <div class=" pl-mode"><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.suriano.org/letters/12/007/17&amp;version=0.4.4" title="Show this on the website" sec="12@007:17">12@007:17</a></span></span>  <span class="txtu">vostra </span><span class="txtu">Serenità </span><span class="txtu">in </span><span class="txtu">una </span><span class="txtu">delle </span><span class="txtu">doi </span><span class="txtu">precedenti </span><span class="txtu">lettere </span><span class="txtu">mie </span><span class="txtu">della </span><span class="txtu">passata</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">settimana </span><span class="txtu">dei </span><span class="txtu">20</span><span class="txtu">, </span><span class="txtu">che </span><span class="txtu">unite </span><span class="txtu">vengono </span><span class="txtu">replicate </span><span class="txtu">con </span><span class="txtu">le</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">presenti </span><span class="txtu">sentirà </span><span class="txtu">quello </span><span class="txtu">che </span><span class="txtu">scrivo </span><span class="txtu"><span class="r_italic ">toccante</span></span><span class="txtu">​</span><span class="txtu"> </span><span class="txtu"><span class="r_italic ">le </span></span><span class="txtu"><span class="r_italic ">tregue</span></span><span class="txtu"><span class="r_italic ">, </span></span><span class="txtu"><span class="r_italic ">et </span></span><span class="txtu"><span class="r_italic ">come</span></span><span class="break"><br></span><span class="txtu"><span class="r_italic "></span></span><span class="txtu"><span class="r_italic ">vi </span></span><span class="txtu"><span class="r_italic ">erano </span></span><span class="txtu"><span class="r_italic ">persone </span></span><span class="txtu"><span class="r_italic ">dalla </span></span><span class="txtu"><span class="r_italic ">parte </span></span><span class="txtu"><span class="r_italic ">di </span></span><span class="txtu"><span class="r_italic ">Brusseles</span></span><span class="txtu"><span class="r_italic ">, </span></span><span class="txtu"><span class="r_italic ">che </span></span><span class="txtu"><span class="r_italic ">ne </span></span><span class="txtu"><span class="r_italic ">trattavano</span></span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span><span class="txtu">desi</span><span class="txtu">-</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">derando </span><span class="txtu">io </span><span class="txtu">cavarne </span><span class="txtu">quello</span><span class="txtu">, </span><span class="txtu">che </span><span class="txtu">potevo </span><span class="txtu">perché </span><span class="txtu">tanto </span><span class="txtu">meglio</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">fosse </span><span class="txtu">la </span><span class="txtu">Serenità </span><span class="txtu">vostra </span><span class="txtu">avvertita </span><span class="txtu">di </span><span class="txtu">ciò </span><span class="txtu">che </span><span class="txtu">passa </span><span class="txtu">ne </span><span class="txtu">messi </span><span class="txtu">destra</span><span class="txtu">-</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">mente </span><span class="txtu">in </span><span class="txtu">proposito </span><span class="txtu">l</span><span class="txtu">’</span><span class="txtu">Eccellenza </span><span class="txtu">sua </span><span class="txtu">et </span><span class="txtu">cavai </span><span class="txtu">esser </span><span class="txtu">in </span><span class="txtu">effetto </span><span class="txtu">vero</span><span class="break"><br></span><span class="txtu"></span><span class="txtu">che </span><span class="txtu"><span class="r_italic ">se</span></span><span class="txtu">​</span><span class="t ...

# %%
NE.makeSheetOfSingleTokens()

# %%
NE.setTask(f".{NER_NAME}-single", force=True)
# Out:
# Annotation set 🧾 persons-single has 475521 annotations
# SHEET data: computing from scratch ...
# --------------
# Reading sheets
# --------------
# Sheet with 1250 rows and 5 columns
#
# -------------------
# Checking scopes ...
# -------------------
#
# --
# ()
# --
#   0.00s Looking up occurrences of many candidates ...
#   2.21s done
# done

# %%
NE.reportHits(showNoHits=True)
# Out:
# Triggers without hits: 71x:
#   triggers without hits:
#     adriaanson
#     alincurt
#     amsterreadt
#     aranges
#     arrigo
#     berneuelt
#     bernvil
#     bilderbeek
#     bilderbeke
#     boels
#     branuich
#     brogh
#     calandrii
#     contareni
#     curtlano
#     emmanuel
#     epinoi
#     federigo
#     gaffier
#     geffier
#     geraerdt
#     gerbrantssen
#     gerritsz
#     godfried
#     goedefroy
#     gormorin
#     havert
#     hele
#     herve
#     hillebrandt
#     iegerdorf
#     iv
#     knoop
#     ladislaus
#     langarauh
#     liévin
#     lunemburg
#     mechior
#     mogle
#     monsù
#     muley
#     nicheeti
#     ogley
#     onderson
#     pinoi
#     plugen
#     proet
#     rutghertins
#     schiavelinch
#     sidan
#     silvius
#     skyt
#     skyte
#     solari
#     stakenbroeck
#     starckenborch
#     sterckenborch
#     sterkenburch
#     sterreburch
#     taecke
#     taffin
#     trever
#     udson
#     vallore
#     vassenoven
#     veit
#     volbergen
#     volrad
#     woodhuysen
#     zidan
#     émile
# Entities targeted:      1248
# Triggers searched for:  1248
# Triggers without hits:    71
# Triggers with hits:     1177
# Total hits:            475521
#
# All hits in report file: ~/gitlab.huc.knaw.nl/suriano/letters/_temp/ner/0.4.4/.persons-single/hits.tsv

# %%
nerMeta(*NE.getMeta(), silent=False)

# %%
NE.bakeEntities()
# Out:
# Entity consolidation for 475521 entity occurrences into version 0.4.4e
# 475521 entity occurrences
#   1177 distinct entities
#   0.00s Creating a dataset with entity nodes ...
#   0.00s preparing and checking ...
#   0.00s Feature overview: 37 for nodes; 2 for edges; 1 configs; 9 computed
#    |     1.58s done
#    |   Delete types: t                   : keep:   shift  nodes       1-1607126 to         1-1607126
#    |   Delete types: author              : keep:   shift  nodes 1607127-1607807 to   1607127-1607807
#    |   Delete types: bibl                : keep:   shift  nodes 1607808-1608488 to   1607808-1608488
#    |   Delete types: biblScope           : keep:   shift  nodes 1608489-1609169 to   1608489-1609169
#    |   Delete types: body                : keep:   shift  nodes 1609170-1609850 to   1609170-1609850
#    |   Delete types: cell                : keep:   shift  nodes 1609851-1624185 to   1609851-1624185
#    |   Delete types: chunk               : keep:   shift  nodes 1624186-1668669 to   1624186-1668669
#    |   Delete types: collection          : keep:   shift  nodes 1668670-1669350 to   1668670-1669350
#    |   Delete types: correspAction       : keep:   shift  nodes 1669351-1670712 to   1669351-1670712
#    |   Delete types: correspDesc         : keep:   shift  nodes 1670713-1671393 to   1670713-1671393
#    |   Delete types: date                : keep:   shift  nodes 1671394-1672074 to   1671394-1672074
#    |   Delete types: div                 : keep:   shift  nodes 1672075-1676173 to   1672075-1676173
#    |   Delete types: editor              : keep:   shift  nodes 1676174-1676854 to   1676174-1676854
#    |   Delete types: file                : keep:   shift  nodes 1676855-1677535 to   1676855-1677535
#    |   Delete types: fileDesc            : keep:   shift  nodes 1677536-1678216 to   1677536-1678216
#    |   Delete types: folder              : keep:   shift  nodes 1678217-1678227 to   1678217-1678227
#    |   Delete types: hi                  : keep:   shift  nodes 1678228-1710898 to   1678228-1710898
#    |   Delete types: idno                : keep:   shift  nodes 1710899-1712941 to   1710899-1712941
#    |   Delete types: institution         : keep:   shift  nodes 1712942-1713622 to   1712942-1713622
#    |   Delete types: ln                  : keep:   shift  nodes 1713623-1872482 to   1713623-1872482
#    |   Delete types: msDesc              : keep:   shift  nodes 1872483-1873163 to   1872483-1873163
#    |   Delete types: msIdentifier        : keep:   shift  nodes 1873164-1873844 to   1873164-1873844
#    |   Delete types: name                : keep:   shift  nodes 1873845-1875887 to   1873845-1875887
#    |   Delete types: note                : keep:   shift  nodes 1875888-1888974 to   1875888-1888974
#    |   Delete types: num                 : keep:   shift  nodes 1888975-1889655 to   1888975-1889655
#    |   Delete types: p                   : keep:   shift  nodes 1889656-1937973 to   1889656-1937973
#    |   Delete types: page                : keep:   shift  nodes 1937974-1946739 to   1937974-1946739
#    |   Delete types: pb                  : keep:   shift  nodes 1946740-1955505 to   1946740-1955505
#    |   Delete types: profileDesc         : keep:   shift  nodes 1955506-1956186 to   1955506-1956186
#    |   Delete types: ptr                 : keep:   shift  nodes 1956187-1967902 to   1956187-1967902
#    |   Delete types: publicationStmt     : keep:   shift  nodes 1967903-1968583 to   1967903-1968583
#    |   Delete types: quote               : keep:   shift  nodes 1968584-1968593 to   1968584-1968593
#    |   Delete types: resp                : keep:   shift  nodes 1968594-1969274 to   1968594-1969274
#    |   Delete types: respStmt            : keep:   shift  nodes 1969275-1969955 to   1969275-1969955
#    |   Delete types: row                 : keep:   shift  nodes 1969956-1973943 to   1969956-1973943
#    |   Delete types: settlement          : keep:   shift  nodes 1973944-1975986 to   1973944-1975986
#    |   Delete types: sourceDesc          : keep:   shift  nodes 1975987-1976667 to   1975987-1976667
#    |   Delete types: table               : keep:   shift  nodes 1976668-1976910 to   1976668-1976910
#    |   Delete types: teiHeader           : keep:   shift  nodes 1976911-1977591 to   1976911-1977591
#    |   Delete types: text                : keep:   shift  nodes 1977592-1978272 to   1977592-1978272
#    |   Delete types: title               : keep:   shift  nodes 1978273-1978953 to   1978273-1978953
#    |   Delete types: titleStmt           : keep:   shift  nodes 1978954-1979634 to   1978954-1979634
#    |   Delete types: max node: shifted from 1979634 to 1979634
#   1.69s add types ...
#    |     0.42s done (2 types)
#    |      |   ent, entity
#   2.11s applying updates ...
#   2.42s write TF data as version 0.4.4e ...
#   0.00s Not all of the warp features otype and oslots are present in
# ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Exporting 39 node and 3 edge and 1 configuration features to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e:
#   0.00s VALIDATING oslots feature
#   0.10s VALIDATING oslots feature
#   0.10s maxSlot=    1607126
#   0.11s maxNode=    2456332
#   0.15s OK: oslots is valid
#    |     0.50s T after                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.01s T chunk                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T corresp              to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T date                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T editornotes          to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.16s T eid                  to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.01s T empty                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.01s T extraspace           to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.01s T facs                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T file                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T folder               to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T id                   to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.02s T is_meta              to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.04s T is_note              to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.14s T kind                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.01s T n                    to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.21s T otype                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T recipient            to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T recipientloc         to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T ref                  to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.01s T rend                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T rend_bold            to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T rend_footnote        to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.04s T rend_italic          to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T rend_smallcaps       to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T rend_superscript     to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T rend_underline       to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.01s T rendition            to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T role                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T sender               to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T senderloc            to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T shelfmark            to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T source               to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.57s T str                  to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T summary              to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T target               to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T type                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T unit                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T when                 to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.02s T eoccs                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.01s T link_target          to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     1.53s T oslots               to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s M otext                to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#   3.49s Exported 39 node features and 3 edge features and 1 config features to ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#   5.91s all done
#   6.04s Done
# The dataset with entities is now in version 0.4.4e
# The dataset with entities is now the standard version
# True

# %% [markdown]
# We load the new data:

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/ner</span>
# This is Text-Fabric 12.5.3
# 43 features found and 0 ignored
#    |     0.74s T otype                from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |       10s T oslots               from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#     11s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.00s T folder               from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.07s T chunk                from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T file                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     3.03s T after                from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     3.58s T str                  from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |      |     0.30s C __levels__           from otype, oslots, otext
#    |      |       19s C __order__            from otype, oslots, __levels__
#    |      |     0.59s C __rank__             from otype, __order__
#    |      |       26s C __levUp__            from otype, oslots, __rank__
#    |      |     8.72s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.35s C __characters__       from otext
#    |      |     5.73s C __boundary__         from otype, oslots, __rank__
#    |      |     0.13s C __sections__         from otype, oslots, otext, __levUp__, __levels__, folder, file, chunk
#  1m 19s All features loaded / computed - for details use TF.isLoaded()
#    |     0.00s T corresp              from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T date                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T editornotes          from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.97s T eid                  from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.06s T empty                from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.37s T eoccs                from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.08s T extraspace           from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.04s T facs                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.03s T id                   from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.10s T is_meta              from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.22s T is_note              from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.92s T kind                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.04s T link_target          from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.07s T n                    from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T recipient            from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T recipientloc         from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T ref                  from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.07s T rend                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T rend_bold            from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.02s T rend_footnote        from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.19s T rend_italic          from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T rend_smallcaps       from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T rend_superscript     from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T rend_underline       from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.03s T rendition            from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T role                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T sender               from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T senderloc            from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T shelfmark            from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T source               from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T summary              from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.03s T target               from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.02s T type                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T unit                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#    |     0.00s T when                 from ~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e
#   3.37s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.5.3</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/app" title="suriano/letters app">suriano/letters/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/about.md" title="provenance of suriano - letters/tf">suriano - letters 0.4.4e</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="suriano - letters feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>11</td>
#     <td>146102.36</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>681</td>
#     <td>2359.95</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>681</td>
#     <td>2281.52</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>681</td>
#     <td>2281.52</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4099</td>
#     <td>733.15</td>
#     <td><i>187</i></td>
# </tr>
#
# <tr>
#     <th>entity</th>
#     <td>1177</td>
#     <td>404.84</td>
#     <td>30</td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.66</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8766</td>
#     <td>157.23</td>
#     <td>86</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>681</td>
#     <td>78.43</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>44484</td>
#     <td>36.13</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>681</td>
#     <td>48.30</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>681</td>
#     <td>33.22</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>48318</td>
#     <td>31.96</td>
#     <td>96</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>681</td>
#     <td>30.13</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>681</td>
#     <td>30.13</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>681</td>
#     <td>18.01</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>681</td>
#     <td>18.01</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>681</td>
#     <td>15.21</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>681</td>
#     <td>14.08</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>158860</td>
#     <td>9.72</td>
#     <td>96</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>681</td>
#     <td>9.36</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13087</td>
#     <td>8.82</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>681</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1362</td>
#     <td>6.84</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>681</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>32671</td>
#     <td>5.25</td>
#     <td>11</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>681</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>681</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>681</td>
#     <td>2.94</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>681</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2043</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>681</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>681</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2043</td>
#     <td>1.64</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2043</td>
#     <td>1.63</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ent</th>
#     <td>475521</td>
#     <td>1.00</td>
#     <td>30</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8766</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11716</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>681</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>681</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1607126</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>suriano - letters/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2024-08-08T11:27:36Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>0.4.4e</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/suriano/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/suriano/letters/tf/0.4.4e/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <details>
#     <summary>number of a chunk within a document</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</di
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/suriano/letters/thumb</span>
# Found 8766 images<br>

# %% [markdown]
# ## Step 6: Convert TF to WATM
#
# N.B. For docs click the WATM link in the output cell.

# %%
WA = WATM(A, "tei", skipMeta=False, prod=True)
# WA = WATM(A, "tei", skipMeta=False, prod=False)
WA.makeText()
WA.makeAnno()
WA.writeAll()
WA.testAll()
# Out:
# textRepoLevel is section level 'folder'
# [WATM exporter documentation](https://annotation.github.io/text-fabric/tf/convert/watm.html)
# 	Writing WATM ...
# Writing production data to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod
# Text file    0:    42233 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/text-0.tsv
# Text file    1:   114086 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/text-1.tsv
# Text file    2:   143568 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/text-2.tsv
# Text file    3:    98423 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/text-3.tsv
# Text file    4:   143925 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/text-4.tsv
# Text file   10:   121885 segments to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/text-10.tsv
# Text files all:  1607126 segments to 11 files
# Anno file    1:   400000 annotations written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/anno-1.tsv
# Anno file    2:   400000 annotations written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/anno-2.tsv
# Anno file    3:   400000 annotations written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/anno-3.tsv
# Anno file    4:   400000 annotations written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/anno-4.tsv
# Anno file    5:   400000 annotations written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/anno-5.tsv
# Anno file    6:   267659 annotations written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/anno-6.tsv
# Anno files all:  2267659 annotations to 6 files
# Slot mapping written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/pos2node.tsv
# Node mapping written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/anno2node.tsv
# Logical pairs (6895) written to ~/gitlab.huc.knaw.nl/suriano/letters/watm/0.4.4e-017/prod/logicalpairs.tsv
# Extra file datasource/entities/entitymeta.json copied to the WATM directory
# 	Testing WATM ...
# Testing the text ...
# 	TF: 1607126
# 	WA: 1607126
# OK - whether the amounts of tokens agree
# 	TF: Letter 02.001 date 1 ...  62 Corretto su 23.
# 	WA: Letter 02.001 date 1 ...  62 Corretto su 23.
# OK - whether the text is the same
# Testing the elements ...
# 	TF: 794779
# 	WA: 794779
# OK - whether the amounts of elements and nodes agree
# Testing the processing instructions ...
# 	TF:      0
# 	WA:      0
# OK - whether the amounts of processing instructions agree
# Testing the element/pi annotations ...
# 	2401905 element/pi annotations
# 	Element      : 794779 x
# 	Pi           :      0 x
# 	Other        : 1435766 x
# 	Good name    : 794779 x
# 	Wrong name   :      0 x
# 	Good target  : 794779 x
# 	Wrong target :      0 x
# 	Unmapped     :      0 x
# OK - whether all element/pi annotations have good bodies
# OK - whether all element/pi annotations have good targets
# Testing the attributes ...
# 	1182894 attribute values
# 	Good:     1182894 x
# 	Wrong:        0 x
# OK - whether annotations are consistent with features
# 	WA attributes: 1182894
# 	TF attributes: 1182894
# OK - whether annotations are complete w.r.t. features
# Testing the format attributes ...
# 	125760 format values
# 	formatting attributes:
# 		112602 x italic
# 		 11725 x footnote
# 		  1062 x superscript
# 		   357 x smallcaps
# 		    12 x bold
# 		     2 x underline
# 	Good:     125760 x
# 	Wrong:        0 x
# OK - whether format annotations are consistent with features
# 	WA format attributes: 125760
# 	TF format attributes: 125760
# OK - whether format annotations are complete w.r.t. features
# Testing the extra annotations ...
# 	0 extra feature values
# 	0 extra annotations
# OK - whether the extra annotations agree
# Testing the edges ...
# 	Found: 2401905 nodes
# 	Found edge link_target with 11716 starting nodes
# 	Checking edge link_target
# 		same 11716 fromNodes
# 	OK - 11716 toNodes checked
# OK - whether all edges agree
# Overall outcome ...
# OK - whether all tests passed

# %% [markdown]
# ## Step 7: Generate IIIF manifests

# %%
II = IIIF(Tei.teiVersion, A, PAGESEQ_JSON, prod=True, silent=False)
# II = IIIF(Tei.teiVersion, A, prod=False, silent=False)
II.manifests()
# Out:
# Maximum dimensions: W = 8504 H = 5976
# Average dimensions: W = 4138 H = 4869
# Average deviation:  W = 1038 H =  660
# Maximum dimensions: W = 5600 H = 5786
# Average dimensions: W = 3253 H = 4359
# Average deviation:  W =  477 H =  607
# Collections:
#    02 with  262 pages
#    03 with  660 pages
#    04 with  806 pages
#    05 with  688 pages
#    06 with  684 pages
#    07 with  628 pages
#    08 with  988 pages
#    09 with  944 pages
#    10 with 1062 pages
#    11 with 1116 pages
#    12 with  928 pages
# IIIF manifests generated in ~/gitlab.huc.knaw.nl/suriano/letters/static/prod/manifests

# %% [markdown]
# ## Step 8: Deploy to k8s and TeamText VM

# %% [markdown]
# NB: you need to have access to the k8s cluster and to the team text VM.
#
# That means:
#
# * The LDAP of the relevant k8s clusters know you
# * You have an ssh key-based login on the Team Text VPN
# * You work inside the firewall

# %%
# !./provision.sh prod watm
#!./provision.sh dev watm
# Out:
# k-suite enabled
# Context "k8s-10-26-6-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# anno-1.tsv                                    100%   16MB   6.2MB/s   00:02
# anno-3.tsv                                    100%   15MB   5.3MB/s   00:02
# anno-2.tsv                                    100%   13MB   5.1MB/s   00:02
# anno-6.tsv                                    100%   10MB   5.3MB/s   00:01
# anno-5.tsv                                    100%   15MB   4.7MB/s   00:03
# anno-4.tsv                                    100%   15MB   5.7MB/s   00:02
# anno2node.tsv                                 100%   14MB   5.7MB/s   00:02
# text-6.tsv                                    100% 1135KB   5.8MB/s   00:00
# text-7.tsv                                    100% 1088KB   4.2MB/s   00:00
# text-5.tsv                                    100%  951KB   5.7MB/s   00:00
# text-4.tsv                                    100%  852KB   6.4MB/s   00:00
# text-0.tsv                                    100%  256KB   4.5MB/s   00:00
# text-1.tsv                                    100%  688KB   6.2MB/s   00:00
# text-3.tsv                                    100%  591KB   5.8MB/s   00:00
# text-2.tsv                                    100%  861KB   6.2MB/s   00:00
# text-9.tsv                                    100% 1213KB   5.8MB/s   00:00
# text-8.tsv                                    100% 1282KB   6.1MB/s   00:00
# entitymeta.json                               100%   78KB   3.2MB/s   00:00
# pos2node.tsv                                  100%   24MB   6.1MB/s   00:03
# text-10.tsv                                   100%  718KB   5.7MB/s   00:00
# logicalpairs.tsv                              100%  171KB   4.3MB/s   00:00

# %%
# !./provision.sh prod files
#!./provision.sh dev files
# Out:
# k-suite enabled
# Context "k8s-10-26-6-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# copying to pod: prod/covers.html
# copying to pod: prod/logo
# copying to pod: prod/manifests
# copying to pod: both/metadata

# %%
# !./provision.sh prod images
#!./provision.sh dev images

# %% [markdown]
# ## Step 9: Test the images

# %% [markdown]
# * [covers](https://suriano.huygens.knaw.nl/files/covers.html)
#
# * [02.json](https://suriano.huygens.knaw.nl/files/manifests/02.json)
#
# * [page 02_171r](https://suriano.huygens.knaw.nl/iiif/3/pages%2F02_071r.jpg/full/max/0/default.jpg)

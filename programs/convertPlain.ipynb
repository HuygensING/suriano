# %% [markdown]
# # Convert from DOCX to TEI to TF to WATM
#
# We convert Suriano DOCX to TEI to TF and then to WATM.
#
# This notebook provides three levels of refinement in the execution. They all have the same outcome,
# but they differ in the level of detail they provide on the conversion.
#
# These are the levels:
#
# * **Debugging**: all the commands directly in Python, the intermediate data remains in memory and can  be inspected.
# * **Step by step**: one command for each main step of the conversion;
# * **Express**: one single command on the command line for the complete conversion;

# %% [markdown]
# # Production or development
#
# Mosts steps are unaffected by the production/development setting.
#
# In the first steps of the pipeline (*ingest* and *scan processing*) we prepare both the dev and the prod data.
#
# The intermediate steps (*from DOCX to TEI*, *from TEI to TF*, *mark named entities*) are identical for prod and dev.
#
# Only for the latter steps (*convert TF to WATM*, generate IIIF manifests*, *deploy to k8s*) there is a distinction between prod and dev.
#
# For these steps we have commented out the line that does the dev version.

# %% [markdown]
# # Requirements
#
# * zsh as command line shell (as in macOS);
# * access to suitable k8s clusters, streamlined by the
#   [k-suite](https://code.huc.knaw.nl/tt/smart-k8s/-/blob/main/docs/k-suite.md);
# * [Pandoc](https://pandoc.org)
# * [Imagemagick](https://imagemagick.org)
# * [Python](https://www.python.org) (3.12 or higher) with additional pip-installable modules:
#   * text-fabric
#   * doc2python
#   * openpyxl

# %% [markdown]
# # Declare the version
#
# Always set the version before running any cell in this notebook!

# %%
VERSION = "2.0.0"

# %% [markdown]
# # In debugging mode.
#
# Now we dig a bit deeper, en do all the steps while keeping the program in memory.
# Now it becomes doable to inspect all intermediate results.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tff.convert.tei import TEI
from tff.convert.watm import WATM
from tff.convert.iiif import IIIF
from tf.advanced.helpers import dm

from processscans import Scans
from processdocs import TeiFromDocx
from bakeEntTei import BakeEntTei
from processhelpers import setStage, nerMeta, NER_NAME, SOURCEBASE, REPORT_PAGESDIR, REPORT_TEIDIR

# %% [markdown]
# ## Step 1: Scan processing

# %%
SC = Scans(silent=False, force=False)

# %%
SC.process()
# Out:
# Already present: sizes file originals (covers)
# Already present: sizes file originals (pages)
# Already present: thumbnails (covers)
# Already present: sizes file thumbnails (covers)
# Already present: thumbnails (pages)
# Already present: sizes file thumbnails (pages)

# %% [markdown]
# ## Step 2: From DOCX to TEI

# %% [markdown]
# You might need to do
#
# ```
# pip install docx2python
# ```

# %%
TFD = TeiFromDocx(silent=False)

# %%
TFD.task("pandoc")
# Out:
# DOCX => simple TEI per filza ...
# 	02.docx ... uptodate
# 	03.docx ... uptodate
# 	04.docx ... uptodate
# 	05.docx ... uptodate
# 	06.docx ... uptodate
# 	07.docx ... uptodate
# 	08.docx ... uptodate
# 	09.docx ... uptodate
# 	09b.docx ... uptodate
# 	10.docx ... uptodate
# 	11.docx ... uptodate
# 	12.docx ... uptodate

# %%
TFD.task("headers")
# Out:
# DOCX => headers ...
# 	02.docx
# 	03.docx
# 	04.docx
# 	05.docx
# 	06.docx
# 	07.docx
# 	08.docx
# 	09.docx
# 	09b.docx
# 	10.docx
# 	11.docx
# 	12.docx
# 	OK: All headers are OK
# Angelo              : 1181 pages in 11 filzas
# Cristina            : 1034 pages in 10 filzas
# Federica            : 684 pages in  7 filzas
# Filippo             : 1084 pages in  9 filzas
# Flavia              : 1282 pages in 11 filzas
# Giorgia             : 934 pages in  9 filzas
# Renzo               :  56 pages in  1 filza
# Ruben               : 1162 pages in 10 filzas
# Vera                : 966 pages in 10 filzas
# Vera, Federica      : 210 pages in  1 filza
# uuu_vvv             :  60 pages in  1 filza
# xxx_yyy             : 122 pages in  1 filza

# %%
TFD.task("tei")
# Out:
# Collecting transcribers ...
# Collecting page scans ...
#   0 x error
# 8952 x good
# Collecting excel metadata ...
# 	found metadata for 725 letters
# 	in filzas 02, 03, 04, 05, 06, 07, 08, 09, 10, 11, 12
# simple TEI per filza => enriched TEI per letter ...
# 	02.xml
# 	03.xml
# 	04.xml
# 	05.xml
# 	06.xml
# 	07.xml
# 	08.xml
# 	09.xml
# 	09b.xml
# 	10.xml
# 	11.xml
# 	12.xml
# Translated italian editorial phrases (218 x 14369)
# 25 discrepancies between summary file and letters
# 	09b 1602-09-15-09b: no metadata for letter 011
# 	09b 1620-08-01-09b: no metadata for letter 001
# 	09b 1620-08-18-09b: no metadata for letter 002
# 	09b 1620-08-28-09b: no metadata for letter 003
# 	09b 1620-08-28-09b: no metadata for letter 004
# 	09b 1620-09-02-09b: no metadata for letter 005
# 	09b 1620-09-08-09b: no metadata for letter 006
# 	09b 1620-09-08-09b: no metadata for letter 007
# 	09b 1620-09-09-09b: no metadata for letter 008
# 	09b 1620-09-14-09b: no metadata for letter 009
# 	09b 1620-09-15-09b: no metadata for letter 010
# 	09b 1620-09-20-09b: no metadata for letter 012
# 	09b 1620-09-20-09b: no metadata for letter 013
# 	09b 1620-09-23-09b: no metadata for letter 014
# 	09b 1620-09-29-09b: no metadata for letter 015
# 	09b 1620-09-30-09b: no metadata for letter 016
# 	09b 1620-09-30-09b: no metadata for letter 017
# 	09b 1620-10-02-09b: no metadata for letter 018
# 	09b 1620-10-05-09b: no metadata for letter 019
# 	09b 1620-10-05-09b: no metadata for letter 020
# 	09b 1620-10-20-09b: no metadata for letter 021
# 	09b 1620-10-21-09b: no metadata for letter 022
# 	09b 1620-10-28-09b: no metadata for letter 023
# 	09b 1620-11-13-09b: no metadata for letter 024
# 	09b 1620-12-15-09b: no metadata for letter 025
# 0 page warnings
# 0 warnings
# 09b: 025bisr: transcription but no scan
# 09b: 025bisv: transcription but no scan
# 09b: 059bisr: transcription but no scan
# 09b: 059bisv: transcription but no scan
# 09b: 078bisr: transcription but no scan
# 09b: 078bisv: transcription but no scan
# Pages with    transcription and    scan:       8948
# Pages with    transcription and missing scan:     6
# Pages with    transcription and no scan:          0
# Pages with no transcription and    scan:          0
# See ~/github/HuygensING/suriano/report/pages/pagescan.tsv

# %% [markdown]
# ## Step 3: From TEI to TF
#
# ### Check the validity of the TEI.

# %%
Tei = TEI(verbose=-1, sourceBase=SOURCEBASE, reportDir=REPORT_TEIDIR, tei="", tf=VERSION)

# %%
Tei.task(check=1, verbose=1, validate=True)
# Out:
# TEI to TF checking: ~/github/HuygensING/suriano/datasource/tei => ~/github/HuygensING/suriano/report/tei
# Processing instructions are ignored
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# INFO: Needs dcr.xsd (exists)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   1 changing override(s)
# 	metamark mixed ==> pure
# Section model I
# 	Start folder 02
# 	Start folder 03
# 	Start folder 04
# 	Start folder 05
# 	Start folder 06
# 	Start folder 07
# 	Start folder 08
# 	Start folder 09
# 	Start folder 09b
# 	Start folder 10
# 	Start folder 11
# 	Start folder 12
# 750 suriano file(s) ...
# 	Validating ...
# 	Making inventory ...
#
# 584 tag(s) type info written to ~/github/HuygensING/suriano/report/tei/types.txt
# Validation OK
# 0 pagebreaks without facs attribute.
# 8952 pagebreaks encountered.
# 8952 distinct scans referred to by pagebreaks.
# 41 tags of which 0 with multiple namespaces written to ~/github/HuygensING/suriano/report/tei/namespaces.txt
# 9184 info line(s) written to ~/github/HuygensING/suriano/report/tei/elements.txt
# Refs written to ~/github/HuygensING/suriano/report/tei/refs.txt
# 	resolvable: 11991 in 11991
# 	dangling:      0 in    0
# 	ALL:        11991 in 11991
# Ids written to ~/github/HuygensING/suriano/report/tei/ids.txt
# 	referenced: 11991 by 11991
# 	non-unique:    0
# 	unused:     1509
# 	ALL:        13500 in 13500
# lb-parent info written to ~/github/HuygensING/suriano/report/tei/lb-parents.txt
# True

# %% [markdown]
# ### Convert the data

# %%
Tei.good = True
Tei.task(convert=True, verbose=0)
# Out:
# Line model II with ln nodes for lines between lb elements
# Page model II with page nodes for pages started by pb elements  keeping the pb elements
# Section model I
# Processing instructions are ignored
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/suriano/datasource/schema/suriano.xsd
# 	round   1:  68 changes
# 137 identical override(s)
#   1 changing override(s)
# 	metamark mixed ==> pure
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# 	Start folder 02:
# 		   1 suriano                                001.xml
# 		   2 suriano                                002.xml
# 		   3 suriano                                003.xml
# 		   4 suriano                                004.xml
# 		   5 suriano                                005.xml
# 		  19 suriano                                019.xml
# End   folder 02
# 	Start folder 03:
# 		  20 suriano                                001.xml
# 		  21 suriano                                002.xml
# 		  22 suriano                                003.xml
# 		  23 suriano                                004.xml
# 		  24 suriano                                005.xml
# 		  74 suriano                                055.xml
# End   folder 03
# 	Start folder 04:
# 		  75 suriano                                001.xml
# 		  76 suriano                                002.xml
# 		  77 suriano                                003.xml
# 		  78 suriano                                004.xml
# 		  79 suriano                                005.xml
# 		 149 suriano                                075.xml
# End   folder 04
# 	Start folder 05:
# 		 150 suriano                                001.xml
# 		 151 suriano                                002.xml
# 		 152 suriano                                003.xml
# 		 153 suriano                                004.xml
# 		 154 suriano                                005.xml
# 		 206 suriano                                057.xml
# End   folder 05
# 	Start folder 06:
# 		 207 suriano                                001.xml
# 		 208 suriano                                002.xml
# 		 209 suriano                                003.xml
# 		 210 suriano                                004.xml
# 		 211 suriano                                005.xml
# 		 246 suriano                                040.xml
# End   folder 06
# 	Start folder 07:
# 		 247 suriano                                001.xml
# 		 248 suriano                                002.xml
# 		 249 suriano                                003.xml
# 		 250 suriano                                004.xml
# 		 251 suriano                                005.xml
# 		 293 suriano                                047.xml
# End   folder 07
# 	Start folder 08:
# 		 294 suriano                                001.xml
# 		 295 suriano                                002.xml
# 		 296 suriano                                003.xml
# 		 297 suriano                                004.xml
# 		 298 suriano                                005.xml
# 		 384 suriano                                091.xml
# End   folder 08
# 	Start folder 09:
# 		 385 suriano                                001.xml
# 		 386 suriano                                002.xml
# 		 387 suriano                                003.xml
# 		 388 suriano                                004.xml
# 		 389 suriano                                005.xml
# 		 478 suriano                                094.xml
# End   folder 09
# 	Start folder 09b:
# 		 479 suriano                                001.xml
# 		 480 suriano                                002.xml
# 		 481 suriano                                003.xml
# 		 482 suriano                                004.xml
# 		 483 suriano                                005.xml
# 		 503 suriano                                025.xml
# End   folder 09b
# 	Start folder 10:
# 		 504 suriano                                001.xml
# 		 505 suriano                                002.xml
# 		 506 suriano                                003.xml
# 		 507 suriano                                004.xml
# 		 508 suriano                                005.xml
# 		 603 suriano                                100.xml
# End   folder 10
# 	Start folder 11:
# 		 604 suriano                                001.xml
# 		 605 suriano                                002.xml
# 		 606 suriano                                003.xml
# 		 607 suriano                                004.xml
# 		 608 suriano                                005.xml
# 		 704 suriano                                101.xml
# End   folder 11
# 	Start folder 12:
# 		 705 suriano                                001.xml
# 		 706 suriano                                002.xml
# 		 707 suriano                                003.xml
# 		 708 suriano                                004.xml
# 		 709 suriano                                005.xml
# 		 750 suriano                                046.xml
# End   folder 12
#
# Resolving links into edges ...
# 	3941 in 11991 reference(s) resolved
#    |       11s "delete" actions: 0
#    |       11s "edge" actions: 11991
#    |       11s "feature" actions: 2796571
#    |       11s "node" actions: 373133
#    |       11s "resume" actions: 0
#    |       11s "slot" actions: 1775518
#    |       11s "terminate" actions: 373883
#    |    2148651 nodes of all types
#    |       11s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.01s OK
#    |     0.00s checking (section) features ...
#    |     0.06s OK
#    |     0.00s reordering nodes ...
#    |     1.15s Max node = 2148651
#    |     1.15s OK
#    |     0.00s reassigning feature values ...
#    |     0.83s OK
# True

# %% [markdown]
# ### Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# True

# %% [markdown]
# ### Use the new dataset
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and pre-computations are performed.
# Next time the loading will be much quicker.

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/2.0.0e</span>
# This is Text-Fabric 13.0.17
# 41 features found and 0 ignored
#   0.30s Dataset without structure sections in otext:no structure functions in the T-API
#   1.08s All features loaded / computed - for details use TF.isLoaded()
#   0.38s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.17</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/about.md" title="provenance of HuygensING - suriano/tf">HuygensING - suriano 2.0.0e</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="HuygensING - suriano feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>12</td>
#     <td>147959.83</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>750</td>
#     <td>2367.36</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>750</td>
#     <td>2180.19</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>750</td>
#     <td>2180.19</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4247</td>
#     <td>736.20</td>
#     <td><i>176</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>750</td>
#     <td>187.17</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8952</td>
#     <td>158.08</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>750</td>
#     <td>121.93</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>750</td>
#     <td>50.10</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>47924</td>
#     <td>37.03</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>750</td>
#     <td>121.93</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>750</td>
#     <td>65.25</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>entity</th>
#     <td>788</td>
#     <td>35.39</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>49473</td>
#     <td>32.66</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>750</td>
#     <td>31.01</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>750</td>
#     <td>31.01</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>750</td>
#     <td>19.09</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13500</td>
#     <td>16.98</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>1</td>
#     <td>15.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>750</td>
#     <td>14.15</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>163123</td>
#     <td>9.91</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>750</td>
#     <td>8.55</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>750</td>
#     <td>8.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>15679</td>
#     <td>7.72</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1500</td>
#     <td>7.70</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2250</td>
#     <td>6.34</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>750</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>750</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2131</td>
#     <td>4.30</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>750</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>750</td>
#     <td>2.64</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2250</td>
#     <td>2.64</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ent</th>
#     <td>12200</td>
#     <td>2.29</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>750</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>750</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>750</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2250</td>
#     <td>1.31</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>metamark</th>
#     <td>3072</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8952</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11991</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>750</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>750</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1775518</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - suriano/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/2.0.0e/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2025-11-19T08:32:14+00:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>2.0.0e</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/2.0.0e/chunk.tf">chunk</a>
# </
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/thumb</span>
# Found 8953 images<br>

# %% [markdown]
# ## Step 4: Mark named entities

# %% [markdown]
# First stage: we use the human-crafted triggers as is.
#
# In the separate notebook [nerCorrect](nerCorrect.ipynb) you can then collect
# additional spelling variants of the triggers.
#
# Some of these triggers are not fit to be used, you have to make a list of variants that are not valid triggers
# and store them in the file `persons-notmerged.txt`, one per line.
#
# Then you can merge the new valid variants automatically with the human-crafted triggers, and
# the result is a new spreadsheet, `persons-merged`.
#
# Second stage: use the merged spreadsheet.

# %% [markdown]
# ### Stage 1
#
# We need to copy the relevant spreadsheet from the `datasource/metadata` directory to the `ner` directory where TF expects it.

# %%
nerStage = 1
nerName, nerOutFile = setStage(nerStage)
# Out:
# Stage 1: working with sheet persons

# %%
NE = A.makeNer(caseSensitive=False, silent=False)
# Out:
# normalizeChars() loaded from ~/github/HuygensING/suriano/ner/code.py
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# #bucketsq {
#   flex: 0 0 auto;
# }
#
# #buckets {
#   flex: 2 1 auto;
#   overflow: auto;
# }
#
# .buckets,#buckets {
#   padding-inline-start: 2rem;
# }
# .buckets.rtl,#buckets.rtl {
#   padding-inline-start: 4rem;
# }
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# div.queried,p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# div.tqueried,span.tqueried {
#   border-radius: 0.2rem;
#   background-color: #dddd00;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #0000ee;
#   text-decoration: underline;
#   unicode-bidi: embed;
# }
# span.bh {
#   text-align: start;
#   margin-inline-start: -2rem;
# }
# span.bh.rtl {
#   margin-inline-start: -1rem;
# }
# .viewer {
#   min-height: 5rem;
#   max-height: 20rem;
#   overflow: auto;
#   font-size:small;
#   background-color: #f2f2f2;
#   padding-inline-start: 2rem;
# }
# .viewer span.bh {
#   color: #888888;
#   text-decoration: none;
# }
# .center {
#   background-color: #ddddff;
# }
# .viewer div.center span.bh
#   color: #0000ff;
#   text-decoration: none;
# }
# span.lgb,span.lge {
#   font-weight: bold;
#   font-size: medium;
#   color: var(--ent-markup-color);
#   background-color: var(--ent-markup-bg);
#   border-radius: 1.5em;
#   padding: 0 0.2em;
# }
# span.lgb {
#   border-right: 0.5em solid white;
#   border-left: 0.2em solid var(--ent-markup-color);
# }
# span.lge {
#   border-left: 0.5em solid white;
#   border-right: 0.2em solid var(--ent-markup-color);
# }
#
# p.msg {
#   font-family: monospace;
#   margin: 0
# }
# .special {
#   font-weight: bold;
#   font-size: large;
#   background-color: #eeeef8;
# }
# p.msg.special {
#   margin-top: 1rem;
# }
# .error {
#   font-weight: bold;
#   background-color: #ffaaaa;
# }
# span.stat,span.statx {
#   font-family: monospace;
#   font-weight: bold;
#   font-size: small;
#   color: #aaaaff;
#   background-color: white;
#   padding-left: 0.5rem;
# }
# span.statx {
#   text-decoration: line-through;
# }
# p.e {
#   margin: 0.1rem 0;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 1rem;
# }
# div.e, div.et {
#   display: flex;
# 	flex-flow: row nowrap;
# 	justify-content: flex-start;
# 	align-items: flex-start;
#   font-size: small;
#   margin-bottom: 0.3rem;
# }
# span.xr {
#   font-family: monospace;
#   font-size: small;
# }
# .neutral {
#   font-size: small;
#   border: 0;
#   padding: 0 0.3rem;
# }
# .warnoccs {
#   color: #ff0000;
#   font-weight: bold;
# }
# .nooccs {
#   background-color: #ffaa88;
#   padding: 0.3rem 0.1rem;
#   margin: 0.1rem;
#   border-radius: 0.3rem;
# }
# .subtle {
#   color: blue;
#   font-weight: bold;
# }
# </style><style type="text/css">.eid {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# }
#
# .eid.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.eid_sel,button.eid_sel {
# 	font-family: monospace;
# 	font-size: small;
# 	font-weight: normal;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.4rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.eid_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
#
# .kind {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# }
#
# .kind.active {
# 	color: black;
# 	background-color: yellow;
# }
#
# span.kind_sel,button.kind_sel {
# 	font-family: monospace;
# 	font-size: medium;
# 	font-weight: bold;
# 	color: black;
# 	background-color: white;
# 	background-color: white;
# 	border-radius: 0.5rem;
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: white;
# 	padding: 0.3rem;
# 	margin: 0.1rem 0.2rem;
# }
#
# button.kind_sel[st=v] {
# 	border-width: 1pt;
# 	border-style: solid;
# 	border-color: yellow;
# 	color: black;
# 	background-color: yellow;
# }
# </style>

# %%
NE.setTask(f".{nerName}", force=True)
# Out:
# Annotation set 🧾 persons has 0 annotations

# %%
NE.triggerInterference()
# Out:
# Looking up 28 potential interferences in 2 passes over the corpus ..
# 2 potential conflicting trigger pairs with 2 conflicts
# ----------
# different rows (0 pairs)
# ----------
# Diagnostic trigger interferences written to ~/github/HuygensING/suriano/_temp/ner/2.0.0/.persons/interference.txt

# %%
NE.reportHits(showNoHits=True)
# Out:
# No slot is covered by more than one trigger
# Triggers without hits: 96x:
# Looking up 96 triggers in 2 passes over the corpus ..
# Entities targeted:            818
# Triggers searched for:       1666
# Triggers without hits:         96
#  - completely covered:         96
#  - missing hits:                0
# Triggers with hits:          1570
# Total hits:                 10597
#
# All hits in report file:      ~/github/HuygensING/suriano/_temp/ner/2.0.0/.persons/hits.tsv
# Triggers by slot in file:     ~/github/HuygensING/suriano/_temp/ner/2.0.0/.persons/triggerBySlot.tsv

# %%
NE.makeSheetOfSingleTokens()
NE.setTask(f".{NER_NAME}-single", caseSensitive=False, force=True)
NE.reportHits(showNoHits=True)
# Out:
# Annotation set 🧾 persons-single has 0 annotations
# No slot is covered by more than one trigger
# Triggers without hits: 14x:
# Looking up 14 triggers in 1 pass over the corpus .
# Entities targeted:           1523
# Triggers searched for:       1523
# Triggers without hits:         14
#  - completely covered:         14
#  - missing hits:                0
# Triggers with hits:          1509
# Total hits:                 513679
#
# All hits in report file:      ~/github/HuygensING/suriano/_temp/ner/2.0.0/.persons-single/hits.tsv
# Triggers by slot in file:     ~/github/HuygensING/suriano/_temp/ner/2.0.0/.persons-single/triggerBySlot.tsv

# %%
NE.setTask(f".{NER_NAME}", caseSensitive=False)
# Out:
# Annotation set 🧾 persons has 10597 annotations

# %% [markdown]
# ### Prepare for stage 2: search variants

# %%
D = NE.variantDetection()
# Out:
# Overview of names by length:
#   10 tokens:   2 names e.g.:
#       cavalier inglese , et il fratello del vescovo di Londra
#       signor d ’ Aspri fratello dell ’ ambasciator dei Stati
#   9 tokens:   2 names e.g.:
#       conte d ’ Henin , chiamato duca di Bornenvil
#       Proveditor general dell ’ arm [ i ] Priuli
#   8 tokens:  15 names e.g.:
#       Alessandro , Giacomo et Pietr ’ Antonio Guadagni
#       ambasciator del signor Granduca nella corte di Praga
#       ambasciator di Francia residente appresso li serenissimi arciduchi
#       doi altri suoi parenti cognato , et cugino
#       doi altri un maschio , et una femina
#   7 tokens:  21 names e.g.:
#       [ duc ] a d ’ Angauleme
#       ambasciator di Spagna residente appresso il Christianissimo
#       Ambasciator straordinario che venne ultimamente di Spagna
#       Ambasciatore , che dal re di Bohemia
#       capitan scocese fratello di quel capitano Seiton
#   6 tokens:  45 names e.g.:
#       al luogotenente di monsignor di Sciatiglione
#       ambasciator Giust ( inia ) no
#       ambasciator Gritti alla corte di Spagna
#       baron di Kessel governator di Husdem
#       baron di Pieterson signor di Meroda
#   5 tokens:  83 names e.g.:
#       A . v . Matenesse
#       accompagnata la sorella di lui
#       Adriano Pieterson Looske da Encusen
#       agente d ’ Inghilterra Trombol
#       agente del re di Marocco
#   4 tokens: 193 names e.g.:
#       agente di quel Principe
#       almirante d ’ Arragona
#       ambasciator Contarini in Francia
#       ambasciator Contarini in Inghilterra
#       ambasciatore Contarini in Inghilterra
#   3 tokens: 497 names e.g.:
#       2 da Principessa
#       Adriano Vander Dussen
#       agente del Kerckoven
#       agente di Fiorenza
#       ambasciator a Constantinopoli
#   2 tokens: 564 names e.g.:
#       abbate Moronato
#       Abraham Pesini
#       Adam Schivelbergh
#       Adrian Pavoni
#       Adrian Ploos
#   1 tokens: 234 names e.g.:
#       Alagamba
#       Alagambe
#       Alagambre
#       Amstenraedt
#       Amsterraedt

# %%
D.prepare()
# Out:
# Alphabet written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/alphabet.tsv
# Text written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/text.txt - 8763854 characters
#   0.00s Collecting the triggers for the lexicon
#   0.00s 1507 triggers collected
#   346 x conte di Mansfelt
#   336 x Pasini
#   279 x Spinola
#   236 x Bernvel
#   217 x principe Mauritio
#   212 x principe d’Oranges
#   211 x Carleton
#   211 x re di Spagna
#   193 x duca di Savoia
#   180 x serenissimi arciduchi
#   ...
#     1 x visconte di Duncaster
#     1 x visconte di Gantes fratello del principe di Pinoe
#     1 x Vuandermil
#     1 x Wandernoot
#     1 x Wassenhovven
#     1 x Wasson[ hoven]
#     1 x Weesterbeeck
#     1 x Weimar il maggiore
#     1 x zelandese nominato Cornelio
#     1 x Zeno
#     1507 lexicon length
# Lexicon written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/lexicon.tsv
# Set up analiticcl
# Computing anagram values for all items in the lexicon...
#  - Found 1507 instances
# Adding all instances to the index...
#  - Found 1502 anagrams
# Creating sorted secondary index...
# Sorting secondary index...
#  - Found 3 anagrams of length 3
#  - Found 13 anagrams of length 4
#  - Found 23 anagrams of length 5
#  - Found 38 anagrams of length 6
#  - Found 49 anagrams of length 7
#  - Found 41 anagrams of length 8
#  - Found 41 anagrams of length 9
#  - Found 29 anagrams of length 10
#  - Found 47 anagrams of length 11
#  - Found 61 anagrams of length 12
#  - Found 70 anagrams of length 13
#  - Found 90 anagrams of length 14
#  - Found 107 anagrams of length 15
#  - Found 103 anagrams of length 16
#  - Found 103 anagrams of length 17
#  - Found 100 anagrams of length 18
#  - Found 83 anagrams of length 19
#  - Found 74 anagrams of length 20
#  - Found 67 anagrams of length 21
#  - Found 54 anagrams of length 22
#  - Found 35 anagrams of length 23
#  - Found 36 anagrams of length 24
#  - Found 25 anagrams of length 25
#  - Found 23 anagrams of length 26
#  - Found 27 anagrams of length 27
#  - Found 18 anagrams of length 28
#  - Found 15 anagrams of length 29
#  - Found 15 anagrams of length 30
#  - Found 6 anagrams of length 31
#  - Found 14 anagrams of length 32
#  - Found 10 anagrams of length 33
#  - Found 5 anagrams of length 34
#  - Found 10 anagrams of length 35
#  - Found 13 anagrams of length 36
#  - Found 4 anagrams of length 37
#  - Found 6 anagrams of length 38
#  - Found 4 anagrams of length 39
#  - Found 3 anagrams of length 40
#  - Found 5 anagrams of length 41
#  - Found 2 anagrams of length 42
#  - Found 4 anagrams of length 43
#  - Found 6 anagrams of length 44
#  - Found 5 anagrams of length 45
#  - Found 1 anagrams of length 46
#  - Found 2 anagrams of length 47
#  - Found 2 anagrams of length 49
#  - Found 1 anagrams of length 50
#  - Found 1 anagrams of length 52
#  - Found 2 anagrams of length 53
#  - Found 2 anagrams of length 54
#  - Found 1 anagrams of length 56
#  - Found 1 anagrams of length 57
#  - Found 1 anagrams of length 59
#  - Found 1 anagrams of length 66
# Constructing Language Model...
#  - No language model provided

# %%
# %%time

# !date

D.search(start=None, end=None, force=1)
# Out:
# Wed Nov 19 09:17:28 CET 2025
#  8763854 text  length
#        0 offset in complete text
#   0.00s Compute variants of the lexicon words ...
# 13m 01s  1404058 raw   matches
# 13m 01s Filter variants of the lexicon words ...
# 13m 02s      712 filtered matches
# 712 variants found
# CPU times: user 41min 20s, sys: 3min 48s, total: 45min 9s
# Wall time: 13min 2s

# %%
D.listVariants(end=10)
D.listVariants(start=-10)
# Out:
#    i | variant                   | score | candidate
# ---- | ------------------------- | ----- | -------------------------
#    0 | a Ferdinando              |  0.87 | re Ferdinando
#    1 | a suo figliolo            |  0.87 | un suo figliolo
#    2 | abbot Moronato            |  0.85 | abbate Moronato
#    3 | Adrian Plois              |  0.88 | Adrian Ploos
#    4 | Adriano Ploos             |  0.85 | Adrian Ploos
#    5 | Adrien Ploos              |  0.86 | Adrian Ploos
#    6 | agente del Kerkoven       |  0.89 | agente del Kerckoven
#    7 | al figliolo               |  0.88 | il figliolo
#    8 | al suo figlio             |  0.89 | il suo figlio
#    9 | Alag]ambe                 |  0.84 | Alagambe
# ---- | ------------------------- | ----- | -------------------------
# 712 variants found and written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/variants.tsv
#    i | variant                   | score | candidate
# ---- | ------------------------- | ----- | -------------------------
#  -10 | Vorberghen                |  0.86 | Vosberghen
#   -9 | Vosbergen                 |  0.88 | Vosberghen
#   -8 | Wassnhoven                |  0.86 | Wassonhoven
#   -7 | Wassomhovem               |  0.85 | Wassonhovem
#   -6 | Wasson[hoven              |  0.85 | Wassonhoven
#   -5 | Wassonhove                |  0.90 | Wassonhoven
#   -4 | Wassonoven                |  0.86 | Wassonhoven
#   -3 | Willem Pietersen          |  0.90 | Willem Pieterssen
#   -2 | è figliolo                |  0.86 | il figliolo
#   -1 | è figliolo                |  0.86 | un figliolo
# ---- | ------------------------- | ----- | -------------------------
# 712 variants found and written to ~/github/HuygensING/suriano/_temp/ner/analyticcl/variants.tsv

# %%
D.mergeTriggers()
# Out:
# 218 excluded variants found in ~/github/HuygensING/suriano/ner/specs/persons-notmerged.txt
# 211 variants excluded as trigger
# row  trigger                                  ~> variant                                  = occurences
# 8    Guglielmo di Nassau                      ~> Guglielmo di Nansau                      = 08x1
# 8    Guglielmo di Nassau                      ~> Guglielmo de Nassau                      = 09x1
# 8    conte Guglielmo suo figlio               ~> conte Guglielmo suo figliolo             = 08x1
# 13   vescovo di Paterborn                     ~> vescovo di Paterbon                      = 07x1
# 14   duca di Nevers                           ~> duca di Nivers                           = 11x1
# 15   Massimiliano                             ~> Massimilia                               = 11x1
# 18   duca di Guisa                            ~> duca di Guesa                            = 07x1
# 19   cardinal Lodovisio                       ~> card(ina)l Lodovisio                     = 10x1
# 20   cardinal Lodovisio                       ~> card(ina)l Lodovisio                     = 10x1
# 871  Miller                                   ~> Muller                                   = 06x5
# 871  Miller                                   ~> Mille                                    = 07x1
# 871  Miller                                   ~> Mille                                    = 08x2
# 871  Miller                                   ~> Mille                                    = 09x1
# 871  Miller                                   ~> Mille                                    = 11x1
# 871  Miller                                   ~> Moller                                   = 06x1
# 871  Miller                                   ~> Miler                                    = 11x1
# 871  Miller                                   ~> Miler                                    = 12x1
# 873  un moscovita                             ~> moscovita                                = 06x2
# 243 triggersets expanded with 500 triggers
# Wrote merge report to file ~/github/HuygensING/suriano/ner/specs/persons-merged-report.tsv
# Wrote merged triggers to sheet ~/github/HuygensING/suriano/ner/specs/persons-merged.xlsx

# %% [markdown]
# ### Stage 2

# %%
nerStage = 2
nerName, nerOutFile = setStage(nerStage)
# Out:
# Stage 2: working with sheet persons-merged

# %%
NE = A.makeNer(caseSensitive=False, silent=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 NE = A.makeNer(caseSensitive=False, silent=False)
#
# NameError: name 'A' is not defined

# %%
NE.setTask(f".{nerName}", force=True)
# Out:
# Annotation set 🧾 persons-merged has 0 annotations

# %%
NE.triggerInterference()
# Out:
# Looking up 29 potential interferences in 2 passes over the corpus ..
# 2 potential conflicting trigger pairs with 2 conflicts
# ----------
# different rows (0 pairs)
# ----------
# Diagnostic trigger interferences written to ~/github/HuygensING/suriano/_temp/ner/2.0.0/.persons-merged/interference.txt

# %%
NE.reportHits(showNoHits=True)
# Out:
# No slot is covered by more than one trigger
# Triggers without hits: 163x:
# Looking up 163 triggers in 2 passes over the corpus ..
# durante di prignì                        ()          : 03@011:9 x 1, 03@018:11 x 1
# henrico di nassau                        ()          : 07@045:86 x 1, 08@087:14 x 1
# smit                                     (02)        : 06@028:132 x 2, 06@028:134 x 1, 06@028:175 x 1, 06@034:74 x 1
# signor conte gioan                       (02-05)     : 06@034:160 x 1
# ambasciator de francia                   (03)        : 12@030:25 x 1
# ambasciatore di franza                   (03)        : 02@012:15 x 1, 08@059:18 x 1
# ambasciatori francia                     (03)        : 04@036:9 x 1
# ambasciator inglese straordinario        (04)        : 08@067:14 x 1
# signor di bredevod                       (04, 11)    : 09b@021:13 x 1
# conte gio ernesto                        (06, 08, 09, 11): 04@026:7 x 1
# figliolo maggiore                        (08)        : 04@016:7 x 1, 11@100:23 x 1
# ambasciator in londra                    (08-11)     : 05@049:16 x 1
# al suo figlio                            (09)        : 04@019:8 x 1
# ambasciatore di danimarca                (10)        : 12@036:93 x 2
# presidenti di gheldria                   (10)        : 04@031:13 x 1
# deputati della rocella                   (11)        : 10@058:27 x 1, 10@098:13 x 1
# un figliol maschio                       (11)        : 09@090:8 x 1
# moller                                   (12)        : 06@034:106 x 1
# moscovita                                (12)        : 05@021:7 x 1, 05@043:9 x 1, 06@031:14 x 1, 06@032:16 x 1, 06@035:25 x 1
#                                                        10@060:11 x 1
# muller                                   (12)        : 06@028:132 x 1, 06@028:134 x 1, 06@028:137 x 1, 06@028:197 x 2
# Entities targeted:            819
# Triggers searched for:       2159
# Triggers without hits:        163
#  - completely covered:        143
#  - missing hits:               20
# Triggers with hits:          1996
# Total hits:                 12200
#
# All hits in report file:      ~/github/HuygensING/suriano/_temp/ner/2.0.0/.persons-merged/hits.tsv
# Triggers by slot in file:     ~/github/HuygensING/suriano/_temp/ner/2.0.0/.persons-merged/triggerBySlot.tsv

# %%
nerMeta(*NE.getMeta(), silent=False)

# %%
NE.bakeEntities()
# Out:
# Entity consolidation for 12200 entity occurrences into version 2.0.0e
#  12200 entity occurrences
#    788 distinct entities
#   0.00s Creating a dataset with entity nodes ...
#   0.00s preparing and checking ...
#   0.00s Feature overview: 34 for nodes; 2 for edges; 1 configs; 9 computed
#    |     1.36s done
#    |   Delete types: t                   : keep:   shift  nodes       1-1775518 to         1-1775518
#    |   Delete types: author              : keep:   shift  nodes 1775519-1776268 to   1775519-1776268
#    |   Delete types: bibl                : keep:   shift  nodes 1776269-1777018 to   1776269-1777018
#    |   Delete types: biblScope           : keep:   shift  nodes 1777019-1777768 to   1777019-1777768
#    |   Delete types: body                : keep:   shift  nodes 1777769-1778518 to   1777769-1778518
#    |   Delete types: cell                : keep:   shift  nodes 1778519-1792853 to   1778519-1792853
#    |   Delete types: chunk               : keep:   shift  nodes 1792854-1840777 to   1792854-1840777
#    |   Delete types: collection          : keep:   shift  nodes 1840778-1841527 to   1840778-1841527
#    |   Delete types: correspAction       : keep:   shift  nodes 1841528-1843027 to   1841528-1843027
#    |   Delete types: correspDesc         : keep:   shift  nodes 1843028-1843777 to   1843028-1843777
#    |   Delete types: date                : keep:   shift  nodes 1843778-1844527 to   1843778-1844527
#    |   Delete types: div                 : keep:   shift  nodes 1844528-1848774 to   1844528-1848774
#    |   Delete types: editor              : keep:   shift  nodes 1848775-1849524 to   1848775-1849524
#    |   Delete types: file                : keep:   shift  nodes 1849525-1850274 to   1849525-1850274
#    |   Delete types: fileDesc            : keep:   shift  nodes 1850275-1851024 to   1850275-1851024
#    |   Delete types: folder              : keep:   shift  nodes 1851025-1851036 to   1851025-1851036
#    |   Delete types: head                : keep:   shift  nodes 1851037-1853167 to   1851037-1853167
#    |   Delete types: hi                  : keep:   shift  nodes 1853168-1868846 to   1853168-1868846
#    |   Delete types: idno                : keep:   shift  nodes 1868847-1871096 to   1868847-1871096
#    |   Delete types: institution         : keep:   shift  nodes 1871097-1871846 to   1871097-1871846
#    |   Delete types: ln                  : keep:   shift  nodes 1871847-2034969 to   1871847-2034969
#    |   Delete types: metamark            : keep:   shift  nodes 2034970-2038041 to   2034970-2038041
#    |   Delete types: msDesc              : keep:   shift  nodes 2038042-2038791 to   2038042-2038791
#    |   Delete types: msIdentifier        : keep:   shift  nodes 2038792-2039541 to   2038792-2039541
#    |   Delete types: name                : keep:   shift  nodes 2039542-2041791 to   2039542-2041791
#    |   Delete types: note                : keep:   shift  nodes 2041792-2055291 to   2041792-2055291
#    |   Delete types: num                 : keep:   shift  nodes 2055292-2056041 to   2055292-2056041
#    |   Delete types: p                   : keep:   shift  nodes 2056042-2105514 to   2056042-2105514
#    |   Delete types: page                : keep:   shift  nodes 2105515-2114466 to   2105515-2114466
#    |   Delete types: pb                  : keep:   shift  nodes 2114467-2123418 to   2114467-2123418
#    |   Delete types: profileDesc         : keep:   shift  nodes 2123419-2124168 to   2123419-2124168
#    |   Delete types: ptr                 : keep:   shift  nodes 2124169-2136159 to   2124169-2136159
#    |   Delete types: publicationStmt     : keep:   shift  nodes 2136160-2136909 to   2136160-2136909
#    |   Delete types: quote               : keep:   shift  nodes 2136910-2136919 to   2136910-2136919
#    |   Delete types: ref                 : keep:   shift  nodes 2136920-2136920 to   2136920-2136920
#    |   Delete types: resp                : keep:   shift  nodes 2136921-2137670 to   2136921-2137670
#    |   Delete types: respStmt            : keep:   shift  nodes 2137671-2138420 to   2137671-2138420
#    |   Delete types: row                 : keep:   shift  nodes 2138421-2142408 to   2138421-2142408
#    |   Delete types: settlement          : keep:   shift  nodes 2142409-2144658 to   2142409-2144658
#    |   Delete types: sourceDesc          : keep:   shift  nodes 2144659-2145408 to   2144659-2145408
#    |   Delete types: table               : keep:   shift  nodes 2145409-2145651 to   2145409-2145651
#    |   Delete types: teiHeader           : keep:   shift  nodes 2145652-2146401 to   2145652-2146401
#    |   Delete types: text                : keep:   shift  nodes 2146402-2147151 to   2146402-2147151
#    |   Delete types: title               : keep:   shift  nodes 2147152-2147901 to   2147152-2147901
#    |   Delete types: titleStmt           : keep:   shift  nodes 2147902-2148651 to   2147902-2148651
#    |   Delete types: max node: shifted from 2148651 to 2148651
#   1.46s add types ...
#    |     0.01s done (2 types)
#    |      |   ent, entity
#   1.47s applying updates ...
#   1.72s write TF data as version 2.0.0e ...
#   0.00s Not all of the warp features otype and oslots are present in
# ~/github/HuygensING/suriano/tf/2.0.0e
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Exporting 37 node and 3 edge and 1 configuration features to ~/github/HuygensING/suriano/tf/2.0.0e:
#   0.00s VALIDATING oslots feature
#   0.10s VALIDATING oslots feature
#   0.11s maxSlot=    1775518
#   0.11s maxNode=    2161639
#   0.13s OK: oslots is valid
#    |     0.60s T after                to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.02s T chunk                to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T corresp              to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T date                 to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T editorNotes          to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.01s T eid                  to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.01s T empty                to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T ename                to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.01s T extraspace           to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.01s T facs                 to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T file                 to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T folder               to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.01s T id                   to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.05s T is_meta              to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.08s T is_note              to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.01s T kind                 to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.01s T n                    to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.19s T otype                to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T recipient            to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T recipientLoc         to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T ref                  to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.01s T rend                 to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.04s T rend_decoded         to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T rend_displaced       to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T rend_footnote        to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T rend_superscript     to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T role                 to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T sender               to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T senderLoc            to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T shelfmark            to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T source               to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.70s T str                  to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T summary              to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T target               to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T type                 to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T unit                 to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T when                 to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s T eoccs                to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.01s T link_target          to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     1.10s T oslots               to ~/github/HuygensING/suriano/tf/2.0.0e
#    |     0.00s M otext                to ~/github/HuygensING/suriano/tf/2.0.0e
#   3.04s Exported 37 node features and 3 edge features and 1 config features to ~/github/HuygensING/suriano/tf/2.0.0e
#   4.76s all done
#   4.82s Done
# The dataset with entities is now in version 2.0.0e
# The dataset with entities is now the standard version
# True

# %% [markdown]
# We load the new data:

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/tf/2.0.0e</span>
# This is Text-Fabric 13.0.17
# 41 features found and 0 ignored
#   0.35s Dataset without structure sections in otext:no structure functions in the T-API
#   1.18s All features loaded / computed - for details use TF.isLoaded()
#   0.49s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.17</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/app" title="HuygensING/suriano app">HuygensING/suriano/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/about.md" title="provenance of HuygensING - suriano/tf">HuygensING - suriano 2.0.0e</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="HuygensING - suriano feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>12</td>
#     <td>147959.83</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>750</td>
#     <td>2367.36</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>750</td>
#     <td>2180.19</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>750</td>
#     <td>2180.19</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>4247</td>
#     <td>736.20</td>
#     <td><i>176</i></td>
# </tr>
#
# <tr>
#     <th>table</th>
#     <td>243</td>
#     <td>217.58</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>750</td>
#     <td>187.17</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8952</td>
#     <td>158.08</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>750</td>
#     <td>121.93</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>750</td>
#     <td>50.10</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>47924</td>
#     <td>37.03</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>750</td>
#     <td>121.93</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>750</td>
#     <td>65.25</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>entity</th>
#     <td>788</td>
#     <td>35.39</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>49473</td>
#     <td>32.66</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>750</td>
#     <td>31.01</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>750</td>
#     <td>31.01</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>750</td>
#     <td>19.09</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>13500</td>
#     <td>16.98</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>1</td>
#     <td>15.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>750</td>
#     <td>14.15</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>row</th>
#     <td>3988</td>
#     <td>13.26</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ln</th>
#     <td>163123</td>
#     <td>9.91</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>biblScope</th>
#     <td>750</td>
#     <td>8.55</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>750</td>
#     <td>8.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>15679</td>
#     <td>7.72</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1500</td>
#     <td>7.70</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>2250</td>
#     <td>6.34</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>collection</th>
#     <td>750</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>10</td>
#     <td>5.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>750</td>
#     <td>5.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2131</td>
#     <td>4.30</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>cell</th>
#     <td>14335</td>
#     <td>3.69</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>750</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>num</th>
#     <td>750</td>
#     <td>2.64</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>2250</td>
#     <td>2.64</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ent</th>
#     <td>12200</td>
#     <td>2.29</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>750</td>
#     <td>2.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>750</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>750</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>2250</td>
#     <td>1.31</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>metamark</th>
#     <td>3072</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8952</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>11991</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>750</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>750</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1775518</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - suriano/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/2.0.0e/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Christofforo Suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Nina Lamal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors3:</div>
#     <div>Helmer Helmers</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2025-11-19T08:32:14+00:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Critical edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute3:</div>
#     <div>NL-LAB</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>it</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + suriano</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Letters</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>2.0.0e</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/suriano/blob/main/docs/transcription.md" title="~/github/HuygensING/suriano/tf/2.0.0e/chunk.tf">chunk</a>
# </
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/suriano/thumb</span>
# Found 8953 images<br>

# %% [markdown]
# # Step 5: Transport the entities to the TEI
#
# The entities have been baked into the TF dataset, but we want to bake them into the earlier generated TEI
# as well.
#
# In order to do that, we must align the slots in TF with the text content of the TEI.
#
# Our conversion from TEI to TF has not preserved all characters of the TEI text 1-1.
# Additional whitespace may have been added, superfluous whitespace may have been stripped.
#
# We make a mapping that maps each slot that has non-white text content to a corresponding position in a TEI source file.

# %%
x = "aap1noot"
x.find("1", 3, -1)
# Out:
# 3

# %%
entity = A.api.F.otype.s("entity")[0]
entity
# Out:
# 2161181

# %%
A.api.E.eoccs.f(entity)
# Out:
# (2153197,
#  2153198,
#  2153199,
#  2153200,
#  2153201,
#  2153202,
#  2153203,
#  2153204,
#  2153205,
#  2153206)

# %%
BE = BakeEntTei(A)
# Out:
# Making entity index ...
# 788 entities with 12200 occurrences

# %%
BE.bakeCorpus(filza=None, file=None)
# Out:
# Bake entities into TEI in ~/github/HuygensING/suriano/datasource/tei-bare (whole corpus) ...
# 	filza 02
# 		letter 001
# 			xml: 14561 chars;  2145 tokens;  18 ents
# 		letter 002
# 			xml: 17441 chars;  2447 tokens;  23 ents
# 		letter 003
# 			xml: 13850 chars;  1899 tokens;   7 ents
# 		letter 004
# 			xml: 23429 chars;  3112 tokens;  23 ents
# 		letter 005
# 			xml: 12726 chars;  1517 tokens;   7 ents
# 		letter 006
# 			xml: 21883 chars;  2743 tokens;  13 ents
# 		letter 007
# 			xml: 16389 chars;  2062 tokens;  10 ents
# 		letter 008
# 			xml: 17852 chars;  2103 tokens;  13 ents
# 		letter 009
# 			xml:  7833 chars;   934 tokens;   4 ents
# 		letter 010
# 			xml: 15659 chars;  2161 tokens;   8 ents
# 		letter 011
# 			xml:  6619 chars;   688 tokens;   2 ents
# 		letter 012
# 			xml: 12145 chars;  1654 tokens;   8 ents
# 		letter 013
# 			xml: 50896 chars;  7247 tokens;  20 ents
# 		letter 014
# 			xml: 13960 chars;  1764 tokens;  22 ents
# 		letter 015
# 			xml: 13953 chars;  1888 tokens;  23 ents
# 		letter 016
# 			xml: 10466 chars;  1404 tokens;   9 ents
# 		letter 017
# 			xml: 12801 chars;  1640 tokens;   6 ents
# 		letter 018
# 			xml: 39873 chars;  5841 tokens;  19 ents
# 		letter 019
# 			xml:  9064 chars;  1113 tokens;   9 ents
# 	filza 02, all good
# 	filza 03
# 		letter 001
# 			xml: 33838 chars;  4991 tokens;  16 ents
# 		letter 002
# 			xml: 14779 chars;  2049 tokens;   4 ents
# 		letter 003
# 			xml:  3865 chars;   282 tokens;   0 ents
# 		letter 004
# 			xml: 18500 chars;  2484 tokens;  15 ents
# 		letter 005
# 			xml: 16479 chars;  2405 tokens;  25 ents
# 		letter 006
# 			xml: 19114 chars;  2434 tokens;  16 ents
# 		letter 007
# 			xml: 15428 chars;  1911 tokens;  17 ents
# 		letter 008
# 			xml: 14037 chars;  1817 tokens;  19 ents
# 		letter 009
# 			xml:  7631 chars;   916 tokens;   9 ents
# 		letter 010
# 			xml: 10449 chars;  1377 tokens;   7 ents
# 		letter 011
# 			xml: 12946 chars;  1789 tokens;  24 ents
# 		letter 012
# 			xml: 15258 chars;  2093 tokens;  33 ents
# 		letter 013
# 			xml: 13089 chars;  1694 tokens;  12 ents
# 		letter 014
# 			xml: 19599 chars;  2302 tokens;  25 ents
# 		letter 015
# 			xml:  7190 chars;   653 tokens;   1 ents
# 		letter 016
# 			xml: 21056 chars;  2805 tokens;  16 ents
# 		letter 017
# 			xml: 31347 chars;  4296 tokens;  18 ents
# 		letter 018
# 			xml: 20016 chars;  2608 tokens;  16 ents
# 		letter 019
# 			xml: 18397 chars;  2624 tokens;  14 ents
# 		letter 020
# 			xml: 18947 chars;  2498 tokens;  19 ents
# 		letter 021
# 			xml: 22542 chars;  3190 tokens;  38 ents
# 		letter 022
# 			xml: 10676 chars;  1224 tokens;  13 ents
# 		letter 023
# 			xml: 15927 chars;  2311 tokens;  27 ents
# 		letter 024
# 			xml: 24947 chars;  3320 tokens;  11 ents
# 		letter 025
# 			xml: 37922 chars;  5760 tokens;  40 ents
# 		letter 026
# 			xml: 28133 chars;  3870 tokens;  41 ents
# 		letter 027
# 			xml:  5391 chars;   532 tokens;   5 ents
# 		letter 028
# 			xml: 13022 chars;  1832 tokens;  21 ents
# 		letter 029
# 			xml: 16573 chars;  2388 tokens;  19 ents
# 		letter 030
# 			xml: 28310 chars;  3946 tokens;  30 ents
# 		letter 031
# 			xml: 14782 chars;  2110 tokens;  15 ents
# 		letter 032
# 			xml: 10596 chars;  1414 tokens;   3 ents
# 		letter 033
# 			xml: 23524 chars;  3179 tokens;  16 ents
# 		letter 034
# 			xml: 11699 chars;  1530 tokens;  11 ents
# 		letter 035
# 			xml: 12422 chars;  1649 tokens;  10 ents
# 		letter 036
# 			xml: 13915 chars;  1793 tokens;  19 ents
# 		letter 037
# 			xml: 17133 chars;  2023 tokens;  11 ents
# 		letter 038
# 			xml: 16582 chars;  2328 tokens;  28 ents
# 		letter 039
# 			xml:  9827 chars;  1227 tokens;  12 ents
# 		letter 040
# 			xml: 14528 chars;  2088 tokens;  15 ents
# 		letter 041
# 			xml: 11235 chars;  1486 tokens;  15 ents
# 		letter 042
# 			xml:  5074 chars;   474 tokens;   3 ents
# 		letter 043
# 			xml: 13838 chars;  1846 tokens;   9 ents
# 		letter 044
# 			xml: 14553 chars;  2066 tokens;  28 ents
# 		letter 045
# 			xml: 14340 chars;  2043 tokens;   6 ents
# 		letter 046
# 			xml:  7419 chars;   875 tokens;  24 ents
# 		letter 047
# 			xml: 12591 chars;  1728 tokens;  18 ents
# 		letter 048
# 			xml:  3680 chars;   260 tokens;   2 ents
# 		letter 049
# 			xml: 11671 chars;  1557 tokens;  10 ents
# 		letter 050
# 			xml: 18004 chars;  2533 tokens;  28 ents
# 		letter 051
# 			xml: 15220 chars;  2164 tokens;  19 ents
# 		letter 052
# 			xml: 31868 chars;  4837 tokens;  31 ents
# 		letter 053
# 			xml: 13502 chars;  1921 tokens;  11 ents
# 		letter 054
# 			xml: 14899 chars;  2136 tokens;  15 ents
# 		letter 055
# 			xml:  3907 chars;   288 tokens;   1 ents
# 	filza 03, all good
# 	filza 04
# 		letter 001
# 			xml: 14757 chars;  2034 tokens;  13 ents
# 		letter 002
# 			xml: 11541 chars;  1574 tokens;  15 ents
# 		letter 003
# 			xml: 14213 chars;  1847 tokens;  21 ents
# 		letter 004
# 			xml: 36299 chars;  5410 tokens;  49 ents
# 		letter 005
# 			xml: 15677 chars;  2224 tokens;  17 ents
# 		letter 006
# 			xml: 16930 chars;  2270 tokens;  34 ents
# 		letter 007
# 			xml: 28683 chars;  4136 tokens;  24 ents
# 		letter 008
# 			xml:  9118 chars;  1187 tokens;  10 ents
# 		letter 009
# 			xml: 10953 chars;  1399 tokens;  14 ents
# 		letter 010
# 			xml: 12164 chars;  1653 tokens;   7 ents
# 		letter 011
# 			xml:  8803 chars;  1060 tokens;  20 ents
# 		letter 012
# 			xml:  6010 chars;   656 tokens;   2 ents
# 		letter 013
# 			xml:  8211 chars;   933 tokens;   0 ents
# 		letter 014
# 			xml: 21059 chars;  2986 tokens;  25 ents
# 		letter 015
# 			xml: 11591 chars;  1414 tokens;  14 ents
# 		letter 016
# 			xml: 11062 chars;  1459 tokens;  11 ents
# 		letter 017
# 			xml:  8770 chars;  1125 tokens;  11 ents
# 		letter 018
# 			xml: 17068 chars;  2327 tokens;  23 ents
# 		letter 019
# 			xml: 10197 chars;  1328 tokens;   8 ents
# 		letter 020
# 			xml: 10149 chars;  1289 tokens;   9 ents
# 		letter 021
# 			xml: 12705 chars;  1671 tokens;  26 ents
# 		letter 022
# 			xml: 11616 chars;  1529 tokens;   9 ents
# 		letter 023
# 			xml: 16506 chars;  2291 tokens;  24 ents
# 		letter 024
# 			xml: 17067 chars;  2485 tokens;  22 ents
# 		letter 025
# 			xml: 19275 chars;  2660 tokens;  26 ents
# 		letter 026
# 			xml: 12373 chars;  1742 tokens;  18 ents
# 		letter 027
# 			xml: 11534 chars;  1557 tokens;  21 ents
# 		letter 028
# 			xml: 10565 chars;  1397 tokens;  13 ents
# 		letter 029
# 			xml: 16266 chars;  2265 tokens;  28 ents
# 		letter 030
# 			xml: 12200 chars;  1607 tokens;  19 ents
# 		letter 031
# 			xml: 25455 chars;  3926 tokens;  30 ents
# 		letter 032
# 			xml: 10421 chars;  1393 tokens;  12 ents
# 		letter 033
# 			xml: 12396 chars;  1683 tokens;  18 ents
# 		letter 034
# 			xml: 11946 chars;  1622 tokens;  22 ents
# 		letter 035
# 			xml: 15788 chars;  2261 tokens;  19 ents
# 		letter 036
# 			xml:  8395 chars;  1061 tokens;  14 ents
# 		letter 037
# 			xml: 24338 chars;  3580 tokens;  28 ents
# 		letter 038
# 			xml: 14763 chars;  2053 tokens;   9 ents
# 		letter 039
# 			xml: 12006 chars;  1480 tokens;  22 ents
# 		letter 040
# 			xml: 12842 chars;  1757 tokens;  20 ents
# 		letter 041
# 			xml: 12569 chars;  1480 tokens;   5 ents
# 		letter 042
# 			xml: 19070 chars;  2677 tokens;  16 ents
# 		letter 043
# 			xml: 26484 chars;  2945 tokens;  18 ents
# 		letter 044
# 			xml: 13745 chars;  1911 tokens;  19 ents
# 		letter 045
# 			xml: 13818 chars;  1858 tokens;  14 ents
# 		letter 046
# 			xml:  6051 chars;   590 tokens;   3 ents
# 		letter 047
# 			xml:  8176 chars;   791 tokens;   8 ents
# 		letter 048
# 			xml: 12716 chars;  1760 tokens;   7 ents
# 		letter 049
# 			xml: 22479 chars;  3176 tokens;  27 ents
# 		letter 050
# 			xml: 20758 chars;  2655 tokens;  21 ents
# 		letter 051
# 			xml: 13234 chars;  1877 tokens;   7 ents
# 		letter 052
# 			xml: 29390 chars;  4257 tokens;  16 ents
# 		letter 053
# 			xml:  4622 chars;   420 tokens;   2 ents
# 		letter 054
# 			xml: 15357 chars;  2048 tokens;  12 ents
# 		letter 055
# 			xml: 18558 chars;  2515 tokens;  15 ents
# 		letter 056
# 			xml: 19486 chars;  2840 tokens;  23 ents
# 		letter 057
# 			xml:  4608 chars;   378 tokens;   3 ents
# 		letter 058
# 			xml:  6048 chars;   567 tokens;   6 ents
# 		letter 059
# 			xml: 14045 chars;  1800 tokens;  15 ents
# 		letter 060
# 			xml: 17465 chars;  2482 tokens;  23 ents
# 		letter 061
# 			xml: 15942 chars;  2076 tokens;   5 ents
# 		letter 062
# 			xml: 17187 chars;  2361 tokens;   6 ents
# 		letter 063
# 			xml:  7488 chars;   815 tokens;   4 ents
# 		letter 064
# 			xml: 15235 chars;  1629 tokens;  11 ents
# 		letter 065
# 			xml: 14370 chars;  2020 tokens;   7 ents
# 		letter 066
# 			xml: 22389 chars;  3166 tokens;  41 ents
# 		letter 067
# 			xml: 14162 chars;  1711 tokens;  13 ents
# 		letter 068
# 			xml: 14093 chars;  1912 tokens;  21 ents
# 		letter 069
# 			xml: 17760 chars;  2466 tokens;  13 ents
# 		letter 070
# 			xml:  8231 chars;   994 tokens;   2 ents
# 		letter 071
# 			xml: 29824 chars;  4702 tokens;  31 ents
# 		letter 072
# 			xml: 15147 chars;  2180 tokens;  16 ents
# 		letter 073
# 			xml: 10752 chars;  1462 tokens;   6 ents
# 		letter 074
# 			xml: 14174 chars;  1912 tokens;  22 ents
# 		letter 075
# 			xml:  8762 chars;   996 tokens;   2 ents
# 	filza 04, all good
# 	filza 05
# 		letter 001
# 			xml: 14447 chars;  2055 tokens;  31 ents
# 		letter 002
# 			xml: 12785 chars;  1633 tokens;  16 ents
# 		letter 003
# 			xml: 16308 chars;  2384 tokens;  19 ents
# 		letter 004
# 			xml: 11786 chars;  1489 tokens;   4 ents
# 		letter 005
# 			xml: 16124 chars;  2150 tokens;   6 ents
# 		letter 006
# 			xml: 18941 chars;  2517 tokens;  23 ents
# 		letter 007
# 			xml: 13112 chars;  1851 tokens;   6 ents
# 		letter 008
# 			xml: 14841 chars;  2032 tokens;   3 ents
# 		letter 009
# 			xml: 22449 chars;  3140 tokens;   8 ents
# 		letter 010
# 			xml: 13221 chars;  1649 tokens;   4 ents
# 		letter 011
# 			xml: 10192 chars;  1308 tokens;  14 ents
# 		letter 012
# 			xml:  4189 chars;   351 tokens;   0 ents
# 		letter 013
# 			xml: 12690 chars;  1659 tokens;  19 ents
# 		letter 014
# 			xml: 12241 chars;  1620 tokens;   5 ents
# 		letter 015
# 			xml: 19306 chars;  2523 tokens;  38 ents
# 		letter 016
# 			xml: 23199 chars;  3069 tokens;  11 ents
# 		letter 017
# 			xml: 12523 chars;  1583 tokens;   4 ents
# 		letter 018
# 			xml: 21394 chars;  2734 tokens;  17 ents
# 		letter 019
# 			xml:  4442 chars;   381 tokens;   0 ents
# 		letter 020
# 			xml: 12755 chars;  1701 tokens;   2 ents
# 		letter 021
# 			xml: 11718 chars;  1558 tokens;  10 ents
# 		letter 022
# 			xml: 14009 chars;  1951 tokens;   6 ents
# 		letter 023
# 			xml:  6776 chars;   777 tokens;   6 ents
# 		letter 024
# 			xml: 12068 chars;  1521 tokens;  11 ents
# 		letter 025
# 			xml: 27781 chars;  3298 tokens;   4 ents
# 		letter 026
# 			xml: 15004 chars;  1995 tokens;   9 ents
# 		letter 027
# 			xml: 33729 chars;  5042 tokens;  12 ents
# 		letter 028
# 			xml: 11489 chars;  1543 tokens;  11 ents
# 		letter 029
# 			xml:  3504 chars;   230 tokens;   0 ents
# 		letter 030
# 			xml: 10346 chars;  1412 tokens;  11 ents
# 		letter 031
# 			xml: 11815 chars;  1581 tokens;  13 ents
# 		letter 032
# 			xml: 14421 chars;  1966 tokens;  14 ents
# 		letter 033
# 			xml:  3552 chars;   242 tokens;   0 ents
# 		letter 034
# 			xml: 10070 chars;  1075 tokens;   0 ents
# 		letter 035
# 			xml: 14238 chars;  1891 tokens;   8 ents
# 		letter 036
# 			xml: 14478 chars;  1704 tokens;   1 ents
# 		letter 037
# 			xml: 22773 chars;  3007 tokens;  12 ents
# 		letter 038
# 			xml: 23576 chars;  3170 tokens;  21 ents
# 		letter 039
# 			xml: 10099 chars;  1240 tokens;   9 ents
# 		letter 040
# 			xml:  4089 chars;   324 tokens;   1 ents
# 		letter 041
# 			xml: 17946 chars;  2345 tokens;  10 ents
# 		letter 042
# 			xml: 17660 chars;  2398 tokens;  15 ents
# 		letter 043
# 			xml: 13439 chars;  1769 tokens;   5 ents
# 		letter 044
# 			xml:  8027 chars;  1001 tokens;   8 ents
# 		letter 045
# 			xml:  4242 chars;   344 tokens;   4 ents
# 		letter 046
# 			xml: 16737 chars;  2438 tokens;   3 ents
# 		letter 047
# 			xml: 12507 chars;  1744 tokens;  13 ents
# 		letter 048
# 			xml: 22146 chars;  3263 tokens;  11 ents
# 		letter 049
# 			xml: 23008 chars;  3282 tokens;  16 ents
# 		letter 050
# 			xml:  8591 chars;  1120 tokens;   5 ents
# 		letter 051
# 			xml: 12242 chars;  1684 tokens;   9 ents
# 		letter 052
# 			xml: 13983 chars;  2016 tokens;   5 ents
# 		letter 053
# 			xml: 22552 chars;  3187 tokens;  17 ents
# 		letter 054
# 			xml: 23136 chars;  3264 tokens;   2 ents
# 		letter 055
# 			xml: 12309 chars;  1681 tokens;  14 ents
# 		letter 056
# 			xml: 16754 chars;  2416 tokens;   2 ents
# 		letter 057
# 			xml: 17143 chars;  2174 tokens;  12 ents
# 	filza 05, all good
# 	filza 06
# 		letter 001
# 			xml: 20274 chars;  3092 tokens;   4 ents
# 		letter 002
# 			xml: 13120 chars;  1817 tokens;  12 ents
# 		letter 003
# 			xml:  9113 chars;  1173 tokens;   6 ents
# 		letter 004
# 			xml: 20064 chars;  2664 tokens;   7 ents
# 		letter 005
# 			xml: 63227 chars;  9266 tokens;  46 ents
# 		letter 006
# 			xml: 30987 chars;  4392 tokens;   2 ents
# 		letter 007
# 			xml: 15479 chars;  2079 tokens;  14 ents
# 		letter 008
# 			xml: 29862 chars;  4039 tokens;   3 ents
# 		letter 009
# 			xml: 22243 chars;  3062 tokens;   7 ents
# 		letter 010
# 			xml: 23124 chars;  3234 tokens;  20 ents
# 		letter 011
# 			xml: 20786 chars;  2945 tokens;   3 ents
# 		letter 012
# 			xml: 12779 chars;  1710 tokens;  10 ents
# 		letter 013
# 			xml:  9768 chars;  1215 tokens;   6 ents
# 		letter 014
# 			xml: 23256 chars;  3237 tokens;   1 ents
# 		letter 015
# 			xml: 11265 chars;  1419 tokens;   1 ents
# 		letter 016
# 			xml: 10176 chars;  1364 tokens;   0 ents
# 		letter 017
# 			xml: 16515 chars;  2233 tokens;   7 ents
# 		letter 018
# 			xml: 15839 chars;  2189 tokens;   9 ents
# 		letter 019
# 			xml:  7364 chars;   866 tokens;   5 ents
# 		letter 020
# 			xml: 17233 chars;  2461 tokens;  14 ents
# 		letter 021
# 			xml: 19139 chars;  2739 tokens;   7 ents
# 		letter 022
# 			xml:  5671 chars;   499 tokens;   1 ents
# 		letter 023
# 			xml: 13000 chars;  1740 tokens;   5 ents
# 		letter 024
# 			xml: 13519 chars;  1884 tokens;   4 ents
# 		letter 025
# 			xml: 12822 chars;  1705 tokens;   3 ents
# 		letter 026
# 			xml: 14425 chars;  2048 tokens;   7 ents
# 		letter 027
# 			xml: 16737 chars;  2381 tokens;  22 ents
# 		letter 028
# 			xml: 197769 chars; 18533 tokens;  89 ents
# 		letter 029
# 			xml: 14401 chars;  2056 tokens;  15 ents
# 		letter 030
# 			xml: 82255 chars;  9227 tokens;  21 ents
# 		letter 031
# 			xml: 19169 chars;  2691 tokens;  13 ents
# 		letter 032
# 			xml: 12655 chars;  1674 tokens;   9 ents
# 		letter 033
# 			xml: 32324 chars;  4080 tokens;  20 ents
# 		letter 034
# 			xml: 265368 chars; 27339 tokens;  40 ents
# 		letter 035
# 			xml: 20150 chars;  2991 tokens;  23 ents
# 		letter 036
# 			xml: 99486 chars;  7833 tokens;  22 ents
# 		letter 037
# 			xml: 22459 chars;  3140 tokens;  18 ents
# 		letter 038
# 			xml:  9915 chars;  1310 tokens;  17 ents
# 		letter 039
# 			xml: 25589 chars;  3537 tokens;  32 ents
# 		letter 040
# 			xml: 22029 chars;  3108 tokens;  13 ents
# 	filza 06, all good
# 	filza 07
# 		letter 001
# 			xml: 25880 chars;  3454 tokens;  20 ents
# 		letter 002
# 			xml:  7399 chars;   873 tokens;   1 ents
# 		letter 003
# 			xml: 10643 chars;  1293 tokens;   4 ents
# 		letter 004
# 			xml:  5446 chars;   554 tokens;   1 ents
# 		letter 005
# 			xml: 69202 chars;  9601 tokens;  43 ents
# 		letter 006
# 			xml: 17837 chars;  2364 tokens;  12 ents
# 		letter 007
# 			xml: 11396 chars;  1527 tokens;   5 ents
# 		letter 008
# 			xml: 19254 chars;  2606 tokens;   9 ents
# 		letter 009
# 			xml: 24611 chars;  3024 tokens;  20 ents
# 		letter 010
# 			xml: 15995 chars;  2290 tokens;   9 ents
# 		letter 011
# 			xml: 10618 chars;  1264 tokens;  10 ents
# 		letter 012
# 			xml: 26863 chars;  4085 tokens;  54 ents
# 		letter 013
# 			xml: 23454 chars;  3427 tokens;  17 ents
# 		letter 014
# 			xml: 28399 chars;  4123 tokens;  11 ents
# 		letter 015
# 			xml: 16094 chars;  2211 tokens;  23 ents
# 		letter 016
# 			xml: 28206 chars;  4079 tokens;  38 ents
# 		letter 017
# 			xml: 61277 chars;  8502 tokens;  31 ents
# 		letter 018
# 			xml: 54451 chars;  7357 tokens;  32 ents
# 		letter 019
# 			xml: 19902 chars;  2928 tokens;  21 ents
# 		letter 020
# 			xml: 23407 chars;  3292 tokens;  20 ents
# 		letter 021
# 			xml: 26570 chars;  3930 tokens;  22 ents
# 		letter 022
# 			xml: 23710 chars;  3578 tokens;  21 ents
# 		letter 023
# 			xml: 43609 chars;  6393 tokens;  19 ents
# 		letter 024
# 			xml: 22331 chars;  3255 tokens;  18 ents
# 		letter 025
# 			xml: 16379 chars;  2342 tokens;  17 ents
# 		letter 026
# 			xml: 26233 chars;  3793 tokens;  10 ents
# 		letter 027
# 			xml:  5248 chars;   487 tokens;   2 ents
# 		letter 028
# 			xml: 20530 chars;  2955 tokens;  10 ents
# 		letter 029
# 			xml: 20344 chars;  2916 tokens;  24 ents
# 		letter 030
# 			xml: 19895 chars;  2596 tokens;   3 ents
# 		letter 031
# 			xml: 21697 chars;  3305 tokens;  31 ents
# 		letter 032
# 			xml: 23195 chars;  3448 tokens;  11 ents
# 		letter 033
# 			xml: 55021 chars;  8464 tokens;  20 ents
# 		letter 034
# 			xml: 15219 chars;  2154 tokens;   3 ents
# 		letter 035
# 			xml: 11873 chars;  1531 tokens;   3 ents
# 		letter 036
# 			xml: 23554 chars;  3406 tokens;   9 ents
# 		letter 037
# 			xml: 30464 chars;  4462 tokens;  11 ents
# 		letter 038
# 			xml: 22726 chars;  3283 tokens;   6 ents
# 		letter 039
# 			xml: 14480 chars;  1924 tokens;   0 ents
# 		letter 040
# 			xml: 62269 chars;  9290 tokens;  10 ents
# 		letter 041
# 			xml: 18062 chars;  2547 tokens;   3 ents
# 		letter 042
# 			xml: 12858 chars;  1753 tokens;   0 ents
# 		letter 043
# 			xml: 66137 chars; 10140 tokens;  13 ents
# 		letter 044
# 			xml:  7377 chars;   895 tokens;   5 ents
# 		letter 045
# 			xml: 35865 chars;  5153 tokens;  17 ents
# 		letter 046
# 			xml: 31488 chars;  4437 tokens;  12 ents
# 		letter 047
# 			xml: 25775 chars;  3604 tokens;  11 ents
# 	filza 07, all good
# 	filza 08
# 		letter 001
# 			xml: 26355 chars;  3587 tokens;  13 ents
# 		letter 002
# 			xml: 45240 chars;  6591 tokens;  35 ents
# 		letter 003
# 			xml: 28529 chars;  4097 tokens;   6 ents
# 		letter 004
# 			xml: 31341 chars;  4606 tokens;  24 ents
# 		letter 005
# 			xml: 19528 chars;  2760 tokens;   9 ents
# 		letter 006
# 			xml: 15056 chars;  2156 tokens;   9 ents
# 		letter 007
# 			xml: 16837 chars;  2320 tokens;  10 ents
# 		letter 008
# 			xml: 17794 chars;  2536 tokens;   5 ents
# 		letter 009
# 			xml: 18172 chars;  2515 tokens;  13 ents
# 		letter 010
# 			xml: 23972 chars;  3453 tokens;  17 ents
# 		letter 011
# 			xml: 22158 chars;  3091 tokens;  22 ents
# 		letter 012
# 			xml:  4186 chars;   345 tokens;   3 ents
# 		letter 013
# 			xml: 27009 chars;  3897 tokens;  16 ents
# 		letter 014
# 			xml:  9986 chars;  1288 tokens;   7 ents
# 		letter 015
# 			xml: 19015 chars;  2770 tokens;  17 ents
# 		letter 016
# 			xml: 15126 chars;  2098 tokens;   5 ents
# 		letter 017
# 			xml: 41992 chars;  6023 tokens;  23 ents
# 		letter 018
# 			xml: 13972 chars;  1959 tokens;   6 ents
# 		letter 019
# 			xml:  9981 chars;  1356 tokens;  11 ents
# 		letter 020
# 			xml: 16534 chars;  2318 tokens;  21 ents
# 		letter 021
# 			xml: 16643 chars;  2322 tokens;  13 ents
# 		letter 022
# 			xml: 17203 chars;  2386 tokens;  17 ents
# 		letter 023
# 			xml: 10971 chars;  1507 tokens;   3 ents
# 		letter 024
# 			xml: 15843 chars;  2341 tokens;   2 ents
# 		letter 025
# 			xml: 21291 chars;  3086 tokens;   3 ents
# 		letter 026
# 			xml: 15800 chars;  2261 tokens;   1 ents
# 		letter 027
# 			xml: 21559 chars;  2910 tokens;  16 ents
# 		letter 028
# 			xml: 31336 chars;  4518 tokens;  10 ents
# 		letter 029
# 			xml: 17767 chars;  2197 tokens;   1 ents
# 		letter 030
# 			xml: 17055 chars;  2403 tokens;  13 ents
# 		letter 031
# 			xml: 12995 chars;  1493 tokens;   3 ents
# 		letter 032
# 			xml: 31411 chars;  3949 tokens;   4 ents
# 		letter 033
# 			xml: 21405 chars;  3023 tokens;  11 ents
# 		letter 034
# 			xml:  3634 chars;   239 tokens;   0 ents
# 		letter 035
# 			xml: 13951 chars;  1997 tokens;   0 ents
# 		letter 036
# 			xml: 12287 chars;  1534 tokens;   6 ents
# 		letter 037
# 			xml: 21847 chars;  2992 tokens;  12 ents
# 		letter 038
# 			xml: 13755 chars;  1792 tokens;  10 ents
# 		letter 039
# 			xml: 11769 chars;  1617 tokens;  14 ents
# 		letter 040
# 			xml: 12519 chars;  1756 tokens;  16 ents
# 		letter 041
# 			xml: 11232 chars;  1480 tokens;   2 ents
# 		letter 042
# 			xml: 15957 chars;  2270 tokens;  15 ents
# 		letter 043
# 			xml: 16978 chars;  2128 tokens;   6 ents
# 		letter 044
# 			xml: 11391 chars;  1494 tokens;   2 ents
# 		letter 045
# 			xml: 13472 chars;  1747 tokens;  13 ents
# 		letter 046
# 			xml: 12926 chars;  1406 tokens;   6 ents
# 		letter 047
# 			xml: 14338 chars;  1939 tokens;  10 ents
# 		letter 048
# 			xml:  9087 chars;   926 tokens;   0 ents
# 		letter 049
# 			xml: 19051 chars;  2730 tokens;   7 ents
# 		letter 050
# 			xml: 11094 chars;  1501 tokens;  14 ents
# 		letter 051
# 			xml: 20645 chars;  2817 tokens;  16 ents
# 		letter 052
# 			xml: 22736 chars;  3224 tokens;  16 ents
# 		letter 053
# 			xml: 58648 chars;  6975 tokens;   8 ents
# 		letter 054
# 			xml: 12810 chars;  1661 tokens;  11 ents
# 		letter 055
# 			xml: 10319 chars;  1379 tokens;   8 ents
# 		letter 056
# 			xml:  8318 chars;   870 tokens;   5 ents
# 		letter 057
# 			xml: 11152 chars;  1558 tokens;   3 ents
# 		letter 058
# 			xml:  8112 chars;  1025 tokens;  16 ents
# 		letter 059
# 			xml:  9098 chars;   966 tokens;   9 ents
# 		letter 060
# 			xml: 16574 chars;  2342 tokens;  19 ents
# 		letter 061
# 			xml: 11551 chars;  1601 tokens;   6 ents
# 		letter 062
# 			xml: 11730 chars;  1540 tokens;   3 ents
# 		letter 063
# 			xml: 12320 chars;  1542 tokens;  11 ents
# 		letter 064
# 			xml:  9492 chars;  1053 tokens;   7 ents
# 		letter 065
# 			xml: 17676 chars;  2583 tokens;  20 ents
# 		letter 066
# 			xml: 10939 chars;  1376 tokens;   6 ents
# 		letter 067
# 			xml: 16089 chars;  2131 tokens;  21 ents
# 		letter 068
# 			xml:  6676 chars;   753 tokens;   3 ents
# 		letter 069
# 			xml:  4378 chars;   362 tokens;   0 ents
# 		letter 070
# 			xml: 14331 chars;  1675 tokens;   1 ents
# 		letter 071
# 			xml: 14735 chars;  2012 tokens;   8 ents
# 		letter 072
# 			xml:  7658 chars;   841 tokens;   3 ents
# 		letter 073
# 			xml:  9685 chars;  1005 tokens;   3 ents
# 		letter 074
# 			xml: 18922 chars;  2498 tokens;  17 ents
# 		letter 075
# 			xml: 59221 chars;  7710 tokens;  27 ents
# 		letter 076
# 			xml: 15661 chars;  2201 tokens;  13 ents
# 		letter 077
# 			xml: 11067 chars;  1207 tokens;   3 ents
# 		letter 078
# 			xml:  7544 chars;   897 tokens;   6 ents
# 		letter 079
# 			xml: 11264 chars;  1491 tokens;  12 ents
# 		letter 080
# 			xml: 13972 chars;  1682 tokens;   2 ents
# 		letter 081
# 			xml: 18241 chars;  2585 tokens;  23 ents
# 		letter 082
# 			xml: 11098 chars;  1524 tokens;   2 ents
# 		letter 083
# 			xml: 21739 chars;  3058 tokens;  22 ents
# 		letter 084
# 			xml:  9924 chars;  1025 tokens;   4 ents
# 		letter 085
# 			xml:  9780 chars;  1190 tokens;   2 ents
# 		letter 086
# 			xml: 11900 chars;  1625 tokens;  23 ents
# 		letter 087
# 			xml:  9332 chars;  1158 tokens;   3 ents
# 		letter 088
# 			xml: 17743 chars;  2497 tokens;  21 ents
# 		letter 089
# 			xml: 12362 chars;  1512 tokens;   1 ents
# 		letter 090
# 			xml: 21737 chars;  2998 tokens;  18 ents
# 		letter 091
# 			xml: 21275 chars;  3040 tokens;  32 ents
# 	filza 08, all good
# 	filza 09
# 		letter 001
# 			xml: 18976 chars;  2684 tokens;  15 ents
# 		letter 002
# 			xml: 13036 chars;  1844 tokens;   6 ents
# 		letter 003
# 			xml: 12857 chars;  1682 tokens;   7 ents
# 		letter 004
# 			xml: 13044 chars;  1671 tokens;   3 ents
# 		letter 005
# 			xml: 10745 chars;  1443 tokens;  18 ents
# 		letter 006
# 			xml: 14918 chars;  2137 tokens;  23 ents
# 		letter 007
# 			xml: 10034 chars;  1317 tokens;   5 ents
# 		letter 008
# 			xml: 12954 chars;  1768 tokens;   7 ents
# 		letter 009
# 			xml:  7562 chars;   867 tokens;   0 ents
# 		letter 010
# 			xml: 25953 chars;  3673 tokens;  21 ents
# 		letter 011
# 			xml: 11218 chars;  1533 tokens;   6 ents
# 		letter 012
# 			xml: 10990 chars;  1422 tokens;  11 ents
# 		letter 013
# 			xml:  7840 chars;   940 tokens;   2 ents
# 		letter 014
# 			xml: 13634 chars;  1749 tokens;   5 ents
# 		letter 015
# 			xml: 13180 chars;  1823 tokens;  17 ents
# 		letter 016
# 			xml: 16283 chars;  2244 tokens;  10 ents
# 		letter 017
# 			xml: 40733 chars;  6311 tokens;  19 ents
# 		letter 018
# 			xml: 16810 chars;  2216 tokens;  24 ents
# 		letter 019
# 			xml: 15959 chars;  2041 tokens;   4 ents
# 		letter 020
# 			xml: 12707 chars;  1706 tokens;   4 ents
# 		letter 021
# 			xml:  8538 chars;  1050 tokens;   3 ents
# 		letter 022
# 			xml: 13310 chars;  1835 tokens;   9 ents
# 		letter 023
# 			xml: 52745 chars;  7498 tokens;  41 ents
# 		letter 024
# 			xml: 15184 chars;  2069 tokens;  19 ents
# 		letter 025
# 			xml: 12471 chars;  1747 tokens;  15 ents
# 		letter 026
# 			xml: 13806 chars;  1902 tokens;  16 ents
# 		letter 027
# 			xml: 15510 chars;  2089 tokens;  27 ents
# 		letter 028
# 			xml: 19446 chars;  2694 tokens;  17 ents
# 		letter 029
# 			xml:  8945 chars;  1173 tokens;   6 ents
# 		letter 030
# 			xml: 44957 chars;  6443 tokens;  63 ents
# 		letter 031
# 			xml: 24304 chars;  3496 tokens;  23 ents
# 		letter 032
# 			xml: 12522 chars;  1659 tokens;   5 ents
# 		letter 033
# 			xml:  7193 chars;   842 tokens;  12 ents
# 		letter 034
# 			xml: 17372 chars;  2420 tokens;  10 ents
# 		letter 035
# 			xml: 11871 chars;  1534 tokens;  20 ents
# 		letter 036
# 			xml: 14382 chars;  2054 tokens;  19 ents
# 		letter 037
# 			xml: 23067 chars;  3179 tokens;  13 ents
# 		letter 038
# 			xml: 16091 chars;  2251 tokens;  11 ents
# 		letter 039
# 			xml: 14437 chars;  1969 tokens;  14 ents
# 		letter 040
# 			xml: 13640 chars;  1904 tokens;  16 ents
# 		letter 041
# 			xml:  9625 chars;  1261 tokens;  11 ents
# 		letter 042
# 			xml: 12055 chars;  1641 tokens;  18 ents
# 		letter 043
# 			xml: 14045 chars;  2002 tokens;   6 ents
# 		letter 044
# 			xml: 26871 chars;  3844 tokens;  31 ents
# 		letter 045
# 			xml: 15539 chars;  2054 tokens;  15 ents
# 		letter 046
# 			xml:  9057 chars;  1111 tokens;  12 ents
# 		letter 047
# 			xml:  7847 chars;   970 tokens;   6 ents
# 		letter 048
# 			xml: 14837 chars;  2093 tokens;   8 ents
# 		letter 049
# 			xml: 15041 chars;  1986 tokens;   7 ents
# 		letter 050
# 			xml: 10362 chars;  1376 tokens;   2 ents
# 		letter 051
# 			xml: 10505 chars;  1355 tokens;   5 ents
# 		letter 052
# 			xml: 13328 chars;  1894 tokens;  17 ents
# 		letter 053
# 			xml: 28356 chars;  4166 tokens;  25 ents
# 		letter 054
# 			xml: 23805 chars;  3286 tokens;  16 ents
# 		letter 055
# 			xml: 22639 chars;  3285 tokens;  35 ents
# 		letter 056
# 			xml:  8793 chars;  1082 tokens;  12 ents
# 		letter 057
# 			xml: 20125 chars;  2951 tokens;  23 ents
# 		letter 058
# 			xml: 18437 chars;  2671 tokens;   8 ents
# 		letter 059
# 			xml:  8166 chars;  1053 tokens;   9 ents
# 		letter 060
# 			xml: 10643 chars;  1457 tokens;  10 ents
# 		letter 061
# 			xml: 16276 chars;  2272 tokens;   5 ents
# 		letter 062
# 			xml:  5952 chars;   656 tokens;   5 ents
# 		letter 063
# 			xml: 11959 chars;  1583 tokens;  16 ents
# 		letter 064
# 			xml:  3988 chars;   305 tokens;   5 ents
# 		letter 065
# 			xml:  7974 chars;  1020 tokens;  11 ents
# 		letter 066
# 			xml: 17814 chars;  2455 tokens;  19 ents
# 		letter 067
# 			xml: 18196 chars;  2504 tokens;  11 ents
# 		letter 068
# 			xml: 11057 chars;  1465 tokens;  12 ents
# 		letter 069
# 			xml:  5582 chars;   594 tokens;   6 ents
# 		letter 070
# 			xml: 13164 chars;  1754 tokens;  13 ents
# 		letter 071
# 			xml: 13908 chars;  1862 tokens;  10 ents
# 		letter 072
# 			xml: 29961 chars;  4343 tokens;  14 ents
# 		letter 073
# 			xml: 12292 chars;  1571 tokens;   6 ents
# 		letter 074
# 			xml: 13137 chars;  1837 tokens;  19 ents
# 		letter 075
# 			xml: 18023 chars;  2460 tokens;  26 ents
# 		letter 076
# 			xml: 12398 chars;  1742 tokens;   7 ents
# 		letter 077
# 			xml: 13893 chars;  1886 tokens;  22 ents
# 		letter 078
# 			xml: 19063 chars;  2515 tokens;  12 ents
# 		letter 079
# 			xml: 15865 chars;  2230 tokens;  20 ents
# 		letter 080
# 			xml: 16399 chars;  2408 tokens;   9 ents
# 		letter 081
# 			xml: 18288 chars;  2653 tokens;  27 ents
# 		letter 082
# 			xml: 21994 chars;  3239 tokens;  28 ents
# 		letter 083
# 			xml: 14257 chars;  2045 tokens;  19 ents
# 		letter 084
# 			xml: 14342 chars;  2001 tokens;  15 ents
# 		letter 085
# 			xml: 17137 chars;  2364 tokens;  18 ents
# 		letter 086
# 			xml: 16100 chars;  2288 tokens;  11 ents
# 		letter 087
# 			xml: 16302 chars;  2216 tokens;  13 ents
# 		letter 088
# 			xml: 14554 chars;  2060 tokens;   6 ents
# 		letter 089
# 			xml: 15354 chars;  2172 tokens;  23 ents
# 		letter 090
# 			xml: 15089 chars;  2117 tokens;  13 ents
# 		letter 091
# 			xml: 14784 chars;  1966 tokens;  20 ents
# 		letter 092
# 			xml:  8381 chars;  1040 tokens;   6 ents
# 		letter 093
# 			xml: 13519 chars;  1826 tokens;   8 ents
# 		letter 094
# 			xml: 15419 chars;  2023 tokens;   5 ents
# 	filza 09, all good
# 	filza 09b
# 		letter 001
# 			xml: 32798 chars;  4301 tokens;  79 ents
# 		letter 002
# 			xml:  4271 chars;   367 tokens;   1 ents
# 		letter 003
# 			xml: 10929 chars;  1492 tokens;  11 ents
# 		letter 004
# 			xml:  7249 chars;   880 tokens;  10 ents
# 		letter 005
# 			xml:  6784 chars;   749 tokens;   5 ents
# 		letter 006
# 			xml: 17067 chars;  2492 tokens;   7 ents
# 		letter 007
# 			xml:  6144 chars;   702 tokens;   6 ents
# 		letter 008
# 			xml:  5846 chars;   633 tokens;   2 ents
# 		letter 009
# 			xml:  6779 chars;   785 tokens;   4 ents
# 		letter 010
# 			xml:  7926 chars;  1015 tokens;  12 ents
# 		letter 011
# 			xml:  4689 chars;   407 tokens;   6 ents
# 		letter 012
# 			xml: 16813 chars;  2465 tokens;   2 ents
# 		letter 013
# 			xml: 13237 chars;  1850 tokens;   5 ents
# 		letter 014
# 			xml:  5369 chars;   533 tokens;   1 ents
# 		letter 015
# 			xml: 12254 chars;  1726 tokens;   9 ents
# 		letter 016
# 			xml: 11536 chars;  1454 tokens;   5 ents
# 		letter 017
# 			xml: 13907 chars;  1900 tokens;  14 ents
# 		letter 018
# 			xml: 19408 chars;  2850 tokens;   8 ents
# 		letter 019
# 			xml: 10115 chars;  1322 tokens;   2 ents
# 		letter 020
# 			xml:  6847 chars;   784 tokens;   5 ents
# 		letter 021
# 			xml: 15120 chars;  2119 tokens;   7 ents
# 		letter 022
# 			xml: 13883 chars;  1965 tokens;  12 ents
# 		letter 023
# 			xml: 14594 chars;  2105 tokens;   7 ents
# 		letter 024
# 			xml:  5007 chars;   467 tokens;   1 ents
# 		letter 025
# 			xml:  7690 chars;   911 tokens;   4 ents
# 	filza 09b, all good
# 	filza 10
# 		letter 001
# 			xml: 13579 chars;  1844 tokens;   7 ents
# 		letter 002
# 			xml:  7568 chars;   928 tokens;   7 ents
# 		letter 003
# 			xml: 13930 chars;  2038 tokens;  14 ents
# 		letter 004
# 			xml:  8000 chars;   924 tokens;   9 ents
# 		letter 005
# 			xml: 18278 chars;  2563 tokens;   5 ents
# 		letter 006
# 			xml: 11267 chars;  1522 tokens;  15 ents
# 		letter 007
# 			xml: 19370 chars;  2823 tokens;  22 ents
# 		letter 008
# 			xml: 11578 chars;  1522 tokens;   8 ents
# 		letter 009
# 			xml: 23532 chars;  3356 tokens;  23 ents
# 		letter 010
# 			xml: 15279 chars;  2156 tokens;  24 ents
# 		letter 011
# 			xml: 12218 chars;  1652 tokens;  19 ents
# 		letter 012
# 			xml:  8324 chars;  1062 tokens;  10 ents
# 		letter 013
# 			xml: 12537 chars;  1633 tokens;   7 ents
# 		letter 014
# 			xml: 13152 chars;  1704 tokens;  21 ents
# 		letter 015
# 			xml: 27503 chars;  2531 tokens;   4 ents
# 		letter 016
# 			xml: 12140 chars;  1590 tokens;   7 ents
# 		letter 017
# 			xml: 14917 chars;  2209 tokens;  20 ents
# 		letter 018
# 			xml: 16445 chars;  2277 tokens;  16 ents
# 		letter 019
# 			xml: 18620 chars;  2600 tokens;  29 ents
# 		letter 020
# 			xml: 11332 chars;  1319 tokens;   3 ents
# 		letter 021
# 			xml: 19321 chars;  2696 tokens;  30 ents
# 		letter 022
# 			xml: 11036 chars;  1300 tokens;   6 ents
# 		letter 023
# 			xml: 19913 chars;  2847 tokens;  17 ents
# 		letter 024
# 			xml: 13496 chars;  1923 tokens;  19 ents
# 		letter 025
# 			xml: 16119 chars;  2196 tokens;  11 ents
# 		letter 026
# 			xml: 12551 chars;  1426 tokens;   7 ents
# 		letter 027
# 			xml: 14920 chars;  2194 tokens;  29 ents
# 		letter 028
# 			xml: 15099 chars;  1968 tokens;   9 ents
# 		letter 029
# 			xml: 13273 chars;  1817 tokens;  16 ents
# 		letter 030
# 			xml: 17371 chars;  2500 tokens;  22 ents
# 		letter 031
# 			xml: 18378 chars;  2644 tokens;  25 ents
# 		letter 032
# 			xml: 19952 chars;  2915 tokens;  17 ents
# 		letter 033
# 			xml: 22389 chars;  3264 tokens;  32 ents
# 		letter 034
# 			xml: 16243 chars;  2210 tokens;   8 ents
# 		letter 035
# 			xml:  4610 chars;   393 tokens;   0 ents
# 		letter 036
# 			xml: 15056 chars;  1704 tokens;   3 ents
# 		letter 037
# 			xml: 20792 chars;  2990 tokens;  28 ents
# 		letter 038
# 			xml: 11960 chars;  1586 tokens;  18 ents
# 		letter 039
# 			xml:  6282 chars;   631 tokens;   6 ents
# 		letter 040
# 			xml: 17449 chars;  2607 tokens;  21 ents
# 		letter 041
# 			xml: 27170 chars;  4085 tokens;  25 ents
# 		letter 042
# 			xml: 21362 chars;  3113 tokens;  36 ents
# 		letter 043
# 			xml: 10497 chars;  1412 tokens;   2 ents
# 		letter 044
# 			xml: 21852 chars;  3132 tokens;  30 ents
# 		letter 045
# 			xml:  8514 chars;  1010 tokens;   1 ents
# 		letter 046
# 			xml: 16741 chars;  2450 tokens;  17 ents
# 		letter 047
# 			xml: 53748 chars;  8299 tokens;  15 ents
# 		letter 048
# 			xml: 13982 chars;  1929 tokens;  16 ents
# 		letter 049
# 			xml: 26542 chars;  3724 tokens;  36 ents
# 		letter 050
# 			xml: 19460 chars;  2972 tokens;  36 ents
# 		letter 051
# 			xml: 18223 chars;  2610 tokens;  31 ents
# 		letter 052
# 			xml:  9761 chars;  1352 tokens;   7 ents
# 		letter 053
# 			xml: 33675 chars;  4913 tokens;  35 ents
# 		letter 054
# 			xml: 26426 chars;  3763 tokens;  19 ents
# 		letter 055
# 			xml: 20186 chars;  2977 tokens;  25 ents
# 		letter 056
# 			xml: 15621 chars;  2206 tokens;   8 ents
# 		letter 057
# 			xml: 11725 chars;  1625 tokens;  16 ents
# 		letter 058
# 			xml: 33671 chars;  5053 tokens;  24 ents
# 		letter 059
# 			xml: 11894 chars;  1615 tokens;   7 ents
# 		letter 060
# 			xml: 32478 chars;  4646 tokens;  15 ents
# 		letter 061
# 			xml: 12001 chars;  1665 tokens;   9 ents
# 		letter 062
# 			xml: 15795 chars;  2214 tokens;  28 ents
# 		letter 063
# 			xml: 11752 chars;  1657 tokens;  21 ents
# 		letter 064
# 			xml: 13263 chars;  1760 tokens;   9 ents
# 		letter 065
# 			xml: 17664 chars;  2518 tokens;   8 ents
# 		letter 066
# 			xml: 11281 chars;  1501 tokens;  22 ents
# 		letter 067
# 			xml: 14159 chars;  1990 tokens;   6 ents
# 		letter 068
# 			xml: 11291 chars;  1420 tokens;  17 ents
# 		letter 069
# 			xml:  5906 chars;   642 tokens;   1 ents
# 		letter 070
# 			xml:  8603 chars;  1038 tokens;   4 ents
# 		letter 071
# 			xml: 19999 chars;  2863 tokens;  26 ents
# 		letter 072
# 			xml: 14278 chars;  1996 tokens;   6 ents
# 		letter 073
# 			xml: 14505 chars;  2008 tokens;  24 ents
# 		letter 074
# 			xml: 14394 chars;  1969 tokens;  29 ents
# 		letter 075
# 			xml: 17839 chars;  2605 tokens;  15 ents
# 		letter 076
# 			xml: 23252 chars;  3362 tokens;  15 ents
# 		letter 077
# 			xml: 14152 chars;  1680 tokens;  14 ents
# 		letter 078
# 			xml: 21823 chars;  3165 tokens;  19 ents
# 		letter 079
# 			xml: 27223 chars;  3883 tokens;  40 ents
# 		letter 080
# 			xml: 11270 chars;  1446 tokens;   0 ents
# 		letter 081
# 			xml: 43503 chars;  6425 tokens;  25 ents
# 		letter 082
# 			xml: 16227 chars;  2301 tokens;  16 ents
# 		letter 083
# 			xml: 18169 chars;  2540 tokens;  22 ents
# 		letter 084
# 			xml: 16178 chars;  2289 tokens;  19 ents
# 		letter 085
# 			xml: 15317 chars;  2029 tokens;  25 ents
# 		letter 086
# 			xml: 14505 chars;  1777 tokens;  13 ents
# 		letter 087
# 			xml:  6516 chars;   746 tokens;   4 ents
# 		letter 088
# 			xml: 13735 chars;  1652 tokens;   4 ents
# 		letter 089
# 			xml: 15461 chars;  1982 tokens;  18 ents
# 		letter 090
# 			xml: 11186 chars;  1287 tokens;   2 ents
# 		letter 091
# 			xml: 47254 chars;  7532 tokens;  72 ents
# 		letter 092
# 			xml: 13543 chars;  1704 tokens;  14 ents
# 		letter 093
# 			xml: 17671 chars;  2202 tokens;  19 ents
# 		letter 094
# 			xml:  6700 chars;   756 tokens;   5 ents
# 		letter 095
# 			xml: 13629 chars;  1512 tokens;  11 ents
# 		letter 096
# 			xml: 16386 chars;  2067 tokens;  23 ents
# 		letter 097
# 			xml: 12494 chars;  1649 tokens;  22 ents
# 		letter 098
# 			xml: 17801 chars;  2318 tokens;  12 ents
# 		letter 099
# 			xml: 20868 chars;  2517 tokens;  17 ents
# 		letter 100
# 			xml: 16722 chars;  2452 tokens;  11 ents
# 	filza 10, all good
# 	filza 11
# 		letter 001
# 			xml: 41431 chars;  6033 tokens;  40 ents
# 		letter 002
# 			xml:  9957 chars;  1263 tokens;   8 ents
# 		letter 003
# 			xml: 20309 chars;  2935 tokens;  27 ents
# 		letter 004
# 			xml: 32733 chars;  4832 tokens;  12 ents
# 		letter 005
# 			xml:  9066 chars;  1128 tokens;   7 ents
# 		letter 006
# 			xml: 12788 chars;  1828 tokens;  21 ents
# 		letter 007
# 			xml:  7964 chars;   963 tokens;   2 ents
# 		letter 008
# 			xml: 19247 chars;  2497 tokens;  19 ents
# 		letter 009
# 			xml:  9868 chars;  1255 tokens;  10 ents
# 		letter 010
# 			xml: 18833 chars;  2572 tokens;  33 ents
# 		letter 011
# 			xml: 20526 chars;  3046 tokens;  36 ents
# 		letter 012
# 			xml: 26338 chars;  3882 tokens;  25 ents
# 		letter 013
# 			xml: 23287 chars;  3554 tokens;  35 ents
# 		letter 014
# 			xml: 16997 chars;  2218 tokens;  34 ents
# 		letter 015
# 			xml: 13992 chars;  1752 tokens;  15 ents
# 		letter 016
# 			xml: 30673 chars;  4406 tokens;  41 ents
# 		letter 017
# 			xml: 13274 chars;  1876 tokens;  37 ents
# 		letter 018
# 			xml: 11040 chars;  1525 tokens;  11 ents
# 		letter 019
# 			xml: 16834 chars;  2468 tokens;  25 ents
# 		letter 020
# 			xml: 21283 chars;  3179 tokens;  35 ents
# 		letter 021
# 			xml:  9300 chars;  1188 tokens;   0 ents
# 		letter 022
# 			xml: 18623 chars;  2635 tokens;  21 ents
# 		letter 023
# 			xml:  9653 chars;  1226 tokens;   6 ents
# 		letter 024
# 			xml: 11460 chars;  1551 tokens;  13 ents
# 		letter 025
# 			xml: 32153 chars;  4654 tokens;  21 ents
# 		letter 026
# 			xml: 16644 chars;  2413 tokens;  37 ents
# 		letter 027
# 			xml:  7712 chars;   939 tokens;   3 ents
# 		letter 028
# 			xml: 15239 chars;  2010 tokens;  27 ents
# 		letter 029
# 			xml: 11679 chars;  1521 tokens;  10 ents
# 		letter 030
# 			xml: 13645 chars;  1895 tokens;   7 ents
# 		letter 031
# 			xml: 16527 chars;  2410 tokens;  32 ents
# 		letter 032
# 			xml: 12797 chars;  1758 tokens;  12 ents
# 		letter 033
# 			xml: 15209 chars;  2208 tokens;  33 ents
# 		letter 034
# 			xml: 18806 chars;  2752 tokens;  30 ents
# 		letter 035
# 			xml: 19884 chars;  2980 tokens;  23 ents
# 		letter 036
# 			xml: 23206 chars;  3268 tokens;  39 ents
# 		letter 037
# 			xml:  7908 chars;   963 tokens;   5 ents
# 		letter 038
# 			xml: 18133 chars;  2511 tokens;  17 ents
# 		letter 039
# 			xml: 25801 chars;  3562 tokens;  34 ents
# 		letter 040
# 			xml: 22021 chars;  3347 tokens;  34 ents
# 		letter 041
# 			xml: 10806 chars;  1467 tokens;  17 ents
# 		letter 042
# 			xml: 17673 chars;  2539 tokens;  20 ents
# 		letter 043
# 			xml: 13660 chars;  1888 tokens;  14 ents
# 		letter 044
# 			xml: 15739 chars;  2307 tokens;  30 ents
# 		letter 045
# 			xml:  8977 chars;  1169 tokens;   2 ents
# 		letter 046
# 			xml: 23587 chars;  3574 tokens;  37 ents
# 		letter 047
# 			xml: 10500 chars;  1425 tokens;  10 ents
# 		letter 048
# 			xml: 10091 chars;  1083 tokens;  18 ents
# 		letter 049
# 			xml: 18301 chars;  2715 tokens;  36 ents
# 		letter 050
# 			xml: 14208 chars;  2104 tokens;  26 ents
# 		letter 051
# 			xml: 24807 chars;  3589 tokens;  42 ents
# 		letter 052
# 			xml: 16442 chars;  2375 tokens;  22 ents
# 		letter 053
# 			xml: 21735 chars;  3173 tokens;  27 ents
# 		letter 054
# 			xml:  8308 chars;  1029 tokens;   6 ents
# 		letter 055
# 			xml: 14327 chars;  2075 tokens;  21 ents
# 		letter 056
# 			xml: 14417 chars;  1954 tokens;  15 ents
# 		letter 057
# 			xml: 12596 chars;  1860 tokens;  20 ents
# 		letter 058
# 			xml: 18499 chars;  2632 tokens;  28 ents
# 		letter 059
# 			xml:  9893 chars;  1156 tokens;  11 ents
# 		letter 060
# 			xml: 12842 chars;  1817 tokens;  32 ents
# 		letter 061
# 			xml: 19064 chars;  2741 tokens;  37 ents
# 		letter 062
# 			xml: 12765 chars;  1840 tokens;  21 ents
# 		letter 063
# 			xml: 12923 chars;  1791 tokens;  16 ents
# 		letter 064
# 			xml:  8680 chars;  1117 tokens;   5 ents
# 		letter 065
# 			xml: 17136 chars;  2520 tokens;  23 ents
# 		letter 066
# 			xml: 14472 chars;  2130 tokens;  25 ents
# 		letter 067
# 			xml: 17300 chars;  2517 tokens;  15 ents
# 		letter 068
# 			xml: 13057 chars;  1802 tokens;  16 ents
# 		letter 069
# 			xml: 14981 chars;  2084 tokens;  37 ents
# 		letter 070
# 			xml: 14411 chars;  2121 tokens;  21 ents
# 		letter 071
# 			xml:  9985 chars;  1235 tokens;   8 ents
# 		letter 072
# 			xml: 18748 chars;  2793 tokens;  38 ents
# 		letter 073
# 			xml: 18980 chars;  2756 tokens;  42 ents
# 		letter 074
# 			xml:  8489 chars;  1055 tokens;  13 ents
# 		letter 075
# 			xml: 11676 chars;  1623 tokens;   6 ents
# 		letter 076
# 			xml: 18557 chars;  2718 tokens;  28 ents
# 		letter 077
# 			xml: 16534 chars;  2447 tokens;  30 ents
# 		letter 078
# 			xml: 16236 chars;  2291 tokens;  28 ents
# 		letter 079
# 			xml: 14681 chars;  1841 tokens;  18 ents
# 		letter 080
# 			xml: 16769 chars;  2381 tokens;  37 ents
# 		letter 081
# 			xml: 12021 chars;  1304 tokens;  13 ents
# 		letter 082
# 			xml: 18629 chars;  2550 tokens;  15 ents
# 		letter 083
# 			xml:  8769 chars;   985 tokens;   9 ents
# 		letter 084
# 			xml: 16095 chars;  2333 tokens;  11 ents
# 		letter 085
# 			xml: 12308 chars;  1508 tokens;  10 ents
# 		letter 086
# 			xml: 13036 chars;  1762 tokens;  10 ents
# 		letter 087
# 			xml: 21513 chars;  3076 tokens;  39 ents
# 		letter 088
# 			xml: 11188 chars;  1540 tokens;  20 ents
# 		letter 089
# 			xml: 11918 chars;  1563 tokens;  11 ents
# 		letter 090
# 			xml: 10450 chars;  1310 tokens;   7 ents
# 		letter 091
# 			xml: 22750 chars;  3010 tokens;  33 ents
# 		letter 092
# 			xml: 37126 chars;  4413 tokens;  29 ents
# 		letter 093
# 			xml: 17407 chars;  2409 tokens;  28 ents
# 		letter 094
# 			xml:  4361 chars;   349 tokens;   0 ents
# 		letter 095
# 			xml: 19000 chars;  2720 tokens;  13 ents
# 		letter 096
# 			xml: 19553 chars;  2467 tokens;  26 ents
# 		letter 097
# 			xml: 10268 chars;  1148 tokens;   3 ents
# 		letter 098
# 			xml: 18384 chars;  2476 tokens;  24 ents
# 		letter 099
# 			xml: 16258 chars;  2124 tokens;  16 ents
# 		letter 100
# 			xml: 14860 chars;  2014 tokens;  25 ents
# 		letter 101
# 			xml:  8967 chars;   837 tokens;  12 ents
# 	filza 11, all good
# 	filza 12
# 		letter 001
# 			xml: 17847 chars;  2138 tokens;  32 ents
# 		letter 002
# 			xml:  9910 chars;  1311 tokens;  11 ents
# 		letter 003
# 			xml: 19430 chars;  2382 tokens;  49 ents
# 		letter 004
# 			xml: 13688 chars;  1780 tokens;  14 ents
# 		letter 005
# 			xml: 17710 chars;  2226 tokens;  30 ents
# 		letter 006
# 			xml: 19298 chars;  2549 tokens;  30 ents
# 		letter 007
# 			xml: 11148 chars;  1533 tokens;  16 ents
# 		letter 008
# 			xml: 19988 chars;  2445 tokens;  16 ents
# 		letter 009
# 			xml: 19310 chars;  2501 tokens;  35 ents
# 		letter 010
# 			xml: 80475 chars; 10782 tokens; 135 ents
# 		letter 011
# 			xml: 12530 chars;  1567 tokens;  10 ents
# 		letter 012
# 			xml: 27606 chars;  3259 tokens;  53 ents
# 		letter 013
# 			xml: 20672 chars;  2816 tokens;  28 ents
# 		letter 014
# 			xml:  8250 chars;   835 tokens;   2 ents
# 		letter 015
# 			xml: 29026 chars;  3624 tokens;  52 ents
# 		letter 016
# 			xml: 22330 chars;  3097 tokens;  46 ents
# 		letter 017
# 			xml: 12982 chars;  1372 tokens;  21 ents
# 		letter 018
# 			xml:  7538 chars;   729 tokens;   6 ents
# 		letter 019
# 			xml: 27732 chars;  3658 tokens;  61 ents
# 		letter 020
# 			xml: 16360 chars;  2069 tokens;  18 ents
# 		letter 021
# 			xml: 10597 chars;  1191 tokens;  11 ents
# 		letter 022
# 			xml: 19837 chars;  2447 tokens;  43 ents
# 		letter 023
# 			xml: 25857 chars;  3367 tokens;  29 ents
# 		letter 024
# 			xml: 23681 chars;  2959 tokens;  56 ents
# 		letter 025
# 			xml: 21349 chars;  2854 tokens;  31 ents
# 		letter 026
# 			xml: 47090 chars;  5941 tokens;  61 ents
# 		letter 027
# 			xml: 15593 chars;  1907 tokens;  26 ents
# 		letter 028
# 			xml: 28775 chars;  3739 tokens;  71 ents
# 		letter 029
# 			xml: 42257 chars;  5769 tokens;  43 ents
# 		letter 030
# 			xml: 30107 chars;  3741 tokens;  73 ents
# 		letter 031
# 			xml: 13166 chars;  1687 tokens;  21 ents
# 		letter 032
# 			xml: 25791 chars;  3195 tokens;  51 ents
# 		letter 033
# 			xml: 22009 chars;  2844 tokens;  32 ents
# 		letter 034
# 			xml: 10209 chars;  1201 tokens;  10 ents
# 		letter 035
# 			xml: 25605 chars;  3233 tokens;  81 ents
# 		letter 036
# 			xml: 38536 chars;  5467 tokens;  83 ents
# 		letter 037
# 			xml: 15139 chars;  1984 tokens;  34 ents
# 		letter 038
# 			xml: 25419 chars;  3325 tokens;  56 ents
# 		letter 039
# 			xml: 23605 chars;  2960 tokens;  45 ents
# 		letter 040
# 			xml: 11915 chars;  1441 tokens;  18 ents
# 		letter 041
# 			xml: 18745 chars;  2394 tokens;  52 ents
# 		letter 042
# 			xml: 28063 chars;  3770 tokens;  47 ents
# 		letter 043
# 			xml: 18665 chars;  2308 tokens;  56 ents
# 		letter 044
# 			xml: 11524 chars;  1439 tokens;  12 ents
# 		letter 045
# 			xml:  5807 chars;   620 tokens;   3 ents
# 		letter 046
# 			xml: 58835 chars;  7869 tokens; 104 ents
# 	filza 12, all good
# Done, all good

# %% [markdown]
# ## Step 5: Convert TF to WATM
#
# N.B. For docs click the WATM link in the output cell.

# %%
# WA = WATM(A, "tei", skipMeta=False, prod="dev")
WA = WATM(A, "tei", skipMeta=False, prod="prod")
# Out:
# conversion settings read from ~/github/HuygensING/suriano/config/watm.yml
# IIIF settings read from ~/github/HuygensING/suriano/config/iiif.yml
# Manifestlevel = folder
# textRepoLevel is section level 'folder'
# No instructions to exclude toplevel section nodes
# Excluded nodes: 0 from 2161639 nodes
# [WATM exporter documentation](https://annotation.github.io/text-fabric-factory/tff/convert/watm.html)
# Found covers in directory: ~/github/HuygensING/suriano/scans/covers
# Maximum dimensions: W = 8504 H = 5976
# Average dimensions: W = 4138 H = 4869
# Average deviation:  W = 1038 H =  660
# Maximum dimensions: W = 5600 H = 5786
# Average dimensions: W = 3262 H = 4375
# Average deviation:  W =  479 H =  617

# %%
WA.makeText()
WA.makeAnno()
WA.writeAll()
WA.testAll()
# Out:
# 	Writing WATM ...
# Writing production data to ~/github/HuygensING/suriano/watm/2.0.0e/prod
# Text file    0:    44362 segments to ~/github/HuygensING/suriano/watm/2.0.0e/prod/text-0.tsv
# Text file    1:   117956 segments to ~/github/HuygensING/suriano/watm/2.0.0e/prod/text-1.tsv
# Text file    2:   147760 segments to ~/github/HuygensING/suriano/watm/2.0.0e/prod/text-2.tsv
# Text file    3:   109482 segments to ~/github/HuygensING/suriano/watm/2.0.0e/prod/text-3.tsv
# Text file    4:   154972 segments to ~/github/HuygensING/suriano/watm/2.0.0e/prod/text-4.tsv
# Text file   11:   132325 segments to ~/github/HuygensING/suriano/watm/2.0.0e/prod/text-11.tsv
# Text files all:  1775518 segments to 12 files
# Anno file    1:   400000 annotations written to ~/github/HuygensING/suriano/watm/2.0.0e/prod/anno-1.tsv
# Anno file    2:   400000 annotations written to ~/github/HuygensING/suriano/watm/2.0.0e/prod/anno-2.tsv
# Anno file    3:   262577 annotations written to ~/github/HuygensING/suriano/watm/2.0.0e/prod/anno-3.tsv
# Inherited annotations: 0
# Anno files all:  1062577 annotations to 3 files
# Slot mapping written to ~/github/HuygensING/suriano/watm/2.0.0e/prod/pos2node.tsv
# Node mapping written to ~/github/HuygensING/suriano/watm/2.0.0e/prod/anno2node.tsv
# Logical pairs (6952) written to ~/github/HuygensING/suriano/watm/2.0.0e/prod/logicalpairs.tsv
# Extra file datasource/entities/entitymeta.json copied to the WATM directory
# 	Testing WATM ...
# Excluded nodes: 0 from 2161639 nodes
# Testing the text ...
# 	TF: 1775518
# 	WA: 1775518
# OK - whether the amounts of tokens agree
# 	TF: Letter 02.001 date 1 ... "corrected on "23."
# 	WA: Letter 02.001 date 1 ... "corrected on "23."
# OK - whether the text is the same
# Testing the elements ...
# 	TF: 328457
# 	WA: 328457
# OK - whether the amounts of elements and nodes agree
# Testing the processing instructions ...
# 	TF:      0
# 	WA:      0
# OK - whether the amounts of processing instructions agree
# Testing the element/pi annotations ...
# 	328457 element/pi annotations
# 	Element      : 328457 x
# 	Pi           :      0 x
# 	Good name    : 328457 x
# 	Wrong name   :      0 x
# 	Good target  : 328457 x
# 	Wrong target :      0 x
# 	Unmapped     :      0 x
# OK - whether all element/pi annotations have good bodies
# OK - whether all element/pi annotations have good targets
# Testing the attributes ...
# 	333910 attribute values
# 	Good:     333910 x
# 	Wrong:        0 x
# OK - whether annotations are consistent with features
# 	WA attributes: 333910
# 	TF attributes: 333910
# OK - whether annotations are complete w.r.t. features
# Testing the format attributes ...
# 	120978 format values
# 	formatting attributes:
# 		107671 x decoded
# 		 12000 x footnote
# 		  1120 x superscript
# 		   187 x displaced
# 	Good:     120978 x
# 	Wrong:        0 x
# OK - whether format annotations are consistent with features
# 	WA format attributes: 120978
# 	TF format attributes: 120978
# OK - whether format annotations are complete w.r.t. features
# Testing the extra annotations ...
# 	0 extra feature values
# 	0 extra annotations
# OK - whether the extra annotations agree
# Testing the edges ...
# 	Found: 1 edges in annotations
# 		edge link_target with 11991 starting nodes
# 	Found: 1 edges in annotations
# 		edge link_target with 11991 starting nodes
# 	Checking edge link_target
# 		same 11991 fromNodes
# 		OK - 11991 toNodes checked
# OK - whether all edges agree
# Overall outcome ...
# OK - whether all tests passed

# %% [markdown]
# ## Step 6: Generate IIIF manifests

# %%
II = IIIF(Tei.teiVersion, A, REPORT_PAGESDIR, prod="prod", silent=False)
# II = IIIF(Tei.teiVersion, A, REPORT_PAGESDIR, prod="dev", silent=False)
II.manifests()
# Out:
# Found covers in directory: ~/github/HuygensING/suriano/scans/covers
# Scan images taken from ~/github/HuygensING/suriano/scans
# IIIF settings read from ~/github/HuygensING/suriano/config/iiif.yml
# Manifestlevel = folder
# All generated urls are for a prod deployment on https:/data.suriano.huygens.knaw.nl
# Maximum dimensions: W = 8504 H = 5976
# Average dimensions: W = 4138 H = 4869
# Average deviation:  W = 1038 H =  660
# Maximum dimensions: W = 5600 H = 5786
# Average dimensions: W = 3262 H = 4375
# Average deviation:  W =  479 H =  617
# Using page info file ~/github/HuygensING/suriano/report/pages/pageseq.json
# Collections:
#         02 with  262 pages
#         03 with  660 pages
#         04 with  806 pages
#         05 with  688 pages
#         06 with  684 pages
#         07 with  628 pages
#         08 with  988 pages
#         09 with  944 pages
#        09b with  188 pages
#         10 with 1062 pages
#         11 with 1116 pages
#         12 with  928 pages
# Missing image files:
# 	pages:
# 		None:
# 			  1 x 09b_025bisr
# 			  1 x 09b_025bisv
# 			  1 x 09b_059bisr
# 			  1 x 09b_059bisv
# 			  1 x 09b_078bisr
# 			  1 x 09b_078bisv
# 	total occurrences of a missing file: 6
# 12 IIIF manifests with 8949 items for 8954 pages generated in ~/github/HuygensING/suriano/static/prod/manifests

# %% [markdown]
# ## Step 7: Deploy to k8s and TeamText VM

# %% [markdown]
# NB: you need to have access to the k8s cluster and to the team text VM.
#
# That means:
#
# * The LDAP of the relevant k8s clusters know you
# * You have an ssh key-based login on the Team Text VPN
# * You work inside the firewall

# %%
# !./provision.sh watm
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# WATM export version: 1.0.1e-029
# anno-1.tsv                                    100%   17MB   5.9MB/s   00:02
# anno-3.tsv                                    100%   10MB   6.4MB/s   00:01
# anno-2.tsv                                    100%   15MB   6.6MB/s   00:02
# anno2node.tsv                                 100% 5658KB   5.9MB/s   00:00
# text-6.tsv                                    100% 1228KB   4.3MB/s   00:00
# text-7.tsv                                    100% 1196KB   4.1MB/s   00:00
# text-5.tsv                                    100% 1018KB   6.0MB/s   00:00
# text-4.tsv                                    100%  914KB   5.8MB/s   00:00
# text-0.tsv                                    100%  267KB   4.3MB/s   00:00
# text-1.tsv                                    100%  705KB   6.2MB/s   00:00
# text-3.tsv                                    100%  655KB   6.0MB/s   00:00
# text-2.tsv                                    100%  879KB   6.3MB/s   00:00
# text-9.tsv                                    100% 1337KB   6.0MB/s   00:00
# text-8.tsv                                    100% 1389KB   5.3MB/s   00:00
# entitymeta.json                               100%  339KB   5.3MB/s   00:00
# pos2node.tsv                                  100%   26MB   6.2MB/s   00:04
# text-10.tsv                                   100%  776KB   5.2MB/s   00:00
# logicalpairs.tsv                              100%  177KB   4.7MB/s   00:00

# %%
# !./provision.sh files
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# copying to pod: prod/covers.html
# copying to pod: prod/logo
# copying to pod: prod/manifests
# copying to pod: both/metadata

# %%
# !./provision.sh prod images

# %% [markdown]
# ## Step 8: Test the images

# %% [markdown]
# * [covers](https://data.suriano.huygens.knaw.nl/files/covers.html)
#
# * [02.json](https://data.suriano.huygens.knaw.nl/files/manifests/02.json)
#
# * [page 02_171r](https://data.suriano.huygens.knaw.nl/iiif/3/pages%2F02_071r.jpg/full/max/0/default.jpg)
